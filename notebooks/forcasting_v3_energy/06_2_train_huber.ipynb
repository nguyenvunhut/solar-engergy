# %% [markdown]
# # Bước 06_1: Train Huber loss khử trễ pha
# Dự án: Tốt nghiệp - Energy Forecasting - Nhóm thực hiện: The Outliers
#
# ## 1. TỔNG QUAN VÀ MỤC TIÊU
#
# ### Vấn đề
# Mô hình cũ bị **trễ pha 30 phút**: dự báo tại `T` khớp nhất với sản lượng thật tại `T-30 phút`.
# Đo trên toàn bộ 42 trạm của tập test, **cả 42 trạm** đều khớp nhất tại `k=2` (tức 2 bước = 30 phút).
#
# Nguyên nhân đã truy được:
#
# 1. `lag_1` của hàng đặc trưng chính là `y(T-30 phút)`, và nó tương quan 99% với mục tiêu.
#    Mô hình tối thiểu hoá sai số trung bình nên **chép** cột đó thay vì học quan hệ vật lý.
# 2. Dữ liệu thời tiết là **theo giờ, bị lặp 4 lần** trên lưới 15 phút. Trong một giờ nó không phân biệt
#    được `12:00` với `12:15`, nên `lag_1` là nguồn tín hiệu 15 phút duy nhất mà mô hình có.
#    Bỏ riêng `lag_1` mà không bù gì thì WAPE tụt thảm vì mất luôn nguồn thông tin đó.
#
# ### Cách khử, năm việc làm cùng lúc
# | việc | mục đích |
# |---|---|
# | Downscale bức xạ về 15 phút bằng bức xạ trời quang | tạo tín hiệu 15 phút thay cho `lag_1` |
# | Góc cao và góc phương vị mặt trời | cho mô hình biết vị trí mặt trời tại trạm, phân giải 15 phút |
# | Quy mô trạm thực nghiệm | `capacity_kw` sai ở nhiều trạm, phải tính lại từ dữ liệu train |
# | Trần công suất trạm | học được đoạn inverter cắt đỉnh, chỗ sản lượng nằm phẳng |
# | Bỏ `lag_1`, `lag_4`, `rolling_*_4`, `rolling_*_12` | cắt đường tắt mang giá trị `T-30 phút` |
#
# **Vẫn giữ `lag_96` và `rolling_*_96`** - lịch sử một ngày trước, nên đây vẫn là mô hình time series
# có ký ức, chỉ bỏ phần mang sẵn đáp án.
#
# ### Kết quả đã đạt
# | | mô hình cũ | mô hình này |
# |---|---|---|
# | số trạm khớp nhất tại `k=0` | 0/42 | **40/42** |
# | RMSE `k=0` so với `k=1` | k=2 nhỏ nhất | **k=0 nhỏ nhất** |
# | WAPE | 24,69% | 21,09% |
#
# ### Điều quan trọng về tính nhân quả
# Toàn bộ đặc trưng mới **chỉ dùng thông tin quá khứ và công thức thiên văn**. Không nội suy giữa các giờ,
# không dùng giá trị của giờ sau. Phần biến thiên trong giờ do bức xạ trời quang tạo ra, mà bức xạ trời quang
# là hàm xác định của thời điểm và toạ độ.

# %% [markdown]
# ## 2. Import thư viện và khai báo tham số

# %%
# ── Gioi han thread: may i5-12450HX co 8 core / 12 thread (4 P-core + 4 E-core).
# Dung het 12 thread lam cac thread tranh nhau va CHAM HON. Dat 6 de bam P-core,
# con lai de cho Jupyter va he dieu hanh. Phai set TRUOC khi numpy nap moi co tac dung.
import os

for _bien in ('OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS','MKL_NUM_THREADS',
              'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS'):
    os.environ.setdefault(_bien, '6')

import gc
import json
import os
import pickle
import platform
import time
import warnings

import lightgbm as lgb
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
from optuna.samplers import TPESampler
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")
optuna.logging.set_verbosity(optuna.logging.WARNING)

# ── Cột khoá ──
VERSION = 'v3'
SITE_COL = 'site_id'
TIMESTAMP_COL = 'timestamp'
TARGET_COL = 'energy_generated_kwh'

# ── Tham số mô hình ──
# Bien the LOSS = HUBER, doi chieu voi 06_1 (mae, dang chon lam mac dinh bao cao) va
# 06_3 (mse). Ket qua so sanh thuc te tren tap test (xem 06_1_train_mae.ipynb):
#   huber a=1  : khop dinh 15p 19,9% | bien do dinh 0,916 | WAPE 21,58%
#   MAE  (l1)  : khop dinh 15p 20,1% | bien do dinh 0,952 | WAPE 21,69%   <- notebook 06_1 chon
# MAE hut bien do dinh tot hon (8,4% -> 4,8%), do tre khong doi (~0 phut o ca hai).
# Notebook nay giu de doi chieu/ablation, KHONG dung lam ket qua bao cao chinh.
LOSS_NAME = 'huber'
LGB_OBJECTIVE = 'huber'
# HORIZON_STEPS: xem cell rieng ngay ben duoi (de doi h1/h4 khong can dong lai o day)
N_TRIALS = 20                  # ngan sach Optuna cho moi loss va horizon
SEED = 42
N_STARTUP_TRIALS = 5            # 5 random + 10 TPE dinh huong trong ngan sach 15 trial
N_CV_SPLITS = 5
MAX_ESTIMATORS_CV = 3000         # tran cao; early stopping trong tung fold quyet dinh so cay
EARLY_STOPPING_ROUNDS = 100

# ── Gioi han theo cau hinh may (i5-12450HX: 8 core / 12 thread, RAM 27 GB, RTX 3050 6 GB) ──
# CPU nay la hybrid 4 P-core + 4 E-core. Dat n_jobs = 12 lam cac thread tranh nhau va CHAM HON.
# Dung 6 thread: bam vao P-core, con lai de cho Jupyter va he dieu hanh.
N_JOBS = 6
MAX_BIN = 127                  # giam tu 255 xuong 127: bot RAM, nhanh hon, gan nhu khong mat do chinh xac
FORCE_COL_WISE = True          # tranh chi phi tu do multi-threading cua LightGBM moi lan fit
DTYPE = 'float32'              # nua bo nho so voi float64

# ── Chinh sach outlier, lay dung tu srcs/05_machine_learning/Forcasting_v3 ──
# srcs khong xoa dong outlier ma dat SAMPLE WEIGHT = 0, va xet nhom cua DONG NHAN y(T+h)
# chu khong phai dong dac trung. Xem build_sample_weight trong 08_train_baselines.py
# va config/05_machine_learning/forecasting_v3_final_cleaned.yaml: active_experiment
EXPERIMENT = 'measured_only_headline'
# cac gia tri hop le:
#   measured_only_headline   : measured + normal/gmm/other/multiple = 1, etl_imputed = 0
#   measured_plus_etl_imputed: nhu tren, them etl_imputed + normal = 1
#   zero_weight_gmm_consensus: bo gmm_if_consensus ra khoi train
#   zero_weight_all_flagged  : bo moi nhom bi gan co ra khoi train
#   tran_theo_du_lieu        : nhu measured_only_headline, NHUNG chi loai dong that su vuot
#                              tran_cong_suat tinh tu DU LIEU, thay vi tin co physical_over_capacity
#                              (co nay suy tu capacity_kw metadata dang SAI o 11/42 tram)
# THU NGHIEM 1 (DA HUY, 2026-07-31) - tung doi mac dinh sang 'tran_theo_du_lieu' vi
#   capacity_kw metadata sai o 11/42 tram (vd site 19 vuot tran metadata 4,89 lan) nen
#   physical_over_capacity dang loai oan du lieu that. NHUNG: kiem tra lai phat hien
#   tran_cong_suat (trinh suy tu du lieu) cung co the bi lech neu du lieu dau vao da
#   nhiem gia tri impute sai gan tran (vd site 19 co dong etl_imputed = 43,08 kWh lap lai,
#   gan tran metadata, khong phai do that) -> dieu kien vuot_tran_that khong loai duoc
#   cac dong nay, model van hoc theo. QUAY VE 'measured_only_headline': zero-weight
#   TOAN BO physical_over_capacity vo dieu kien (dung nhu srcs/05 goc), de dam bao khi
#   plot actual-vs-predict co the CHUNG MINH model khong hoc theo outlier.

# THU NGHIEM 2 - trong so vung dinh, chua sai biet bien do ~6-12% tren ca 42 site.
# Nhan trong so voi (1 + HE_SO_TRONG_SO_DINH * k) de ep model hoc ky vung san luong cao.
# Dat 0.0 de tat han thu nghiem nay.
HE_SO_TRONG_SO_DINH = 1.0   # thu 0.0/1.0/2.0: 1.0 can bang WAPE va bien do dinh tot nhat

# THU NGHIEM 3 - KHU LAG BANG CACH DICH DAC TRUNG TAT DINH SANG THOI DIEM MUC TIEU.
# Van de: y_true la san luong tai T+h, nhung sin_elevation/ghi_cs/hour... van la gia tri tai T.
# Model dung vi tri mat troi luc T de dung lai san luong luc T+h -> duong du bao chinh la
# duong mat troi bi TRE h buoc. Do cung la mau so chuan hoa (site_scale * sin_elevation(T)).
# Dich cac cot nay sang T+h KHONG phai leakage: vi tri mat troi va nhan thoi gian tai T+h la
# tinh toan thien van/lich thuan tuy, dung o T da biet chinh xac. Khac han thoi tiet (phai do).
# Thoi tiet, lag_96, rolling_* GIU NGUYEN tai T de dam bao causal.
THEM_DAC_TRUNG_MUC_TIEU = True
# Thu nghiem truoc (bac bo) chay tren du lieu CHUA hotfix join causal, luc do do tre
# chi 1 buoc. Sau hotfix (2026-07-30 21:49), cong 10.2 do lai ra shortwave_radiation
# tre 2 buoc (30 phut), sin_elevation tre 1 buoc - tinh huong khac han, phai thu lai
# tren nen du lieu moi, khong dung ket luan cu.
# Them ban tai T+h thanh cot MOI (hau to _mt), GIU NGUYEN ban tai T.
# Vi sao them chu khong thay the: da thu THAY THE va BAC BO bang so lieu that
# (duong bao y_hat = site_scale * sin_elevation, do bang MAE tren tap development):
#     toan bo     : tai T 3,1873  |  tai T+h 3,1884   -> gan nhu y nhau
#     sang 06-09h : tai T 1,5934  |  tai T+h 2,1833   -> TE HON 37%
#     chieu 16-18h: tai T 3,4002  |  tai T+h 2,8574   -> TOT HON 16%
# Ly do: buoi sang san luong that VON di sau mat troi (pin con lanh/am, inverter khoi dong),
# nen gia tri tai T khop hon; buoi chieu thi nguoc lai. Giu ca hai de model tu chon theo gio.
#
# Day la cach HOP PHAP duy nhat de bu lai do tre cai san: vi tri mat troi va nhan thoi gian
# tai T+h la tinh toan thien van/lich thuan tuy, dung o T da biet chinh xac -> KHONG leakage.
# Khac han thoi tiet: phai do moi biet, nen bat buoc giu o T.
COT_TAT_DINH = [
    # hinh hoc mat troi va dai luong suy ra tu no
    'solar_elevation', 'solar_azimuth', 'azimuth_sin', 'azimuth_cos', 'sin_elevation',
    'ghi_cs', 'clearsky_proxy', 'ky_vong', 'ty_le_bao_hoa',
    # nhan thoi gian theo lich
    'minute_of_day', 'hour_of_day', 'hour_bucket_model', 'hour', 'hour_sin', 'hour_cos',
    'minute', 'day', 'day_of_week', 'month', 'day_of_year', 'doy_sin', 'doy_cos',
]
# KHONG dich: shortwave_radiation, diffuse_solar_radiation, direct_normal_irradiance,
# temperature_c, diffuse_ratio, temp_x_shortwave, cloud_x_shortwave, rad_x_sinelev
# (co chua thoi tiet), lag_96, rolling_*_96 (lich su san luong).

# ── Tham số khử trễ pha ──
EPS_ELEV = 0.05                # nguong sin(goc cao) coi la ban ngay
CLIP_CSI = 1.2                 # tran chi so troi quang
TZ_HE = 11.0                   # gio mua he Uc (thang 10..3)
TZ_DONG = 10.0                 # gio mua dong Uc (thang 4..9)
BO_PREFIX_NGAN = ('lag_1', 'lag_4')          # lag ngan mang gia tri T-30 phut

# ── Đường dẫn ──
# Cac dac trung dien mat troi (goc mat troi, buc xa downscale, quy mo tram) da duoc sinh
# o notebook 03-2 va di qua 04, 05. Notebook nay chi doc va train, khong tu dung dac trung.
SELECTED_DIR = '../../data/model/v3/05_selected'
# OUTPUT_DIR: xem cell rieng ngay ben duoi (phu thuoc HORIZON_STEPS)

# ── Thiết bị train và tính tái lập ──
# USE_GPU = False la CO CHU DICH, khong phai quen bat. DETERMINISTIC la co che DUY NHAT
# cua LightGBM cho ra model giong het nhau moi lan chay, va tai lieu Parameters.rst ghi ro
# no "Used only with cpu device type" - nghia la phai TAT GPU thi no moi co tac dung.
#
# DO THUC TE 2026-08-08 (huber h1, 887.980 dong x 54 dac trung, train 3 lan lien tiep,
# cung may cung seed - xem srcs/05_machine_learning/pipeline/checks/do_tinh_tai_lap_s08.py):
#   GPU (deterministic bi bo qua) : 3 lan ra 3 model KHAC nhau, lech toi 7,485e-02  | 24 giay
#   CPU, DETERMINISTIC = False    : 2 lan ra 2 model KHAC nhau, lech 2,220e-16      | 30 giay
#   CPU, DETERMINISTIC = True     : 3 lan ra 3 model GIONG HET,  lech 0             | 31 giay
#
# Gia phai tra: 7 giay moi model. Doi lai: bao cao chay lai luc nao cung ra dung con so do.
USE_GPU = False
DETERMINISTIC = True
GPU_PLATFORM_ID = 0
GPU_DEVICE_ID = 0

print("Đã import thư viện và khai báo tham số.")
print(f"- Loss              : {LOSS_NAME}")
print(f"- Số trial Optuna   : {N_TRIALS}")
print(f"- Số thread         : {N_JOBS} trên 12 thread (CPU hybrid nên không dùng hết)")
print(f"- max_bin           : {MAX_BIN}")
# Horizon va Thu muc xuat: in o cell rieng ngay ben duoi (phu thuoc HORIZON_STEPS)
# Out:
# Đã import thư viện và khai báo tham số.
# - Loss              : huber
# - Số trial Optuna   : 20
# - Số thread         : 6 trên 12 thread (CPU hybrid nên không dùng hết)
# - max_bin           : 127

# %%
# ── CHON HORIZON: h1 hay h4 (1 cell rieng, khong dinh vao cell config chinh) ──
# De train h4 sau nay: chi doi HORIZON_STEPS o day roi Restart & Run All TU CELL NAY tro
# xuong (khong can chay lai tu dau notebook, vi du lieu 05_selected da co san cho ca 2
# horizon - y_true duoc tinh runtime trong ham them_muc_tieu() qua shift(-h)).
# h1 = du bao T+15 phut (1 buoc), h4 = du bao T+60 phut/1 gio (4 buoc).
# OUTPUT_DIR tach rieng theo horizon de KHONG ghi de len ket qua h1 khi chay h4.
HORIZON_STEPS = 1              # <-- DOI DONG NAY THANH 4 DE TRAIN H4

OUTPUT_DIR = (
    '../../data/model/v3/06_2_train_huber' if HORIZON_STEPS == 1
    else f'../../data/model/v3/06_2_train_huber_h{HORIZON_STEPS}'
)
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Horizon dang chon: h{HORIZON_STEPS} ({HORIZON_STEPS * 15} phut)")
print(f"Ghi ket qua vao: {OUTPUT_DIR}")
# Out:
# Horizon dang chon: h1 (15 phut)
# Ghi ket qua vao: ../../data/model/v3/06_2_train_huber

# %% [markdown]
# ## 3. Thiết lập GPU (OpenCL) cho LightGBM
#
# Máy Linux/NixOS tự đặt `OCL_ICD_VENDORS`. Máy Windows bỏ qua, LightGBM tự tìm GPU hoặc chạy CPU.

# %%
LA_LINUX = (os.name == 'posix' and platform.system() == 'Linux')

if LA_LINUX:
    OCL_CANDIDATES = [
        '/run/opengl-driver/etc/OpenCL/vendors',
        '/etc/OpenCL/vendors',
    ]
    if 'OCL_ICD_VENDORS' in os.environ:
        print(f"OCL_ICD_VENDORS đã được đặt sẵn: {os.environ['OCL_ICD_VENDORS']}")
    else:
        for _p in OCL_CANDIDATES:
            if os.path.isdir(_p) and any(f.endswith('.icd') for f in os.listdir(_p)):
                os.environ['OCL_ICD_VENDORS'] = _p
                print(f"Đã tự đặt OCL_ICD_VENDORS = {_p}")
                break
        else:
            print("[CẢNH BÁO] Không tìm thấy thư mục ICD OpenCL trên máy Linux này.")
else:
    print(f"Hệ điều hành: {platform.system()} - bỏ qua OCL_ICD_VENDORS.")


def kiem_tra_gpu():
    """Train một model nhỏ trên GPU để biết có dùng được không."""
    try:
        X = np.random.rand(200, 4)
        y = np.random.rand(200)
        lgb.train(
            {'objective': 'regression', 'device': 'gpu',
             'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID, 'verbose': -1},
            lgb.Dataset(X, y), num_boost_round=1,
        )
        return True, ''
    except Exception as e:
        return False, str(e)[:200]


GPU_SAN_SANG = False
if USE_GPU:
    GPU_SAN_SANG, _err = kiem_tra_gpu()
    if GPU_SAN_SANG:
        print("GPU OpenCL sẵn sàng, LightGBM sẽ chạy trên GPU.")
    else:
        print("[CẢNH BÁO] Không dùng được GPU, tự chuyển sang CPU.")
        print(f"   Lý do: {_err}")
else:
    print("USE_GPU = False, chạy CPU theo cấu hình.")
print(f"Chế độ tính toán: {'GPU' if GPU_SAN_SANG else 'CPU'}")
# Out:
# Đã tự đặt OCL_ICD_VENDORS = /run/opengl-driver/etc/OpenCL/vendors
# USE_GPU = False, chạy CPU theo cấu hình.
# Chế độ tính toán: CPU

# %% [markdown]
# ## 4. Đọc danh sách đặc trưng và tách nhóm phải bỏ
#
# Bỏ các cột mang giá trị `T-30 phút`. Giữ lại nhóm `96` vì đó là lịch sử một ngày trước, không gây trễ.

# %%
with open(f'{SELECTED_DIR}/selected_features.json', 'r', encoding='utf-8') as f:
    _sel_raw = json.load(f)
selected_features = _sel_raw['selected_features'] if isinstance(_sel_raw, dict) else _sel_raw

# QUYET DINH (2026-07-31, dong bo voi 06_1): lag_1 gay lech pha he thong (audit doc lap:
# 39/40 site vuot nguong, 126/127 ngay du bao di sau thuc te). Dung lag_4 (T-1 gio) - audit
# PASS sach (0/40 site vuot nguong, WAPE tot hon baseline). Giu rolling_*_4.
bo_di = [c for c in selected_features
         if (c.startswith(BO_PREFIX_NGAN) or c.startswith('rolling_'))
         and '96' not in c and c not in ('lag_4', 'rolling_mean_4', 'rolling_std_4',
                                          'rolling_min_4', 'rolling_max_4')]
giu_lai = [c for c in selected_features if c not in bo_di]

print(f"Tổng đặc trưng ban đầu : {len(selected_features)}")
print(f"\nBỏ đi ({len(bo_di)} cột):")
for c in bo_di:
    print(f"   {c}")
print(f"\nGiữ lại nhóm lịch sử dài: {[c for c in giu_lai if c.startswith(('lag_', 'rolling_'))]}")
print(f"Còn lại {len(giu_lai)} cột gốc, sẽ bổ sung thêm đặc trưng mới ở các bước dưới.")
# Out:
# Tổng đặc trưng ban đầu : 40
#
# Bỏ đi (0 cột):
#
# Giữ lại nhóm lịch sử dài: ['rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'lag_96', 'lag_4', 'rolling_std_4', 'rolling_std_96', 'rolling_mean_96', 'rolling_max_96', 'rolling_min_96']
# Còn lại 40 cột gốc, sẽ bổ sung thêm đặc trưng mới ở các bước dưới.

# %% [markdown]
# ## 5. Kiểm tra nhóm đặc trưng điện mặt trời đã có sẵn
#
# Các đặc trưng khử trễ pha được sinh ở **notebook 03-2** rồi đi qua 04 và 05, nên notebook này chỉ cần
# kiểm chúng có mặt đủ. Nếu thiếu thì phải chạy lại 03-2 → 04 → 05 trước.
#
# | nhóm | cột |
# |---|---|
# | hình học mặt trời | `solar_elevation`, `solar_azimuth`, `sin_elevation`, `ghi_cs`, `clearsky_proxy`, `rad_x_sinelev` |
# | quy mô trạm | `site_scale`, `tran_cong_suat`, `ky_vong`, `ty_le_bao_hoa`, `con_cach_tran` |
# | lịch sử một ngày | `lag_96`, `rolling_mean_96`, `rolling_max_96`, `rolling_std_96` |

# %%
NHOM_MAT_TROI = ['solar_elevation', 'solar_azimuth', 'azimuth_sin', 'azimuth_cos',
                 'sin_elevation', 'ghi_cs', 'cs_factor', 'clearsky_proxy', 'rad_x_sinelev']
NHOM_QUY_MO = ['site_scale', 'tran_cong_suat', 'ky_vong', 'ty_le_bao_hoa']
# con_cach_tran bi cam co chu dich o buoc 05 (DENY_STRUCTURAL_COLLINEAR: to hop tuyen tinh
# chinh xac cua tran_cong_suat va ky_vong), khong dua vao nhom kiem tra nay nua.
COT_BAT_BUOC = ['site_scale', 'sin_elevation', 'tran_cong_suat']   # can de chuan hoa va chan tran

_co_san = set(pq.ParquetFile(f'{SELECTED_DIR}/{VERSION}_test_selected.parquet').schema_arrow.names)

print("--- KIEM NHOM DAC TRUNG DIEN MAT TROI ---")
for _ten, _nhom in (('hinh hoc mat troi', NHOM_MAT_TROI), ('quy mo tram', NHOM_QUY_MO)):
    _co = [c for c in _nhom if c in _co_san]
    _thieu = [c for c in _nhom if c not in _co_san]
    print(f"   {_ten:<20} co {len(_co)}/{len(_nhom)}" + (f"  THIEU: {_thieu}" if _thieu else ""))

_thieu_bb = [c for c in COT_BAT_BUOC if c not in _co_san]
if _thieu_bb:
    raise KeyError(
        f"Thieu cot bat buoc {_thieu_bb}. Hay chay lai notebook 03-2, 04, 05 truoc khi train."
    )
print(f"\nDu {len(COT_BAT_BUOC)} cot bat buoc de chuan hoa muc tieu va chan tran cong suat.")

_lag = sorted(c for c in _co_san if c.startswith(('lag_', 'rolling_')))
print(f"Lag/rolling con lai trong du lieu: {_lag}")
_xau = [c for c in _lag if '96' not in c]
if _xau:
    print(f"[CANH BAO] Con lag/rolling ngan: {_xau}")
    print("   Chung mang gia tri T-30 phut va se gay tre pha. Hay dat LAGS = (96,) va")
    print("   ROLLING_WINDOWS = (96,) trong notebook 03-1 roi chay lai tu 03-1.")
# Out:
# --- KIEM NHOM DAC TRUNG DIEN MAT TROI ---
#    hinh hoc mat troi    co 9/9
#    quy mo tram          co 4/4
#
# Du 3 cot bat buoc de chuan hoa muc tieu va chan tran cong suat.
# Lag/rolling con lai trong du lieu: ['lag_4', 'lag_96', 'rolling_max_4', 'rolling_max_96', 'rolling_mean_4', 'rolling_mean_96', 'rolling_min_4', 'rolling_min_96', 'rolling_std_4', 'rolling_std_96']
# [CANH BAO] Con lag/rolling ngan: ['lag_4', 'rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'rolling_std_4']
#    Chung mang gia tri T-30 phut va se gay tre pha. Hay dat LAGS = (96,) va
#    ROLLING_WINDOWS = (96,) trong notebook 03-1 roi chay lai tu 03-1.

# %% [markdown]
# ## 6. Đọc dữ liệu development và test

# %%
COT_PHU = [TARGET_COL, SITE_COL, TIMESTAMP_COL, 'energy_source', 'exclude_from_training',
           'outlier_group', 'has_complete_history_features', 'is_daylight']

# Loai han 2 site co capacity_kw KHONG dang tin (khong phai imputed - ghi that tu nguon
# Kaggle - nhung lech qua nang so voi hanh vi thuc te, xac nhan bang doi chieu 42 site):
#   site 19: dinh thuc te vuot tran ly thuyet (capacity_kw*0.25) toi 5.03 lan, 63.9% dong
#            ban ngay vuot tran - qua nhieu de coi la loi do ngau nhien.
#   site 24: vuot 1.77 lan, 26.3% dong ban ngay vuot tran.
# Giu capacity_kw lam chuan cho 40 site con lai (da validate dung qua doi chieu fleet-wide,
# xem docs/2026_07_30_Khu_Tre_Pha_Du_Bao_15_Phut.md). Thay vi tu "cuu" outlier bang trans
# rieng (da thu va huy - xem lich su o buoc 2), loai han 2 site nay khoi train/test de
# khong lam sai lech ham muc tieu cua ca 40 site con lai, va khong "hoc theo outlier".
EXCLUDE_SITES = [19, 24]


def doc_du_lieu(ten_file):
    """Doc parquet, chi lay cot can, loc dong hop le. Khong dung dac trung o day."""
    duong_dan = f'{SELECTED_DIR}/{ten_file}.parquet'
    co_san = set(pq.ParquetFile(duong_dan).schema_arrow.names)
    cot = [c for c in dict.fromkeys(giu_lai + COT_PHU + COT_BAT_BUOC) if c in co_san]
    d = pd.read_parquet(duong_dan, columns=cot)

    n0 = len(d)
    if 'exclude_from_training' in d.columns:
        d = d[d['exclude_from_training'] == False]
    if 'has_complete_history_features' in d.columns:
        d = d[d['has_complete_history_features'] == True]
    d = d.dropna(subset=[TARGET_COL])
    if EXCLUDE_SITES:
        n_truoc = len(d)
        d = d[~d[SITE_COL].isin(EXCLUDE_SITES)]
        print(f"    Loai {EXCLUDE_SITES} (capacity_kw khong dang tin): "
              f"{n_truoc:,} -> {len(d):,} dong")
    print(f"Lọc {ten_file}: {n0:,} -> {len(d):,} dòng ({len(cot)} cột)")
    return d.sort_values([SITE_COL, TIMESTAMP_COL]).reset_index(drop=True)


dev = doc_du_lieu('v3_train_selected')

FEATURES = [c for c in giu_lai if c in dev.columns]
print(f"\nSố đặc trưng dùng để train: {len(FEATURES)}")
print(f"   nhóm mặt trời : {len([c for c in FEATURES if c in NHOM_MAT_TROI])}")
print(f"   nhóm quy mô   : {len([c for c in FEATURES if c in NHOM_QUY_MO])}")
print(f"   lag/rolling   : {[c for c in FEATURES if c.startswith(('lag_', 'rolling_'))]}")
print(f"\nBộ nhớ: dev {dev.memory_usage(deep=True).sum() / 1024**2:.0f} MB")
print("Tap TEST: KHONG doc o notebook nay - chi doc o notebook 07.")
display(dev[[TIMESTAMP_COL, 'shortwave_radiation', 'ghi_cs', 'sin_elevation',
             'site_scale', 'tran_cong_suat']].head(6))
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 1,751,015 -> 1,670,531 dong
# Lọc v3_train_selected: 1,791,894 -> 1,670,531 dòng (49 cột)
#
# Số đặc trưng dùng để train: 40
#    nhóm mặt trời : 9
#    nhóm quy mô   : 3
#    lag/rolling   : ['rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'lag_96', 'lag_4', 'rolling_std_4', 'rolling_std_96', 'rolling_mean_96', 'rolling_max_96', 'rolling_min_96']
#
# Bộ nhớ: dev 481 MB
# Tap TEST: KHONG doc o notebook nay - chi doc o notebook 07.
#             timestamp  shortwave_radiation  ghi_cs  sin_elevation  site_scale  \
# 0 2020-01-02 00:15:00                  0.0     0.0            0.0    21.46875
# 1 2020-01-02 00:30:00                  0.0     0.0            0.0    21.46875
# 2 2020-01-02 00:45:00                  0.0     0.0            0.0    21.46875
# 3 2020-01-02 01:00:00                  0.0     0.0            0.0    21.46875
# 4 2020-01-02 01:15:00                  0.0     0.0            0.0    21.46875
# 5 2020-01-02 01:30:00                  0.0     0.0            0.0    21.46875
#
#    tran_cong_suat
# 0        22.74991
# 1        22.74991
# 2        22.74991
# 3        22.74991
# 4        22.74991
# 5        22.74991

# %% [markdown]
# ## 9. Hàm mục tiêu, chuẩn hoá và các hàm đo
#
# **Mục tiêu chuẩn hoá:** thay vì học `y(T+15)` trực tiếp, mô hình học tỉ lệ
#
# ```
# k = y(T+15) / (site_scale x sin_elevation)
# ```
#
# rồi khi dự báo nhân ngược lại. Việc này giúp mô hình không phải tự suy ra quy mô từng trạm, và
# nhịp trong ngày do `sin_elevation` quyết định. Đây là thứ chữa lệch biên độ ở trạm 11, 19, 25, 27.
#
# **Phép đo trễ pha:** so `dự báo(T)` với `thực tế(T - k bước)` cho `k` từ 0 đến 3. Nếu RMSE nhỏ nhất
# tại `k=0` thì không trễ. Nếu nhỏ nhất tại `k=2` thì dự báo đang bám giá trị của 30 phút trước.

# %%
def mau_chuan_hoa(df):
    """Mau so de chuan hoa muc tieu: quy mo tram nhan sin(goc cao mat troi)."""
    return (df['site_scale'] * np.clip(df['sin_elevation'], EPS_ELEV, None)).to_numpy()


COT_NHAN = {
    'energy_source': '',
    'outlier_group': 'normal',
    'is_daylight': False,
    'exclude_from_training': False,
    'after_source_gap_steps_remaining': 0,
}


def them_muc_tieu(df, horizon_steps):
    """Muc tieu la san luong tai T + horizon_steps buoc. Day la du bao that.

    Dong thoi dich cac cot phan loai sang gia tri cua DONG NHAN, dat tien to nhan_.
    Phai dich TRUOC khi dropna, neu khong thi shift bi lech sau khi bo dong.
    Giong _label_series trong srcs/05_machine_learning/Forcasting_v3/08_train_baselines.py
    """
    h = int(horizon_steps)
    out = df.copy()
    out['y_true'] = out.groupby(SITE_COL)[TARGET_COL].shift(-h)
    out['plot_timestamp'] = out[TIMESTAMP_COL] + pd.Timedelta(minutes=15 * h)
    g = out.groupby(SITE_COL)

    # THU NGHIEM 3: THEM ban tai thoi diem muc tieu T+h thanh cot moi (hau to _mt),
    # giu nguyen ban tai T. Luoi 15 phut lien tuc (notebook 01) nen shift(-h) dung h buoc.
    if THEM_DAC_TRUNG_MUC_TIEU:
        for _c in [c for c in COT_TAT_DINH if c in out.columns]:
            out[f'{_c}_mt'] = g[_c].shift(-h)

    for cot, mac_dinh in COT_NHAN.items():
        if cot in out.columns:
            out[f'nhan_{cot}'] = g[cot].shift(-h)
            out[f'nhan_{cot}'] = out[f'nhan_{cot}'].fillna(mac_dinh)
        else:
            out[f'nhan_{cot}'] = mac_dinh
    return out.dropna(subset=['y_true'])


def eligibility_mask(df):
    """Dieu kien cung, khong phu thuoc experiment. Giong eligibility_mask cua srcs.

    Chi giu dong ma NHAN cua no ve nguyen tac dung duoc: ban ngay, nguon la measured
    hoac etl_imputed, khong nam trong vung sau gap, khong bi exclude_from_training.
    Chinh sach outlier va etl_imputed do build_sample_weight xu ly sau.
    """
    ban_ngay = df['nhan_is_daylight'].astype(bool)
    nguon = df['nhan_energy_source'].astype(str)
    bi_loai = df['nhan_exclude_from_training'].astype(bool)
    sau_gap = pd.to_numeric(df['nhan_after_source_gap_steps_remaining'], errors='coerce').fillna(0).gt(0)
    m = ban_ngay & nguon.isin(['measured', 'etl_imputed']) & ~sau_gap & ~bi_loai
    return m & df['y_true'].notna()


def build_sample_weight(df, experiment=EXPERIMENT):
    """Trong so mau theo dung bang experiment cua srcs.

    Dong co weight = 0 khong tham gia ham muc tieu nhung VAN GIU trong du lieu de bao cao.
    Binh thuong weight chi la 1.0 hoac 0.0; khi HE_SO_TRONG_SO_DINH > 0 thi dong ban ngay
    duoc nhan them trong so theo k de model hoc ky vung dinh (xem THU NGHIEM 2 o buoc 2).
    """
    nguon = df['nhan_energy_source'].astype(str)
    nhom = df['nhan_outlier_group'].astype(str)
    w = pd.Series(0.0, index=df.index)
    el = eligibility_mask(df)

    measured = nguon.eq('measured')
    etl = nguon.eq('etl_imputed')
    normal = nhom.eq('normal')
    physical = nhom.eq('physical_over_capacity')
    gmm = nhom.eq('gmm_if_consensus')
    other_or_multi = nhom.isin(['other_physical_rule', 'multiple_rules'])

    w.loc[el & measured & normal] = 1.0
    w.loc[el & measured & other_or_multi] = 1.0

    if experiment in {'measured_only_headline', 'measured_plus_etl_imputed', 'tran_theo_du_lieu'}:
        w.loc[el & measured & gmm] = 1.0
    elif experiment == 'zero_weight_gmm_consensus':
        w.loc[el & measured & gmm] = 0.0
    elif experiment == 'zero_weight_all_flagged':
        w.loc[el & measured & (gmm | other_or_multi)] = 0.0

    if experiment == 'measured_plus_etl_imputed':
        w.loc[el & etl & normal] = 1.0

    # Vuot tran cong suat vat ly la bat kha thi nen phai loai. Nhung cai co
    # physical_over_capacity duoc gan tu capacity_kw METADATA, ma metadata nay sai o 11/42 tram
    # (site 19 vuot tran metadata 4,89 lan) nen no dang loai oan du lieu do that.
    # Experiment 'tran_theo_du_lieu' doi sang tran tinh TU DU LIEU (cot tran_cong_suat, sinh o
    # notebook 03-2 tu phan vi 99,9 cua tap TRAIN) - chi loai dong that su vuot tran do.
    if experiment == 'tran_theo_du_lieu' and 'tran_cong_suat' in df.columns:
        vuot_tran_that = df['y_true'] > df['tran_cong_suat'] * 1.02
        w.loc[el & measured & physical & ~vuot_tran_that] = 1.0
        w.loc[vuot_tran_that] = 0.0
    else:
        w.loc[physical] = 0.0

    # THU NGHIEM 2: tang trong so vung dinh. k cang gan tran thi trong so cang lon.
    if HE_SO_TRONG_SO_DINH > 0:
        _k = (df['y_true'] / mau_chuan_hoa(df)).clip(0, 1.5).fillna(0.0)
        w = w * (1.0 + HE_SO_TRONG_SO_DINH * _k)
    return w


def scope_masks(df):
    """Tam pham vi bao cao, giong scope_masks cua srcs."""
    el = eligibility_mask(df)
    nguon = df['nhan_energy_source'].astype(str)
    nhom = df['nhan_outlier_group'].astype(str)
    return {
        'eligible_rows': el,
        'headline': el & nguon.eq('measured') & ~nhom.eq('physical_over_capacity'),
        'normal_rows': el & nguon.eq('measured') & nhom.eq('normal'),
        'etl_imputed_rows': el & nguon.eq('etl_imputed'),
        'gmm_if_consensus_rows': el & nguon.eq('measured') & nhom.eq('gmm_if_consensus'),
        'physical_over_capacity_rows': el & nguon.eq('measured') & nhom.eq('physical_over_capacity'),
        'other_physical_rule_rows': el & nguon.eq('measured') & nhom.eq('other_physical_rule'),
        'multiple_rules_rows': el & nguon.eq('measured') & nhom.eq('multiple_rules'),
    }


def compute_wape(yt, yp):
    denom = np.nansum(np.abs(yt))
    return float(np.nansum(np.abs(yt - yp)) / denom * 100.0) if denom > 0 else np.nan


def compute_metrics(yt, yp):
    return {
        'wape': compute_wape(yt, yp),
        'rmse': float(root_mean_squared_error(yt, yp)),
        'mae': float(mean_absolute_error(yt, yp)),
        'r2': float(r2_score(yt, yp)),
        'n': int(len(yt)),
    }


def _cot_loc(df, ten_goc):
    """Cot dung de loc pham vi, UU TIEN ban tai T+h (tien to nhan_).

    Nhan la y(T+h) nen "do that ban ngay" phai xet DONG NHAN tai T+h, khong phai dong
    dac trung tai T. Ban cu loc theo cot tai T nen van dem ca nhung dong ma NHAN do buoc
    dien khuyet ETL sinh ra.

    Do da tren tap test niem phong (2026-08-09):
        h1: 17,6354% -> 17,7486%  (+0,11 diem, loai 9.681 dong)
        h4: 21,4351% -> 21,7786%  (+0,34 diem, loai 26.893 dong)
    Con so chat o h1 gan trung khit 17,7488% ma muc Skill Score da dung, nen sua nay lam
    hai muc trong bao cao thong nhat.

    them_muc_tieu() sinh san cot nhan_*; lui ve cot tai T neu khung khong co.
    """
    ten_nhan = f'nhan_{ten_goc}'
    if ten_nhan in df.columns:
        return df[ten_nhan]
    if ten_goc in df.columns:
        return df[ten_goc]
    return None


def metrics_3_pham_vi(df):
    """Ba pham vi: all / measured / measured_daylight. Con so chinh thuc la measured_daylight."""
    res = {'all': compute_metrics(df['y_true'].values, df['y_pred'].values)}
    _nguon = _cot_loc(df, 'energy_source')
    m = ((_nguon == 'measured').to_numpy()
         if _nguon is not None else np.ones(len(df), bool))
    if m.sum():
        res['measured'] = compute_metrics(df['y_true'].values[m], df['y_pred'].values[m])
    _ngay = _cot_loc(df, 'is_daylight')
    if _ngay is not None:
        md_ = m & _ngay.fillna(False).astype(bool).to_numpy()
        if md_.sum():
            res['measured_daylight'] = compute_metrics(df['y_true'].values[md_], df['y_pred'].values[md_])
    return res


def quet_do_tre(df, k_max=3):
    """Voi moi k, tinh RMSE giua du bao(T) va thuc te(T - k buoc). k=0 nho nhat la khong tre."""
    v = df[df['is_daylight'].fillna(False).astype(bool)].sort_values([SITE_COL, TIMESTAMP_COL])
    g = v.groupby(SITE_COL)['y_true']
    ket = {}
    for k in range(0, k_max + 1):
        yt = g.shift(k)
        m = yt.notna()
        ket[k] = float(np.sqrt(np.mean((v['y_pred'][m] - yt[m]) ** 2)))
    return ket


print("Đã định nghĩa các hàm chuẩn hoá, tính metric và quét độ trễ.")
# Out:
# Đã định nghĩa các hàm chuẩn hoá, tính metric và quét độ trễ.

# %% [markdown]
# ## 10. Chuẩn bị ma trận huấn luyện

# %%
dev_h = them_muc_tieu(dev, HORIZON_STEPS)
dev_h = dev_h[(dev_h['site_scale'] > 0) & (dev_h['sin_elevation'] > EPS_ELEV)].copy()
dev_h['k_target'] = np.clip(dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h), 0, 1.5)
dev_h['w'] = build_sample_weight(dev_h)

# THU NGHIEM 3: bo sung cac cot tat dinh tai T+h vao tap dac trung.
# Phai lam sau them_muc_tieu vi cot _mt duoc sinh trong do.
_mt = [f'{c}_mt' for c in COT_TAT_DINH if f'{c}_mt' in dev_h.columns]
FEATURES = FEATURES + [c for c in _mt if c not in FEATURES]
print(f"Them {len(_mt)} dac trung tat dinh tai T+{HORIZON_STEPS * 15} phut:")
print(f"   {_mt}")

MEDIANS = dev_h[FEATURES].median(numeric_only=True).fillna(0.0)

# Chi train tren dong co weight > 0, giong srcs: mask = label_mask & weight_all.gt(0)
_train_mask = dev_h['w'].gt(0)
X_dev = dev_h.loc[_train_mask, FEATURES].fillna(MEDIANS).astype(DTYPE)
y_dev = dev_h.loc[_train_mask, 'k_target'].astype(DTYPE)
w_dev = dev_h.loc[_train_mask, 'w'].astype(DTYPE)

print(f"Ma tran train : {X_dev.shape[0]:,} dong x {X_dev.shape[1]} dac trung")
print(f"Muc tieu chuan hoa k: min {y_dev.min():.4f}  trung vi {np.median(y_dev):.4f}  max {y_dev.max():.4f}")

print(f"\n--- CHINH SACH OUTLIER, experiment = {EXPERIMENT} ---")
print("Dong co weight = 0 khong tham gia ham muc tieu nhung van giu de bao cao.")
_bang_w = dev_h.groupby(['nhan_energy_source', 'nhan_outlier_group'], observed=True).agg(
    so_dong=('w', 'size'),
    so_dong_weight_1=('w', lambda x: int((x > 0).sum())),
).reset_index()
_bang_w['ty_le_duoc_train_%'] = (_bang_w['so_dong_weight_1'] / _bang_w['so_dong'] * 100).round(1)
display(_bang_w.sort_values('so_dong', ascending=False))

_loai = int((~_train_mask).sum())
print(f"Tong dong bi loai khoi ham muc tieu: {_loai:,} / {len(dev_h):,} ({_loai / len(dev_h) * 100:.2f}%)")
_pc = int((dev_h['nhan_outlier_group'].astype(str) == 'physical_over_capacity').sum())
print(f"   trong do physical_over_capacity: {_pc:,} dong (luon bi loai o moi experiment)")

print(f"\nKhoang thoi gian train: {dev_h[TIMESTAMP_COL].min()} -> {dev_h[TIMESTAMP_COL].max()}")
# Out:
# Them 14 dac trung tat dinh tai T+15 phut:
#    ['solar_elevation_mt', 'solar_azimuth_mt', 'azimuth_sin_mt', 'azimuth_cos_mt', 'sin_elevation_mt', 'ghi_cs_mt', 'clearsky_proxy_mt', 'ky_vong_mt', 'ty_le_bao_hoa_mt', 'minute_of_day_mt', 'hour_mt', 'hour_cos_mt', 'doy_sin_mt', 'doy_cos_mt']
# Ma tran train : 677,401 dong x 54 dac trung
# Muc tieu chuan hoa k: min 0.0000  trung vi 0.6144  max 1.5000
#
# --- CHINH SACH OUTLIER, experiment = measured_only_headline ---
# Dong co weight = 0 khong tham gia ham muc tieu nhung van giu de bao cao.
#          nhan_energy_source   nhan_outlier_group  so_dong  so_dong_weight_1  \
# 9                  measured               normal   675989            674104
# 5               etl_imputed               normal    90569                 0
# 7                  measured     gmm_if_consensus     2648              2648
# 10                 measured  other_physical_rule      349               349
# 8                  measured       multiple_rules      300               300
# 3               etl_imputed     gmm_if_consensus      139                 0
# 0    causal_day_persistence               normal       69                 0
# 1     causal_profile_median               normal       18                 0
# 6               etl_imputed  other_physical_rule        7                 0
# 4               etl_imputed       multiple_rules        4                 0
# 2   causal_week_persistence               normal        2                 0
#
#     ty_le_duoc_train_%
# 9                 99.7
# 5                  0.0
# 7                100.0
# 10               100.0
# 8                100.0
# 3                  0.0
# 0                  0.0
# 1                  0.0
# 6                  0.0
# 4                  0.0
# 2                  0.0
# Tong dong bi loai khoi ham muc tieu: 92,693 / 770,094 (12.04%)
#    trong do physical_over_capacity: 0 dong (luon bi loai o moi experiment)
#
# Khoang thoi gian train: 2020-01-02 06:30:00 -> 2021-08-20 17:45:00

# %%
# ── Ham doc fold (chuyen len day de tap validation dung duoc ngay) ──
FOLDS_DIR = f'{SELECTED_DIR}/time_series_folds'


def doc_fold(n, vai_tro):
    """Doc mot fold, dung muc tieu va weight giong tap development."""
    duong_dan = f'{FOLDS_DIR}/fold_{n}_{vai_tro}_selected.parquet'
    if not os.path.exists(duong_dan):
        return None
    co_san = set(pq.ParquetFile(duong_dan).schema_arrow.names)
    cot = [c for c in dict.fromkeys(FEATURES + COT_PHU + COT_BAT_BUOC) if c in co_san]
    d = pd.read_parquet(duong_dan, columns=cot).sort_values([SITE_COL, TIMESTAMP_COL]).reset_index(drop=True)
    if EXCLUDE_SITES and SITE_COL in d.columns:
        d = d[~d[SITE_COL].isin(EXCLUDE_SITES)]
    d = them_muc_tieu(d, HORIZON_STEPS)
    d = d[(d['site_scale'] > 0) & (d['sin_elevation'] > EPS_ELEV)].copy()
    d['k_target'] = np.clip(d['y_true'].to_numpy() / mau_chuan_hoa(d), 0, 1.5)
    d['w'] = build_sample_weight(d)
    d = d[d['w'].gt(0)]
    return d


def doc_val_that():
    """Doc tap VALIDATION THAT (v3_val_selected), xu ly y het doc_fold().

    TACH BIET HOAN TOAN voi tap hoc: mo hinh chi hoc v3_train_selected, nen moi dong
    trong khung nay deu la dong CHUA TUNG duoc hoc. Truoc day cho nay gop 5 fold val -
    ma fold nam trong development (= train + val) va mo hinh cuoi lai hoc ca development,
    nen con so thu duoc la cham tren bai da hoc, khong dung de chon mo hinh duoc.
    """
    d = doc_du_lieu('v3_val_selected')
    d = them_muc_tieu(d, HORIZON_STEPS)
    d = d[(d['site_scale'] > 0) & (d['sin_elevation'] > EPS_ELEV)].copy()
    d['k_target'] = np.clip(d['y_true'].to_numpy() / mau_chuan_hoa(d), 0, 1.5)
    d['w'] = build_sample_weight(d)
    return d[d['w'].gt(0)]


# ── TAP VALIDATION thay cho tap test ──
# Tap test BI NIEM PHONG: notebook nay tuyet doi khong mo no. Moi danh gia (do tre pha,
# metric 3 pham vi, metric 8 pham vi, bieu do actual-vs-predict) deu chay tren tap
# VALIDATION gop tu 5 fold. Tap test chi duoc mo DUY NHAT 1 lan o notebook 07, sau khi
# mo hinh vo dich da duoc chon xong bang chinh so lieu validation nay.
#
# Vi sao doi: ban cu mo tap test ngay trong buoc train roi in metric ra man hinh. Du
# khong dung con so do de chon gi, viec nhin thay no da lam mat y nghia "niem phong" -
# nguoi lam co the (vo tinh) chinh tham so theo huong lam dep con so test.
def _nap_val_gop():
    """Gop 5 fold validation thanh 1 khung, ap dung y het cach xu ly tap development."""
    _khung = []
    _n = 1
    while True:
        _d = doc_fold(_n, 'val')
        if _d is None:
            break
        _khung.append(_d)
        _n += 1
    if not _khung:
        raise FileNotFoundError(
            f"Khong tim thay fold validation nao trong {FOLDS_DIR}. "
            f"Hay chay lai notebook 02 den 05 truoc.")
    return pd.concat(_khung, ignore_index=True)


val_h = doc_val_that()
print(f"Tap VALIDATION that (v3_val_selected): {len(val_h):,} dong")
print("Tap nay TACH BIET voi tap hoc - mo hinh chi hoc v3_train_selected.")
print("Tap TEST: KHONG mo o notebook nay (chi mo o notebook 07).")
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 476,868 -> 454,160 dong
# Lọc v3_val_selected: 482,076 -> 454,160 dòng (49 cột)
# Tap VALIDATION that (v3_val_selected): 210,579 dong
# Tap nay TACH BIET voi tap hoc - mo hinh chi hoc v3_train_selected.
# Tap TEST: KHONG mo o notebook nay (chi mo o notebook 07).

# %% [markdown]
# ## 10.1. Chẩn đoán ngay trong lúc train - in ra các trường hợp đáng nghi
#
# In thẳng ra 3 nhóm bằng chứng để không phải đi dò lại sau khi train xong:
#
# 1. **Trần công suất**: site nào bị loại nhiều dòng vì cờ `physical_over_capacity`, và đỉnh mà model
#    thực sự được học so với đỉnh thật (nếu lệch nhiều thì model không thể dựng lại đỉnh).
# 2. **Join thời tiết**: bao nhiêu dòng đang dùng thời tiết của giờ chưa xảy ra
#    (`weather_timestamp > timestamp`). Xem `docs/open_meteo_hourly_column_semantics_vi.md` mục 5.
# 3. **Clip mục tiêu**: bao nhiêu dòng bị ngưỡng `k <= 1.5` cắt mất.

# %%
print("=" * 78)
print("CHAN DOAN 1: TRAN CONG SUAT - dinh that vs dinh model duoc hoc, theo site")
print("=" * 78)
_ch = dev_h.copy()
_ch['duoc_train'] = _ch['w'] > 0
_rows = []
for _s, _g in _ch.groupby(SITE_COL, observed=True):
    _t = _g[_g['duoc_train']]
    _rows.append({
        'site_id': _s,
        'dong_ban_ngay': len(_g),
        'dong_bi_loai': int((~_g['duoc_train']).sum()),
        'ty_le_loai_%': round((~_g['duoc_train']).mean() * 100, 1),
        'dinh_that': round(float(_g['y_true'].max()), 2),
        'dinh_duoc_hoc': round(float(_t['y_true'].max()), 2) if len(_t) else np.nan,
        'median_that': round(float(_g['y_true'].median()), 2),
        'median_duoc_hoc': round(float(_t['y_true'].median()), 2) if len(_t) else np.nan,
    })
_bang_ch = pd.DataFrame(_rows)
_bang_ch['thieu_dinh_%'] = ((_bang_ch['dinh_that'] - _bang_ch['dinh_duoc_hoc'])
                            / _bang_ch['dinh_that'] * 100).round(1)
_dang_nghi = _bang_ch[(_bang_ch['ty_le_loai_%'] > 10) | (_bang_ch['thieu_dinh_%'] > 5)]
print(f"Experiment dang dung: {EXPERIMENT} | HE_SO_TRONG_SO_DINH = {HE_SO_TRONG_SO_DINH}")
print(f"So site DANG NGHI (loai > 10% dong hoac thieu dinh > 5%): {len(_dang_nghi)}/{len(_bang_ch)}")
if len(_dang_nghi):
    display(_dang_nghi.sort_values('ty_le_loai_%', ascending=False))
else:
    print("Khong con site nao bi loai qua nhieu du lieu - tran cong suat da dung.")

print()
print("=" * 78)
print("CHAN DOAN 2: JOIN THOI TIET - co dung thoi tiet cua gio CHUA XAY RA khong")
print("=" * 78)
_MLMART = '../../data/mlmart_base/v3_final_cleaned.parquet'
try:
    _wnames = set(pq.ParquetFile(_MLMART).schema_arrow.names)
    if {'timestamp', 'weather_timestamp'} <= _wnames:
        _wd = pd.read_parquet(_MLMART, columns=['timestamp', 'weather_timestamp'])
        _delta = ((pd.to_datetime(_wd['weather_timestamp']) - pd.to_datetime(_wd['timestamp']))
                  .dt.total_seconds() / 60)
        _leak = int((_delta > 0).sum())
        print("Phan bo (weather_timestamp - timestamp), don vi phut:")
        print(_delta.value_counts().sort_index().to_string())
        print(f"\nSo dong dung THOI TIET TUONG LAI: {_leak:,}/{len(_wd):,} ({_leak / len(_wd) * 100:.2f}%)")
        if _leak:
            print("[CANH BAO] Dong nao co delta > 0 la dang lay thoi tiet cua gio chua xay ra.")
            print("   Vi du delta = +45: dong 10:15 dung thoi tiet dan nhan 11:00.")
            print("   Cac cot buc xa/precipitation/sunshine la TRUNG BINH CA GIO nen vua ro ri")
            print("   tuong lai, vua lam PHANG dinh that - xem docs/open_meteo_hourly_column_semantics_vi.md")
        del _wd, _delta
        gc.collect()
    else:
        print("Khong co cot weather_timestamp trong mlmart base, bo qua kiem tra nay.")
except FileNotFoundError:
    print(f"Khong tim thay {_MLMART}, bo qua kiem tra nay.")

print()
print("=" * 78)
print("CHAN DOAN 3: CLIP MUC TIEU - bao nhieu dong bi nguong k <= 1.5 cat")
print("=" * 78)
_k_raw = dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h)
_bi_cat = int((_k_raw > 1.5).sum())
print(f"So dong bi clip boi nguong 1.5 : {_bi_cat:,}/{len(dev_h):,} ({_bi_cat / len(dev_h) * 100:.2f}%)")
print(f"k_raw lon nhat               : {np.nanmax(_k_raw):.3f}")
print("Neu ty le nay nho (< 1%) thi clip KHONG phai nguyen nhan mat bien do.")
del _ch, _k_raw
gc.collect()
print()
print("Hoan tat chan doan truoc khi train.")
# Out:
# ==============================================================================
# CHAN DOAN 1: TRAN CONG SUAT - dinh that vs dinh model duoc hoc, theo site
# ==============================================================================
# Experiment dang dung: measured_only_headline | HE_SO_TRONG_SO_DINH = 1.0
# So site DANG NGHI (loai > 10% dong hoac thieu dinh > 5%): 25/40
#     site_id  dong_ban_ngay  dong_bi_loai  ty_le_loai_%  dinh_that  \
# 6         7          26009          9945          38.2      16.86
# 8         9          26009          5427          20.9       2.19
# 12       13          24852          4875          19.6      13.02
# 4         5          10926          2142          19.6       2.00
# 32       35          22292          4370          19.6       6.21
# 25       28          17156          3345          19.5       3.46
# 24       27          26206          5067          19.3      99.22
# 26       29          17342          3292          19.0       3.31
# 3         4          10926          1842          16.9       2.00
# 15       16          10827          1763          16.3       3.40
# 31       34          22151          3086          13.9       4.42
# 13       14          18679          2510          13.4      14.20
# 36       39          16656          2169          13.0       6.91
# 27       30          16656          2036          12.2       8.45
# 23       26          18787          2206          11.7       7.96
# 19       21          18787          2153          11.5       8.11
# 29       32          18787          2093          11.1       7.36
# 21       23          16656          1814          10.9      12.47
# 16       17          18787          1913          10.2       9.56
# 33       36          18787          1898          10.1      10.23
# 18       20          18787          1697           9.0      16.84
# 39       42          26019          2260           8.7       6.71
# 1         2          26032          1766           6.8      20.33
# 9        10          26009          1530           5.9       9.00
# 0         1          26032          1182           4.5      23.54
#
#     dinh_duoc_hoc  median_that  median_duoc_hoc  thieu_dinh_%
# 6           16.03         5.03             4.83           4.9
# 8            2.01         0.68             0.79           8.2
# 12          13.02         4.50             4.66           0.0
# 4            2.00         0.61             0.71           0.0
# 32           6.03         1.54             1.59           2.9
# 25           3.46         0.78             0.85           0.0
# 24          99.22        27.94            27.12           0.0
# 26           3.31         0.77             0.87           0.0
# 3            2.00         0.60             0.70           0.0
# 15           3.31         0.78             0.89           2.6
# 31           4.06         1.15             1.23           8.1
# 13          13.56         3.71             3.86           4.5
# 36           6.54         1.82             1.89           5.4
# 27           8.40         2.14             2.17           0.6
# 23           7.68         2.13             2.17           3.5
# 19           8.02         1.96             2.03           1.1
# 29           7.36         1.70             1.77           0.0
# 21          12.05         3.08             3.03           3.4
# 16           9.55         2.40             2.48           0.1
# 33          10.15         2.55             2.60           0.8
# 18          15.82         4.30             4.30           6.1
# 39           6.28         2.11             2.16           6.4
# 1           18.56         6.47             6.47           8.7
# 9            7.75         3.19             3.20          13.9
# 0           21.78         7.88             7.84           7.5
# ==============================================================================
# CHAN DOAN 2: JOIN THOI TIET - co dung thoi tiet cua gio CHUA XAY RA khong
# ==============================================================================
# Phan bo (weather_timestamp - timestamp), don vi phut:
# -45.0    682347
# -30.0    682464
# -15.0    682575
#  0.0     682714
#
# So dong dung THOI TIET TUONG LAI: 0/2,731,946 (0.00%)
#
# ==============================================================================
# CHAN DOAN 3: CLIP MUC TIEU - bao nhieu dong bi nguong k <= 1.5 cat
# ==============================================================================
# So dong bi clip boi nguong 1.5 : 2,842/770,094 (0.37%)
# k_raw lon nhat               : 7.430
# Neu ty le nay nho (< 1%) thi clip KHONG phai nguyen nhan mat bien do.
#
# Hoan tat chan doan truoc khi train.

# %% [markdown]
# ## 10.2. CỔNG KIỂM TRA TRƯỚC TRAIN — không đạt thì dừng, không train
#
# Trước đây đã đưa ra nhiều giả thuyết về trễ pha rồi mới train, và phần lớn sai. Bước này đảo lại
# thứ tự: **đo trên dữ liệu trước, chỉ train khi dữ liệu không bắt buộc model phải trễ.**
#
# Nói rõ giới hạn: cổng này chứng minh được **dữ liệu không cài sẵn độ trễ không thể bù**, nhưng
# không bảo đảm model học ra sẽ không trễ — đó là kết quả của quá trình học, phải đo lại ở `09`.
#
# Bốn kiểm tra, `raise` ngay nếu vi phạm:
#
# | | Kiểm tra | Tiêu chí dừng |
# |---|---|---|
# | A | Nhãn đúng là `energy(T+h)` | sai lệch shift → dừng |
# | B | Thời tiết causal (`weather_ts <= timestamp`) | còn dòng dùng tương lai → dừng |
# | C | Độ trễ cài sẵn: dịch đặc trưng `k` bước thì khớp mục tiêu nhất | `k != 0` mà **không có** đặc trưng `_mt` để bù → dừng |
# | D | Vùng đỉnh có được học | site bị loại >50% dòng ban ngày → dừng |

# %%
_loi = []
print("=" * 74); print("CONG KIEM TRA TRUOC TRAIN"); print("=" * 74)

# ---- A. Nhan co dung la energy(T+h) ----
_s0 = dev_h[SITE_COL].iloc[0]
_sub = dev.loc[dev[SITE_COL].eq(_s0)].sort_values(TIMESTAMP_COL).head(HORIZON_STEPS + 5)
_ok_a = np.allclose(_sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 4].to_numpy(dtype=float),
                    _sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 4].to_numpy(dtype=float))
_chk = them_muc_tieu(_sub.copy(), HORIZON_STEPS)
if len(_chk):
    _ok_a = np.allclose(_chk['y_true'].iloc[:3].to_numpy(dtype=float),
                        _sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 3].to_numpy(dtype=float),
                        equal_nan=True)
print(f"[A] y_true(T) == energy(T+{HORIZON_STEPS}): {'DAT' if _ok_a else 'SAI'}")
if not _ok_a:
    _loi.append("A: nhan khong khop energy(T+h) - shift bi lech")

# ---- B. Thoi tiet causal ----
# Notebook 01 sua join trong BO NHO roi ghi ra v3_continuous_grid.parquet, KHONG ghi lai vao
# mlmart_base. Nen phai kiem chinh file ma luong train dung, khong kiem file nguon.
# Buoc 3.1 cua notebook 01 dat weather_join_method = 'hour_causal_floor' khi sua thanh cong.
_GRID = '../../data/model/v3/01_reindex/v3_continuous_grid.parquet'
if os.path.exists(_GRID):
    _gn = set(pq.ParquetFile(_GRID).schema_arrow.names)
    if 'weather_join_method' in _gn:
        _jm = pd.read_parquet(_GRID, columns=['weather_join_method'])['weather_join_method']
        _vc = _jm.value_counts(dropna=False)
        print("[B] Thoi tiet causal - weather_join_method trong v3_continuous_grid:")
        for _k, _v in _vc.items():
            print(f"       {str(_k):<26} {_v:>10,}")
        _n_cu = int(_jm.astype(str).eq('raw_hour_causal_manual').sum())
        if _n_cu:
            _loi.append(f"B: con {_n_cu:,} dong mang nhan join CU 'raw_hour_causal_manual' "
                        f"(join hoi cuu, 71,90% dong dung thoi tiet tuong lai). "
                        f"Chay lai notebook 01 - buoc 3.1 se sua thanh 'hour_causal_floor'.")
        else:
            print("       -> Da la join causal (hour_causal_floor), khong dung du lieu tuong lai.")
        del _jm, _vc
        gc.collect()
    else:
        print("[B] Khong co cot weather_join_method trong grid, bo qua kiem tra nay.")
else:
    _loi.append(f"B: chua co {_GRID} - phai chay notebook 01 truoc.")

# ---- C. Do tre cai san ----
_b = dev_h[dev_h['w'].gt(0)]
_gb = _b.groupby(SITE_COL)
print(f"[C] Do tre cai san (dich dac trung k buoc, do bang MAE - khong dung RMSE):")
_k_xau = []
for _col in ['shortwave_radiation', 'sin_elevation']:
    if _col not in _b.columns:
        continue
    _r = {}
    for _k in range(-2, 3):
        _x = _gb[_col].shift(-_k).to_numpy(dtype=float)
        _y = _b['y_true'].to_numpy(dtype=float)
        _m = np.isfinite(_x) & np.isfinite(_y)
        if _m.sum() < 1000:
            continue
        _sc = np.nansum(_x[_m] * _y[_m]) / np.nansum(_x[_m] * _x[_m])
        _r[_k] = float(np.mean(np.abs(_sc * _x[_m] - _y[_m])))
    if not _r:
        continue
    _kb = min(_r, key=_r.get)
    print(f"    {_col:<22} " + " | ".join(f"k={k}:{v:.4f}" for k, v in _r.items())
          + f"  -> k tot nhat = {_kb}")
    if _kb != 0:
        _k_xau.append((_col, _kb))

_co_mt = [c for c in FEATURES if c.endswith('_mt')]
if _k_xau:
    print(f"    Co {len(_k_xau)} dac trung tre cai san: {_k_xau}")
    if _co_mt:
        print(f"    Nhung DA CO {len(_co_mt)} dac trung tai T+h de model tu bu -> cho di tiep.")
    else:
        _loi.append(f"C: du lieu tre cai san {_k_xau} ma KHONG co dac trung _mt de bu. "
                    f"Dat THEM_DAC_TRUNG_MUC_TIEU = True o buoc 2.")
else:
    print("    Khong co dac trung nao tre cai san.")

# ---- D. Vung dinh co duoc hoc ----
_t = dev_h.copy()
_t['duoc_train'] = _t['w'] > 0
_bo = (_t.groupby(SITE_COL, observed=True)['duoc_train']
       .apply(lambda x: 1 - x.mean()).mul(100).round(1))
_nang = _bo[_bo > 50]
print(f"[D] Site bi loai > 50% dong ban ngay: {len(_nang)}/{_bo.size}")
if len(_nang):
    print(_nang.to_string())
    _loi.append(f"D: {len(_nang)} site bi loai qua nua du lieu ban ngay -> khong hoc duoc vung dinh. "
                f"Kiem tra EXPERIMENT (dang la '{EXPERIMENT}')")
del _t, _b
gc.collect()

# ---- KET LUAN ----
print()
print("=" * 74)
if _loi:
    print("CONG KIEM TRA: KHONG DAT - DUNG, KHONG TRAIN")
    for _e in _loi:
        print(f"  - {_e}")
    print("=" * 74)
    raise RuntimeError(f"Cong kiem tra truoc train khong dat ({len(_loi)} loi). "
                       f"Sua xong roi chay lai, dung train khi chua dat.")
print("CONG KIEM TRA: DAT TOAN BO - du lieu khong cai san do tre khong the bu, cho train.")
print("=" * 74)
# Out:
# ==========================================================================
# CONG KIEM TRA TRUOC TRAIN
# ==========================================================================
# [A] y_true(T) == energy(T+1): DAT
# [B] Thoi tiet causal - weather_join_method trong v3_continuous_grid:
#        hour_causal_floor           2,730,100
#        nan                            52,492
#        missing_weather                 1,846
#        -> Da la join causal (hour_causal_floor), khong dung du lieu tuong lai.
# [C] Do tre cai san (dich dac trung k buoc, do bang MAE - khong dung RMSE):
#     shortwave_radiation    k=-2:5.0821 | k=-1:4.9474 | k=0:4.8124 | k=1:4.6930 | k=2:4.6152  -> k tot nhat = 2
#     sin_elevation          k=-2:5.1859 | k=-1:5.1253 | k=0:5.0871 | k=1:5.0821 | k=2:5.1018  -> k tot nhat = 1
#     Co 2 dac trung tre cai san: [('shortwave_radiation', 2), ('sin_elevation', 1)]
#     Nhung DA CO 14 dac trung tai T+h de model tu bu -> cho di tiep.
# [D] Site bi loai > 50% dong ban ngay: 0/40
#
# ==========================================================================
# CONG KIEM TRA: DAT TOAN BO - du lieu khong cai san do tre khong the bu, cho train.
# ==========================================================================

# %% [markdown]
# ## 10.3. Train thử nhanh và ĐO TRỄ THẬT — không sạch thì dừng, không tune
#
# Cổng ở `10.2` chỉ chứng minh **dữ liệu** không cài sẵn độ trễ. Bước này đo **model thật sự có trễ
# hay không**, bằng một mô hình nhỏ chạy trong ~1 phút, **trước khi** bỏ thời gian cho Optuna
# (15 trial × 5 fold mới là phần tốn hàng chục phút).
#
# Cách đo — theo độ dốc, **không dùng RMSE** và không dùng `argmax` đỉnh:
#
# ```
# doc(t) = (thuc_te(t+1) - thuc_te(t-1)) / 2      # do doc cua duong thuc te
# err(t) = du_bao(t) - thuc_te(t)
# tre_phut = -sum(doc * err) / sum(doc^2) * 15
# ```
#
# Nếu dự báo bị dịch phải `c` bước thì `err ≈ -c · doc`, nên hệ số hồi quy trả về đúng `c` tính bằng
# phút. Chỉ số này **tách sai số biên độ ra khỏi sai số thời điểm** — dự báo cao hay thấp đều không
# ảnh hưởng, nên không bị nhiễu bởi chuyện đỉnh tù. Đây cũng đúng công thức dashboard đang hiển thị.
#
# Không đạt ngưỡng thì `raise`, không chạy tiếp.

# %%
# ── Tham so cong do tre ──
NGUONG_TRE_PHUT = 5.0      # |tre| vuot nguong nay thi dung, khong tune
MAU_THU_NHANH = 300_000    # so dong lay mau de train thu cho nhanh
DUNG_NEU_TRE = True        # dat False de van chay tiep du tre (chi khi co ly do ro rang)


def do_tre_phut(d, cot_that, cot_du_bao):
    """Do do tre theo do doc, tra ve so PHUT. Duong = du bao di sau (dich phai).

    err ~ -c * doc neu du bao bi dich c buoc, nen he so hoi quy chinh la c.
    Tach sai so BIEN DO ra khoi sai so THOI DIEM: du bao cao hay thap deu khong anh huong.
    """
    x = d.sort_values([SITE_COL, TIMESTAMP_COL])
    g = x.groupby(SITE_COL, observed=True)[cot_that]
    doc = (g.shift(-1) - g.shift(1)) / 2
    err = x[cot_du_bao] - x[cot_that]
    m = doc.notna() & err.notna()
    if 'is_daylight' in x.columns:
        m = m & x['is_daylight'].fillna(False).astype(bool)
    a = doc[m].to_numpy(dtype=float)
    b = err[m].to_numpy(dtype=float)
    if a.size < 200 or (a ** 2).sum() == 0:
        return np.nan, 0
    return -float((a * b).sum() / (a * a).sum()) * 15, int(a.size)


print("=" * 74)
print("TRAIN THU NHANH DE DO TRE (truoc khi tune)")
print("=" * 74)

_n = min(MAU_THU_NHANH, len(X_dev))
_idx = X_dev.sample(n=_n, random_state=SEED).index
_p = {'objective': LGB_OBJECTIVE, 'random_state': SEED, 'verbosity': -1, 'n_jobs': N_JOBS,
      'max_bin': MAX_BIN, 'force_col_wise': FORCE_COL_WISE, 'deterministic': DETERMINISTIC,
      'n_estimators': 200,
      'learning_rate': 0.08, 'num_leaves': 63, 'min_child_samples': 40}
if LGB_OBJECTIVE == 'huber':
    _p['alpha'] = 1.0
if GPU_SAN_SANG:
    _p.update({'device': 'gpu', 'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID})

def _fit_thu(params, Xa, ya, wa):
    """Fit tai cho, GPU loi thi lui ve CPU. Dinh nghia rieng vi fit_an_toan
    nam o buoc 11 (phia sau cell nay)."""
    try:
        m = LGBMRegressor(**params)
        m.fit(Xa, ya, sample_weight=wa)
        return m
    except Exception as e:
        if params.get('device') == 'gpu':
            print(f"   [CANH BAO] GPU loi, lui ve CPU: {str(e)[:80]}")
            p2 = {k: v for k, v in params.items()
                  if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
            m = LGBMRegressor(**p2)
            m.fit(Xa, ya, sample_weight=wa)
            return m
        raise


_t0_thu = time.time()
_m_thu = _fit_thu(_p, X_dev.loc[_idx], y_dev.loc[_idx], w_dev.loc[_idx])
print(f"Train thu {_n:,} dong x {len(FEATURES)} dac trung trong {time.time() - _t0_thu:.1f} giay")

# Du bao tren tap test, nhan nguoc mau chuan hoa va chan tran giong luc cham diem that
_te = val_h[(val_h['site_scale'] > 0) & (val_h['sin_elevation'] > EPS_ELEV)].copy()
_k = np.clip(_m_thu.predict(_te[FEATURES].fillna(MEDIANS).astype(DTYPE)), 0, 1.5)
_yp = np.minimum(_k * mau_chuan_hoa(_te), _te['tran_cong_suat'].to_numpy() * 1.02)
_te['y_pred'] = np.where(_te['sin_elevation'].to_numpy() <= EPS_ELEV, 0.0, _yp)
if 'nhan_is_daylight' in _te.columns:
    _te['is_daylight'] = _te['nhan_is_daylight']

_tre, _nd = do_tre_phut(_te, 'y_true', 'y_pred')
_wape = float(np.abs(_te['y_pred'] - _te['y_true']).sum() / np.abs(_te['y_true']).sum() * 100)
print(f"\nTREN {_nd:,} diem ban ngay cua tap test:")
print(f"   Do tre        : {_tre:+.2f} phut   (duong = du bao di SAU thuc te)")
print(f"   Nguong cho phep: +/- {NGUONG_TRE_PHUT:.1f} phut")
print(f"   WAPE tham khao : {_wape:.2f}%  (model nho, chua tune - chi de doi chieu)")

# Do theo tung site: 1 site tre nang cung la bug, khong duoc de con so tong the che mat
_rows_tre = []
for _s, _g in _te.groupby(SITE_COL, observed=True):
    _t1, _n1 = do_tre_phut(_g, 'y_true', 'y_pred')
    if _n1 >= 200:
        _rows_tre.append({'site_id': _s, 'tre_phut': round(_t1, 2), 'so_diem': _n1})
_bang_tre = pd.DataFrame(_rows_tre).sort_values('tre_phut', key=abs, ascending=False)
_qua = _bang_tre[_bang_tre['tre_phut'].abs() > NGUONG_TRE_PHUT]
print(f"\nSite vuot nguong: {len(_qua)}/{len(_bang_tre)}")
if len(_qua):
    display(_qua.head(15))
else:
    print("   Khong site nao vuot nguong.")
print(f"Tre theo site: trung vi {_bang_tre['tre_phut'].median():+.2f} phut | "
      f"nho nhat {_bang_tre['tre_phut'].min():+.2f} | lon nhat {_bang_tre['tre_phut'].max():+.2f}")

del _m_thu, _te, _k, _yp
gc.collect()

print()
print("=" * 74)
if not np.isfinite(_tre) or abs(_tre) > NGUONG_TRE_PHUT or len(_qua) > 0:
    print("CONG DO TRE: KHONG DAT")
    if abs(_tre) > NGUONG_TRE_PHUT:
        print(f"  - Tong the tre {_tre:+.2f} phut, vuot nguong {NGUONG_TRE_PHUT} phut")
    if len(_qua):
        print(f"  - Co {len(_qua)} site tre vuot nguong (tre local van la bug)")
    print("  Khong tune/train tiep. Sua nguyen nhan roi chay lai tu buoc gay ra no.")
    print("=" * 74)
    if DUNG_NEU_TRE:
        raise RuntimeError(f"Model thu nghiem con tre {_tre:+.2f} phut "
                           f"({len(_qua)} site vuot nguong) - dung, khong tune.")
else:
    print(f"CONG DO TRE: DAT - tre {_tre:+.2f} phut, khong site nao vuot nguong.")
    print("Cho phep chay Optuna va train that.")
    print("=" * 74)
# Out:
# ==========================================================================
# TRAIN THU NHANH DE DO TRE (truoc khi tune)
# ==========================================================================
# Train thu 300,000 dong x 54 dac trung trong 4.3 giay
#
# TREN 210,499 diem ban ngay cua tap test:
#    Do tre        : +2.17 phut   (duong = du bao di SAU thuc te)
#    Nguong cho phep: +/- 5.0 phut
#    WAPE tham khao : 21.62%  (model nho, chua tune - chi de doi chieu)
#
# Site vuot nguong: 0/40
#    Khong site nao vuot nguong.
# Tre theo site: trung vi +2.34 phut | nho nhat +1.47 | lon nhat +3.59
#
# ==========================================================================
# CONG DO TRE: DAT - tre +2.17 phut, khong site nao vuot nguong.
# Cho phep chay Optuna va train that.
# ==========================================================================

# %% [markdown]
# ## 11. Tune siêu tham số bằng Optuna trên 5 fold, loss Huber
#
# Dùng đúng **5 fold TimeSeriesSplit** do notebook 02 sinh ra, không dùng phép cắt 80/20 tạm bợ.
# Hàm mục tiêu là **pooled WAPE** — gộp toàn bộ residual của 5 fold rồi mới chia, thay vì lấy trung bình
# WAPE từng fold. Cách gộp này không để fold ít dòng có trọng lượng bằng fold nhiều dòng.
#
# **Sample weight áp cho cả 5 fold**, đúng chính sách `EXPERIMENT` ở trên. Nếu chỉ áp cho tập train cuối
# mà không áp cho fold thì Optuna sẽ chọn tham số trên dữ liệu có outlier rồi đem train trên dữ liệu không
# có — hai bài toán khác nhau, tham số chọn ra không còn đúng.
#
# Đặt `N_TRIALS = 0` ở cell tham số nếu muốn bỏ qua bước này.

# %%
CAC_FOLD = []
if N_TRIALS > 0:
    _n = 1
    while True:
        _tr = doc_fold(_n, 'train')
        _va = doc_fold(_n, 'val')
        if _tr is None or _va is None:
            break
        _med = _tr[FEATURES].median(numeric_only=True).fillna(0.0)
        CAC_FOLD.append({
            'fold': _n,
            'Xtr': _tr[FEATURES].fillna(_med).astype(DTYPE),
            'ytr': _tr['k_target'].astype(DTYPE),
            'wtr': _tr['w'].astype(DTYPE),
            'Xva': _va[FEATURES].fillna(_med).astype(DTYPE),
            'yva': _va['k_target'].astype(DTYPE),
            # danh gia tren thang do GOC (kWh), khong phai thang do chuan hoa
            'yva_kwh': _va['y_true'].to_numpy(),
            'mau_va': mau_chuan_hoa(_va),
            'tran_va': _va['tran_cong_suat'].to_numpy(),
            'sin_va': _va['sin_elevation'].to_numpy(),
        })
        print(f"- fold {_n}: train {len(_tr):,} dong, val {len(_va):,} dong (da ap weight)")
        del _tr, _va
        gc.collect()
        _n += 1

    if not CAC_FOLD:
        raise FileNotFoundError(
            f"Khong tim thay fold nao trong {FOLDS_DIR}. Hay chay lai notebook 02 den 05."
        )
    _tong_ram = sum(f['Xtr'].memory_usage(deep=True).sum() + f['Xva'].memory_usage(deep=True).sum()
                    for f in CAC_FOLD) / 1024**3
    print(f"\nDa nap {len(CAC_FOLD)} fold, chiem khoang {_tong_ram:.2f} GB RAM")
else:
    print("N_TRIALS = 0 nen bo qua nap fold.")

_t0 = time.time()


def tham_so_co_ban(trial=None):
    p = {'objective': LGB_OBJECTIVE, 'random_state': SEED, 'verbosity': -1,
         'n_jobs': N_JOBS, 'max_bin': MAX_BIN, 'force_col_wise': FORCE_COL_WISE,
         'deterministic': DETERMINISTIC}
    if trial is None:
        p.update({'n_estimators': 800, 'learning_rate': 0.05, 'num_leaves': 160,
                  'min_child_samples': 30, 'subsample': 0.9, 'colsample_bytree': 0.9})
        if LGB_OBJECTIVE == 'huber':
            p['alpha'] = 1.0
    else:
        p.update({
            'n_estimators': trial.suggest_int('n_estimators', 400, 1200),
            'learning_rate': trial.suggest_float('learning_rate', 0.02, 0.12, log=True),
            'num_leaves': trial.suggest_int('num_leaves', 63, 255),
            'min_child_samples': trial.suggest_int('min_child_samples', 20, 120),
            'subsample': trial.suggest_float('subsample', 0.7, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
            # alpha la delta cua Huber: cang lon thi cang gan MSE, cang nhay voi sai so lon
            # nen bat duoc dinh tot hon. Noi tran tu 5 len 20 cho THU NGHIEM 2.
            # alpha (delta cua Huber) chi co y nghia khi objective='huber'
            **({'alpha': trial.suggest_float('alpha', 0.5, 20.0, log=True)}
               if LGB_OBJECTIVE == 'huber' else {}),
        })
    if GPU_SAN_SANG:
        p.update({'device': 'gpu', 'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID})
    return p


def fit_an_toan(params, Xa, ya, wa=None, X_val=None, y_val=None, lich_su=None):
    """Fit, va dung som tren validation khi duoc cung cap."""
    fit_kwargs = {'sample_weight': wa}
    if X_val is not None and y_val is not None:
        callbacks = [early_stopping(EARLY_STOPPING_ROUNDS, first_metric_only=True, verbose=True),
                     log_evaluation(period=200)]
        if lich_su is not None:
            callbacks.insert(0, lgb.record_evaluation(lich_su))
        fit_kwargs.update({
            'eval_set': [(Xa, ya), (X_val, y_val)],
            'eval_names': ['train', 'val'],
            'eval_metric': 'l1',
            'callbacks': callbacks,
        })
    try:
        m = LGBMRegressor(**params)
        m.fit(Xa, ya, **fit_kwargs)
        return m
    except Exception as e:
        if params.get('device') == 'gpu':
            print(f"   [CANH BAO] GPU loi (lightgbm_cpu_after_gpu_retry): {str(e)[:90]}")
            p2 = {k: v for k, v in params.items()
                  if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
            p2['n_jobs'] = N_JOBS
            m = LGBMRegressor(**p2)
            m.fit(Xa, ya, **fit_kwargs)
            return m
        raise


def du_bao_kwh(model, f, so_cay=None):
    """Du bao roi nhan nguoc mau chuan hoa va chan tran, tra ve thang do kWh.

    so_cay: chi dung `so_cay` cay dau tien. De None thi dung het. Khi co early stopping
    phai truyen model.best_iteration_ vao, neu khong se cham diem bang ca nhung cay moc
    them sau diem dung - tuc bo phi ca cong dung som.
    """
    k = np.clip(model.predict(f['Xva'], num_iteration=so_cay), 0, 1.5)
    yp = np.minimum(k * f['mau_va'], f['tran_va'] * 1.02)
    return np.where(f['sin_va'] <= EPS_ELEV, 0.0, yp)


if N_TRIALS > 0:
    def objective(trial):
        params = tham_so_co_ban(trial)
        tong_sai_so = 0.0
        tong_thuc_te = 0.0
        _cay_tung_fold = []
        for f in CAC_FOLD:
            m = fit_an_toan(params, f['Xtr'], f['ytr'], f['wtr'], f['Xva'], f['yva'])
            _cay_tung_fold.append(int(m.best_iteration_ or params['n_estimators']))
            yp = du_bao_kwh(m, f, m.best_iteration_)
            tong_sai_so += float(np.abs(yp - f['yva_kwh']).sum())
            tong_thuc_te += float(np.abs(f['yva_kwh']).sum())
            del m
        trial.set_user_attr('so_cay_tung_fold', _cay_tung_fold)
        return tong_sai_so / tong_thuc_te * 100.0 if tong_thuc_te > 0 else np.nan

    def log_trial(study, trial):
        done = trial.number + 1
        el = (time.time() - _t0) / 60
        val = f"{trial.value:.4f}%" if trial.value is not None else "pruned"
        print(f"   [Trial {done:>2}/{N_TRIALS}] pooled WAPE {val:>10} | tot nhat {study.best_value:.4f}% "
              f"| da chay {el:.1f} phut, con khoang {el / done * (N_TRIALS - done):.1f} phut")

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=SEED))
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=False, callbacks=[log_trial])
    BEST_PARAMS = tham_so_co_ban()
    BEST_PARAMS.update(study.best_params)
    # So cay do EARLY STOPPING quyet dinh, khong lay tu de xuat cua Optuna: trung vi
    # best_iteration qua 5 fold. Dung trung vi thay vi trung binh de mot fold di thuong
    # (vi du fold 1 rat it du lieu) khong keo lech.
    _cay_es = study.best_trial.user_attrs.get('so_cay_tung_fold')
    if _cay_es:
        BEST_PARAMS['n_estimators'] = int(np.median(_cay_es))
        print(f"So cay tung fold (early stopping): {_cay_es}")
        print(f"-> n_estimators = {BEST_PARAMS['n_estimators']} (trung vi)")
    POOLED_WAPE_CV = float(study.best_value)
    print(f"\nPooled WAPE tot nhat tren {len(CAC_FOLD)} fold = {POOLED_WAPE_CV:.4f}%")
    del CAC_FOLD
    gc.collect()
else:
    BEST_PARAMS = tham_so_co_ban()
    POOLED_WAPE_CV = None
    print("N_TRIALS = 0 nen bo qua Optuna, dung tham so mac dinh.")

for _k, _v in BEST_PARAMS.items():
    print(f"   {_k}: {_v}")
# Out:
# - fold 1: train 62,807 dong, val 89,583 dong (da ap weight)
# - fold 2: train 152,402 dong, val 172,458 dong (da ap weight)
# - fold 3: train 324,860 dong, val 194,132 dong (da ap weight)
# - fold 4: train 519,027 dong, val 159,314 dong (da ap weight)
# - fold 5: train 678,341 dong, val 210,579 dong (da ap weight)
#
# Da nap 5 fold, chiem khoang 0.53 GB RAM
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	train's l1: 0.0951136	train's huber: 0.0094783	val's l1: 0.200999	val's huber: 0.0317748
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	train's l1: 0.114853	train's huber: 0.0127803	val's l1: 0.151628	val's huber: 0.0204472
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0800003	train's huber: 0.00682027	val's l1: 0.130035	val's huber: 0.0166582
# Early stopping, best iteration is:
# [212]	train's l1: 0.0787664	train's huber: 0.00662809	val's l1: 0.129983	val's huber: 0.016657
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0826703	train's huber: 0.00727967	val's l1: 0.163005	val's huber: 0.0238554
# Early stopping, best iteration is:
# [274]	train's l1: 0.0760051	train's huber: 0.00627275	val's l1: 0.162771	val's huber: 0.0238801
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	train's l1: 0.119429	train's huber: 0.013815	val's l1: 0.144432	val's huber: 0.0198744
# Evaluated only: l1
#    [Trial  1/20] pooled WAPE   22.9402% | tot nhat 22.9402% | da chay 0.5 phut, con khoang 10.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0949513	train's huber: 0.00954968	val's l1: 0.200754	val's huber: 0.031622
# Early stopping, best iteration is:
# [239]	train's l1: 0.0897302	train's huber: 0.00875315	val's l1: 0.19974	val's huber: 0.0314452
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119533	train's huber: 0.0136292	val's l1: 0.152502	val's huber: 0.0206386
# [400]	train's l1: 0.0977471	train's huber: 0.00964891	val's l1: 0.150852	val's huber: 0.0203362
# Early stopping, best iteration is:
# [329]	train's l1: 0.104304	train's huber: 0.0108332	val's l1: 0.150662	val's huber: 0.0203306
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118665	train's huber: 0.0134442	val's l1: 0.13223	val's huber: 0.0168593
# [400]	train's l1: 0.0985083	train's huber: 0.00988274	val's l1: 0.129206	val's huber: 0.0164319
# [600]	train's l1: 0.0877975	train's huber: 0.00809847	val's l1: 0.128888	val's huber: 0.0163778
# [800]	train's l1: 0.0809166	train's huber: 0.00702681	val's l1: 0.128499	val's huber: 0.0163082
# Did not meet early stopping. Best iteration is:
# [959]	train's l1: 0.0766792	train's huber: 0.00639717	val's l1: 0.128392	val's huber: 0.0162963
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117687	train's huber: 0.0133876	val's l1: 0.166224	val's huber: 0.0238579
# [400]	train's l1: 0.0993107	train's huber: 0.0100673	val's l1: 0.161785	val's huber: 0.0232705
# [600]	train's l1: 0.0897321	train's huber: 0.00841531	val's l1: 0.160785	val's huber: 0.0231726
# [800]	train's l1: 0.0828449	train's huber: 0.00733118	val's l1: 0.160494	val's huber: 0.0231771
# Did not meet early stopping. Best iteration is:
# [895]	train's l1: 0.0803566	train's huber: 0.00695851	val's l1: 0.160362	val's huber: 0.023166
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126865	train's huber: 0.0151888	val's l1: 0.145467	val's huber: 0.0198646
# [400]	train's l1: 0.108378	train's huber: 0.0115844	val's l1: 0.143105	val's huber: 0.0196628
# [600]	train's l1: 0.0991667	train's huber: 0.00991053	val's l1: 0.142999	val's huber: 0.019675
# Early stopping, best iteration is:
# [507]	train's l1: 0.102951	train's huber: 0.0105756	val's l1: 0.142858	val's huber: 0.0196264
# Evaluated only: l1
#    [Trial  2/20] pooled WAPE   22.7803% | tot nhat 22.7803% | da chay 2.6 phut, con khoang 23.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0872615	train's huber: 0.00816333	val's l1: 0.202439	val's huber: 0.0319438
# Early stopping, best iteration is:
# [242]	train's l1: 0.0826243	train's huber: 0.00736237	val's l1: 0.201832	val's huber: 0.0319524
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.11235	train's huber: 0.012329	val's l1: 0.149983	val's huber: 0.0200579
# Early stopping, best iteration is:
# [278]	train's l1: 0.102681	train's huber: 0.010462	val's l1: 0.149575	val's huber: 0.0199651
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110829	train's huber: 0.0121018	val's l1: 0.130504	val's huber: 0.0166189
# [400]	train's l1: 0.0939293	train's huber: 0.00902815	val's l1: 0.129273	val's huber: 0.0164174
# [600]	train's l1: 0.0843215	train's huber: 0.00747122	val's l1: 0.128762	val's huber: 0.0163321
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.0796012	train's huber: 0.00674193	val's l1: 0.128555	val's huber: 0.0163057
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110578	train's huber: 0.0121322	val's l1: 0.163615	val's huber: 0.0235396
# [400]	train's l1: 0.0950551	train's huber: 0.0092723	val's l1: 0.161192	val's huber: 0.0232512
# [600]	train's l1: 0.0862354	train's huber: 0.00782286	val's l1: 0.160766	val's huber: 0.0232434
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.0817069	train's huber: 0.00711244	val's l1: 0.160615	val's huber: 0.0232522
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119263	train's huber: 0.0137288	val's l1: 0.144044	val's huber: 0.0197774
# [400]	train's l1: 0.104396	train's huber: 0.010803	val's l1: 0.143673	val's huber: 0.0197543
# Early stopping, best iteration is:
# [486]	train's l1: 0.100157	train's huber: 0.0100421	val's l1: 0.143518	val's huber: 0.0197544
# Evaluated only: l1
#    [Trial  3/20] pooled WAPE   22.7747% | tot nhat 22.7747% | da chay 4.1 phut, con khoang 23.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0969725	train's huber: 0.0100041	val's l1: 0.192572	val's huber: 0.0302909
# Early stopping, best iteration is:
# [235]	train's l1: 0.0942025	train's huber: 0.00947528	val's l1: 0.192224	val's huber: 0.0302934
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119258	train's huber: 0.0137842	val's l1: 0.148289	val's huber: 0.0196345
# [400]	train's l1: 0.104856	train's huber: 0.0109803	val's l1: 0.147824	val's huber: 0.019608
# Early stopping, best iteration is:
# [369]	train's l1: 0.106589	train's huber: 0.0113058	val's l1: 0.147544	val's huber: 0.0195555
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.11803	train's huber: 0.0135496	val's l1: 0.131237	val's huber: 0.0166845
# [400]	train's l1: 0.10418	train's huber: 0.0108773	val's l1: 0.12942	val's huber: 0.0163748
# [600]	train's l1: 0.0959286	train's huber: 0.00941758	val's l1: 0.128771	val's huber: 0.0162735
# [800]	train's l1: 0.089889	train's huber: 0.00841917	val's l1: 0.128527	val's huber: 0.0162446
# Did not meet early stopping. Best iteration is:
# [754]	train's l1: 0.0911314	train's huber: 0.00861748	val's l1: 0.128503	val's huber: 0.016237
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.116462	train's huber: 0.0133068	val's l1: 0.163996	val's huber: 0.0235514
# [400]	train's l1: 0.104154	train's huber: 0.0109489	val's l1: 0.161862	val's huber: 0.0232847
# [600]	train's l1: 0.096732	train's huber: 0.00960953	val's l1: 0.160881	val's huber: 0.0231582
# [800]	train's l1: 0.0912213	train's huber: 0.00865688	val's l1: 0.160858	val's huber: 0.0231989
# Early stopping, best iteration is:
# [707]	train's l1: 0.0935927	train's huber: 0.00907009	val's l1: 0.160789	val's huber: 0.0231765
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124823	train's huber: 0.0149113	val's l1: 0.145541	val's huber: 0.0198407
# [400]	train's l1: 0.11313	train's huber: 0.0125491	val's l1: 0.144641	val's huber: 0.0197643
# Early stopping, best iteration is:
# [392]	train's l1: 0.113521	train's huber: 0.0126305	val's l1: 0.144601	val's huber: 0.0197536
# Evaluated only: l1
#    [Trial  4/20] pooled WAPE   22.5669% | tot nhat 22.5669% | da chay 5.1 phut, con khoang 20.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0912727	train's huber: 0.00878711	val's l1: 0.20019	val's huber: 0.0314879
# Early stopping, best iteration is:
# [171]	train's l1: 0.0961708	train's huber: 0.00954618	val's l1: 0.199654	val's huber: 0.0313175
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118894	train's huber: 0.0135376	val's l1: 0.150764	val's huber: 0.0202346
# [400]	train's l1: 0.0982577	train's huber: 0.00965835	val's l1: 0.149762	val's huber: 0.0200053
# Early stopping, best iteration is:
# [319]	train's l1: 0.104951	train's huber: 0.0108745	val's l1: 0.149717	val's huber: 0.0200091
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.11855	train's huber: 0.0135445	val's l1: 0.131277	val's huber: 0.0167891
# [400]	train's l1: 0.100065	train's huber: 0.0100857	val's l1: 0.129606	val's huber: 0.0164788
# [600]	train's l1: 0.0904017	train's huber: 0.00847484	val's l1: 0.129408	val's huber: 0.0164247
# Did not meet early stopping. Best iteration is:
# [578]	train's l1: 0.0912442	train's huber: 0.00860927	val's l1: 0.129365	val's huber: 0.0164121
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117402	train's huber: 0.013423	val's l1: 0.165576	val's huber: 0.023768
# [400]	train's l1: 0.100633	train's huber: 0.0102558	val's l1: 0.16177	val's huber: 0.0232217
# [600]	train's l1: 0.0916884	train's huber: 0.00869767	val's l1: 0.160707	val's huber: 0.0231077
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.0901123	train's huber: 0.00843269	val's l1: 0.160616	val's huber: 0.023103
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126503	train's huber: 0.0152261	val's l1: 0.144938	val's huber: 0.0198462
# [400]	train's l1: 0.110118	train's huber: 0.0118787	val's l1: 0.143557	val's huber: 0.0196923
# [600]	train's l1: 0.101243	train's huber: 0.0102275	val's l1: 0.143425	val's huber: 0.0197044
# Early stopping, best iteration is:
# [528]	train's l1: 0.1043	train's huber: 0.010783	val's l1: 0.14341	val's huber: 0.0196906
# Evaluated only: l1
#    [Trial  5/20] pooled WAPE   22.7478% | tot nhat 22.5669% | da chay 6.6 phut, con khoang 19.9 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0930302	train's huber: 0.00932647	val's l1: 0.199104	val's huber: 0.0315851
# [400]	train's l1: 0.0774911	train's huber: 0.00655793	val's l1: 0.198423	val's huber: 0.0317154
# Early stopping, best iteration is:
# [341]	train's l1: 0.0808166	train's huber: 0.0071125	val's l1: 0.197903	val's huber: 0.0315502
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.114732	train's huber: 0.0128957	val's l1: 0.150433	val's huber: 0.0202272
# Early stopping, best iteration is:
# [297]	train's l1: 0.103812	train's huber: 0.0107602	val's l1: 0.149734	val's huber: 0.0201305
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.113018	train's huber: 0.0126115	val's l1: 0.129989	val's huber: 0.0165707
# [400]	train's l1: 0.0962309	train's huber: 0.00947738	val's l1: 0.128889	val's huber: 0.016367
# [600]	train's l1: 0.0873303	train's huber: 0.00799948	val's l1: 0.128259	val's huber: 0.0162336
# Early stopping, best iteration is:
# [646]	train's l1: 0.0858551	train's huber: 0.00776651	val's l1: 0.128155	val's huber: 0.0162247
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.11163	train's huber: 0.0123779	val's l1: 0.164064	val's huber: 0.0236746
# [400]	train's l1: 0.0969454	train's huber: 0.00964989	val's l1: 0.161703	val's huber: 0.0234041
# [600]	train's l1: 0.0885999	train's huber: 0.00824801	val's l1: 0.161269	val's huber: 0.023414
# Early stopping, best iteration is:
# [551]	train's l1: 0.0903668	train's huber: 0.0085357	val's l1: 0.161188	val's huber: 0.0233662
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.120443	train's huber: 0.014042	val's l1: 0.144376	val's huber: 0.0198866
# [400]	train's l1: 0.106252	train's huber: 0.0112081	val's l1: 0.14392	val's huber: 0.0198675
# Early stopping, best iteration is:
# [419]	train's l1: 0.105353	train's huber: 0.0110482	val's l1: 0.143867	val's huber: 0.0198703
# Evaluated only: l1
#    [Trial  6/20] pooled WAPE   22.6844% | tot nhat 22.5669% | da chay 8.3 phut, con khoang 19.3 phut
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	train's l1: 0.108854	train's huber: 0.0121883	val's l1: 0.198388	val's huber: 0.0310638
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [84]	train's l1: 0.122241	train's huber: 0.0143008	val's l1: 0.148862	val's huber: 0.019769
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.103268	train's huber: 0.0106556	val's l1: 0.129639	val's huber: 0.0162961
# [400]	train's l1: 0.0872968	train's huber: 0.00787921	val's l1: 0.128935	val's huber: 0.0162369
# [600]	train's l1: 0.0785246	train's huber: 0.00650503	val's l1: 0.128855	val's huber: 0.0162727
# Early stopping, best iteration is:
# [507]	train's l1: 0.0822347	train's huber: 0.00707803	val's l1: 0.128708	val's huber: 0.0162312
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.103265	train's huber: 0.0106987	val's l1: 0.162812	val's huber: 0.0236515
# [400]	train's l1: 0.0894679	train's huber: 0.00828732	val's l1: 0.161768	val's huber: 0.0235284
# Early stopping, best iteration is:
# [339]	train's l1: 0.0930107	train's huber: 0.00888276	val's l1: 0.161689	val's huber: 0.0234937
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112219	train's huber: 0.0122464	val's l1: 0.145695	val's huber: 0.0200039
# Early stopping, best iteration is:
# [276]	train's l1: 0.105639	train's huber: 0.0109912	val's l1: 0.145451	val's huber: 0.0200074
# Evaluated only: l1
#    [Trial  7/20] pooled WAPE   22.7139% | tot nhat 22.5669% | da chay 8.9 phut, con khoang 16.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0957004	train's huber: 0.00980858	val's l1: 0.202091	val's huber: 0.0315422
# [400]	train's l1: 0.0806392	train's huber: 0.00711435	val's l1: 0.200949	val's huber: 0.031485
# Early stopping, best iteration is:
# [416]	train's l1: 0.0798399	train's huber: 0.00698231	val's l1: 0.200718	val's huber: 0.0314438
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117032	train's huber: 0.0133258	val's l1: 0.149548	val's huber: 0.0199997
# [400]	train's l1: 0.0988128	train's huber: 0.00984987	val's l1: 0.148644	val's huber: 0.0198433
# [600]	train's l1: 0.0899953	train's huber: 0.00831365	val's l1: 0.148504	val's huber: 0.0198361
# Did not meet early stopping. Best iteration is:
# [680]	train's l1: 0.0873223	train's huber: 0.00787472	val's l1: 0.148349	val's huber: 0.019824
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.114597	train's huber: 0.012893	val's l1: 0.130058	val's huber: 0.0165138
# [400]	train's l1: 0.0982634	train's huber: 0.00983996	val's l1: 0.128339	val's huber: 0.0162065
# [600]	train's l1: 0.0893719	train's huber: 0.00834414	val's l1: 0.127597	val's huber: 0.0160892
# Did not meet early stopping. Best iteration is:
# [678]	train's l1: 0.0868573	train's huber: 0.00794052	val's l1: 0.127398	val's huber: 0.0160623
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.113043	train's huber: 0.0126714	val's l1: 0.164151	val's huber: 0.0235764
# [400]	train's l1: 0.0984269	train's huber: 0.00991168	val's l1: 0.161453	val's huber: 0.0232263
# [600]	train's l1: 0.0897562	train's huber: 0.00842856	val's l1: 0.16089	val's huber: 0.0232179
# Did not meet early stopping. Best iteration is:
# [660]	train's l1: 0.0878937	train's huber: 0.00812702	val's l1: 0.160733	val's huber: 0.0232149
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.121633	train's huber: 0.0142642	val's l1: 0.144002	val's huber: 0.0196985
# [400]	train's l1: 0.107177	train's huber: 0.011371	val's l1: 0.143446	val's huber: 0.0196514
# Early stopping, best iteration is:
# [307]	train's l1: 0.112626	train's huber: 0.0124249	val's l1: 0.143349	val's huber: 0.0196103
# Evaluated only: l1
#    [Trial  8/20] pooled WAPE   22.6247% | tot nhat 22.5669% | da chay 10.3 phut, con khoang 15.5 phut
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	train's l1: 0.0917651	train's huber: 0.00908073	val's l1: 0.199413	val's huber: 0.0312898
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0851701	train's huber: 0.00746944	val's l1: 0.150598	val's huber: 0.0202866
# Early stopping, best iteration is:
# [117]	train's l1: 0.0993996	train's huber: 0.00992091	val's l1: 0.149815	val's huber: 0.0200966
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.087117	train's huber: 0.00796502	val's l1: 0.130347	val's huber: 0.0165989
# Early stopping, best iteration is:
# [271]	train's l1: 0.080092	train's huber: 0.00683256	val's l1: 0.130037	val's huber: 0.0165653
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0876362	train's huber: 0.00808506	val's l1: 0.161771	val's huber: 0.0235045
# Early stopping, best iteration is:
# [211]	train's l1: 0.0865639	train's huber: 0.00791245	val's l1: 0.161684	val's huber: 0.0234971
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0972606	train's huber: 0.00954981	val's l1: 0.144609	val's huber: 0.0199718
# Early stopping, best iteration is:
# [137]	train's l1: 0.105948	train's huber: 0.0111034	val's l1: 0.144205	val's huber: 0.0198523
# Evaluated only: l1
#    [Trial  9/20] pooled WAPE   22.8034% | tot nhat 22.5669% | da chay 11.0 phut, con khoang 13.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.102867	train's huber: 0.0111278	val's l1: 0.196844	val's huber: 0.0308634
# Early stopping, best iteration is:
# [269]	train's l1: 0.0971532	train's huber: 0.00999514	val's l1: 0.196443	val's huber: 0.030981
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.127788	train's huber: 0.0155495	val's l1: 0.149499	val's huber: 0.0198913
# [400]	train's l1: 0.111752	train's huber: 0.0122392	val's l1: 0.148023	val's huber: 0.0196821
# Early stopping, best iteration is:
# [451]	train's l1: 0.109244	train's huber: 0.0117492	val's l1: 0.147759	val's huber: 0.0196435
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.125084	train's huber: 0.0149736	val's l1: 0.132237	val's huber: 0.016828
# [400]	train's l1: 0.111911	train's huber: 0.012347	val's l1: 0.130296	val's huber: 0.0165208
# [600]	train's l1: 0.103143	train's huber: 0.0106759	val's l1: 0.12919	val's huber: 0.0163302
# [800]	train's l1: 0.0971927	train's huber: 0.00960727	val's l1: 0.12866	val's huber: 0.0162425
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.0945822	train's huber: 0.00917099	val's l1: 0.128449	val's huber: 0.0162069
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.123273	train's huber: 0.0146753	val's l1: 0.166117	val's huber: 0.023936
# [400]	train's l1: 0.11105	train's huber: 0.0122412	val's l1: 0.162496	val's huber: 0.0233524
# [600]	train's l1: 0.103563	train's huber: 0.0107952	val's l1: 0.161301	val's huber: 0.0232247
# [800]	train's l1: 0.0977991	train's huber: 0.00973608	val's l1: 0.160841	val's huber: 0.0231911
# Did not meet early stopping. Best iteration is:
# [854]	train's l1: 0.0964383	train's huber: 0.00948916	val's l1: 0.160711	val's huber: 0.023169
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.130939	train's huber: 0.0162262	val's l1: 0.146188	val's huber: 0.0199982
# [400]	train's l1: 0.119429	train's huber: 0.0137592	val's l1: 0.144717	val's huber: 0.0198038
# [600]	train's l1: 0.112397	train's huber: 0.0123543	val's l1: 0.144605	val's huber: 0.019815
# Early stopping, best iteration is:
# [551]	train's l1: 0.113969	train's huber: 0.0126616	val's l1: 0.144515	val's huber: 0.0197954
# Evaluated only: l1
#    [Trial 10/20] pooled WAPE   22.6356% | tot nhat 22.5669% | da chay 12.4 phut, con khoang 12.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0871594	train's huber: 0.0082451	val's l1: 0.195992	val's huber: 0.0308416
# Early stopping, best iteration is:
# [270]	train's l1: 0.0815321	train's huber: 0.00725064	val's l1: 0.195758	val's huber: 0.0308043
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.107054	train's huber: 0.0113978	val's l1: 0.150174	val's huber: 0.0200631
# Early stopping, best iteration is:
# [246]	train's l1: 0.102368	train's huber: 0.0105166	val's l1: 0.149715	val's huber: 0.0199798
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.10611	train's huber: 0.0112659	val's l1: 0.129648	val's huber: 0.0164688
# [400]	train's l1: 0.0913401	train's huber: 0.00866164	val's l1: 0.128638	val's huber: 0.0163091
# Early stopping, best iteration is:
# [402]	train's l1: 0.0912516	train's huber: 0.00864593	val's l1: 0.128615	val's huber: 0.0163061
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.105566	train's huber: 0.0112183	val's l1: 0.162278	val's huber: 0.0234385
# [400]	train's l1: 0.0919823	train's huber: 0.0088046	val's l1: 0.16146	val's huber: 0.0234364
# [600]	train's l1: 0.0841038	train's huber: 0.00752132	val's l1: 0.161296	val's huber: 0.023475
# Early stopping, best iteration is:
# [559]	train's l1: 0.0855892	train's huber: 0.00775768	val's l1: 0.161241	val's huber: 0.0234448
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.11484	train's huber: 0.0128929	val's l1: 0.144499	val's huber: 0.0198686
# Early stopping, best iteration is:
# [237]	train's l1: 0.111713	train's huber: 0.0122945	val's l1: 0.144251	val's huber: 0.019845
# Evaluated only: l1
#    [Trial 11/20] pooled WAPE   22.6683% | tot nhat 22.5669% | da chay 13.3 phut, con khoang 10.9 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.086764	train's huber: 0.00816043	val's l1: 0.199072	val's huber: 0.0311058
# Early stopping, best iteration is:
# [100]	train's l1: 0.101225	train's huber: 0.0108667	val's l1: 0.198829	val's huber: 0.0306793
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.107205	train's huber: 0.0114169	val's l1: 0.148844	val's huber: 0.0197602
# Early stopping, best iteration is:
# [271]	train's l1: 0.100238	train's huber: 0.0101378	val's l1: 0.148464	val's huber: 0.01972
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.106139	train's huber: 0.011202	val's l1: 0.129505	val's huber: 0.0163142
# [400]	train's l1: 0.0914	train's huber: 0.00865575	val's l1: 0.128196	val's huber: 0.0161042
# Did not meet early stopping. Best iteration is:
# [472]	train's l1: 0.087896	train's huber: 0.00809426	val's l1: 0.12804	val's huber: 0.0160723
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.105652	train's huber: 0.011217	val's l1: 0.161545	val's huber: 0.0229497
# [400]	train's l1: 0.091842	train's huber: 0.00877613	val's l1: 0.159994	val's huber: 0.0227413
# Did not meet early stopping. Best iteration is:
# [519]	train's l1: 0.0870334	train's huber: 0.00799229	val's l1: 0.159819	val's huber: 0.0227588
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.114379	train's huber: 0.0127706	val's l1: 0.144124	val's huber: 0.0196104
# Early stopping, best iteration is:
# [262]	train's l1: 0.10935	train's huber: 0.0118	val's l1: 0.143817	val's huber: 0.0195704
# Evaluated only: l1
#    [Trial 12/20] pooled WAPE   22.6384% | tot nhat 22.5669% | da chay 14.2 phut, con khoang 9.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0891736	train's huber: 0.00855536	val's l1: 0.203871	val's huber: 0.0322329
# Early stopping, best iteration is:
# [298]	train's l1: 0.0813252	train's huber: 0.00718445	val's l1: 0.203586	val's huber: 0.0322431
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.111254	train's huber: 0.0121591	val's l1: 0.149354	val's huber: 0.0198356
# Early stopping, best iteration is:
# [208]	train's l1: 0.110273	train's huber: 0.011959	val's l1: 0.149343	val's huber: 0.0198413
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110638	train's huber: 0.0120955	val's l1: 0.130001	val's huber: 0.0165204
# [400]	train's l1: 0.0955614	train's huber: 0.00934224	val's l1: 0.128865	val's huber: 0.0163247
# [600]	train's l1: 0.086752	train's huber: 0.00788	val's l1: 0.128512	val's huber: 0.0162799
# Early stopping, best iteration is:
# [638]	train's l1: 0.0854779	train's huber: 0.00767669	val's l1: 0.128397	val's huber: 0.0162538
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110069	train's huber: 0.0120414	val's l1: 0.162752	val's huber: 0.023415
# [400]	train's l1: 0.0960511	train's huber: 0.00946383	val's l1: 0.160886	val's huber: 0.023206
# [600]	train's l1: 0.0880753	train's huber: 0.00813038	val's l1: 0.160675	val's huber: 0.0232611
# Did not meet early stopping. Best iteration is:
# [784]	train's l1: 0.0827351	train's huber: 0.00729006	val's l1: 0.160466	val's huber: 0.0232651
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118178	train's huber: 0.0135095	val's l1: 0.144473	val's huber: 0.0198387
# [400]	train's l1: 0.104666	train's huber: 0.0108751	val's l1: 0.143897	val's huber: 0.0198269
# Early stopping, best iteration is:
# [378]	train's l1: 0.105902	train's huber: 0.0110977	val's l1: 0.143827	val's huber: 0.0198058
# Evaluated only: l1
#    [Trial 13/20] pooled WAPE   22.7481% | tot nhat 22.5669% | da chay 15.3 phut, con khoang 8.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0812756	train's huber: 0.007202	val's l1: 0.206774	val's huber: 0.0326737
# [400]	train's l1: 0.0672455	train's huber: 0.00504606	val's l1: 0.206519	val's huber: 0.0328034
# Early stopping, best iteration is:
# [324]	train's l1: 0.0711478	train's huber: 0.00561409	val's l1: 0.205891	val's huber: 0.0326161
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.100693	train's huber: 0.0101423	val's l1: 0.151534	val's huber: 0.0203624
# [400]	train's l1: 0.0835849	train's huber: 0.00722956	val's l1: 0.150949	val's huber: 0.0202566
# Early stopping, best iteration is:
# [477]	train's l1: 0.0798991	train's huber: 0.00665878	val's l1: 0.150763	val's huber: 0.0202337
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0995012	train's huber: 0.0100441	val's l1: 0.129522	val's huber: 0.0165242
# [400]	train's l1: 0.0832069	train's huber: 0.0073245	val's l1: 0.128554	val's huber: 0.0163581
# Did not meet early stopping. Best iteration is:
# [550]	train's l1: 0.0768331	train's huber: 0.00635091	val's l1: 0.128268	val's huber: 0.0163166
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0993914	train's huber: 0.0100503	val's l1: 0.162054	val's huber: 0.0233521
# [400]	train's l1: 0.0843193	train's huber: 0.00755356	val's l1: 0.160791	val's huber: 0.0232717
# Did not meet early stopping. Best iteration is:
# [583]	train's l1: 0.0766998	train's huber: 0.00640804	val's l1: 0.160625	val's huber: 0.0232974
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.108427	train's huber: 0.0116042	val's l1: 0.143202	val's huber: 0.0196415
# Early stopping, best iteration is:
# [239]	train's l1: 0.104444	train's huber: 0.0108655	val's l1: 0.142888	val's huber: 0.0196007
# Evaluated only: l1
#    [Trial 14/20] pooled WAPE   22.8220% | tot nhat 22.5669% | da chay 16.7 phut, con khoang 7.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0810369	train's huber: 0.00721717	val's l1: 0.201764	val's huber: 0.0319856
# Early stopping, best iteration is:
# [113]	train's l1: 0.0925161	train's huber: 0.00930987	val's l1: 0.20127	val's huber: 0.0318017
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.097726	train's huber: 0.00966506	val's l1: 0.150852	val's huber: 0.0202903
# Early stopping, best iteration is:
# [169]	train's l1: 0.101582	train's huber: 0.0103746	val's l1: 0.150574	val's huber: 0.0202422
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0966939	train's huber: 0.00957956	val's l1: 0.130048	val's huber: 0.0165011
# [400]	train's l1: 0.0826584	train's huber: 0.00727228	val's l1: 0.129518	val's huber: 0.0164343
# Early stopping, best iteration is:
# [324]	train's l1: 0.0869028	train's huber: 0.007954	val's l1: 0.12945	val's huber: 0.0163887
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.096683	train's huber: 0.00959472	val's l1: 0.162395	val's huber: 0.0236375
# [400]	train's l1: 0.0833278	train's huber: 0.00741472	val's l1: 0.161963	val's huber: 0.0236481
# Early stopping, best iteration is:
# [357]	train's l1: 0.0855043	train's huber: 0.00775629	val's l1: 0.161811	val's huber: 0.0236009
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.106027	train's huber: 0.0111802	val's l1: 0.145033	val's huber: 0.0200667
# Early stopping, best iteration is:
# [111]	train's l1: 0.117789	train's huber: 0.0135002	val's l1: 0.144554	val's huber: 0.0199102
# Evaluated only: l1
#    [Trial 15/20] pooled WAPE   22.8686% | tot nhat 22.5669% | da chay 17.4 phut, con khoang 5.8 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.111287	train's huber: 0.0127854	val's l1: 0.197206	val's huber: 0.0305569
# [400]	train's l1: 0.0985643	train's huber: 0.0102601	val's l1: 0.195143	val's huber: 0.0305387
# [600]	train's l1: 0.0912093	train's huber: 0.00888526	val's l1: 0.194897	val's huber: 0.0306533
# Early stopping, best iteration is:
# [663]	train's l1: 0.0894328	train's huber: 0.00857365	val's l1: 0.19469	val's huber: 0.0306221
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.137587	train's huber: 0.0176267	val's l1: 0.151262	val's huber: 0.0200846
# [400]	train's l1: 0.122226	train's huber: 0.0143743	val's l1: 0.147905	val's huber: 0.0195207
# [600]	train's l1: 0.113384	train's huber: 0.0125813	val's l1: 0.146886	val's huber: 0.0193774
# Did not meet early stopping. Best iteration is:
# [777]	train's l1: 0.107765	train's huber: 0.0114979	val's l1: 0.146629	val's huber: 0.0193398
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133872	train's huber: 0.0167275	val's l1: 0.134929	val's huber: 0.0172538
# [400]	train's l1: 0.121059	train's huber: 0.0141524	val's l1: 0.131527	val's huber: 0.0166199
# [600]	train's l1: 0.113416	train's huber: 0.0126309	val's l1: 0.130033	val's huber: 0.016382
# Did not meet early stopping. Best iteration is:
# [789]	train's l1: 0.107869	train's huber: 0.0115665	val's l1: 0.129252	val's huber: 0.0162546
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.131022	train's huber: 0.0162249	val's l1: 0.168915	val's huber: 0.0243117
# [400]	train's l1: 0.119174	train's huber: 0.0138597	val's l1: 0.163858	val's huber: 0.0234539
# [600]	train's l1: 0.11252	train's huber: 0.0125629	val's l1: 0.16179	val's huber: 0.023139
# Did not meet early stopping. Best iteration is:
# [790]	train's l1: 0.10761	train's huber: 0.0116097	val's l1: 0.160968	val's huber: 0.0230401
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138379	train's huber: 0.0177472	val's l1: 0.148495	val's huber: 0.0203086
# [400]	train's l1: 0.127139	train's huber: 0.0154509	val's l1: 0.145141	val's huber: 0.0197849
# [600]	train's l1: 0.120886	train's huber: 0.0141148	val's l1: 0.144545	val's huber: 0.0197085
# Did not meet early stopping. Best iteration is:
# [790]	train's l1: 0.116213	train's huber: 0.0131665	val's l1: 0.144213	val's huber: 0.0196916
# Evaluated only: l1
#    [Trial 16/20] pooled WAPE   22.5922% | tot nhat 22.5669% | da chay 18.7 phut, con khoang 4.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.1117	train's huber: 0.0128899	val's l1: 0.19765	val's huber: 0.0309164
# [400]	train's l1: 0.0988399	train's huber: 0.0103218	val's l1: 0.19538	val's huber: 0.0310099
# Early stopping, best iteration is:
# [340]	train's l1: 0.101634	train's huber: 0.0108725	val's l1: 0.194949	val's huber: 0.030818
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138549	train's huber: 0.0178447	val's l1: 0.150928	val's huber: 0.0201444
# [400]	train's l1: 0.123018	train's huber: 0.0145259	val's l1: 0.147565	val's huber: 0.0194887
# [600]	train's l1: 0.114035	train's huber: 0.0127133	val's l1: 0.146671	val's huber: 0.0193504
# [800]	train's l1: 0.107953	train's huber: 0.0115376	val's l1: 0.146474	val's huber: 0.0193374
# Early stopping, best iteration is:
# [801]	train's l1: 0.107923	train's huber: 0.0115318	val's l1: 0.146464	val's huber: 0.0193366
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.134341	train's huber: 0.0168056	val's l1: 0.13516	val's huber: 0.017245
# [400]	train's l1: 0.121412	train's huber: 0.0142256	val's l1: 0.131734	val's huber: 0.0166268
# [600]	train's l1: 0.113861	train's huber: 0.0127284	val's l1: 0.13037	val's huber: 0.0164129
# [800]	train's l1: 0.107904	train's huber: 0.011553	val's l1: 0.129622	val's huber: 0.0162947
# [1000]	train's l1: 0.103073	train's huber: 0.0106658	val's l1: 0.129144	val's huber: 0.0162091
# Did not meet early stopping. Best iteration is:
# [1020]	train's l1: 0.102631	train's huber: 0.0105885	val's l1: 0.129095	val's huber: 0.0161985
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.131558	train's huber: 0.016334	val's l1: 0.168497	val's huber: 0.0242463
# [400]	train's l1: 0.119583	train's huber: 0.013942	val's l1: 0.163798	val's huber: 0.023451
# [600]	train's l1: 0.112732	train's huber: 0.012579	val's l1: 0.161867	val's huber: 0.0231347
# [800]	train's l1: 0.107601	train's huber: 0.0115917	val's l1: 0.16095	val's huber: 0.0230333
# [1000]	train's l1: 0.103345	train's huber: 0.0107884	val's l1: 0.160602	val's huber: 0.0230075
# Did not meet early stopping. Best iteration is:
# [1015]	train's l1: 0.103073	train's huber: 0.0107405	val's l1: 0.160563	val's huber: 0.0230018
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138806	train's huber: 0.0178444	val's l1: 0.148952	val's huber: 0.0204628
# [400]	train's l1: 0.127492	train's huber: 0.0154986	val's l1: 0.145704	val's huber: 0.0199304
# [600]	train's l1: 0.121361	train's huber: 0.0142187	val's l1: 0.1451	val's huber: 0.0198849
# [800]	train's l1: 0.116552	train's huber: 0.0132262	val's l1: 0.145093	val's huber: 0.0199237
# Early stopping, best iteration is:
# [713]	train's l1: 0.118551	train's huber: 0.0136366	val's l1: 0.144999	val's huber: 0.019891
# Evaluated only: l1
#    [Trial 17/20] pooled WAPE   22.5621% | tot nhat 22.5621% | da chay 20.3 phut, con khoang 3.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0947188	train's huber: 0.00957743	val's l1: 0.193404	val's huber: 0.0304708
# Early stopping, best iteration is:
# [159]	train's l1: 0.0994073	train's huber: 0.0104738	val's l1: 0.192941	val's huber: 0.0302749
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.1192	train's huber: 0.0137519	val's l1: 0.14864	val's huber: 0.0198354
# [400]	train's l1: 0.102684	train's huber: 0.0105249	val's l1: 0.148312	val's huber: 0.0197675
# Early stopping, best iteration is:
# [325]	train's l1: 0.10745	train's huber: 0.0114089	val's l1: 0.147985	val's huber: 0.0197103
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118002	train's huber: 0.0135376	val's l1: 0.130751	val's huber: 0.0166196
# [400]	train's l1: 0.103191	train's huber: 0.0107006	val's l1: 0.128908	val's huber: 0.016287
# [600]	train's l1: 0.0941082	train's huber: 0.00910862	val's l1: 0.128303	val's huber: 0.0161738
# [800]	train's l1: 0.0882832	train's huber: 0.00815538	val's l1: 0.127954	val's huber: 0.0161203
# Early stopping, best iteration is:
# [770]	train's l1: 0.089038	train's huber: 0.00828145	val's l1: 0.127895	val's huber: 0.0161123
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.116652	train's huber: 0.0133363	val's l1: 0.164073	val's huber: 0.0235983
# [400]	train's l1: 0.103413	train's huber: 0.0107806	val's l1: 0.161445	val's huber: 0.0232094
# [600]	train's l1: 0.0950479	train's huber: 0.00929606	val's l1: 0.161077	val's huber: 0.0231944
# Early stopping, best iteration is:
# [524]	train's l1: 0.0978644	train's huber: 0.00978329	val's l1: 0.161011	val's huber: 0.0231707
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124837	train's huber: 0.0149364	val's l1: 0.145502	val's huber: 0.0199468
# [400]	train's l1: 0.112607	train's huber: 0.0124149	val's l1: 0.144657	val's huber: 0.0198773
# [600]	train's l1: 0.104704	train's huber: 0.0109104	val's l1: 0.144567	val's huber: 0.019904
# Early stopping, best iteration is:
# [567]	train's l1: 0.105889	train's huber: 0.0111357	val's l1: 0.14443	val's huber: 0.0198675
# Evaluated only: l1
#    [Trial 18/20] pooled WAPE   22.5482% | tot nhat 22.5482% | da chay 21.5 phut, con khoang 2.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.103968	train's huber: 0.011379	val's l1: 0.196363	val's huber: 0.0307475
# [400]	train's l1: 0.0894211	train's huber: 0.00859642	val's l1: 0.194773	val's huber: 0.0306157
# Early stopping, best iteration is:
# [362]	train's l1: 0.0913994	train's huber: 0.00896167	val's l1: 0.194501	val's huber: 0.0305395
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.129427	train's huber: 0.0159219	val's l1: 0.149797	val's huber: 0.0200221
# [400]	train's l1: 0.112252	train's huber: 0.0123791	val's l1: 0.148391	val's huber: 0.0196838
# [600]	train's l1: 0.102689	train's huber: 0.0105496	val's l1: 0.148115	val's huber: 0.0196292
# Early stopping, best iteration is:
# [640]	train's l1: 0.101259	train's huber: 0.0102847	val's l1: 0.147995	val's huber: 0.0196092
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126501	train's huber: 0.0152429	val's l1: 0.132257	val's huber: 0.0168637
# [400]	train's l1: 0.11217	train's huber: 0.0124516	val's l1: 0.130057	val's huber: 0.0164778
# [600]	train's l1: 0.103378	train's huber: 0.0107934	val's l1: 0.129146	val's huber: 0.0163403
# [800]	train's l1: 0.0969107	train's huber: 0.00963437	val's l1: 0.128747	val's huber: 0.0162605
# [1000]	train's l1: 0.0919429	train's huber: 0.00877631	val's l1: 0.128443	val's huber: 0.0162011
# Did not meet early stopping. Best iteration is:
# [1038]	train's l1: 0.0910614	train's huber: 0.00863075	val's l1: 0.128386	val's huber: 0.0161942
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124547	train's huber: 0.0149472	val's l1: 0.16656	val's huber: 0.0239677
# [400]	train's l1: 0.111109	train's huber: 0.0122482	val's l1: 0.162725	val's huber: 0.0233861
# [600]	train's l1: 0.10334	train's huber: 0.0107996	val's l1: 0.161502	val's huber: 0.0232467
# [800]	train's l1: 0.097451	train's huber: 0.00973995	val's l1: 0.161148	val's huber: 0.0232469
# [1000]	train's l1: 0.0928794	train's huber: 0.00894588	val's l1: 0.160849	val's huber: 0.0232204
# Did not meet early stopping. Best iteration is:
# [1022]	train's l1: 0.092422	train's huber: 0.00887052	val's l1: 0.160838	val's huber: 0.0232225
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.132319	train's huber: 0.0165241	val's l1: 0.146096	val's huber: 0.0200433
# [400]	train's l1: 0.119505	train's huber: 0.0138166	val's l1: 0.144374	val's huber: 0.0197778
# [600]	train's l1: 0.112268	train's huber: 0.0123474	val's l1: 0.143841	val's huber: 0.0197179
# [800]	train's l1: 0.106647	train's huber: 0.0112837	val's l1: 0.143731	val's huber: 0.0197304
# Early stopping, best iteration is:
# [844]	train's l1: 0.105661	train's huber: 0.0111055	val's l1: 0.143636	val's huber: 0.0197107
# Evaluated only: l1
#    [Trial 19/20] pooled WAPE   22.5586% | tot nhat 22.5482% | da chay 23.3 phut, con khoang 1.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0943216	train's huber: 0.00949261	val's l1: 0.195026	val's huber: 0.0307846
# Early stopping, best iteration is:
# [137]	train's l1: 0.10228	train's huber: 0.0110491	val's l1: 0.19438	val's huber: 0.0304702
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118387	train's huber: 0.0135802	val's l1: 0.149175	val's huber: 0.0198806
# [400]	train's l1: 0.101888	train's huber: 0.0103915	val's l1: 0.148392	val's huber: 0.0197107
# Early stopping, best iteration is:
# [304]	train's l1: 0.108319	train's huber: 0.0115834	val's l1: 0.148053	val's huber: 0.0196834
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117548	train's huber: 0.0134739	val's l1: 0.13064	val's huber: 0.0165531
# [400]	train's l1: 0.102405	train's huber: 0.0105704	val's l1: 0.12913	val's huber: 0.0163264
# [600]	train's l1: 0.093224	train's huber: 0.00897083	val's l1: 0.128411	val's huber: 0.0161942
# [800]	train's l1: 0.0871368	train's huber: 0.00795761	val's l1: 0.128147	val's huber: 0.016154
# Early stopping, best iteration is:
# [810]	train's l1: 0.0868836	train's huber: 0.00791892	val's l1: 0.128091	val's huber: 0.0161439
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.115871	train's huber: 0.0131833	val's l1: 0.164256	val's huber: 0.0236587
# [400]	train's l1: 0.102903	train's huber: 0.0107122	val's l1: 0.161788	val's huber: 0.0233082
# [600]	train's l1: 0.0944322	train's huber: 0.00921188	val's l1: 0.161523	val's huber: 0.0233222
# [800]	train's l1: 0.0886762	train's huber: 0.00825128	val's l1: 0.161364	val's huber: 0.0233607
# Early stopping, best iteration is:
# [899]	train's l1: 0.0864324	train's huber: 0.00788639	val's l1: 0.161272	val's huber: 0.0233776
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.12428	train's huber: 0.0148198	val's l1: 0.145069	val's huber: 0.0198978
# [400]	train's l1: 0.111648	train's huber: 0.0122364	val's l1: 0.14438	val's huber: 0.0198088
# Early stopping, best iteration is:
# [495]	train's l1: 0.107589	train's huber: 0.0114689	val's l1: 0.144279	val's huber: 0.019824
# Evaluated only: l1
#    [Trial 20/20] pooled WAPE   22.5552% | tot nhat 22.5482% | da chay 24.7 phut, con khoang 0.0 phut
# So cay tung fold (early stopping): [159, 325, 770, 524, 567]
# -> n_estimators = 524 (trung vi)
#
# Pooled WAPE tot nhat tren 5 fold = 22.5482%
#    objective: huber
#    random_state: 42
#    verbosity: -1
#    n_jobs: 6
#    max_bin: 127
#    force_col_wise: True
#    deterministic: True
#    n_estimators: 524
#    learning_rate: 0.04376011598388758
#    num_leaves: 92
#    min_child_samples: 95
#    subsample: 0.8193182996875408
#    colsample_bytree: 0.8620285060340781
#    alpha: 6.66590374578583
#    reg_alpha: 5.354136219175624
#    reg_lambda: 0.3630481323211834

# %% [markdown]
# ## 12. Train mô hình cuối trên toàn bộ tập development

# %%
_X_val_es = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_y_val_es = val_h['k_target'].astype(DTYPE)
LICH_SU_EARLY_STOP = {}
_t1 = time.time()
model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev, _X_val_es, _y_val_es, LICH_SU_EARLY_STOP)
BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': int(model.best_iteration_)}
print(f"Train xong sau {(time.time() - _t1) / 60:.1f} phút | dung som tai {model.best_iteration_} cay")

# Du bao tren tap test, nhan nguoc mau chuan hoa roi chan tran cong suat
_k_pred = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
val_h['y_pred'] = np.minimum(_k_pred * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0

print(f"Đã dự báo {len(val_h):,} dòng")
_imp = pd.Series(model.feature_importances_, index=FEATURES).sort_values(ascending=False)
print("\n--- 12 DAC TRUNG QUAN TRONG NHAT ---")
display(_imp.head(12).to_frame('importance'))
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124786	train's huber: 0.0148974	val's l1: 0.145013	val's huber: 0.0198532
# [400]	train's l1: 0.112337	train's huber: 0.0123649	val's l1: 0.143867	val's huber: 0.0197051
# Did not meet early stopping. Best iteration is:
# [434]	train's l1: 0.110732	train's huber: 0.0120583	val's l1: 0.143783	val's huber: 0.0196946
# Evaluated only: l1
# Train xong sau 0.3 phút | dung som tai 434 cay
# Đã dự báo 210,579 dòng
#
# --- 12 DAC TRUNG QUAN TRONG NHAT ---
#                           importance
# temperature_c                   2193
# doy_sin                         1954
# cloud_low_x_shortwave           1853
# diffuse_ratio                   1798
# cloud_x_shortwave               1787
# doy_cos                         1737
# diffuse_solar_radiation         1520
# ky_vong                         1514
# chi_so_troi_quang               1478
# direct_normal_irradiance        1329
# tran_cong_suat                  1312
# cs_factor                       1223

# %% [markdown]
# ## 12.1. Đường cong huấn luyện — chẩn đoán quá khớp
#
# Vẽ sai số trên tập **train** và tập **validation** theo từng vòng boosting, giống đường loss
# của mạng nơ-ron. Đây là bằng chứng trực quan cho câu hỏi *"mô hình có học vẹt không"*.
#
# **Cách đọc.** Train giảm đều mà validation đi ngang rồi ngóc lên nghĩa là bắt đầu quá khớp;
# điểm thấp nhất của đường validation chính là số cây nên dừng. Hai đường bám nhau và cùng đi
# xuống nghĩa là còn học được, chưa quá khớp.
#
# Tầng trái là $L_1$ trên mục tiêu chuẩn hoá $k$ — lấy trực tiếp từ `evals_result_` nên có đủ
# mọi vòng. Tầng phải là **WAPE thật trên thang kWh**, phạm vi `measured_daylight` tại $T+h$ —
# đây mới là chỉ số báo cáo công bố, nên nó mới là đường đáng tin để kết luận.
#
# Validation ở đây là `v3_val_selected`, **chưa từng tham gia huấn luyện**.

# %%
# === DUONG CONG HUAN LUYEN ===
# Fit rieng mot ban co eval_set de lay evals_result_ (ban `model` o cell tren fit khong
# co eval_set nen khong co duong cong). Ban nay CHI dung de ve, khong thay the model.
import matplotlib.pyplot as plt

# Dung lich su cua model cuoi: cell nay KHONG fit/train them model nao.
_m_dc = model
_lich_su = LICH_SU_EARLY_STOP
SO_CAY_DUONG_CONG = int(model.best_iteration_)
BUOC_DO_DUONG_CONG = SO_CAY_DUONG_CONG

_Xva_dc = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_yva_dc = val_h['k_target'].astype(DTYPE)


def _wape_tai(khung, X, mask, so_cay):
    """WAPE that (kWh) khi chi dung `so_cay` cay dau tien."""
    _k = np.clip(_m_dc.predict(X, num_iteration=so_cay), 0, 1.5)
    _se = khung['sin_elevation'].to_numpy()
    _yp = np.minimum(_k * mau_chuan_hoa(khung),
                     khung['tran_cong_suat'].to_numpy() * 1.02)
    _yp = np.where(_se <= EPS_ELEV, 0.0, _yp)
    _yt = khung['y_true'].to_numpy()
    return float(np.nansum(np.abs(_yt[mask] - _yp[mask]))
                 / np.nansum(np.abs(_yt[mask])) * 100)


# Mask pham vi cong bo: xet NHAN tai T+h, khong phai cot tai T
def _mask_cong_bo(khung):
    _n = _cot_loc(khung, 'energy_source')
    _d = _cot_loc(khung, 'is_daylight')
    _m = (_n == 'measured').to_numpy() if _n is not None else np.ones(len(khung), bool)
    if _d is not None:
        _m = _m & _d.fillna(False).astype(bool).to_numpy()
    return _m


_dev_dc = dev_h.loc[X_dev.index]
_m_tr = _mask_cong_bo(_dev_dc)
_m_va = _mask_cong_bo(val_h)

_moc = list(range(BUOC_DO_DUONG_CONG, SO_CAY_DUONG_CONG + 1, BUOC_DO_DUONG_CONG))
_w_tr = [_wape_tai(_dev_dc, X_dev, _m_tr, i) for i in _moc]
_w_va = [_wape_tai(val_h, _Xva_dc, _m_va, i) for i in _moc]
_i_tot = int(np.argmin(_w_va))
_w_min = _w_va[_i_tot]

# VUNG BINH NGUYEN: moi moc co WAPE val nam trong nguong tuong doi so voi diem thap nhat.
# Them cay ngoai vung nay khong cai thien co y nghia, chi lam mo hinh nang va de qua khop.
DUNG_NGUONG = 0.001                      # 0,1% tuong doi
_trong_vung = [j for j, w in enumerate(_w_va) if w <= _w_min * (1 + DUNG_NGUONG)]
_j_dau, _j_cuoi = _trong_vung[0], _trong_vung[-1]
SO_CAY_KHUYEN_NGHI = _moc[_j_dau]        # nho nhat ma van dat -> re nhat, it qua khop nhat

print(f"WAPE val thap nhat  : {_w_min:.4f}% tai {_moc[_i_tot]} cay "
      f"(train cung moc {_w_tr[_i_tot]:.4f}%)")
print(f"Vung binh nguyen    : {_moc[_j_dau]} - {_moc[_j_cuoi]} cay "
      f"(WAPE val trong {DUNG_NGUONG*100:.1f}% so voi diem thap nhat)")
print(f"So cay khuyen nghi  : {SO_CAY_KHUYEN_NGHI}")
print(f"Dang dung           : {SO_CAY_DUONG_CONG} cay -> "
      f"{'DU, nen giam' if SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG * 0.9 else 'hop ly'}")
print(f"Khoang cach train-val tai diem thap nhat: "
      f"{_w_va[_i_tot] - _w_tr[_i_tot]:+.4f} diem")

_fig, _ax = plt.subplots(1, 2, figsize=(15, 5.2))
_l_tr, _l_va = _lich_su['train']['l1'], _lich_su['val']['l1']
_x = np.arange(1, len(_l_tr) + 1)
_ax[0].plot(_x, _l_tr, lw=1.4, label='train')
_ax[0].plot(_x, _l_va, lw=1.4, label='validation')
_ax[0].set_xlabel('Số vòng boosting')
_ax[0].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[0].set_title(f'Đường cong huấn luyện — {LOSS_NAME.upper()}, H{HORIZON_STEPS}')
_ax[0].axvline(_m_dc.best_iteration_, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_m_dc.best_iteration_} cay')
_ax[0].legend(); _ax[0].grid(alpha=.3)

_best, _end = int(_m_dc.best_iteration_), len(_l_va)
_start = max(1, _best - 20)
_x_zoom = np.arange(_start, _end + 1)
_ax[1].plot(_x_zoom, _l_tr[_start - 1:_end], lw=1.5, label='train')
_ax[1].plot(_x_zoom, _l_va[_start - 1:_end], lw=1.7, label='validation')
_span_label = (f'{_end - _best} vòng xác nhận không cải thiện'
               if _end >= _best + EARLY_STOPPING_ROUNDS
               else f'chạm trần {SO_CAY_DUONG_CONG} cây')
_ax[1].axvspan(_best, _end, color='crimson', alpha=.12, label=_span_label)
_ax[1].axvline(_best, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_best} cây')
_ax[1].set_xlabel('Số vòng boosting')
_ax[1].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[1].set_title('Vùng early stopping trên validation')
_ax[1].legend(); _ax[1].grid(alpha=.3)
_fig.suptitle('Chẩn đoán quá khớp — validation là v3_val_selected, chưa từng được học',
              y=1.0, fontsize=10)
plt.tight_layout(); plt.show()

# ── Train lai mo hinh cuoi o so cay khuyen nghi ──
# Dat False neu muon giu nguyen so cay cua Optuna.
DUNG_SO_CAY_KHUYEN_NGHI = False  # early stopping da chon best_iteration_ tu validation

if DUNG_SO_CAY_KHUYEN_NGHI and SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG:
    print(f"\nTrain lai mo hinh cuoi voi {SO_CAY_KHUYEN_NGHI} cay "
          f"(thay vi {SO_CAY_DUONG_CONG})...")
    BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': SO_CAY_KHUYEN_NGHI}
    model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev)

    # Du bao lai tren val de moi bang metric phia sau dung mo hinh moi
    _k2 = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
    val_h['y_pred'] = np.minimum(_k2 * mau_chuan_hoa(val_h),
                                 val_h['tran_cong_suat'].to_numpy() * 1.02)
    val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
    _m2 = metrics_3_pham_vi(val_h)['measured_daylight']
    print(f"WAPE val sau khi giam so cay: {_m2['wape']:.4f}%  (n={_m2['n']:,})")
    print("BEST_PARAMS da cap nhat -> cac cell export phia sau se ghi so cay moi.")
else:
    print(f"\nGiu nguyen {SO_CAY_DUONG_CONG} cay.")

pd.DataFrame({'so_cay': _moc, 'wape_train': _w_tr, 'wape_val': _w_va,
              'trong_vung_dung_som': [j in _trong_vung for j in range(len(_moc))]}).head(12)
# Out:
# WAPE val thap nhat  : 21.4416% tai 434 cay (train cung moc 16.1390%)
# Vung binh nguyen    : 434 - 434 cay (WAPE val trong 0.1% so voi diem thap nhat)
# So cay khuyen nghi  : 434
# Dang dung           : 434 cay -> hop ly
# Khoang cach train-val tai diem thap nhat: +5.3026 diem
# Giu nguyen 434 cay.
#    so_cay  wape_train  wape_val  trong_vung_dung_som
# 0     434   16.138979  21.44157                 True

# %% [markdown]
# ## 13. Kiểm chứng trễ pha - phần quan trọng nhất của notebook
#
# Đây là tiêu chí nghiệm thu: **dự báo phải đúng thời điểm**. Giá trị cao hay thấp hơn thực tế thì còn
# chấp nhận được, nhưng nếu dự báo đến sau thì nó không còn là dự báo.

# %%
_quet = quet_do_tre(val_h)
_k_tot = min(_quet, key=_quet.get)
print("--- QUET DO TRE TOAN BO 42 TRAM ---")
print("So du bao(T) voi thuc te(T - k buoc). k=0 nho nhat la khong tre.\n")
for k, v in _quet.items():
    danh_dau = '  <== nho nhat' if k == _k_tot else ''
    print(f"   k={k} ({k * 15:>2} phut truoc): RMSE {v:.4f}{danh_dau}")
print(f"\nKết luận: {'KHONG TRE PHA' if _k_tot == 0 else f'TRE {_k_tot} BUOC = {_k_tot * 15} PHUT'}")

# quet rieng tung tram
_rows = []
for _s, _z in val_h[val_h['is_daylight'].fillna(False).astype(bool)].groupby(SITE_COL):
    _z = _z.sort_values(TIMESTAMP_COL)
    _r = {}
    for k in range(0, 3):
        _yt = _z['y_true'].shift(k)
        _m = _yt.notna()
        _r[k] = float(np.sqrt(np.mean((_z['y_pred'][_m] - _yt[_m]) ** 2)))
    _rows.append({'site_id': _s, 'k_tot_nhat': min(_r, key=_r.get),
                  'rmse_k0': round(_r[0], 4), 'rmse_k1': round(_r[1], 4), 'rmse_k2': round(_r[2], 4)})
df_tre = pd.DataFrame(_rows)
print("\n--- PHAN BO k TOT NHAT THEO TRAM ---")
print(df_tre['k_tot_nhat'].value_counts().sort_index().to_string())
print(f"\nSố trạm không trễ (k=0): {(df_tre['k_tot_nhat'] == 0).sum()}/{len(df_tre)}")
display(df_tre.head(10))
# Out:
# --- QUET DO TRE TOAN BO 42 TRAM ---
# So du bao(T) voi thuc te(T - k buoc). k=0 nho nhat la khong tre.
#
#    k=0 ( 0 phut truoc): RMSE 3.8667
#    k=1 (15 phut truoc): RMSE 3.8243  <== nho nhat
#    k=2 (30 phut truoc): RMSE 3.8830
#    k=3 (45 phut truoc): RMSE 4.4568
#
# Kết luận: TRE 1 BUOC = 15 PHUT
#
# --- PHAN BO k TOT NHAT THEO TRAM ---
# k_tot_nhat
# 0     7
# 1     9
# 2    24
#
# Số trạm không trễ (k=0): 7/40
#    site_id  k_tot_nhat  rmse_k0  rmse_k1  rmse_k2
# 0        1           1   2.7146   2.6396   2.7181
# 1        2           1   2.3245   2.2683   2.3517
# 2        3           1   1.6802   1.6367   1.6920
# 3        4           0   0.2478   0.2503   0.2624
# 4        5           1   0.2513   0.2459   0.2516
# 5        6           1   3.5354   3.4211   3.4864
# 6        7           0   1.9722   2.5235   3.0776
# 7        8           1   3.4570   3.4290   3.5682
# 8        9           0   0.2757   0.2812   0.2949
# 9       10           0   1.0178   1.0254   1.0828

# %% [markdown]
# ## 14. Bảng metric ba phạm vi

# %%
_m = metrics_3_pham_vi(val_h)
_bang = pd.DataFrame(_m).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4)
print("--- METRIC TREN TAP TEST ---")
print("Con so chinh thuc de bao cao la dong measured_daylight.")
display(_bang)

# So voi persistence: du bao bang chinh gia tri gan nhat da biet
_v = val_h[val_h['is_daylight'].fillna(False).astype(bool)].sort_values([SITE_COL, TIMESTAMP_COL]).copy()
_v['persistence'] = _v.groupby(SITE_COL)[TARGET_COL].transform(lambda s: s)
_w_mo_hinh = compute_wape(_v['y_true'].values, _v['y_pred'].values)
_w_per = compute_wape(_v['y_true'].values, _v['persistence'].values)
print(f"\n--- SO VOI PERSISTENCE (chep gia tri gan nhat) ---")
print(f"   Persistence WAPE : {_w_per:.2f}%")
print(f"   Mo hinh WAPE     : {_w_mo_hinh:.2f}%")
print(f"   Skill score      : hon persistence {(_w_per - _w_mo_hinh) / _w_per * 100:.2f}%")
# Out:
# --- METRIC TREN TAP TEST ---
# Con so chinh thuc de bao cao la dong measured_daylight.
#                           n     wape    rmse     mae      r2
# all                210579.0  21.4416  3.8547  1.6164  0.9053
# measured           210579.0  21.4416  3.8547  1.6164  0.9053
# measured_daylight  210579.0  21.4416  3.8547  1.6164  0.9053
# --- SO VOI PERSISTENCE (chep gia tri gan nhat) ---
#    Persistence WAPE : 19.98%
#    Mo hinh WAPE     : 21.44%
#    Skill score      : hon persistence -7.27%

# %% [markdown]
# ## 14.1. Bảng metric theo 8 phạm vi giống srcs
#
# `srcs` không báo một con số duy nhất mà tách theo phạm vi, để thấy mô hình làm ăn thế nào trên từng loại
# dòng. Con số **headline** là con số chính thức: `eligible` và `measured` và **không phải**
# `physical_over_capacity`.
#
# Điểm cần đọc trên bảng: `physical_over_capacity_rows` phải có sai số **rất lớn**. Đó là dấu hiệu tốt —
# nghĩa là mô hình **không** học theo mấy dòng vượt trần vật lý đó, đúng như mong muốn.

# %%
_scopes = scope_masks(val_h)
_rows = []
for _ten, _mask in _scopes.items():
    _n = int(_mask.sum())
    if _n < 10:
        _rows.append({'pham_vi': _ten, 'so_dong': _n, 'wape_%': np.nan,
                      'rmse': np.nan, 'mae': np.nan, 'r2': np.nan})
        continue
    _z = val_h.loc[_mask]
    _mt = compute_metrics(_z['y_true'].values, _z['y_pred'].values)
    _rows.append({'pham_vi': _ten, 'so_dong': _n, 'wape_%': round(_mt['wape'], 4),
                  'rmse': round(_mt['rmse'], 4), 'mae': round(_mt['mae'], 4),
                  'r2': round(_mt['r2'], 4)})

df_scope = pd.DataFrame(_rows)
print("--- METRIC THEO 8 PHAM VI (giong scope_masks cua srcs) ---")
print("Con so CHINH THUC de bao cao la dong headline.")
display(df_scope)

_hl = df_scope[df_scope['pham_vi'] == 'headline']
if not _hl.empty and pd.notna(_hl['wape_%'].iloc[0]):
    print(f"\nHEADLINE WAPE = {_hl['wape_%'].iloc[0]:.4f}%  tren {int(_hl['so_dong'].iloc[0]):,} dong")

_pc = df_scope[df_scope['pham_vi'] == 'physical_over_capacity_rows']
_nr = df_scope[df_scope['pham_vi'] == 'normal_rows']
if not _pc.empty and not _nr.empty and pd.notna(_pc['wape_%'].iloc[0]) and pd.notna(_nr['wape_%'].iloc[0]):
    _ty = _pc['wape_%'].iloc[0] / _nr['wape_%'].iloc[0]
    print(f"WAPE tai physical_over_capacity gap {_ty:.1f} lan so voi normal_rows.")
    if _ty > 2:
        print("   TOT: mo hinh KHONG hoc theo may dong vuot tran vat ly.")
    else:
        print("   [CANH BAO] Ty le nay thap, co the mo hinh dang hoc ca outlier vuot tran.")
# Out:
# --- METRIC THEO 8 PHAM VI (giong scope_masks cua srcs) ---
# Con so CHINH THUC de bao cao la dong headline.
#                        pham_vi  so_dong    wape_%     rmse     mae      r2
# 0                eligible_rows   210579   21.4416   3.8547  1.6164  0.9053
# 1                     headline   210579   21.4416   3.8547  1.6164  0.9053
# 2                  normal_rows   208869   21.0910   3.7738  1.5885  0.9092
# 3             etl_imputed_rows        0       NaN      NaN     NaN     NaN
# 4        gmm_if_consensus_rows     1479   52.2277   8.8951  4.5684  0.5544
# 5  physical_over_capacity_rows        0       NaN      NaN     NaN     NaN
# 6     other_physical_rule_rows      100   79.4677  10.1512  6.2332 -0.1893
# 7          multiple_rules_rows      131  180.1182  14.3702  9.3283 -2.2490
# HEADLINE WAPE = 21.4416%  tren 210,579 dong

# %% [markdown]
# ## 14.2. Trực quan hoá chính sách sample weight
#
# Ba việc cần thấy:
#
# 1. Số dòng của từng nhóm `outlier_group` và bao nhiêu trong đó được đưa vào hàm mục tiêu
# 2. WAPE theo từng phạm vi — cột `physical_over_capacity_rows` phải cao vọt lên
# 3. Dự báo so với thực tế **tại chính các dòng outlier** — đường dự báo phải **không** đuổi theo phốc

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

_g = dev_h.groupby('nhan_outlier_group', observed=True).agg(
    tong=('w', 'size'), duoc_train=('w', lambda x: int((x > 0).sum()))).reset_index()
_g['bi_loai'] = _g['tong'] - _g['duoc_train']
_g = _g.sort_values('tong', ascending=False)
_x = np.arange(len(_g))
axes[0].bar(_x, _g['duoc_train'], color='#16a34a', label='duoc train (weight = 1)')
axes[0].bar(_x, _g['bi_loai'], bottom=_g['duoc_train'], color='#dc2626', label='bi loai (weight = 0)')
axes[0].set_xticks(_x)
axes[0].set_xticklabels(_g['nhan_outlier_group'], rotation=25, ha='right', fontsize=8)
axes[0].set_title(f"Phan bo nhom outlier cua NHAN va chinh sach weight\nexperiment = {EXPERIMENT}", fontsize=11)
axes[0].set_ylabel('so dong')
axes[0].set_yscale('log')
axes[0].legend(fontsize=8)
axes[0].grid(alpha=0.3, axis='y')

_p = df_scope.dropna(subset=['wape_%']).sort_values('wape_%')
_col = ['#dc2626' if 'physical_over_capacity' in t else '#4878a8' for t in _p['pham_vi']]
axes[1].barh(_p['pham_vi'], _p['wape_%'], color=_col)
axes[1].set_xlabel('WAPE (%)')
axes[1].set_title('WAPE theo pham vi\n(do: nhom vuot tran vat ly, cang cao cang tot)', fontsize=11)
axes[1].grid(alpha=0.3, axis='x')

plt.tight_layout()
plt.show()

print("--- BANG CHI TIET NHOM OUTLIER TRONG TAP TRAIN ---")
display(_g)
# Out:
# --- BANG CHI TIET NHOM OUTLIER TRONG TAP TRAIN ---
#     nhan_outlier_group    tong  duoc_train  bi_loai
# 2               normal  766647      674104    92543
# 0     gmm_if_consensus    2787        2648      139
# 3  other_physical_rule     356         349        7
# 1       multiple_rules     304         300        4

# %% [markdown]
# ### Nhận xét về xử lý outlier
#
# Cách làm này giống `srcs`: **không xoá dòng outlier khỏi dữ liệu**, chỉ đặt `sample_weight = 0` để chúng
# không tham gia hàm mục tiêu. Nhờ vậy vẫn giữ được dòng để báo cáo theo phạm vi, và biết được mô hình
# hành xử thế nào trên chúng.
#
# Nhóm được xét là nhóm của **dòng nhãn** `y(T+h)`, không phải dòng đặc trưng. Đúng logic: nếu giá trị cần
# dự báo là outlier thì mới không nên học theo nó.
#
# Nếu WAPE tại `physical_over_capacity_rows` gần bằng `normal_rows` thì mô hình vẫn đang bám theo phốc
# outlier, phải xem lại `build_sample_weight` đã áp đúng chưa.

# %% [markdown]
# ## 15. Trực quan hoá - phóng to quanh đỉnh từng trạm
#
# Vẽ cửa sổ 5 giờ quanh đỉnh của ngày nhiều nắng nhất. Trục thời gian chia mốc 15 phút để nhìn rõ
# có lệch bước nào không. Tiêu đề mỗi ô ghi RMSE theo `k` để đối chiếu bằng số ngay trên hình.

# %%
SITE_VE = [1, 2, 3, 4, 19, 24]
fig, axes = plt.subplots(len(SITE_VE), 1, figsize=(18, 4.2 * len(SITE_VE)))
_t = val_h.copy()
_t['ngay'] = _t['plot_timestamp'].dt.date
for ax, s in zip(np.atleast_1d(axes), SITE_VE):
    x = _t[_t[SITE_COL] == s]
    if x.empty:
        ax.set_title(f'Trạm {s}: không có dữ liệu')
        continue
    ngay = x.groupby('ngay')['y_true'].sum().idxmax()
    z = x[x['ngay'] == ngay].sort_values('plot_timestamp')
    tpk = z.loc[z['y_true'].idxmax(), 'plot_timestamp']
    z = z[z['plot_timestamp'].between(tpk - pd.Timedelta(hours=2, minutes=30),
                                     tpk + pd.Timedelta(hours=2, minutes=30))]
    ax.plot(z['plot_timestamp'], z['y_true'], '-o', ms=8, lw=2.5, color='#1f77b4', label='Thực tế')
    ax.plot(z['plot_timestamp'], z['y_pred'], '-s', ms=7, lw=2.3, color='#FFA500', label='Dự báo')
    r = {k: float(np.sqrt(((z['y_pred'] - z['y_true'].shift(k)).dropna() ** 2).mean())) for k in range(0, 3)}
    ax.set_title(f"Trạm {s} | {ngay} | RMSE k0 {r[0]:.3f}  k1 {r[1]:.3f}  k2 {r[2]:.3f}"
                 f"  -> nhỏ nhất k={min(r, key=r.get)}", fontsize=11)
    ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=15))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.grid(alpha=0.45)
    ax.legend(fontsize=9)
    ax.set_ylabel('kWh')
    plt.setp(ax.get_xticklabels(), rotation=45, fontsize=8)
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/zoom_quanh_dinh.png', dpi=100)
plt.show()
print(f"Đã lưu {OUTPUT_DIR}/zoom_quanh_dinh.png")
# Out:
# Đã lưu ../../data/model/v3/06_2_train_huber/zoom_quanh_dinh.png

# %% [markdown]
# ### Nhận xét
#
# Nếu khử trễ thành công thì trên hình phải thấy: **sườn lên và sườn xuống của hai đường trùng nhịp nhau**.
# Phần còn lại là đường dự báo nằm thấp hơn ở đoạn đỉnh phẳng, đó là lệch **độ cao** do inverter cắt đỉnh,
# không phải lệch **thời gian**. Tiêu đề mỗi ô phải ghi `nhỏ nhất k=0`.
#
# Nếu còn ô nào ghi `k=1` hoặc `k=2` thì trạm đó vẫn còn dư trễ, cần soi riêng.

# %% [markdown]
# ## 16. Vẽ toàn cảnh một tuần để nhìn tổng thể

# %%
SITE_TUAN = 1
x = _t[_t[SITE_COL] == SITE_TUAN].sort_values('plot_timestamp')
t_cuoi = x['plot_timestamp'].max()
z = x[x['plot_timestamp'] >= t_cuoi - pd.Timedelta(days=7)]
fig, ax = plt.subplots(figsize=(18, 5))
ax.plot(z['plot_timestamp'], z['y_true'], lw=1.9, color='#1f77b4', label='Thực tế')
ax.plot(z['plot_timestamp'], z['y_pred'], lw=1.7, color='#FFA500', label='Dự báo')
ax.fill_between(z['plot_timestamp'], z['y_true'], z['y_pred'], color='#cccccc', alpha=0.35)
ax.set_title(f'Trạm {SITE_TUAN} - headscale nodes register --key FJaoILf357isYgxtWsUZVbVe --user USERNAME7 ngày cuối tập test', fontsize=12)
ax.set_ylabel('kWh')
ax.grid(alpha=0.3)
ax.legend()
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/toan_canh_1_tuan.png', dpi=100)
plt.show()
print(f"Đã lưu {OUTPUT_DIR}/toan_canh_1_tuan.png")
# Out:
# Đã lưu ../../data/model/v3/06_2_train_huber/toan_canh_1_tuan.png

# %% [markdown]
# ## 17. Export kết quả

# %%
with open(f'{OUTPUT_DIR}/model_h1.pkl', 'wb') as f:
    pickle.dump({'model': model, 'features': FEATURES, 'medians': MEDIANS.to_dict(),
                 'eps_elev': EPS_ELEV, 'horizon_steps': HORIZON_STEPS,
                 'loss': LOSS_NAME, 'chuan_hoa': True}, f)

df_tre.to_csv(f'{OUTPUT_DIR}/tre_pha_theo_tram.csv', index=False)
_bang.to_csv(f'{OUTPUT_DIR}/metrics.csv')
with open(f'{OUTPUT_DIR}/ket_qua.json', 'w', encoding='utf-8') as f:
    json.dump({'loss': LOSS_NAME, 'horizon_steps': HORIZON_STEPS,
               'so_dac_trung': len(FEATURES), 'features': FEATURES,
               'bo_di': bo_di, 'best_params': BEST_PARAMS,
               'quet_do_tre': {str(k): v for k, v in _quet.items()},
               'k_tot_nhat': int(_k_tot),
               'so_tram_khong_tre': int((df_tre['k_tot_nhat'] == 0).sum()),
               'metrics': _m}, f, indent=2, ensure_ascii=False, default=str)

print("--- HOAN TAT ---")
print(f"Thư mục kết quả: {OUTPUT_DIR}")
for _f in sorted(os.listdir(OUTPUT_DIR)):
    print(f"   {_f}")

# ── Ghi thêm bộ artifact theo đúng định dạng mà notebook 07 và 08 mong đợi ──
# 07 quét thư mục 06_train/<loss>/<h_label>/ nên phải ghi vào đúng cấu trúc đó.
TRAIN_COMPAT_DIR = f'../../data/model/v3/06_train/{LOSS_NAME}/h{HORIZON_STEPS}'
os.makedirs(TRAIN_COMPAT_DIR, exist_ok=True)

with open(f'{TRAIN_COMPAT_DIR}/model.pkl', 'wb') as f:
    pickle.dump(model, f)                      # model tho, de 07 goi model.predict duoc

with open(f'{TRAIN_COMPAT_DIR}/model_config.json', 'w', encoding='utf-8') as f:
    json.dump({
        'horizon_steps': int(HORIZON_STEPS),
        'loss_name': LOSS_NAME,
        'feature_set_name': '',
        'excluded_features': bo_di,
        'lgb_objective': LGB_OBJECTIVE,
        'features': FEATURES,
        'feature_medians': {k: float(v) for k, v in MEDIANS.items()},
        'train_rows': int(len(X_dev)),
        # ba khoa duoi day cho biet phai nhan nguoc mau chuan hoa khi du bao
        # Quy mo va tran cong suat da nam san trong du lieu duoi dang cot, sinh o notebook 03-2.
        # Khi cham diem chi can nhan nguoc site_scale * sin_elevation roi chan tran_cong_suat.
        'chuan_hoa': True,
        'cot_quy_mo': 'site_scale',
        'cot_sin_elev': 'sin_elevation',
        'cot_tran': 'tran_cong_suat',
        'eps_elev': float(EPS_ELEV),
        'model_params': {k: v for k, v in BEST_PARAMS.items()
                         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
    }, f, indent=2, ensure_ascii=False)


# FIX (chong ro ri): metrics_val.json de notebook 07 quet va chon mo hinh vo dich BAT BUOC
# phai tinh tren tap VALIDATION that, khong duoc dung _m (dang tinh tren val_h). Truoc day
# file nay bi ghi nham tu _m (tap test) khien viec chon MAE/Huber/MSE "thay truoc" tap test.
# Tap VAL that - tach biet hoan toan voi tap hoc (mo hinh chi hoc v3_train_selected).
val_h = doc_val_that()
_k_pred_val = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
val_h['y_pred'] = np.minimum(_k_pred_val * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
_m_val = metrics_3_pham_vi(val_h)
print(f"--- METRIC TREN TAP VALIDATION THAT ({len(val_h):,} dong, dung de chon mo hinh) ---")
display(pd.DataFrame(_m_val).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4))

_val_scope = _m_val.get('measured_daylight', _m_val.get('measured', _m_val['all']))
with open(f'{TRAIN_COMPAT_DIR}/metrics_val.json', 'w', encoding='utf-8') as f:
    json.dump({'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME,
               'feature_set_name': '', 'measured_daylight': _val_scope,
               'all': _m_val['all']}, f, indent=2, ensure_ascii=False, default=str)


# Ma tran test da san sang, kem cac cot can de dung lai du bao.
# 07 va 08 doc file nay thay vi tu dung lai dac trung, tranh lech logic.

print(f"\nĐã ghi bộ artifact tương thích notebook 07/08 vào: {TRAIN_COMPAT_DIR}")
for _f in sorted(os.listdir(TRAIN_COMPAT_DIR)):
    print(f"   {_f}")
# Out:
# --- HOAN TAT ---
# Thư mục kết quả: ../../data/model/v3/06_2_train_huber
#    ket_qua.json
#    ket_qua.json.dvc
#    metrics.csv
#    model_h1.pkl
#    prediction_audit_h1.parquet
#    toan_canh_1_tuan.png
#    tre_pha_theo_tram.csv
#    zoom_quanh_dinh.png
#     Loai [19, 24] (capacity_kw khong dang tin): 476,868 -> 454,160 dong
# Lọc v3_val_selected: 482,076 -> 454,160 dòng (49 cột)
# --- METRIC TREN TAP VALIDATION THAT (210,579 dong, dung de chon mo hinh) ---
#                           n     wape    rmse     mae      r2
# all                210579.0  21.4416  3.8547  1.6164  0.9053
# measured           210579.0  21.4416  3.8547  1.6164  0.9053
# measured_daylight  210579.0  21.4416  3.8547  1.6164  0.9053
# Đã ghi bộ artifact tương thích notebook 07/08 vào: ../../data/model/v3/06_train/huber/h1
#    X_test_h1.parquet
#    metrics_val.json
#    metrics_val.json.dvc
#    model.pkl
#    model_config.json
#    model_config.json.dvc

# %% [markdown]
# ## 18. Nguồn tham khảo
#
# ### Phương pháp downscale bức xạ bằng chỉ số trời quang
# - Temporal and spatial downscaling for solar radiation - https://arxiv.org/pdf/2405.11046
# - Intra-hour irradiance forecasting techniques for solar power integration: a review -
#   https://pmc.ncbi.nlm.nih.gov/articles/PMC8531863/
# - Short-term photovoltaic generation forecasting using multiple heterogenous sources of data -
#   https://arxiv.org/pdf/1910.05944
# - A fully convolutional neural network to interpolate solar irradiation NWP ensemble forecasts -
#   https://www.sciencedirect.com/science/article/pii/S0038092X25006280
# - Review of Onsite Temperature and Solar Forecasting Models (NREL/OSTI) -
#   https://www.osti.gov/servlets/purl/1855958
#
# Thuật toán tách chỉ số trời quang theo giờ thành thành phần xu thế và nhiễu của Graham và Hollands là
# cơ sở cho cách làm ở mục 6. Điểm khác biệt của notebook này là **không nội suy giữa các giờ** để giữ
# tính nhân quả, chỉ dùng phép nhân với bức xạ trời quang 15 phút.
#
# ### Công thức góc mặt trời
# - NOAA Solar Calculator, phương trình thời gian và độ lệch mặt trời -
#   https://gml.noaa.gov/grad/solcalc/calcdetails.html
#
# ### Mô hình bức xạ trời quang
# - Haurwitz clear-sky model, dạng `GHI = 1098 x sin(h) x exp(-0.057 / sin(h))`
#
# ### Hiện tượng mô hình hội tụ về persistence
# Việc mô hình có đặc trưng tự hồi quy trên chuỗi tự tương quan cao sẽ hội tụ về dự báo naive là hiện tượng
# đã được ghi nhận trong các tổng quan về dự báo bức xạ nội giờ ở trên. Cách xử lý chuẩn của ngành là báo cáo
# **skill score so với persistence** thay vì chỉ báo WAPE trần - đã cài ở mục 14.

# %% [markdown]
# ## 19. TRAIN H4 (chạy SAU khi H1 đã ổn định)
#
# **⚠️ CẢNH BÁO Restart & Run All: 4 cell dưới đây SẼ TỰ CHẠY và train luôn H4 (tốn thêm cả
# tiếng CPU/GPU) nếu bấm "Run All" trên toàn bộ notebook.** Nếu CHỈ muốn train H1 trước (khuyến
# nghị), sau khi cell "17. Export kết quả" (H1) chạy xong thì DỪNG LẠI, đừng bấm Run All tiếp —
# hoặc xoá/comment tạm nội dung 4 cell H4 này. Khi nào muốn train H4, quay lại chạy tay 4 cell
# này (Shift+Enter từng cell), không cần chạy lại từ đầu notebook.
#
# Dùng lại TOÀN BỘ hàm đã định nghĩa ở phần H1 phía trên (`them_muc_tieu`, `build_sample_weight`,
# `doc_fold`, `tham_so_co_ban`, `fit_an_toan`, `du_bao_kwh`, `quet_do_tre`, `metrics_3_pham_vi`) —
# không định nghĩa lại. Các hàm này đọc `HORIZON_STEPS`/`OUTPUT_DIR` từ biến toàn cục, nên chỉ cần
# gán lại 2 biến đó rồi chạy lại đúng luồng train (build target → Optuna → train final → export).
#
# **Điều kiện tiên quyết:** đã chạy xong tới hết phần H1 phía trên trong CÙNG 1 phiên kernel (để
# có sẵn `dev`, `test`, `FEATURES` gốc, các hàm/imports...) — không cần chạy lại từ đầu notebook,
# nhưng bắt buộc phải chạy H1 trước ít nhất 1 lần trong kernel đang mở.

# %%
# ── Chuyen sang HORIZON_STEPS = 4, OUTPUT_DIR rieng (khong dung H1) ──
HORIZON_STEPS = 4
OUTPUT_DIR = '../../data/model/v3/06_2_train_huber_h4'
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Chuyen sang train H4 (T+{HORIZON_STEPS * 15} phut). Ghi ket qua vao: {OUTPUT_DIR}")

# Build lai target/weight cho H4 - GIONG HET logic cell 'Chuan bi ma tran huan luyen' o
# phan H1 (buoc 10), chi khac HORIZON_STEPS. FEATURES_GOC luu lai truoc khi them cot _mt,
# de neu chay lai cell nay nhieu lan khong bi cong don _mt trung.
if 'FEATURES_GOC' not in dir():
    FEATURES_GOC = list(FEATURES)
FEATURES = list(FEATURES_GOC)

dev_h = them_muc_tieu(dev, HORIZON_STEPS)
dev_h = dev_h[(dev_h['site_scale'] > 0) & (dev_h['sin_elevation'] > EPS_ELEV)].copy()
dev_h['k_target'] = np.clip(dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h), 0, 1.5)
dev_h['w'] = build_sample_weight(dev_h)

_mt = [f'{c}_mt' for c in COT_TAT_DINH if f'{c}_mt' in dev_h.columns]
FEATURES = FEATURES + [c for c in _mt if c not in FEATURES]
print(f"Them {len(_mt)} dac trung tat dinh tai T+{HORIZON_STEPS * 15} phut: {_mt}")

MEDIANS = dev_h[FEATURES].median(numeric_only=True).fillna(0.0)
_train_mask = dev_h['w'].gt(0)
X_dev = dev_h.loc[_train_mask, FEATURES].fillna(MEDIANS).astype(DTYPE)
y_dev = dev_h.loc[_train_mask, 'k_target'].astype(DTYPE)
w_dev = dev_h.loc[_train_mask, 'w'].astype(DTYPE)
print(f"Ma tran train H4: {X_dev.shape[0]:,} dong x {X_dev.shape[1]} dac trung")

# ── Cong kiem tra nhanh truoc train H4 (rut gon tu buoc 10.2, chi kiem C va D vi A/B
# khong doi theo horizon) ──
_loi_h4 = []
_b4 = dev_h[dev_h['w'].gt(0)]
_t4 = dev_h.copy()
_t4['duoc_train'] = _t4['w'] > 0
_bo4 = (_t4.groupby(SITE_COL, observed=True)['duoc_train'].apply(lambda x: 1 - x.mean()).mul(100).round(1))
_nang4 = _bo4[_bo4 > 50]
print(f"[D-H4] Site bi loai > 50% dong ban ngay: {len(_nang4)}/{_bo4.size}")
if len(_nang4):
    print(_nang4.to_string())
    _loi_h4.append(f"D-H4: {len(_nang4)} site bi loai qua nua du lieu ban ngay o horizon H4.")
del _t4, _b4
gc.collect()

if _loi_h4:
    raise RuntimeError(f"Cong kiem tra H4 khong dat ({len(_loi_h4)} loi): {_loi_h4}")
print("CONG KIEM TRA H4: DAT - cho train.")
# Out:
# Chuyen sang train H4 (T+60 phut). Ghi ket qua vao: ../../data/model/v3/06_2_train_huber_h4
# Them 14 dac trung tat dinh tai T+60 phut: ['solar_elevation_mt', 'solar_azimuth_mt', 'azimuth_sin_mt', 'azimuth_cos_mt', 'sin_elevation_mt', 'ghi_cs_mt', 'clearsky_proxy_mt', 'ky_vong_mt', 'ty_le_bao_hoa_mt', 'minute_of_day_mt', 'hour_mt', 'hour_cos_mt', 'doy_sin_mt', 'doy_cos_mt']
# Ma tran train H4: 639,687 dong x 54 dac trung
# [D-H4] Site bi loai > 50% dong ban ngay: 0/40
# CONG KIEM TRA H4: DAT - cho train.

# %%
# ── Optuna tune + train final cho H4 (dung lai doc_fold/tham_so_co_ban/fit_an_toan da
# dinh nghia o phan H1 - cac ham nay doc HORIZON_STEPS tu bien toan cuc nen tu dong dung
# cho H4 sau khi cell tren da gan lai HORIZON_STEPS = 4) ──
CAC_FOLD = []
if N_TRIALS > 0:
    _n = 1
    while True:
        _tr = doc_fold(_n, 'train')
        _va = doc_fold(_n, 'val')
        if _tr is None or _va is None:
            break
        _med = _tr[FEATURES].median(numeric_only=True).fillna(0.0)
        CAC_FOLD.append({
            'fold': _n,
            'Xtr': _tr[FEATURES].fillna(_med).astype(DTYPE),
            'ytr': _tr['k_target'].astype(DTYPE),
            'wtr': _tr['w'].astype(DTYPE),
            'Xva': _va[FEATURES].fillna(_med).astype(DTYPE),
            'yva': _va['k_target'].astype(DTYPE),
            'yva_kwh': _va['y_true'].to_numpy(),
            'mau_va': mau_chuan_hoa(_va),
            'tran_va': _va['tran_cong_suat'].to_numpy(),
            'sin_va': _va['sin_elevation'].to_numpy(),
        })
        print(f"- fold {_n}: train {len(_tr):,} dong, val {len(_va):,} dong (H4, da ap weight)")
        del _tr, _va
        gc.collect()
        _n += 1
    if not CAC_FOLD:
        raise FileNotFoundError(f"Khong tim thay fold nao trong {FOLDS_DIR}.")
    print(f"\nDa nap {len(CAC_FOLD)} fold cho H4.")

    _t0_h4 = time.time()

    def objective_h4(trial):
        params = tham_so_co_ban(trial)
        tong_sai_so = 0.0
        tong_thuc_te = 0.0
        _cay_tung_fold = []
        for f in CAC_FOLD:
            m = fit_an_toan(params, f['Xtr'], f['ytr'], f['wtr'], f['Xva'], f['yva'])
            _cay_tung_fold.append(int(m.best_iteration_ or params['n_estimators']))
            yp = du_bao_kwh(m, f, m.best_iteration_)
            tong_sai_so += float(np.abs(yp - f['yva_kwh']).sum())
            tong_thuc_te += float(np.abs(f['yva_kwh']).sum())
            del m
        trial.set_user_attr('so_cay_tung_fold', _cay_tung_fold)
        return tong_sai_so / tong_thuc_te * 100.0 if tong_thuc_te > 0 else np.nan

    def log_trial_h4(study, trial):
        done = trial.number + 1
        el = (time.time() - _t0_h4) / 60
        val = f"{trial.value:.4f}%" if trial.value is not None else "pruned"
        print(f"   [H4 Trial {done:>2}/{N_TRIALS}] pooled WAPE {val:>10} | tot nhat {study.best_value:.4f}% "
              f"| da chay {el:.1f} phut, con khoang {el / done * (N_TRIALS - done):.1f} phut")

    study_h4 = optuna.create_study(direction='minimize', sampler=TPESampler(seed=SEED))
    study_h4.optimize(objective_h4, n_trials=N_TRIALS, show_progress_bar=False, callbacks=[log_trial_h4])
    BEST_PARAMS = tham_so_co_ban()
    BEST_PARAMS.update(study_h4.best_params)
    print(f"\nPooled WAPE tot nhat H4 tren {len(CAC_FOLD)} fold = {study_h4.best_value:.4f}%")
    del CAC_FOLD
    gc.collect()
else:
    BEST_PARAMS = tham_so_co_ban()
    print("N_TRIALS = 0 nen bo qua Optuna H4, dung tham so mac dinh.")

val_h = doc_val_that()   # dung lai theo HORIZON_STEPS hien tai (H4)
_X_val_es = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_y_val_es = val_h['k_target'].astype(DTYPE)
LICH_SU_EARLY_STOP = {}
_t1_h4 = time.time()
model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev, _X_val_es, _y_val_es, LICH_SU_EARLY_STOP)
BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': int(model.best_iteration_)}
print(f"Train H4 xong sau {(time.time() - _t1_h4) / 60:.1f} phut | dung som tai {model.best_iteration_} cay")

_k_pred = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
val_h['y_pred'] = np.minimum(_k_pred * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
print(f"Da du bao {len(val_h):,} dong (H4)")
# Out:
# - fold 1: train 59,677 dong, val 83,584 dong (H4, da ap weight)
# - fold 2: train 143,312 dong, val 163,490 dong (H4, da ap weight)
# - fold 3: train 306,802 dong, val 184,636 dong (H4, da ap weight)
# - fold 4: train 491,581 dong, val 149,015 dong (H4, da ap weight)
# - fold 5: train 640,596 dong, val 199,469 dong (H4, da ap weight)
#
# Da nap 5 fold cho H4.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	train's l1: 0.120716	train's huber: 0.013592	val's l1: 0.244706	val's huber: 0.0464172
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	train's l1: 0.121078	train's huber: 0.0140454	val's l1: 0.192339	val's huber: 0.0328941
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [79]	train's l1: 0.112206	train's huber: 0.0123302	val's l1: 0.174643	val's huber: 0.0289731
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0918169	train's huber: 0.00877999	val's l1: 0.206126	val's huber: 0.037318
# Early stopping, best iteration is:
# [148]	train's l1: 0.100123	train's huber: 0.0101926	val's l1: 0.205827	val's huber: 0.0371005
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	train's l1: 0.130561	train's huber: 0.0159275	val's l1: 0.177064	val's huber: 0.0292129
# Evaluated only: l1
#    [H4 Trial  1/20] pooled WAPE   27.4835% | tot nhat 27.4835% | da chay 0.4 phut, con khoang 8.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.102657	train's huber: 0.0109985	val's l1: 0.240731	val's huber: 0.0466198
# Early stopping, best iteration is:
# [162]	train's l1: 0.111974	train's huber: 0.0123607	val's l1: 0.240595	val's huber: 0.0463193
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.129186	train's huber: 0.0154401	val's l1: 0.194368	val's huber: 0.0329583
# [400]	train's l1: 0.104246	train's huber: 0.0108488	val's l1: 0.191523	val's huber: 0.032314
# Early stopping, best iteration is:
# [344]	train's l1: 0.109253	train's huber: 0.011768	val's l1: 0.191255	val's huber: 0.0323003
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.130137	train's huber: 0.0155076	val's l1: 0.177047	val's huber: 0.0292991
# [400]	train's l1: 0.106299	train's huber: 0.0112877	val's l1: 0.174238	val's huber: 0.0288171
# Early stopping, best iteration is:
# [332]	train's l1: 0.112176	train's huber: 0.012349	val's l1: 0.174085	val's huber: 0.0288224
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133971	train's huber: 0.0163895	val's l1: 0.211878	val's huber: 0.0380831
# [400]	train's l1: 0.110995	train's huber: 0.0121919	val's l1: 0.204927	val's huber: 0.0366077
# [600]	train's l1: 0.10001	train's huber: 0.0102065	val's l1: 0.203604	val's huber: 0.0364027
# [800]	train's l1: 0.0926113	train's huber: 0.00897612	val's l1: 0.202938	val's huber: 0.0363185
# Did not meet early stopping. Best iteration is:
# [963]	train's l1: 0.0876804	train's huber: 0.00818982	val's l1: 0.202779	val's huber: 0.0363229
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.146817	train's huber: 0.0191401	val's l1: 0.178847	val's huber: 0.0292586
# [400]	train's l1: 0.123214	train's huber: 0.0143838	val's l1: 0.176322	val's huber: 0.0290161
# Early stopping, best iteration is:
# [401]	train's l1: 0.123144	train's huber: 0.0143698	val's l1: 0.176306	val's huber: 0.0290133
# Evaluated only: l1
#    [H4 Trial  2/20] pooled WAPE   27.3512% | tot nhat 27.3512% | da chay 2.0 phut, con khoang 18.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0924042	train's huber: 0.00905816	val's l1: 0.246804	val's huber: 0.0481304
# Early stopping, best iteration is:
# [139]	train's l1: 0.104318	train's huber: 0.0110916	val's l1: 0.24337	val's huber: 0.0469521
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119866	train's huber: 0.013739	val's l1: 0.191815	val's huber: 0.0323746
# Early stopping, best iteration is:
# [249]	train's l1: 0.112893	train's huber: 0.0123617	val's l1: 0.191291	val's huber: 0.0322117
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.121952	train's huber: 0.0141853	val's l1: 0.174392	val's huber: 0.0287307
# [400]	train's l1: 0.102236	train's huber: 0.0104488	val's l1: 0.173191	val's huber: 0.0284288
# [600]	train's l1: 0.0911762	train's huber: 0.00855072	val's l1: 0.172715	val's huber: 0.0282844
# Did not meet early stopping. Best iteration is:
# [671]	train's l1: 0.0882983	train's huber: 0.00808843	val's l1: 0.172598	val's huber: 0.0282688
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.125995	train's huber: 0.0150533	val's l1: 0.20718	val's huber: 0.0370832
# [400]	train's l1: 0.106847	train's huber: 0.0113698	val's l1: 0.204815	val's huber: 0.0366392
# [600]	train's l1: 0.096646	train's huber: 0.0095469	val's l1: 0.203814	val's huber: 0.036504
# Did not meet early stopping. Best iteration is:
# [732]	train's l1: 0.0916775	train's huber: 0.0087263	val's l1: 0.20341	val's huber: 0.0364297
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138856	train's huber: 0.0176724	val's l1: 0.176987	val's huber: 0.0290094
# Early stopping, best iteration is:
# [188]	train's l1: 0.140976	train's huber: 0.0181532	val's l1: 0.176881	val's huber: 0.0289688
# Evaluated only: l1
#    [H4 Trial  3/20] pooled WAPE   27.4187% | tot nhat 27.3512% | da chay 3.2 phut, con khoang 18.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.106101	train's huber: 0.0117218	val's l1: 0.247485	val's huber: 0.0469123
# Early stopping, best iteration is:
# [176]	train's l1: 0.109311	train's huber: 0.0123857	val's l1: 0.247053	val's huber: 0.0468794
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.132727	train's huber: 0.0166095	val's l1: 0.192499	val's huber: 0.0319995
# Early stopping, best iteration is:
# [142]	train's l1: 0.141672	train's huber: 0.0186108	val's l1: 0.192366	val's huber: 0.0320413
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133817	train's huber: 0.0167255	val's l1: 0.17436	val's huber: 0.0282167
# [400]	train's l1: 0.116217	train's huber: 0.0131431	val's l1: 0.172634	val's huber: 0.0278098
# [600]	train's l1: 0.106059	train's huber: 0.0112353	val's l1: 0.172369	val's huber: 0.027742
# [800]	train's l1: 0.0985636	train's huber: 0.00991448	val's l1: 0.172005	val's huber: 0.0276555
# Did not meet early stopping. Best iteration is:
# [794]	train's l1: 0.0987295	train's huber: 0.0099432	val's l1: 0.171962	val's huber: 0.0276513
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136979	train's huber: 0.0174818	val's l1: 0.208804	val's huber: 0.0373367
# [400]	train's l1: 0.120227	train's huber: 0.0140112	val's l1: 0.205914	val's huber: 0.0367409
# [600]	train's l1: 0.110283	train's huber: 0.0121015	val's l1: 0.204839	val's huber: 0.0366345
# [800]	train's l1: 0.102757	train's huber: 0.0107202	val's l1: 0.204241	val's huber: 0.0365415
# Did not meet early stopping. Best iteration is:
# [792]	train's l1: 0.103019	train's huber: 0.0107683	val's l1: 0.204212	val's huber: 0.0365302
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.149393	train's huber: 0.0202159	val's l1: 0.178995	val's huber: 0.0292651
# [400]	train's l1: 0.132258	train's huber: 0.0163686	val's l1: 0.178295	val's huber: 0.0292969
# Early stopping, best iteration is:
# [405]	train's l1: 0.131983	train's huber: 0.0163078	val's l1: 0.178259	val's huber: 0.0292861
# Evaluated only: l1
#    [H4 Trial  4/20] pooled WAPE   27.4265% | tot nhat 27.3512% | da chay 4.1 phut, con khoang 16.3 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0977722	train's huber: 0.00994427	val's l1: 0.247431	val's huber: 0.0481317
# Early stopping, best iteration is:
# [119]	train's l1: 0.121633	train's huber: 0.0134525	val's l1: 0.246208	val's huber: 0.0473411
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.128312	train's huber: 0.015298	val's l1: 0.193516	val's huber: 0.0328538
# Early stopping, best iteration is:
# [283]	train's l1: 0.116389	train's huber: 0.0130086	val's l1: 0.192271	val's huber: 0.0324958
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.13025	train's huber: 0.0156858	val's l1: 0.176453	val's huber: 0.0292566
# [400]	train's l1: 0.108627	train's huber: 0.0116009	val's l1: 0.17474	val's huber: 0.0287931
# Early stopping, best iteration is:
# [364]	train's l1: 0.111425	train's huber: 0.012124	val's l1: 0.174549	val's huber: 0.0287641
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.134254	train's huber: 0.0166118	val's l1: 0.209815	val's huber: 0.0376624
# [400]	train's l1: 0.113833	train's huber: 0.0126558	val's l1: 0.204427	val's huber: 0.0365585
# [600]	train's l1: 0.103045	train's huber: 0.0106581	val's l1: 0.203133	val's huber: 0.0363193
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.101296	train's huber: 0.0103483	val's l1: 0.20293	val's huber: 0.0362873
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.147388	train's huber: 0.0194613	val's l1: 0.17761	val's huber: 0.0290633
# Early stopping, best iteration is:
# [299]	train's l1: 0.134642	train's huber: 0.0167337	val's l1: 0.176379	val's huber: 0.0289251
# Evaluated only: l1
#    [H4 Trial  5/20] pooled WAPE   27.4458% | tot nhat 27.3512% | da chay 5.3 phut, con khoang 16.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0990898	train's huber: 0.010414	val's l1: 0.240895	val's huber: 0.0460302
# Early stopping, best iteration is:
# [209]	train's l1: 0.0977844	train's huber: 0.0101659	val's l1: 0.240658	val's huber: 0.0460265
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.12402	train's huber: 0.0147139	val's l1: 0.191071	val's huber: 0.0319922
# [400]	train's l1: 0.103475	train's huber: 0.0106905	val's l1: 0.191286	val's huber: 0.0320294
# Early stopping, best iteration is:
# [318]	train's l1: 0.110138	train's huber: 0.011938	val's l1: 0.190891	val's huber: 0.0319361
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124613	train's huber: 0.0148539	val's l1: 0.174186	val's huber: 0.0286573
# [400]	train's l1: 0.105506	train's huber: 0.0111767	val's l1: 0.173619	val's huber: 0.02846
# [600]	train's l1: 0.0952593	train's huber: 0.00937931	val's l1: 0.173201	val's huber: 0.0284177
# Early stopping, best iteration is:
# [696]	train's l1: 0.0914844	train's huber: 0.00874133	val's l1: 0.173112	val's huber: 0.0283687
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.128128	train's huber: 0.0156121	val's l1: 0.207625	val's huber: 0.0373354
# [400]	train's l1: 0.109906	train's huber: 0.0120163	val's l1: 0.204267	val's huber: 0.0366215
# [600]	train's l1: 0.0998539	train's huber: 0.0102258	val's l1: 0.203345	val's huber: 0.0364924
# [800]	train's l1: 0.0925467	train's huber: 0.00898353	val's l1: 0.202919	val's huber: 0.036505
# Did not meet early stopping. Best iteration is:
# [919]	train's l1: 0.0891942	train's huber: 0.00843185	val's l1: 0.202721	val's huber: 0.0365039
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.140552	train's huber: 0.0181627	val's l1: 0.177524	val's huber: 0.0292038
# Early stopping, best iteration is:
# [226]	train's l1: 0.136999	train's huber: 0.0173816	val's l1: 0.177436	val's huber: 0.0292109
# Evaluated only: l1
#    [H4 Trial  6/20] pooled WAPE   27.3778% | tot nhat 27.3512% | da chay 6.8 phut, con khoang 16.0 phut
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	train's l1: 0.114259	train's huber: 0.0132207	val's l1: 0.254154	val's huber: 0.049569
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.111404	train's huber: 0.0120172	val's l1: 0.191244	val's huber: 0.0322152
# Early stopping, best iteration is:
# [113]	train's l1: 0.127064	train's huber: 0.0152345	val's l1: 0.190217	val's huber: 0.0318594
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.114082	train's huber: 0.0125387	val's l1: 0.173649	val's huber: 0.0284797
# [400]	train's l1: 0.0952748	train's huber: 0.00914383	val's l1: 0.173474	val's huber: 0.0284412
# Early stopping, best iteration is:
# [450]	train's l1: 0.0920614	train's huber: 0.0086115	val's l1: 0.173189	val's huber: 0.028362
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118699	train's huber: 0.0136364	val's l1: 0.206489	val's huber: 0.0371382
# [400]	train's l1: 0.100629	train's huber: 0.010181	val's l1: 0.204901	val's huber: 0.036924
# [600]	train's l1: 0.0899234	train's huber: 0.00836933	val's l1: 0.204301	val's huber: 0.0368941
# [800]	train's l1: 0.0826082	train's huber: 0.00722306	val's l1: 0.203928	val's huber: 0.0368373
# Did not meet early stopping. Best iteration is:
# [857]	train's l1: 0.0809686	train's huber: 0.00696279	val's l1: 0.20377	val's huber: 0.0368166
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.130696	train's huber: 0.0159356	val's l1: 0.179585	val's huber: 0.0298095
# Early stopping, best iteration is:
# [249]	train's l1: 0.124836	train's huber: 0.0147041	val's l1: 0.179326	val's huber: 0.0298154
# Evaluated only: l1
#    [H4 Trial  7/20] pooled WAPE   27.4762% | tot nhat 27.3512% | da chay 7.5 phut, con khoang 14.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.102194	train's huber: 0.0109524	val's l1: 0.245647	val's huber: 0.0465494
# [400]	train's l1: 0.0847784	train's huber: 0.00784476	val's l1: 0.244303	val's huber: 0.0463288
# Early stopping, best iteration is:
# [314]	train's l1: 0.090358	train's huber: 0.00880594	val's l1: 0.244014	val's huber: 0.0462174
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126494	train's huber: 0.0151815	val's l1: 0.19304	val's huber: 0.0323549
# [400]	train's l1: 0.106372	train's huber: 0.0112209	val's l1: 0.192293	val's huber: 0.03222
# [600]	train's l1: 0.0958955	train's huber: 0.00934709	val's l1: 0.191991	val's huber: 0.0321895
# Did not meet early stopping. Best iteration is:
# [648]	train's l1: 0.0941353	train's huber: 0.00904446	val's l1: 0.191919	val's huber: 0.0321732
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126392	train's huber: 0.0151376	val's l1: 0.174332	val's huber: 0.0287116
# [400]	train's l1: 0.107202	train's huber: 0.011455	val's l1: 0.172844	val's huber: 0.0282974
# [600]	train's l1: 0.0969517	train's huber: 0.00962698	val's l1: 0.172357	val's huber: 0.0281224
# Did not meet early stopping. Best iteration is:
# [646]	train's l1: 0.0950974	train's huber: 0.00931132	val's l1: 0.172252	val's huber: 0.0280968
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.129954	train's huber: 0.0159141	val's l1: 0.208254	val's huber: 0.0373093
# [400]	train's l1: 0.111047	train's huber: 0.0121873	val's l1: 0.204638	val's huber: 0.0365679
# [600]	train's l1: 0.101013	train's huber: 0.0103831	val's l1: 0.203805	val's huber: 0.0364648
# Did not meet early stopping. Best iteration is:
# [680]	train's l1: 0.0980865	train's huber: 0.00988558	val's l1: 0.203515	val's huber: 0.0364255
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.142795	train's huber: 0.0186398	val's l1: 0.176717	val's huber: 0.0289424
# [400]	train's l1: 0.122943	train's huber: 0.0143609	val's l1: 0.176719	val's huber: 0.0291385
# Early stopping, best iteration is:
# [304]	train's l1: 0.130813	train's huber: 0.015997	val's l1: 0.176529	val's huber: 0.0290066
# Evaluated only: l1
#    [H4 Trial  8/20] pooled WAPE   27.3508% | tot nhat 27.3508% | da chay 8.9 phut, con khoang 13.3 phut
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	train's l1: 0.104591	train's huber: 0.011393	val's l1: 0.243069	val's huber: 0.0471089
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [82]	train's l1: 0.117039	train's huber: 0.0132779	val's l1: 0.192318	val's huber: 0.0325653
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0938829	train's huber: 0.00908437	val's l1: 0.173694	val's huber: 0.0286233
# Early stopping, best iteration is:
# [274]	train's l1: 0.0857824	train's huber: 0.00775716	val's l1: 0.173186	val's huber: 0.0284878
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0986398	train's huber: 0.00995893	val's l1: 0.204062	val's huber: 0.0367813
# [400]	train's l1: 0.0814115	train's huber: 0.00714463	val's l1: 0.20377	val's huber: 0.0369574
# Did not meet early stopping. Best iteration is:
# [403]	train's l1: 0.0812587	train's huber: 0.00712441	val's l1: 0.203747	val's huber: 0.0369537
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.109878	train's huber: 0.0118593	val's l1: 0.178954	val's huber: 0.0297902
# Early stopping, best iteration is:
# [135]	train's l1: 0.121007	train's huber: 0.0140037	val's l1: 0.178402	val's huber: 0.0295887
# Evaluated only: l1
#    [H4 Trial  9/20] pooled WAPE   27.4382% | tot nhat 27.3508% | da chay 9.5 phut, con khoang 11.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112913	train's huber: 0.0130303	val's l1: 0.250227	val's huber: 0.0481167
# [400]	train's l1: 0.0966651	train's huber: 0.00982629	val's l1: 0.249113	val's huber: 0.0477144
# Early stopping, best iteration is:
# [402]	train's l1: 0.0965457	train's huber: 0.009802	val's l1: 0.249077	val's huber: 0.0477151
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.142094	train's huber: 0.018627	val's l1: 0.192328	val's huber: 0.0320674
# Early stopping, best iteration is:
# [216]	train's l1: 0.140144	train's huber: 0.0181947	val's l1: 0.192041	val's huber: 0.0319882
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.143584	train's huber: 0.0188089	val's l1: 0.176169	val's huber: 0.0288415
# [400]	train's l1: 0.125779	train's huber: 0.014979	val's l1: 0.173853	val's huber: 0.0282805
# [600]	train's l1: 0.11533	train's huber: 0.0129191	val's l1: 0.17298	val's huber: 0.0280437
# [800]	train's l1: 0.107725	train's huber: 0.0114834	val's l1: 0.172665	val's huber: 0.0279092
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.104627	train's huber: 0.0109141	val's l1: 0.172402	val's huber: 0.0278594
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.1467	train's huber: 0.0196493	val's l1: 0.210877	val's huber: 0.0378639
# [400]	train's l1: 0.129805	train's huber: 0.0159588	val's l1: 0.207202	val's huber: 0.0370292
# [600]	train's l1: 0.119656	train's huber: 0.0138554	val's l1: 0.20594	val's huber: 0.0368187
# [800]	train's l1: 0.112371	train's huber: 0.0124269	val's l1: 0.204744	val's huber: 0.0366142
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.109155	train's huber: 0.0118173	val's l1: 0.204241	val's huber: 0.0365424
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.158594	train's huber: 0.0224351	val's l1: 0.179763	val's huber: 0.0293851
# [400]	train's l1: 0.141797	train's huber: 0.0184139	val's l1: 0.179052	val's huber: 0.0294114
# [600]	train's l1: 0.131746	train's huber: 0.0162009	val's l1: 0.179043	val's huber: 0.0295671
# Early stopping, best iteration is:
# [510]	train's l1: 0.135795	train's huber: 0.0170778	val's l1: 0.178845	val's huber: 0.0294565
# Evaluated only: l1
#    [H4 Trial 10/20] pooled WAPE   27.4754% | tot nhat 27.3508% | da chay 10.8 phut, con khoang 10.8 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0920038	train's huber: 0.00906702	val's l1: 0.245754	val's huber: 0.0464838
# [400]	train's l1: 0.0774981	train's huber: 0.00660808	val's l1: 0.245436	val's huber: 0.0464791
# Early stopping, best iteration is:
# [398]	train's l1: 0.077578	train's huber: 0.00661963	val's l1: 0.24541	val's huber: 0.0464652
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.116487	train's huber: 0.0132004	val's l1: 0.190734	val's huber: 0.0315316
# Early stopping, best iteration is:
# [193]	train's l1: 0.117471	train's huber: 0.0133969	val's l1: 0.190632	val's huber: 0.0315246
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117969	train's huber: 0.0135194	val's l1: 0.173636	val's huber: 0.0281883
# [400]	train's l1: 0.100152	train's huber: 0.010184	val's l1: 0.172775	val's huber: 0.0279327
# Early stopping, best iteration is:
# [474]	train's l1: 0.0961781	train's huber: 0.00951063	val's l1: 0.172621	val's huber: 0.0278899
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.121612	train's huber: 0.0142626	val's l1: 0.206069	val's huber: 0.0364744
# [400]	train's l1: 0.103898	train's huber: 0.0109006	val's l1: 0.20444	val's huber: 0.0361914
# [600]	train's l1: 0.0938934	train's huber: 0.00919785	val's l1: 0.203434	val's huber: 0.0360829
# [800]	train's l1: 0.0869796	train's huber: 0.0080496	val's l1: 0.203028	val's huber: 0.0360658
# [1000]	train's l1: 0.0820849	train's huber: 0.00727137	val's l1: 0.203028	val's huber: 0.0361259
# Early stopping, best iteration is:
# [918]	train's l1: 0.083943	train's huber: 0.0075605	val's l1: 0.202858	val's huber: 0.0360456
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133535	train's huber: 0.016633	val's l1: 0.178252	val's huber: 0.0291383
# Early stopping, best iteration is:
# [153]	train's l1: 0.140698	train's huber: 0.0181927	val's l1: 0.178087	val's huber: 0.0290509
# Evaluated only: l1
#    [H4 Trial 11/20] pooled WAPE   27.3955% | tot nhat 27.3508% | da chay 11.9 phut, con khoang 9.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.104103	train's huber: 0.0113001	val's l1: 0.23981	val's huber: 0.0463269
# Early stopping, best iteration is:
# [212]	train's l1: 0.10178	train's huber: 0.0109313	val's l1: 0.239324	val's huber: 0.0461924
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.129404	train's huber: 0.0155219	val's l1: 0.196102	val's huber: 0.033423
# Early stopping, best iteration is:
# [286]	train's l1: 0.116251	train's huber: 0.0131276	val's l1: 0.193118	val's huber: 0.032713
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.13041	train's huber: 0.0155961	val's l1: 0.176775	val's huber: 0.0293684
# [400]	train's l1: 0.106762	train's huber: 0.0113946	val's l1: 0.17372	val's huber: 0.0287134
# Early stopping, best iteration is:
# [444]	train's l1: 0.103802	train's huber: 0.0108517	val's l1: 0.173585	val's huber: 0.028685
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.134526	train's huber: 0.0165486	val's l1: 0.211917	val's huber: 0.0381539
# [400]	train's l1: 0.111542	train's huber: 0.0122966	val's l1: 0.205476	val's huber: 0.0368741
# [600]	train's l1: 0.100455	train's huber: 0.0102872	val's l1: 0.203704	val's huber: 0.0365138
# [800]	train's l1: 0.0927666	train's huber: 0.00901078	val's l1: 0.203038	val's huber: 0.03643
# [1000]	train's l1: 0.0871868	train's huber: 0.00811467	val's l1: 0.202674	val's huber: 0.0364068
# Did not meet early stopping. Best iteration is:
# [1103]	train's l1: 0.0847823	train's huber: 0.00773962	val's l1: 0.2025	val's huber: 0.0363992
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.14706	train's huber: 0.0192558	val's l1: 0.179201	val's huber: 0.0293529
# [400]	train's l1: 0.123348	train's huber: 0.0144279	val's l1: 0.176957	val's huber: 0.0291449
# Early stopping, best iteration is:
# [347]	train's l1: 0.127836	train's huber: 0.0153278	val's l1: 0.176662	val's huber: 0.0290431
# Evaluated only: l1
#    [H4 Trial 12/20] pooled WAPE   27.4160% | tot nhat 27.3508% | da chay 13.6 phut, con khoang 9.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.105606	train's huber: 0.0118093	val's l1: 0.244679	val's huber: 0.0473055
# Early stopping, best iteration is:
# [103]	train's l1: 0.13408	train's huber: 0.0162538	val's l1: 0.24286	val's huber: 0.0454596
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.124147	train's huber: 0.0147102	val's l1: 0.193168	val's huber: 0.0328373
# Early stopping, best iteration is:
# [283]	train's l1: 0.112077	train's huber: 0.0123963	val's l1: 0.192641	val's huber: 0.0326508
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.123169	train's huber: 0.0144533	val's l1: 0.17466	val's huber: 0.0289846
# [400]	train's l1: 0.101791	train's huber: 0.0105632	val's l1: 0.17359	val's huber: 0.0286463
# Did not meet early stopping. Best iteration is:
# [473]	train's l1: 0.0970754	train's huber: 0.00972961	val's l1: 0.173382	val's huber: 0.0285769
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126302	train's huber: 0.0151058	val's l1: 0.208462	val's huber: 0.037437
# [400]	train's l1: 0.106007	train's huber: 0.0113241	val's l1: 0.203962	val's huber: 0.0365115
# Did not meet early stopping. Best iteration is:
# [480]	train's l1: 0.100983	train's huber: 0.0104193	val's l1: 0.203519	val's huber: 0.0364541
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138845	train's huber: 0.0176287	val's l1: 0.177153	val's huber: 0.0290758
# Early stopping, best iteration is:
# [287]	train's l1: 0.127356	train's huber: 0.0152743	val's l1: 0.176269	val's huber: 0.0289405
# Evaluated only: l1
#    [H4 Trial 13/20] pooled WAPE   27.4187% | tot nhat 27.3508% | da chay 14.8 phut, con khoang 8.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110211	train's huber: 0.012603	val's l1: 0.243053	val's huber: 0.0463158
# Early stopping, best iteration is:
# [297]	train's l1: 0.0994593	train's huber: 0.0105073	val's l1: 0.242004	val's huber: 0.0461959
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136277	train's huber: 0.0173096	val's l1: 0.191614	val's huber: 0.0321073
# [400]	train's l1: 0.115706	train's huber: 0.0130604	val's l1: 0.190707	val's huber: 0.0318474
# Early stopping, best iteration is:
# [438]	train's l1: 0.113093	train's huber: 0.0125473	val's l1: 0.190545	val's huber: 0.0317929
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136774	train's huber: 0.0172724	val's l1: 0.176196	val's huber: 0.0290841
# [400]	train's l1: 0.117297	train's huber: 0.0134069	val's l1: 0.173915	val's huber: 0.0284475
# [600]	train's l1: 0.106606	train's huber: 0.0113963	val's l1: 0.173164	val's huber: 0.0282126
# [800]	train's l1: 0.0993878	train's huber: 0.0101082	val's l1: 0.172888	val's huber: 0.0281105
# [1000]	train's l1: 0.0935873	train's huber: 0.00910945	val's l1: 0.172765	val's huber: 0.0280664
# Did not meet early stopping. Best iteration is:
# [1027]	train's l1: 0.0928956	train's huber: 0.00899511	val's l1: 0.172724	val's huber: 0.0280664
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.139663	train's huber: 0.0179846	val's l1: 0.210073	val's huber: 0.0376462
# [400]	train's l1: 0.121044	train's huber: 0.014193	val's l1: 0.205757	val's huber: 0.0368043
# [600]	train's l1: 0.110667	train's huber: 0.0121815	val's l1: 0.204423	val's huber: 0.0365988
# [800]	train's l1: 0.103432	train's huber: 0.0108676	val's l1: 0.203588	val's huber: 0.0364893
# [1000]	train's l1: 0.0977387	train's huber: 0.00988087	val's l1: 0.203058	val's huber: 0.0364457
# Did not meet early stopping. Best iteration is:
# [1023]	train's l1: 0.0971723	train's huber: 0.00978952	val's l1: 0.202981	val's huber: 0.0364312
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.152461	train's huber: 0.0208196	val's l1: 0.178237	val's huber: 0.0291707
# [400]	train's l1: 0.13338	train's huber: 0.016579	val's l1: 0.17683	val's huber: 0.0290801
# Early stopping, best iteration is:
# [402]	train's l1: 0.13325	train's huber: 0.0165556	val's l1: 0.176772	val's huber: 0.0290673
# Evaluated only: l1
#    [H4 Trial 14/20] pooled WAPE   27.3154% | tot nhat 27.3154% | da chay 16.3 phut, con khoang 7.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0950751	train's huber: 0.00961302	val's l1: 0.244657	val's huber: 0.046828
# Early stopping, best iteration is:
# [272]	train's l1: 0.0878259	train's huber: 0.00831862	val's l1: 0.243703	val's huber: 0.0466523
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.120267	train's huber: 0.0139154	val's l1: 0.190435	val's huber: 0.0320365
# Early stopping, best iteration is:
# [247]	train's l1: 0.114533	train's huber: 0.0127606	val's l1: 0.190414	val's huber: 0.0320352
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.121964	train's huber: 0.0142614	val's l1: 0.173926	val's huber: 0.0283693
# [400]	train's l1: 0.103793	train's huber: 0.0108265	val's l1: 0.172424	val's huber: 0.0279481
# Did not meet early stopping. Best iteration is:
# [585]	train's l1: 0.0940427	train's huber: 0.00912617	val's l1: 0.172001	val's huber: 0.0278835
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.125792	train's huber: 0.0151206	val's l1: 0.206525	val's huber: 0.0370034
# [400]	train's l1: 0.1078	train's huber: 0.0116158	val's l1: 0.204604	val's huber: 0.0367125
# Did not meet early stopping. Best iteration is:
# [585]	train's l1: 0.0981261	train's huber: 0.00988678	val's l1: 0.203656	val's huber: 0.0365538
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.137919	train's huber: 0.0175434	val's l1: 0.177289	val's huber: 0.0290815
# Early stopping, best iteration is:
# [205]	train's l1: 0.137282	train's huber: 0.0173996	val's l1: 0.177217	val's huber: 0.029075
# Evaluated only: l1
#    [H4 Trial 15/20] pooled WAPE   27.3686% | tot nhat 27.3154% | da chay 17.3 phut, con khoang 5.8 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.108881	train's huber: 0.0121801	val's l1: 0.252584	val's huber: 0.0484054
# [400]	train's l1: 0.0910675	train's huber: 0.00889557	val's l1: 0.251478	val's huber: 0.0483278
# Early stopping, best iteration is:
# [374]	train's l1: 0.092726	train's huber: 0.00918716	val's l1: 0.25141	val's huber: 0.0483243
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136462	train's huber: 0.0173302	val's l1: 0.191247	val's huber: 0.031727
# [400]	train's l1: 0.116142	train's huber: 0.0131195	val's l1: 0.190029	val's huber: 0.0313591
# [600]	train's l1: 0.105375	train's huber: 0.0110365	val's l1: 0.190107	val's huber: 0.0313395
# Early stopping, best iteration is:
# [522]	train's l1: 0.109043	train's huber: 0.0117297	val's l1: 0.189972	val's huber: 0.0313269
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136679	train's huber: 0.0172399	val's l1: 0.176457	val's huber: 0.0289462
# [400]	train's l1: 0.117703	train's huber: 0.0134752	val's l1: 0.173834	val's huber: 0.0282647
# [600]	train's l1: 0.107379	train's huber: 0.0114961	val's l1: 0.172967	val's huber: 0.0279947
# [800]	train's l1: 0.100033	train's huber: 0.0101632	val's l1: 0.172433	val's huber: 0.0278335
# [1000]	train's l1: 0.0942048	train's huber: 0.00915799	val's l1: 0.172444	val's huber: 0.0278304
# Early stopping, best iteration is:
# [905]	train's l1: 0.0967321	train's huber: 0.00958778	val's l1: 0.172253	val's huber: 0.0277915
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.140168	train's huber: 0.0180833	val's l1: 0.21043	val's huber: 0.0373264
# [400]	train's l1: 0.121504	train's huber: 0.0142317	val's l1: 0.205458	val's huber: 0.0362162
# [600]	train's l1: 0.111422	train's huber: 0.0122618	val's l1: 0.204253	val's huber: 0.0359791
# [800]	train's l1: 0.104399	train's huber: 0.0109795	val's l1: 0.203353	val's huber: 0.0358328
# [1000]	train's l1: 0.0984772	train's huber: 0.00995316	val's l1: 0.203005	val's huber: 0.0358065
# Did not meet early stopping. Best iteration is:
# [1054]	train's l1: 0.097115	train's huber: 0.00972179	val's l1: 0.202792	val's huber: 0.0357735
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.152592	train's huber: 0.0208797	val's l1: 0.178256	val's huber: 0.0289604
# [400]	train's l1: 0.133751	train's huber: 0.0166562	val's l1: 0.177105	val's huber: 0.0288427
# Early stopping, best iteration is:
# [372]	train's l1: 0.135615	train's huber: 0.0170496	val's l1: 0.176965	val's huber: 0.0287943
# Evaluated only: l1
#    [H4 Trial 16/20] pooled WAPE   27.3869% | tot nhat 27.3154% | da chay 18.8 phut, con khoang 4.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0924173	train's huber: 0.00910374	val's l1: 0.246367	val's huber: 0.0471589
# Early stopping, best iteration is:
# [224]	train's l1: 0.0894897	train's huber: 0.00859351	val's l1: 0.24597	val's huber: 0.0470794
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118821	train's huber: 0.0135899	val's l1: 0.191623	val's huber: 0.0322071
# Early stopping, best iteration is:
# [237]	train's l1: 0.113802	train's huber: 0.0125967	val's l1: 0.191384	val's huber: 0.0321818
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.120119	train's huber: 0.0138714	val's l1: 0.17426	val's huber: 0.0285465
# [400]	train's l1: 0.100938	train's huber: 0.0102899	val's l1: 0.173258	val's huber: 0.0282802
# Early stopping, best iteration is:
# [478]	train's l1: 0.0963263	train's huber: 0.00949071	val's l1: 0.172795	val's huber: 0.0281664
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.12421	train's huber: 0.0147615	val's l1: 0.206375	val's huber: 0.036909
# [400]	train's l1: 0.106001	train's huber: 0.0112353	val's l1: 0.20385	val's huber: 0.0364167
# [600]	train's l1: 0.0954971	train's huber: 0.00940642	val's l1: 0.203068	val's huber: 0.0362967
# [800]	train's l1: 0.088326	train's huber: 0.00821205	val's l1: 0.202687	val's huber: 0.0362889
# [1000]	train's l1: 0.0828667	train's huber: 0.00735654	val's l1: 0.202445	val's huber: 0.0363051
# Did not meet early stopping. Best iteration is:
# [960]	train's l1: 0.0838034	train's huber: 0.0074975	val's l1: 0.202406	val's huber: 0.0362759
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136591	train's huber: 0.0172048	val's l1: 0.177459	val's huber: 0.0291983
# Early stopping, best iteration is:
# [215]	train's l1: 0.134607	train's huber: 0.016779	val's l1: 0.177168	val's huber: 0.029165
# Evaluated only: l1
#    [H4 Trial 17/20] pooled WAPE   27.3929% | tot nhat 27.3154% | da chay 20.0 phut, con khoang 3.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112552	train's huber: 0.0130909	val's l1: 0.245027	val's huber: 0.0466378
# [400]	train's l1: 0.0949624	train's huber: 0.00966081	val's l1: 0.242682	val's huber: 0.0461745
# Did not meet early stopping. Best iteration is:
# [516]	train's l1: 0.0895059	train's huber: 0.00866027	val's l1: 0.242325	val's huber: 0.0461148
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.138798	train's huber: 0.0179167	val's l1: 0.190752	val's huber: 0.03182
# [400]	train's l1: 0.119177	train's huber: 0.0137694	val's l1: 0.189798	val's huber: 0.0315444
# Early stopping, best iteration is:
# [372]	train's l1: 0.12111	train's huber: 0.014163	val's l1: 0.189621	val's huber: 0.0314866
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.139119	train's huber: 0.0178294	val's l1: 0.176879	val's huber: 0.0290938
# [400]	train's l1: 0.120248	train's huber: 0.0140069	val's l1: 0.174359	val's huber: 0.0284403
# Did not meet early stopping. Best iteration is:
# [561]	train's l1: 0.111586	train's huber: 0.0123143	val's l1: 0.17363	val's huber: 0.028266
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.141953	train's huber: 0.0185444	val's l1: 0.209913	val's huber: 0.0376309
# [400]	train's l1: 0.124106	train's huber: 0.0148173	val's l1: 0.205925	val's huber: 0.036761
# Did not meet early stopping. Best iteration is:
# [565]	train's l1: 0.115533	train's huber: 0.0131451	val's l1: 0.204843	val's huber: 0.0365742
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.154706	train's huber: 0.0214053	val's l1: 0.17864	val's huber: 0.0291841
# [400]	train's l1: 0.136005	train's huber: 0.0171505	val's l1: 0.177234	val's huber: 0.0290693
# Early stopping, best iteration is:
# [376]	train's l1: 0.13766	train's huber: 0.0175161	val's l1: 0.177182	val's huber: 0.0290455
# Evaluated only: l1
#    [H4 Trial 18/20] pooled WAPE   27.3300% | tot nhat 27.3154% | da chay 21.1 phut, con khoang 2.3 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.114301	train's huber: 0.0134034	val's l1: 0.243594	val's huber: 0.0465504
# [400]	train's l1: 0.0967712	train's huber: 0.00996482	val's l1: 0.242012	val's huber: 0.0463547
# Did not meet early stopping. Best iteration is:
# [531]	train's l1: 0.0901885	train's huber: 0.00875446	val's l1: 0.241822	val's huber: 0.0463745
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.142349	train's huber: 0.0186335	val's l1: 0.190199	val's huber: 0.031862
# [400]	train's l1: 0.122332	train's huber: 0.014391	val's l1: 0.189141	val's huber: 0.0314692
# Early stopping, best iteration is:
# [333]	train's l1: 0.127725	train's huber: 0.0155203	val's l1: 0.188839	val's huber: 0.0313965
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.143243	train's huber: 0.0186567	val's l1: 0.177072	val's huber: 0.029107
# [400]	train's l1: 0.124495	train's huber: 0.0147932	val's l1: 0.174277	val's huber: 0.0284459
# Did not meet early stopping. Best iteration is:
# [563]	train's l1: 0.115577	train's huber: 0.0130276	val's l1: 0.173438	val's huber: 0.0282128
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.146367	train's huber: 0.0194765	val's l1: 0.211155	val's huber: 0.0379414
# [400]	train's l1: 0.128116	train's huber: 0.0155785	val's l1: 0.20582	val's huber: 0.0367399
# Did not meet early stopping. Best iteration is:
# [562]	train's l1: 0.119285	train's huber: 0.0138126	val's l1: 0.204508	val's huber: 0.0364884
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.158656	train's huber: 0.0223056	val's l1: 0.179323	val's huber: 0.029279
# [400]	train's l1: 0.140255	train's huber: 0.0180824	val's l1: 0.177627	val's huber: 0.0290964
# Early stopping, best iteration is:
# [359]	train's l1: 0.143081	train's huber: 0.018716	val's l1: 0.177498	val's huber: 0.0290314
# Evaluated only: l1
#    [H4 Trial 19/20] pooled WAPE   27.3354% | tot nhat 27.3154% | da chay 22.2 phut, con khoang 1.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.101436	train's huber: 0.0108562	val's l1: 0.244652	val's huber: 0.0468404
# Early stopping, best iteration is:
# [263]	train's l1: 0.0949346	train's huber: 0.00959461	val's l1: 0.244145	val's huber: 0.046781
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.129257	train's huber: 0.0158397	val's l1: 0.188528	val's huber: 0.0313208
# Early stopping, best iteration is:
# [275]	train's l1: 0.119896	train's huber: 0.0138737	val's l1: 0.188366	val's huber: 0.0312973
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.130863	train's huber: 0.016103	val's l1: 0.174361	val's huber: 0.0284253
# [400]	train's l1: 0.112549	train's huber: 0.0124636	val's l1: 0.173459	val's huber: 0.02815
# [600]	train's l1: 0.101751	train's huber: 0.0105022	val's l1: 0.172967	val's huber: 0.0280259
# Early stopping, best iteration is:
# [626]	train's l1: 0.100628	train's huber: 0.0103102	val's l1: 0.172773	val's huber: 0.0279947
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.134727	train's huber: 0.016996	val's l1: 0.208218	val's huber: 0.0373157
# [400]	train's l1: 0.116997	train's huber: 0.0133767	val's l1: 0.205027	val's huber: 0.0366656
# [600]	train's l1: 0.106485	train's huber: 0.0113897	val's l1: 0.204205	val's huber: 0.0366159
# [800]	train's l1: 0.0989228	train's huber: 0.0100274	val's l1: 0.203574	val's huber: 0.0364863
# Did not meet early stopping. Best iteration is:
# [815]	train's l1: 0.0985029	train's huber: 0.00995824	val's l1: 0.20353	val's huber: 0.0364825
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.147169	train's huber: 0.0196834	val's l1: 0.178856	val's huber: 0.0293112
# Early stopping, best iteration is:
# [286]	train's l1: 0.137934	train's huber: 0.017591	val's l1: 0.178638	val's huber: 0.029403
# Evaluated only: l1
#    [H4 Trial 20/20] pooled WAPE   27.3279% | tot nhat 27.3154% | da chay 23.3 phut, con khoang 0.0 phut
#
# Pooled WAPE tot nhat H4 tren 5 fold = 27.3154%
#     Loai [19, 24] (capacity_kw khong dang tin): 476,868 -> 454,160 dong
# Lọc v3_val_selected: 482,076 -> 454,160 dòng (49 cột)
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.15259	train's huber: 0.0208631	val's l1: 0.17798	val's huber: 0.0290806
# Early stopping, best iteration is:
# [238]	train's l1: 0.147565	train's huber: 0.0197368	val's l1: 0.177173	val's huber: 0.0289253
# Evaluated only: l1
# Train H4 xong sau 0.3 phut | dung som tai 238 cay
# Da du bao 199,469 dong (H4)

# %% [markdown]
# ## 12.1. Đường cong huấn luyện — chẩn đoán quá khớp
#
# Vẽ sai số trên tập **train** và tập **validation** theo từng vòng boosting, giống đường loss
# của mạng nơ-ron. Đây là bằng chứng trực quan cho câu hỏi *"mô hình có học vẹt không"*.
#
# **Cách đọc.** Train giảm đều mà validation đi ngang rồi ngóc lên nghĩa là bắt đầu quá khớp;
# điểm thấp nhất của đường validation chính là số cây nên dừng. Hai đường bám nhau và cùng đi
# xuống nghĩa là còn học được, chưa quá khớp.
#
# Tầng trái là $L_1$ trên mục tiêu chuẩn hoá $k$ — lấy trực tiếp từ `evals_result_` nên có đủ
# mọi vòng. Tầng phải là **WAPE thật trên thang kWh**, phạm vi `measured_daylight` tại $T+h$ —
# đây mới là chỉ số báo cáo công bố, nên nó mới là đường đáng tin để kết luận.
#
# Validation ở đây là `v3_val_selected`, **chưa từng tham gia huấn luyện**.

# %%
# === DUONG CONG HUAN LUYEN ===
# Fit rieng mot ban co eval_set de lay evals_result_ (ban `model` o cell tren fit khong
# co eval_set nen khong co duong cong). Ban nay CHI dung de ve, khong thay the model.
import matplotlib.pyplot as plt

BUOC_DO_DUONG_CONG = 50          # do WAPE that moi bao nhieu cay
SO_CAY_DUONG_CONG = int(BEST_PARAMS.get('n_estimators', 685))

_p_dc = {k: v for k, v in BEST_PARAMS.items()
         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
_p_dc['n_estimators'] = SO_CAY_DUONG_CONG

_Xva_dc = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_yva_dc = val_h['k_target'].astype(DTYPE)

_lich_su = {}
_m_dc = lgb.LGBMRegressor(**_p_dc)
_m_dc.fit(X_dev, y_dev, sample_weight=w_dev,
          eval_set=[(X_dev, y_dev), (_Xva_dc, _yva_dc)],
          eval_names=['train', 'val'], eval_metric='l1',
          callbacks=[lgb.record_evaluation(_lich_su),
                     early_stopping(EARLY_STOPPING_ROUNDS, first_metric_only=True, verbose=True),
                     lgb.log_evaluation(period=200)])
SO_CAY_DUONG_CONG = int(_m_dc.best_iteration_)
# WAPE chi tinh mot moc de tom tat; do thi dung loss theo tung vong de thay early stopping.
BUOC_DO_DUONG_CONG = SO_CAY_DUONG_CONG


def _wape_tai(khung, X, mask, so_cay):
    """WAPE that (kWh) khi chi dung `so_cay` cay dau tien."""
    _k = np.clip(_m_dc.predict(X, num_iteration=so_cay), 0, 1.5)
    _se = khung['sin_elevation'].to_numpy()
    _yp = np.minimum(_k * mau_chuan_hoa(khung),
                     khung['tran_cong_suat'].to_numpy() * 1.02)
    _yp = np.where(_se <= EPS_ELEV, 0.0, _yp)
    _yt = khung['y_true'].to_numpy()
    return float(np.nansum(np.abs(_yt[mask] - _yp[mask]))
                 / np.nansum(np.abs(_yt[mask])) * 100)


# Mask pham vi cong bo: xet NHAN tai T+h, khong phai cot tai T
def _mask_cong_bo(khung):
    _n = _cot_loc(khung, 'energy_source')
    _d = _cot_loc(khung, 'is_daylight')
    _m = (_n == 'measured').to_numpy() if _n is not None else np.ones(len(khung), bool)
    if _d is not None:
        _m = _m & _d.fillna(False).astype(bool).to_numpy()
    return _m


_dev_dc = dev_h.loc[X_dev.index]
_m_tr = _mask_cong_bo(_dev_dc)
_m_va = _mask_cong_bo(val_h)

_moc = list(range(BUOC_DO_DUONG_CONG, SO_CAY_DUONG_CONG + 1, BUOC_DO_DUONG_CONG))
_w_tr = [_wape_tai(_dev_dc, X_dev, _m_tr, i) for i in _moc]
_w_va = [_wape_tai(val_h, _Xva_dc, _m_va, i) for i in _moc]
_i_tot = int(np.argmin(_w_va))
_w_min = _w_va[_i_tot]

# VUNG BINH NGUYEN: moi moc co WAPE val nam trong nguong tuong doi so voi diem thap nhat.
# Them cay ngoai vung nay khong cai thien co y nghia, chi lam mo hinh nang va de qua khop.
DUNG_NGUONG = 0.001                      # 0,1% tuong doi
_trong_vung = [j for j, w in enumerate(_w_va) if w <= _w_min * (1 + DUNG_NGUONG)]
_j_dau, _j_cuoi = _trong_vung[0], _trong_vung[-1]
SO_CAY_KHUYEN_NGHI = _moc[_j_dau]        # nho nhat ma van dat -> re nhat, it qua khop nhat

print(f"WAPE val thap nhat  : {_w_min:.4f}% tai {_moc[_i_tot]} cay "
      f"(train cung moc {_w_tr[_i_tot]:.4f}%)")
print(f"Vung binh nguyen    : {_moc[_j_dau]} - {_moc[_j_cuoi]} cay "
      f"(WAPE val trong {DUNG_NGUONG*100:.1f}% so voi diem thap nhat)")
print(f"So cay khuyen nghi  : {SO_CAY_KHUYEN_NGHI}")
print(f"Dang dung           : {SO_CAY_DUONG_CONG} cay -> "
      f"{'DU, nen giam' if SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG * 0.9 else 'hop ly'}")
print(f"Khoang cach train-val tai diem thap nhat: "
      f"{_w_va[_i_tot] - _w_tr[_i_tot]:+.4f} diem")

_fig, _ax = plt.subplots(1, 2, figsize=(15, 5.2))
_l_tr, _l_va = _lich_su['train']['l1'], _lich_su['val']['l1']
_x = np.arange(1, len(_l_tr) + 1)
_ax[0].plot(_x, _l_tr, lw=1.4, label='train')
_ax[0].plot(_x, _l_va, lw=1.4, label='validation')
_ax[0].set_xlabel('Số vòng boosting')
_ax[0].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[0].set_title(f'Đường cong huấn luyện — {LOSS_NAME.upper()}, H{HORIZON_STEPS}')
_ax[0].axvline(_m_dc.best_iteration_, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_m_dc.best_iteration_} cay')
_ax[0].legend(); _ax[0].grid(alpha=.3)

_best, _end = int(_m_dc.best_iteration_), len(_l_va)
_start = max(1, _best - 20)
_x_zoom = np.arange(_start, _end + 1)
_ax[1].plot(_x_zoom, _l_tr[_start - 1:_end], lw=1.5, label='train')
_ax[1].plot(_x_zoom, _l_va[_start - 1:_end], lw=1.7, label='validation')
_span_label = (f'{_end - _best} vòng xác nhận không cải thiện'
               if _end >= _best + EARLY_STOPPING_ROUNDS
               else f'chạm trần {SO_CAY_DUONG_CONG} cây')
_ax[1].axvspan(_best, _end, color='crimson', alpha=.12, label=_span_label)
_ax[1].axvline(_best, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_best} cây')
_ax[1].set_xlabel('Số vòng boosting')
_ax[1].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[1].set_title('Vùng early stopping trên validation')
_ax[1].legend(); _ax[1].grid(alpha=.3)
_fig.suptitle('Chẩn đoán quá khớp — validation là v3_val_selected, chưa từng được học',
              y=1.0, fontsize=10)
plt.tight_layout(); plt.show()

# ── Train lai mo hinh cuoi o so cay khuyen nghi ──
# Dat False neu muon giu nguyen so cay cua Optuna.
DUNG_SO_CAY_KHUYEN_NGHI = False  # early stopping da chon best_iteration_ tu validation

if DUNG_SO_CAY_KHUYEN_NGHI and SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG:
    print(f"\nTrain lai mo hinh cuoi voi {SO_CAY_KHUYEN_NGHI} cay "
          f"(thay vi {SO_CAY_DUONG_CONG})...")
    BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': SO_CAY_KHUYEN_NGHI}
    model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev)

    # Du bao lai tren val de moi bang metric phia sau dung mo hinh moi
    _k2 = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
    val_h['y_pred'] = np.minimum(_k2 * mau_chuan_hoa(val_h),
                                 val_h['tran_cong_suat'].to_numpy() * 1.02)
    val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
    _m2 = metrics_3_pham_vi(val_h)['measured_daylight']
    print(f"WAPE val sau khi giam so cay: {_m2['wape']:.4f}%  (n={_m2['n']:,})")
    print("BEST_PARAMS da cap nhat -> cac cell export phia sau se ghi so cay moi.")
else:
    print(f"\nGiu nguyen {SO_CAY_DUONG_CONG} cay.")

pd.DataFrame({'so_cay': _moc, 'wape_train': _w_tr, 'wape_val': _w_va,
              'trong_vung_dung_som': [j in _trong_vung for j in range(len(_moc))]}).head(12)
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.15259	train's huber: 0.0208631	val's l1: 0.17798	val's huber: 0.0290806
# Did not meet early stopping. Best iteration is:
# [238]	train's l1: 0.147565	train's huber: 0.0197368	val's l1: 0.177173	val's huber: 0.0289253
# Evaluated only: l1
# WAPE val thap nhat  : 25.7893% tai 238 cay (train cung moc 21.3590%)
# Vung binh nguyen    : 238 - 238 cay (WAPE val trong 0.1% so voi diem thap nhat)
# So cay khuyen nghi  : 238
# Dang dung           : 238 cay -> hop ly
# Khoang cach train-val tai diem thap nhat: +4.4303 diem
# Giu nguyen 238 cay.
#    so_cay  wape_train   wape_val  trong_vung_dung_som
# 0     238   21.359021  25.789314                 True

# %%
# ── Kiem chung tre pha + metric cho H4 (dung lai quet_do_tre/metrics_3_pham_vi) ──
_quet = quet_do_tre(val_h)
_k_tot = min(_quet, key=_quet.get)
print("--- QUET DO TRE H4 - TOAN BO 42 TRAM (SAU KHI LOAI SITE 19/24) ---")
for k, v in _quet.items():
    danh_dau = '  <== nho nhat' if k == _k_tot else ''
    print(f"   k={k} ({k * 15:>2} phut truoc): RMSE {v:.4f}{danh_dau}")
print(f"\nKet luan H4: {'KHONG TRE PHA' if _k_tot == 0 else f'TRE {_k_tot} BUOC = {_k_tot * 15} PHUT'}")

_rows = []
for _s, _z in val_h[val_h['is_daylight'].fillna(False).astype(bool)].groupby(SITE_COL):
    _z = _z.sort_values(TIMESTAMP_COL)
    _r = {}
    for k in range(0, 3):
        _yt = _z['y_true'].shift(k)
        _m = _yt.notna()
        _r[k] = float(np.sqrt(np.mean((_z['y_pred'][_m] - _yt[_m]) ** 2)))
    _rows.append({'site_id': _s, 'k_tot_nhat': min(_r, key=_r.get)})
df_tre = pd.DataFrame(_rows)
print(f"So tram khong tre (k=0): {(df_tre['k_tot_nhat'] == 0).sum()}/{len(df_tre)}")

_m = metrics_3_pham_vi(val_h)
_bang = pd.DataFrame(_m).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4)
print("\n--- METRIC H4 TREN TAP TEST (measured_daylight la con so chinh thuc) ---")
display(_bang)
# Out:
# --- QUET DO TRE H4 - TOAN BO 42 TRAM (SAU KHI LOAI SITE 19/24) ---
#    k=0 ( 0 phut truoc): RMSE 4.5508  <== nho nhat
#    k=1 (15 phut truoc): RMSE 4.5914
#    k=2 (30 phut truoc): RMSE 4.8575
#    k=3 (45 phut truoc): RMSE 5.3002
#
# Ket luan H4: KHONG TRE PHA
# So tram khong tre (k=0): 27/40
#
# --- METRIC H4 TREN TAP TEST (measured_daylight la con so chinh thuc) ---
#                           n     wape    rmse     mae      r2
# all                199469.0  25.7893  4.5309  2.0354  0.8741
# measured           199469.0  25.7893  4.5309  2.0354  0.8741
# measured_daylight  199469.0  25.7893  4.5309  2.0354  0.8741

# %%
# ── Export H4 - dung dung cau truc file nhu H1 (ten file tu dong doi theo HORIZON_STEPS) ──

with open(f'{OUTPUT_DIR}/model_h{HORIZON_STEPS}.pkl', 'wb') as f:
    pickle.dump({'model': model, 'features': FEATURES, 'medians': MEDIANS.to_dict(),
                 'eps_elev': EPS_ELEV, 'horizon_steps': HORIZON_STEPS,
                 'loss': LOSS_NAME, 'chuan_hoa': True}, f)

df_tre.to_csv(f'{OUTPUT_DIR}/tre_pha_theo_tram.csv', index=False)
_bang.to_csv(f'{OUTPUT_DIR}/metrics.csv')
with open(f'{OUTPUT_DIR}/ket_qua.json', 'w', encoding='utf-8') as f:
    json.dump({'loss': LOSS_NAME, 'horizon_steps': HORIZON_STEPS,
               'so_dac_trung': len(FEATURES), 'features': FEATURES,
               'best_params': BEST_PARAMS,
               'quet_do_tre': {str(k): v for k, v in _quet.items()},
               'k_tot_nhat': int(_k_tot),
               'so_tram_khong_tre': int((df_tre['k_tot_nhat'] == 0).sum()),
               'metrics': _m}, f, indent=2, ensure_ascii=False, default=str)

TRAIN_COMPAT_DIR = f'../../data/model/v3/06_train/{LOSS_NAME}/h{HORIZON_STEPS}'
os.makedirs(TRAIN_COMPAT_DIR, exist_ok=True)
with open(f'{TRAIN_COMPAT_DIR}/model.pkl', 'wb') as f:
    pickle.dump(model, f)
with open(f'{TRAIN_COMPAT_DIR}/model_config.json', 'w', encoding='utf-8') as f:
    json.dump({
        'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME, 'feature_set_name': '',
        'lgb_objective': LGB_OBJECTIVE, 'features': FEATURES,
        'feature_medians': {k: float(v) for k, v in MEDIANS.items()},
        'train_rows': int(len(X_dev)), 'chuan_hoa': True,
        'cot_quy_mo': 'site_scale', 'cot_sin_elev': 'sin_elevation', 'cot_tran': 'tran_cong_suat',
        'eps_elev': float(EPS_ELEV),
        'model_params': {k: v for k, v in BEST_PARAMS.items()
                         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
    }, f, indent=2, ensure_ascii=False)


# FIX (chong ro ri): metrics_val.json de notebook 07 quet va chon mo hinh vo dich BAT BUOC
# phai tinh tren tap VALIDATION that, khong duoc dung _m (dang tinh tren val_h). Truoc day
# file nay bi ghi nham tu _m (tap test) khien viec chon MAE/Huber/MSE "thay truoc" tap test.
# Tap VAL that - tach biet hoan toan voi tap hoc (mo hinh chi hoc v3_train_selected).
val_h = doc_val_that()
_k_pred_val = np.clip(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)), 0, 1.5)
val_h['y_pred'] = np.minimum(_k_pred_val * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
_m_val = metrics_3_pham_vi(val_h)
print(f"--- METRIC TREN TAP VALIDATION THAT ({len(val_h):,} dong, dung de chon mo hinh) ---")
display(pd.DataFrame(_m_val).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4))

_val_scope_h4 = _m_val.get('measured_daylight', _m_val.get('measured', _m_val['all']))
with open(f'{TRAIN_COMPAT_DIR}/metrics_val.json', 'w', encoding='utf-8') as f:
    json.dump({'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME,
               'feature_set_name': '', 'measured_daylight': _val_scope_h4,
               'all': _m_val['all']}, f, indent=2, ensure_ascii=False, default=str)


# X_test_h4.parquet - dong bo voi 06_1, tranh loi so cot khong khop khi 07 doc
_cot_xuat_h4 = list(dict.fromkeys(
    FEATURES + [SITE_COL, TIMESTAMP_COL, 'plot_timestamp', TARGET_COL, 'y_true',
                'energy_source', 'is_daylight', 'site_scale', 'sin_elevation', 'tran']
))
_cot_xuat_h4 = [c for c in _cot_xuat_h4 if c in val_h.columns]

print("--- HOAN TAT H4 ---")
print(f"Thu muc ket qua: {OUTPUT_DIR}")
for _f in sorted(os.listdir(OUTPUT_DIR)):
    print(f"   {_f}")
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 476,868 -> 454,160 dong
# Lọc v3_val_selected: 482,076 -> 454,160 dòng (49 cột)
# --- METRIC TREN TAP VALIDATION THAT (199,469 dong, dung de chon mo hinh) ---
#                           n     wape    rmse     mae      r2
# all                199469.0  25.7893  4.5309  2.0354  0.8741
# measured           199469.0  25.7893  4.5309  2.0354  0.8741
# measured_daylight  199469.0  25.7893  4.5309  2.0354  0.8741
# --- HOAN TAT H4 ---
# Thu muc ket qua: ../../data/model/v3/06_2_train_huber_h4
#    ket_qua.json
#    ket_qua.json.dvc
#    metrics.csv
#    model_h4.pkl
#    prediction_audit_h4.parquet
#    tre_pha_theo_tram.csv
