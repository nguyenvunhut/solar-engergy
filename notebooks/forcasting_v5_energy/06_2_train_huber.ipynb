# %% [markdown]
# # Bước 06_1: Train Huber loss khử trễ pha
# Dự án: Tốt nghiệp - Energy Forecasting - Nhóm thực hiện: The Outliers
#
# ## 1. TỔNG QUAN VÀ MỤC TIÊU
#
# ### Vấn đề
# Mô hình cũ bị **trễ pha 30 phút**: dự báo tại `T` khớp nhất với sản lượng thật tại `T-30 phút`.
# Đo trên toàn bộ 42 trạm, **cả 42 trạm** đều khớp nhất tại `k=2` (tức 2 bước = 30 phút).
#
# Nguyên nhân đã truy được:
#
# 1. `lag_1` của hàng đặc trưng chính là `y(T-30 phút)`, và nó tương quan 99% với mục tiêu.
#    Mô hình tối thiểu hoá sai số trung bình nên **chép** cột đó thay vì học quan hệ vật lý.
# 2. Dữ liệu thời tiết là **theo giờ, bị lặp 4 lần** trên lưới 15 phút. Trong một giờ nó không phân biệt
#    được `12:00` với `12:15`, nên `lag_1` là nguồn tín hiệu 15 phút duy nhất mà mô hình có.
#    Bỏ riêng `lag_1` mà không bù gì thì WAPE tụt thảm vì mất luôn nguồn thông tin đó.
#
# ### Cách khử, năm việc làm cùng lúc
# | việc | mục đích |
# |---|---|
# | Downscale bức xạ về 15 phút bằng bức xạ trời quang | tạo tín hiệu 15 phút thay cho `lag_1` |
# | Góc cao và góc phương vị mặt trời | cho mô hình biết vị trí mặt trời tại trạm, phân giải 15 phút |
# | Quy mô trạm thực nghiệm | `capacity_kw` sai ở nhiều trạm, phải tính lại từ dữ liệu train |
# | Trần công suất trạm | học được đoạn inverter cắt đỉnh, chỗ sản lượng nằm phẳng |
# | Bỏ `lag_1`, `lag_4`, `rolling_*_4`, `rolling_*_12` | cắt đường tắt mang giá trị `T-30 phút` |
#
# **Vẫn giữ `lag_96` và `rolling_*_96`** - lịch sử một ngày trước, nên đây vẫn là mô hình time series
# có ký ức, chỉ bỏ phần mang sẵn đáp án.
#
# ### Kết quả đã đạt
# | | mô hình cũ | mô hình này |
# |---|---|---|
# | số trạm khớp nhất tại `k=0` | 0/42 | **40/42** |
# | RMSE `k=0` so với `k=1` | k=2 nhỏ nhất | **k=0 nhỏ nhất** |
# | WAPE | 24,69% | 21,09% |
#
# ### Điều quan trọng về tính nhân quả
# Toàn bộ đặc trưng mới **chỉ dùng thông tin quá khứ và công thức thiên văn**. Không nội suy giữa các giờ,
# không dùng giá trị của giờ sau. Phần biến thiên trong giờ do bức xạ trời quang tạo ra, mà bức xạ trời quang
# là hàm xác định của thời điểm và toạ độ.

# %% [markdown]
# ## 2. Import thư viện và khai báo tham số

# %%
# ── Gioi han thread: may i5-12450HX co 8 core / 12 thread (4 P-core + 4 E-core).
# Dung het 12 thread lam cac thread tranh nhau va CHAM HON. Dat 6 de bam P-core,
# con lai de cho Jupyter va he dieu hanh. Phai set TRUOC khi numpy nap moi co tac dung.
import os

for _bien in ('OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS','MKL_NUM_THREADS',
              'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS'):
    os.environ.setdefault(_bien, '6')

import gc
import json
import os
import pickle
import platform
import time
import warnings

import lightgbm as lgb
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
from optuna.samplers import TPESampler
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")
optuna.logging.set_verbosity(optuna.logging.WARNING)

# ── Cột khoá ──
VERSION = 'v5'
SITE_COL = 'site_id'
TIMESTAMP_COL = 'timestamp'
TARGET_COL = 'energy_generated_kwh'

# ── Tham số mô hình ──
# Bien the LOSS = HUBER, doi chieu voi 06_1 (mae, dang chon lam mac dinh bao cao) va
# 06_3 (mse). Ket qua so sanh thuc te tren tap test (xem 06_1_train_mae.ipynb):
#   huber a=1  : khop dinh 15p 19,9% | bien do dinh 0,916 | WAPE 21,58%
#   MAE  (l1)  : khop dinh 15p 20,1% | bien do dinh 0,952 | WAPE 21,69%   <- notebook 06_1 chon
# MAE hut bien do dinh tot hon (8,4% -> 4,8%), do tre khong doi (~0 phut o ca hai).
# Notebook nay giu de doi chieu/ablation, KHONG dung lam ket qua bao cao chinh.
LOSS_NAME = 'huber'
LGB_OBJECTIVE = 'huber'
# HORIZON_STEPS: xem cell rieng ngay ben duoi (de doi h1/h4 khong can dong lai o day)
N_TRIALS = 20                  # ngan sach Optuna cho moi loss va horizon
SEED = 42
EARLY_STOPPING_ROUNDS = 100

# ── Gioi han theo cau hinh may (i5-12450HX: 8 core / 12 thread, RAM 27 GB, RTX 3050 6 GB) ──
# CPU nay la hybrid 4 P-core + 4 E-core. Dat n_jobs = 12 lam cac thread tranh nhau va CHAM HON.
# Dung 6 thread: bam vao P-core, con lai de cho Jupyter va he dieu hanh.
N_JOBS = 6
MAX_BIN = 127                  # giam tu 255 xuong 127: bot RAM, nhanh hon, gan nhu khong mat do chinh xac
FORCE_COL_WISE = True          # tranh chi phi tu do multi-threading cua LightGBM moi lan fit
DTYPE = 'float32'              # nua bo nho so voi float64

# ── Chinh sach outlier, lay dung tu srcs/05_machine_learning/Forcasting_v3 ──
# srcs khong xoa dong outlier ma dat SAMPLE WEIGHT = 0, va xet nhom cua DONG NHAN y(T+h)
# chu khong phai dong dac trung. Xem build_sample_weight trong 08_train_baselines.py
# va config/05_machine_learning/forecasting_v3_final_cleaned.yaml: active_experiment
EXPERIMENT = 'measured_only_headline'
# cac gia tri hop le:
#   measured_only_headline   : measured + normal/gmm/other/multiple = 1, etl_imputed = 0
#   measured_plus_etl_imputed: nhu tren, them etl_imputed + normal = 1
#   zero_weight_gmm_consensus: bo gmm_if_consensus ra khoi train
#   zero_weight_all_flagged  : bo moi nhom bi gan co ra khoi train
#   tran_theo_du_lieu        : nhu measured_only_headline, NHUNG chi loai dong that su vuot
#                              tran_cong_suat tinh tu DU LIEU, thay vi tin co physical_over_capacity
#                              (co nay suy tu capacity_kw metadata dang SAI o 11/42 tram)
# THU NGHIEM 1 (DA HUY, 2026-07-31) - tung doi mac dinh sang 'tran_theo_du_lieu' vi
#   capacity_kw metadata sai o 11/42 tram (vd site 19 vuot tran metadata 4,89 lan) nen
#   physical_over_capacity dang loai oan du lieu that. NHUNG: kiem tra lai phat hien
#   tran_cong_suat (trinh suy tu du lieu) cung co the bi lech neu du lieu dau vao da
#   nhiem gia tri impute sai gan tran (vd site 19 co dong etl_imputed = 43,08 kWh lap lai,
#   gan tran metadata, khong phai do that) -> dieu kien vuot_tran_that khong loai duoc
#   cac dong nay, model van hoc theo. QUAY VE 'measured_only_headline': zero-weight
#   TOAN BO physical_over_capacity vo dieu kien (dung nhu srcs/05 goc), de dam bao khi
#   plot actual-vs-predict co the CHUNG MINH model khong hoc theo outlier.

# ── TRONG SO MAU ──────────────────────────────────────────────────────────────
# 'mau_so' (dang dung): w = mau_so chuan hoa = site_scale x sin_elevation. Vi
#   y_hat - y = mau_so x (k_hat - k), toi thieu hoa MAE co trong so mau_so tren thang k
#   CHINH LA toi thieu hoa tu so cua WAPE kWh - huan luyen dung tren thuoc do bao cao
#   (nhat quan loss-metric: Gneiting 2011; WAPE = MAE/trung binh y: Kolassa 2007).
#   Trong so nay TAT DINH (khong nhin nhan) nen khong lam thien lech du bao.
# 'khong': w = 1/0 thuan.
# Co che cu w = 1 + a*k DA BO 2026-08-20: do tren du lieu v5 no lam xau WAPE
# (22.2349 vs 22.1904 khi tat) va tang thien lech ME gap ~3 lan (+0.371 vs +0.126 kWh).
# Bang doi chieu day du cua ca ba co che nam o notebook 05b (TN4/TN11).
CHE_DO_TRONG_SO = 'mau_so'

# THU NGHIEM 3 - KHU LAG BANG CACH DICH DAC TRUNG TAT DINH SANG THOI DIEM MUC TIEU.
# Van de: y_true la san luong tai T+h, nhung sin_elevation/ghi_cs/hour... van la gia tri tai T.
# Model dung vi tri mat troi luc T de dung lai san luong luc T+h -> duong du bao chinh la
# duong mat troi bi TRE h buoc. Do cung la mau so chuan hoa (site_scale * sin_elevation(T)).
# Dich cac cot nay sang T+h KHONG phai leakage: vi tri mat troi va nhan thoi gian tai T+h la
# tinh toan thien van/lich thuan tuy, dung o T da biet chinh xac. Khac han thoi tiet (phai do).
# Thoi tiet, lag_96, rolling_* GIU NGUYEN tai T de dam bao causal.
THEM_DAC_TRUNG_MUC_TIEU = True
# Thu nghiem truoc (bac bo) chay tren du lieu CHUA hotfix join causal, luc do do tre
# chi 1 buoc. Sau hotfix (2026-07-30 21:49), cong 10.2 do lai ra shortwave_radiation
# tre 2 buoc (30 phut), sin_elevation tre 1 buoc - tinh huong khac han, phai thu lai
# tren nen du lieu moi, khong dung ket luan cu.
# Them ban tai T+h thanh cot MOI (hau to _mt), GIU NGUYEN ban tai T.
# Vi sao them chu khong thay the: da thu THAY THE va BAC BO bang so lieu that
# (duong bao y_hat = site_scale * sin_elevation, do bang MAE tren tap development):
#     toan bo     : tai T 3,1873  |  tai T+h 3,1884   -> gan nhu y nhau
#     sang 06-09h : tai T 1,5934  |  tai T+h 2,1833   -> TE HON 37%
#     chieu 16-18h: tai T 3,4002  |  tai T+h 2,8574   -> TOT HON 16%
# Ly do: buoi sang san luong that VON di sau mat troi (pin con lanh/am, inverter khoi dong),
# nen gia tri tai T khop hon; buoi chieu thi nguoc lai. Giu ca hai de model tu chon theo gio.
#
# Day la cach HOP PHAP duy nhat de bu lai do tre cai san: vi tri mat troi va nhan thoi gian
# tai T+h la tinh toan thien van/lich thuan tuy, dung o T da biet chinh xac -> KHONG leakage.
# Khac han thoi tiet: phai do moi biet, nen bat buoc giu o T.
COT_TAT_DINH = [
    # hinh hoc mat troi va dai luong suy ra tu no
    'solar_elevation', 'solar_azimuth', 'azimuth_sin', 'azimuth_cos', 'sin_elevation',
    'ghi_cs', 'ky_vong', 'ty_le_bao_hoa',
    # nhan thoi gian theo lich
    'minute_of_day', 'hour_of_day', 'hour_bucket_model', 'hour', 'hour_sin', 'hour_cos',
    'minute', 'day', 'day_of_week', 'month', 'day_of_year', 'doy_sin', 'doy_cos',
]
# KHONG dich: shortwave_radiation, diffuse_solar_radiation, direct_normal_irradiance,
# temperature_c, diffuse_ratio, temp_x_shortwave, cloud_x_shortwave, rad_x_sinelev
# (co chua thoi tiet), lag_96, rolling_*_96 (lich su san luong).

# ── Tham số khử trễ pha ──
# ── CONG TAC MAU SO CHUAN HOA MUC TIEU ──────────────────────────────────────────
# 'lonij'      : dung DUNG cong thuc cua Lonij et al. (2012), phuong trinh (18) trong
#                Engerer & Mills (2014) Solar Energy 105:679-693. Mau so la phan vi 80
#                cua san luong do duoc tai CUNG KHUNG GIO, tinh tren 15 ngay LIEN TRUOC.
#                Cot pv_clr_lonij duoc sinh o notebook 03-1. PDF: reports/references/.
# 'site_scale' : cong thuc cu cua du an, site_scale (phan vi 99 toan tap) x sin(goc cao).
#                KHONG co trong bai bao nao - phan vi 99 va phep nhan sin la tu dat.
# Xem docs/2026_08_13_Nguon_Goc_Cong_Thuc_Chuan_Hoa_Muc_Tieu.md
MAU_SO = 'site_scale'
# CHON BANG THUC NGHIEM DOI DAU (2026-08-13), khong phai chon theo cam tinh.
# Cung dac trung, cung sieu tham so, CUNG TAP DONG (615.288 train / 301.634 val - giao cua
# hai mau so de so cong bang), LightGBM MAE, tam du bao 15 phut:
#     'lonij'      (dung cong thuc Lonij et al. 2012)  -> WAPE 24,8740%  (nguong cat 2,4202)
#     'site_scale' (bien the cua du an)                -> WAPE 21,9157%  (nguong cat 1,3850)
# Bien the cua du an TOT HON 2,96 diem, va tot hon o CA 13/13 khung gio. Chenh lon nhat dung
# o ria ngay: 07:00 hon 9,55 diem, 17:00 hon 5,96, 06:00 hon 5,64.
# Ly do: mau so cua Lonij cung la SO DO nen luc binh minh/hoang hon no nho va nhieu, ty so
# bung ra. Mau so cua du an dung sin(goc cao Mat Troi) - dai luong thien van biet chinh xac -
# nen on dinh o moi gio. Doi chieu them: hai mau so tuong quan 0,9797 voi nhau.
# Hinh: data/model/v5/05_selected/hinh/so_sanh_mau_so_chuan_hoa.png
# Chi tiet trich dan: docs/2026_08_13_Nguon_Goc_Cong_Thuc_Chuan_Hoa_Muc_Tieu.md

# Nguong cat muc tieu chuan hoa. De None thi SUY TU DU LIEU: lay phan vi CLIP_PHAN_VI
# cua k tren tap TRAIN. Truoc day dat cung 1.5 ma khong co xuat xu.
CLIP_K = None
CLIP_PHAN_VI = 0.99
# CHON BANG THUC NGHIEM (2026-08-13), khong tu dat. Quet muc phan vi tren tap kiem dinh,
# 276.377 dong do that ban ngay, cung dac trung va sieu tham so:
#     phan vi 90   -> nguong 1,1475 | chan 10,0%  | WAPE 22,4800%
#     phan vi 95   -> nguong 1,2252 | chan  5,0%  | WAPE 21,9856%
#     phan vi 97,5 -> nguong 1,2954 | chan  2,5%  | WAPE 21,8644%
#     phan vi 99   -> nguong 1,3813 | chan  1,0%  | WAPE 21,8714%
#     phan vi 99,5 -> nguong 1,4574 | chan  0,5%  | WAPE 21,8357%
#     phan vi 99,9 -> nguong 1,7353 | chan  0,1%  | WAPE 21,7467%   <== TOI UU
#     khong cat    -> nguong 7,4226 | chan  0,0%  | WAPE 21,7870%
# Doc ket qua: vung 97,5-100 chenh nhau chi 0,12 diem, duoi 95 thi xau di ro. Dang chu y la
# KHONG CAT lai te hon cat o 99,9 -> viec cat co ich that, khong phai lam cho dep.
# Doi chieu tai lieu: Engerer & Mills (2014) khong quy dinh gia tri cat nao, nhung moi bieu do
# cua ho ve truc K_PV trong khoang [0; 1,2] va ho goi vung tren 1 la bat thuong do may rai rac.
# Phan vi 95 tren du lieu du an cho nguong 1,2252 - gan trung mo ta do.
# Hinh: data/model/v5/05_selected/hinh/quet_muc_phan_vi_nguong_cat.png
# So lieu: data/model/v5/05_selected/quet_muc_phan_vi_nguong_cat.csv
# VI SAO CHON 0,99 CHU KHONG PHAI 0,999 (toi uu do duoc): day la lua chon THIEN VE AN TOAN,
# co chu dich, khong phai bo sot. Ly do:
#   - Chenh lech giua hai muc chi 0,125 diem WAPE (21,8714% so voi 21,7467%), rat nho.
#   - Muc 0,999 chi chan 0,1% quan sat, tuc gan nhu khong chan gi; nguong 1,7353 de lot cac
#     gia tri cuc doan ma mau so tham chieu da mat tin cay o goc cao Mat Troi thap.
#   - Muc 0,99 cho nguong 1,3813, nam gan khoang [0; 1,2] ma Engerer & Mills (2014) ve truc
#     cho chi so troi quang, va sat vung ho goi la bat thuong (tren 1).
#   - Doi lay 0,125 diem sai so de co mot rao chan chac chan hon truoc gia tri cuc doan la
#     danh doi hop ly cho mot he thong se chay that.
# Toan bo bang quet van duoc bao cao day du, khong giau muc toi uu.

EPS_ELEV = 0.05                # nguong sin(goc cao) coi la ban ngay
BO_PREFIX_NGAN = ('lag_1', 'lag_4')          # lag ngan mang gia tri T-30 phut

# ── Đường dẫn ──
# Cac dac trung dien mat troi (goc mat troi, buc xa downscale, quy mo tram) da duoc sinh
# o notebook 03-2 va di qua 04, 05. Notebook nay chi doc va train, khong tu dung dac trung.
SELECTED_DIR = '../../data/model/v5/05_selected'
# OUTPUT_DIR: xem cell rieng ngay ben duoi (phu thuoc HORIZON_STEPS)

# ── Thiết bị train và tính tái lập ──
# USE_GPU = False la CO CHU DICH, khong phai quen bat. DETERMINISTIC la co che DUY NHAT
# cua LightGBM cho ra model giong het nhau moi lan chay, va tai lieu Parameters.rst ghi ro
# no "Used only with cpu device type" - nghia la phai TAT GPU thi no moi co tac dung.
#
# DO THUC TE 2026-08-08 (huber h1, 887.980 dong x 54 dac trung, train 3 lan lien tiep,
# cung may cung seed - xem srcs/05_machine_learning/pipeline/checks/do_tinh_tai_lap_s08.py):
#   GPU (deterministic bi bo qua) : 3 lan ra 3 model KHAC nhau, lech toi 7,485e-02  | 24 giay
#   CPU, DETERMINISTIC = False    : 2 lan ra 2 model KHAC nhau, lech 2,220e-16      | 30 giay
#   CPU, DETERMINISTIC = True     : 3 lan ra 3 model GIONG HET,  lech 0             | 31 giay
#
# Gia phai tra: 7 giay moi model. Doi lai: bao cao chay lai luc nao cung ra dung con so do.
USE_GPU = False
DETERMINISTIC = True
GPU_PLATFORM_ID = 0
GPU_DEVICE_ID = 0

print("Đã import thư viện và khai báo tham số.")
print(f"- Loss              : {LOSS_NAME}")
print(f"- Số trial Optuna   : {N_TRIALS}")
print(f"- Số thread         : {N_JOBS} trên 12 thread (CPU hybrid nên không dùng hết)")
print(f"- max_bin           : {MAX_BIN}")
# Horizon va Thu muc xuat: in o cell rieng ngay ben duoi (phu thuoc HORIZON_STEPS)


# ── delta cua Huber (tham so 'alpha' cua LightGBM) ────────────────────────────
# KHONG viet cung o day. No duoc SUY TU DU LIEU o buoc 10.3 (fit so bo -> do thang phan
# du -> delta = 1,345 x sigma, quy tac Huber 1964 cho 95% hieu qua tiem can khi nhieu chuan).
# Ly do khong de 1.0 nhu truoc: tren thang chuan hoa k phan du rat nho (p90 ~ 0,35) nen
# delta = 1 lon hon 99,98% phan du => Huber roi han vao vung bac hai, SUY BIEN THANH MSE.
HUBER_DELTA = None
# Out:
# Đã import thư viện và khai báo tham số.
# - Loss              : huber
# - Số trial Optuna   : 20
# - Số thread         : 6 trên 12 thread (CPU hybrid nên không dùng hết)
# - max_bin           : 127

# %%
# ── CHON HORIZON: h1 hay h4 (1 cell rieng, khong dinh vao cell config chinh) ──
# De train h4 sau nay: chi doi HORIZON_STEPS o day roi Restart & Run All TU CELL NAY tro
# xuong (khong can chay lai tu dau notebook, vi du lieu 05_selected da co san cho ca 2
# horizon - y_true duoc tinh runtime trong ham them_muc_tieu() qua shift(-h)).
# h1 = du bao T+15 phut (1 buoc), h4 = du bao T+60 phut/1 gio (4 buoc).
# OUTPUT_DIR tach rieng theo horizon de KHONG ghi de len ket qua h1 khi chay h4.
HORIZON_STEPS = 1              # <-- DOI DONG NAY THANH 4 DE TRAIN H4

OUTPUT_DIR = (
    '../../data/model/v5/06_2_train_huber' if HORIZON_STEPS == 1
    else f'../../data/model/v5/06_2_train_huber_h{HORIZON_STEPS}'
)
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Horizon dang chon: h{HORIZON_STEPS} ({HORIZON_STEPS * 15} phut)")
print(f"Ghi ket qua vao: {OUTPUT_DIR}")
# Out:
# Horizon dang chon: h1 (15 phut)
# Ghi ket qua vao: ../../data/model/v5/06_2_train_huber

# %% [markdown]
# ## 3. Thiết lập GPU (OpenCL) cho LightGBM
#
# Máy Linux/NixOS tự đặt `OCL_ICD_VENDORS`. Máy Windows bỏ qua, LightGBM tự tìm GPU hoặc chạy CPU.

# %%
LA_LINUX = (os.name == 'posix' and platform.system() == 'Linux')

if LA_LINUX:
    OCL_CANDIDATES = [
        '/run/opengl-driver/etc/OpenCL/vendors',
        '/etc/OpenCL/vendors',
    ]
    if 'OCL_ICD_VENDORS' in os.environ:
        print(f"OCL_ICD_VENDORS đã được đặt sẵn: {os.environ['OCL_ICD_VENDORS']}")
    else:
        for _p in OCL_CANDIDATES:
            if os.path.isdir(_p) and any(f.endswith('.icd') for f in os.listdir(_p)):
                os.environ['OCL_ICD_VENDORS'] = _p
                print(f"Đã tự đặt OCL_ICD_VENDORS = {_p}")
                break
        else:
            print("[CẢNH BÁO] Không tìm thấy thư mục ICD OpenCL trên máy Linux này.")
else:
    print(f"Hệ điều hành: {platform.system()} - bỏ qua OCL_ICD_VENDORS.")


def kiem_tra_gpu():
    """Train một model nhỏ trên GPU để biết có dùng được không."""
    try:
        X = np.random.rand(200, 4)
        y = np.random.rand(200)
        lgb.train(
            {'objective': 'regression', 'device': 'gpu',
             'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID, 'verbose': -1},
            lgb.Dataset(X, y), num_boost_round=1,
        )
        return True, ''
    except Exception as e:
        return False, str(e)[:200]


GPU_SAN_SANG = False
if USE_GPU:
    GPU_SAN_SANG, _err = kiem_tra_gpu()
    if GPU_SAN_SANG:
        print("GPU OpenCL sẵn sàng, LightGBM sẽ chạy trên GPU.")
    else:
        print("[CẢNH BÁO] Không dùng được GPU, tự chuyển sang CPU.")
        print(f"   Lý do: {_err}")
else:
    print("USE_GPU = False, chạy CPU theo cấu hình.")
print(f"Chế độ tính toán: {'GPU' if GPU_SAN_SANG else 'CPU'}")
# Out:
# Đã tự đặt OCL_ICD_VENDORS = /run/opengl-driver/etc/OpenCL/vendors
# USE_GPU = False, chạy CPU theo cấu hình.
# Chế độ tính toán: CPU

# %% [markdown]
# ## 4. Đọc danh sách đặc trưng và tách nhóm phải bỏ
#
# Bỏ các cột mang giá trị `T-30 phút`. Giữ lại nhóm `96` vì đó là lịch sử một ngày trước, không gây trễ.

# %%
with open(f'{SELECTED_DIR}/selected_features.json', 'r', encoding='utf-8') as f:
    _sel_raw = json.load(f)
selected_features = _sel_raw['selected_features'] if isinstance(_sel_raw, dict) else _sel_raw

# QUYET DINH (2026-07-31, dong bo voi 06_1): lag_1 gay lech pha he thong (audit doc lap:
# 39/40 site vuot nguong, 126/127 ngay du bao di sau thuc te). Dung lag_4 (T-1 gio) - audit
# PASS sach (0/40 site vuot nguong, WAPE tot hon baseline). Giu rolling_*_4.
bo_di = [c for c in selected_features
         if (c.startswith(BO_PREFIX_NGAN) or c.startswith('rolling_'))
         and '96' not in c and c not in ('lag_4', 'rolling_mean_4', 'rolling_std_4',
                                          'rolling_min_4', 'rolling_max_4')]
giu_lai = [c for c in selected_features if c not in bo_di]

print(f"Tổng đặc trưng ban đầu : {len(selected_features)}")
print(f"\nBỏ đi ({len(bo_di)} cột):")
for c in bo_di:
    print(f"   {c}")
print(f"\nGiữ lại nhóm lịch sử dài: {[c for c in giu_lai if c.startswith(('lag_', 'rolling_'))]}")
print(f"Còn lại {len(giu_lai)} cột gốc, sẽ bổ sung thêm đặc trưng mới ở các bước dưới.")
# Out:
# Tổng đặc trưng ban đầu : 39
#
# Bỏ đi (0 cột):
#
# Giữ lại nhóm lịch sử dài: ['rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'lag_96', 'lag_4', 'rolling_std_4', 'rolling_std_96', 'rolling_mean_96', 'rolling_max_96']
# Còn lại 39 cột gốc, sẽ bổ sung thêm đặc trưng mới ở các bước dưới.

# %% [markdown]
# ## 5. Kiểm tra nhóm đặc trưng điện mặt trời đã có sẵn
#
# Các đặc trưng khử trễ pha được sinh ở **notebook 03-2** rồi đi qua 04 và 05, nên notebook này chỉ cần
# kiểm chúng có mặt đủ. Nếu thiếu thì phải chạy lại 03-2 → 04 → 05 trước.
#
# | nhóm | cột |
# |---|---|
# | hình học mặt trời | `solar_elevation`, `solar_azimuth`, `sin_elevation`, `ghi_cs`, `rad_x_sinelev` |
# | quy mô trạm | `site_scale`, `tran_cong_suat`, `ky_vong`, `ty_le_bao_hoa`, `con_cach_tran` |
# | lịch sử một ngày | `lag_96`, `rolling_mean_96`, `rolling_max_96`, `rolling_std_96` |

# %%
NHOM_MAT_TROI = ['solar_elevation', 'solar_azimuth', 'azimuth_sin', 'azimuth_cos',
                 'sin_elevation', 'ghi_cs', 'cs_factor', 'rad_x_sinelev']
NHOM_QUY_MO = ['site_scale', 'tran_cong_suat', 'ky_vong', 'ty_le_bao_hoa']
# con_cach_tran bi cam co chu dich o buoc 05 (DENY_STRUCTURAL_COLLINEAR: to hop tuyen tinh
# chinh xac cua tran_cong_suat va ky_vong), khong dua vao nhom kiem tra nay nua.
COT_BAT_BUOC = ['site_scale', 'sin_elevation', 'tran_cong_suat', 'pv_clr_lonij']   # can de chuan hoa va chan tran

_co_san = set(pq.ParquetFile(f'{SELECTED_DIR}/{VERSION}_test_selected.parquet').schema_arrow.names)

print("--- KIEM NHOM DAC TRUNG DIEN MAT TROI ---")
for _ten, _nhom in (('hinh hoc mat troi', NHOM_MAT_TROI), ('quy mo tram', NHOM_QUY_MO)):
    _co = [c for c in _nhom if c in _co_san]
    _thieu = [c for c in _nhom if c not in _co_san]
    print(f"   {_ten:<20} co {len(_co)}/{len(_nhom)}" + (f"  THIEU: {_thieu}" if _thieu else ""))

_thieu_bb = [c for c in COT_BAT_BUOC if c not in _co_san]
if _thieu_bb:
    raise KeyError(
        f"Thieu cot bat buoc {_thieu_bb}. Hay chay lai notebook 03-2, 04, 05 truoc khi train."
    )
print(f"\nDu {len(COT_BAT_BUOC)} cot bat buoc de chuan hoa muc tieu va chan tran cong suat.")

_lag = sorted(c for c in _co_san if c.startswith(('lag_', 'rolling_')))
print(f"Lag/rolling con lai trong du lieu: {_lag}")
_xau = [c for c in _lag if '96' not in c]
if _xau:
    print(f"[CANH BAO] Con lag/rolling ngan: {_xau}")
    print("   Chung mang gia tri T-30 phut va se gay tre pha. Hay dat LAGS = (96,) va")
    print("   ROLLING_WINDOWS = (96,) trong notebook 03-1 roi chay lai tu 03-1.")
# Out:
# --- KIEM NHOM DAC TRUNG DIEN MAT TROI ---
#    hinh hoc mat troi    co 8/8
#    quy mo tram          co 4/4
#
# Du 4 cot bat buoc de chuan hoa muc tieu va chan tran cong suat.
# Lag/rolling con lai trong du lieu: ['lag_4', 'lag_96', 'rolling_max_4', 'rolling_max_96', 'rolling_mean_4', 'rolling_mean_96', 'rolling_min_4', 'rolling_std_4', 'rolling_std_96']
# [CANH BAO] Con lag/rolling ngan: ['lag_4', 'rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'rolling_std_4']
#    Chung mang gia tri T-30 phut va se gay tre pha. Hay dat LAGS = (96,) va
#    ROLLING_WINDOWS = (96,) trong notebook 03-1 roi chay lai tu 03-1.

# %% [markdown]
# ## 6. Đọc dữ liệu development và test

# %%
COT_PHU = [TARGET_COL, SITE_COL, TIMESTAMP_COL, 'energy_source', 'exclude_from_training',
           'outlier_group', 'has_complete_history_features', 'is_daylight']

# Loai han 2 site co capacity_kw KHONG dang tin (khong phai imputed - ghi that tu nguon
# Kaggle - nhung lech qua nang so voi hanh vi thuc te, xac nhan bang doi chieu 42 site):
#   site 19: dinh thuc te vuot tran ly thuyet (capacity_kw*0.25) toi 5.03 lan, 63.9% dong
#            ban ngay vuot tran - qua nhieu de coi la loi do ngau nhien.
#   site 24: vuot 1.77 lan, 26.3% dong ban ngay vuot tran.
# Giu capacity_kw lam chuan cho 40 site con lai (da validate dung qua doi chieu fleet-wide,
# xem docs/2026_07_30_Khu_Tre_Pha_Du_Bao_15_Phut.md). Thay vi tu "cuu" outlier bang trans
# rieng (da thu va huy - xem lich su o buoc 2), loai han 2 site nay khoi train/test de
# khong lam sai lech ham muc tieu cua ca 40 site con lai, va khong "hoc theo outlier".
EXCLUDE_SITES = [19, 24]


def doc_du_lieu(ten_file):
    """Doc parquet, chi lay cot can, loc dong hop le. Khong dung dac trung o day."""
    duong_dan = f'{SELECTED_DIR}/{ten_file}.parquet'
    co_san = set(pq.ParquetFile(duong_dan).schema_arrow.names)
    cot = [c for c in dict.fromkeys(giu_lai + COT_PHU + COT_BAT_BUOC) if c in co_san]
    d = pd.read_parquet(duong_dan, columns=cot)

    n0 = len(d)
    if 'exclude_from_training' in d.columns:
        d = d[d['exclude_from_training'] == False]
    if 'has_complete_history_features' in d.columns:
        d = d[d['has_complete_history_features'] == True]
    d = d.dropna(subset=[TARGET_COL])
    if EXCLUDE_SITES:
        n_truoc = len(d)
        d = d[~d[SITE_COL].isin(EXCLUDE_SITES)]
        print(f"    Loai {EXCLUDE_SITES} (capacity_kw khong dang tin): "
              f"{n_truoc:,} -> {len(d):,} dong")
    print(f"Lọc {ten_file}: {n0:,} -> {len(d):,} dòng ({len(cot)} cột)")
    return d.sort_values([SITE_COL, TIMESTAMP_COL]).reset_index(drop=True)


dev = doc_du_lieu('v5_train_selected')

FEATURES = [c for c in giu_lai if c in dev.columns]
print(f"\nSố đặc trưng dùng để train: {len(FEATURES)}")
print(f"   nhóm mặt trời : {len([c for c in FEATURES if c in NHOM_MAT_TROI])}")
print(f"   nhóm quy mô   : {len([c for c in FEATURES if c in NHOM_QUY_MO])}")
print(f"   lag/rolling   : {[c for c in FEATURES if c.startswith(('lag_', 'rolling_'))]}")
print(f"\nBộ nhớ: dev {dev.memory_usage(deep=True).sum() / 1024**2:.0f} MB")
print("Tap TEST: KHONG doc o notebook nay - chi doc o notebook 07.")
display(dev[[TIMESTAMP_COL, 'shortwave_radiation', 'ghi_cs', 'sin_elevation',
             'site_scale', 'tran_cong_suat']].head(6))
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 1,516,104 -> 1,446,760 dong
# Lọc v5_train_selected: 1,550,856 -> 1,446,760 dòng (49 cột)
#
# Số đặc trưng dùng để train: 39
#    nhóm mặt trời : 8
#    nhóm quy mô   : 3
#    lag/rolling   : ['rolling_max_4', 'rolling_mean_4', 'rolling_min_4', 'lag_96', 'lag_4', 'rolling_std_4', 'rolling_std_96', 'rolling_mean_96', 'rolling_max_96']
#
# Bộ nhớ: dev 415 MB
# Tap TEST: KHONG doc o notebook nay - chi doc o notebook 07.
#             timestamp  shortwave_radiation  ghi_cs  sin_elevation  site_scale  \
# 0 2020-01-02 00:15:00                  0.0     0.0            0.0        21.5
# 1 2020-01-02 00:30:00                  0.0     0.0            0.0        21.5
# 2 2020-01-02 00:45:00                  0.0     0.0            0.0        21.5
# 3 2020-01-02 01:00:00                  0.0     0.0            0.0        21.5
# 4 2020-01-02 01:15:00                  0.0     0.0            0.0        21.5
# 5 2020-01-02 01:30:00                  0.0     0.0            0.0        21.5
#
#    tran_cong_suat
# 0        22.81418
# 1        22.81418
# 2        22.81418
# 3        22.81418
# 4        22.81418
# 5        22.81418

# %% [markdown]
# ## 9. Hàm mục tiêu, chuẩn hoá và các hàm đo
#
# **Mục tiêu chuẩn hoá:** thay vì học `y(T+15)` trực tiếp, mô hình học tỉ lệ
#
# ```
# k = y(T+15) / (site_scale x sin_elevation)
# ```
#
# rồi khi dự báo nhân ngược lại. Việc này giúp mô hình không phải tự suy ra quy mô từng trạm, và
# nhịp trong ngày do `sin_elevation` quyết định. Đây là thứ chữa lệch biên độ ở trạm 11, 19, 25, 27.
#
# **Phép đo trễ pha:** so `dự báo(T)` với `thực tế(T - k bước)` cho `k` từ 0 đến 3. Nếu RMSE nhỏ nhất
# tại `k=0` thì không trễ. Nếu nhỏ nhất tại `k=2` thì dự báo đang bám giá trị của 30 phút trước.

# %%
def mau_chuan_hoa(df):
    """Mau so de chuan hoa muc tieu, chon theo cong tac MAU_SO o buoc 2.

    'lonij'      : phan vi 80 san luong do duoc tai cung khung gio, 15 ngay lien truoc
                   (Lonij et al. 2012, pt (18) trong Engerer & Mills 2014).
    'site_scale' : quy mo tram nhan sin(goc cao mat troi) - cong thuc cu cua du an.
    """
    if MAU_SO == 'lonij':
        return df['pv_clr_lonij'].to_numpy()
    return (df['site_scale'] * np.clip(df['sin_elevation'], EPS_ELEV, None)).to_numpy()


def tinh_clip_tu_train(df, phan_vi=CLIP_PHAN_VI):
    """Suy nguong cat tu phan bo k tren tap TRAIN. Tra ve gia tri, KHONG gan bien.

    Nguong cat khong xoa dong nao, no chi chan nhan lai. Vung bi chan la vung mau so
    tham chieu mat tin cay o goc cao Mat Troi thap.
    """
    k = pd.Series(df['y_true'].to_numpy() / mau_chuan_hoa(df))
    k = k.replace([np.inf, -np.inf], np.nan).dropna()
    gt = float(k.quantile(phan_vi))
    print(f"Nguong cat suy tu tap train: phan vi {phan_vi} cua k = {gt:.4f}")
    print(f"   chan lai {(k > gt).mean() * 100:.2f}% quan sat (khong xoa dong nao)")
    return gt


def lay_clip():
    """Tra ve nguong cat, dung ngay neu chua duoc tinh tu tap train.

    Khong dung bien toan cuc gan ngam: CLIP_K duoc gan TUONG MINH o buoc chuan bi ma
    tran huan luyen. Neu mot o chay lech thu tu thi ham nay bao loi ro rang, thay vi
    de np.clip(x, 0, None) am tham khong cat gi.
    """
    if CLIP_K is None or not np.isfinite(CLIP_K):
        raise RuntimeError(
            "CLIP_K chua duoc tinh. Hay chay o 'Chuan bi ma tran huan luyen' truoc, "
            "o do co dong CLIP_K = tinh_clip_tu_train(dev_h)."
        )
    return CLIP_K


def cat_k(x, clip_k=None):
    """Cat k ve [0, nguong]; mac dinh CLIP_K toan cuc, truyen clip_k cho fold-local."""
    return np.clip(x, 0, lay_clip() if clip_k is None else float(clip_k))


def cot_categorical(X):
    """Cot *_enc khai bao categorical cho LightGBM (split theo nhom; ma -1 = missing)."""
    return [c for c in X.columns if c.endswith('_enc')]




COT_NHAN = {
    'energy_source': '',
    'outlier_group': 'normal',
    'is_daylight': False,
    'exclude_from_training': False,
    'after_source_gap_steps_remaining': 0,
}


def them_muc_tieu(df, horizon_steps):
    """Muc tieu la san luong tai T + horizon_steps buoc. Day la du bao that.

    Dong thoi dich cac cot phan loai sang gia tri cua DONG NHAN, dat tien to nhan_.
    Phai dich TRUOC khi dropna, neu khong thi shift bi lech sau khi bo dong.
    Giong _label_series trong srcs/05_machine_learning/Forcasting_v3/08_train_baselines.py
    """
    h = int(horizon_steps)
    out = df.copy()
    out['y_true'] = out.groupby(SITE_COL)[TARGET_COL].shift(-h)
    out['plot_timestamp'] = out[TIMESTAMP_COL] + pd.Timedelta(minutes=15 * h)
    g = out.groupby(SITE_COL)

    # THU NGHIEM 3: THEM ban tai thoi diem muc tieu T+h thanh cot moi (hau to _mt),
    # giu nguyen ban tai T. Luoi 15 phut lien tuc (notebook 01) nen shift(-h) dung h buoc.
    if THEM_DAC_TRUNG_MUC_TIEU:
        for _c in [c for c in COT_TAT_DINH if c in out.columns]:
            out[f'{_c}_mt'] = g[_c].shift(-h)

    for cot, mac_dinh in COT_NHAN.items():
        if cot in out.columns:
            out[f'nhan_{cot}'] = g[cot].shift(-h)
            out[f'nhan_{cot}'] = out[f'nhan_{cot}'].fillna(mac_dinh)
        else:
            out[f'nhan_{cot}'] = mac_dinh
    return out.dropna(subset=['y_true'])


def eligibility_mask(df):
    """Dieu kien cung, khong phu thuoc experiment. Giong eligibility_mask cua srcs.

    Chi giu dong ma NHAN cua no ve nguyen tac dung duoc: ban ngay, nguon la measured
    hoac etl_imputed, khong nam trong vung sau gap, khong bi exclude_from_training.
    Chinh sach outlier va etl_imputed do build_sample_weight xu ly sau.
    """
    ban_ngay = df['nhan_is_daylight'].astype(bool)
    nguon = df['nhan_energy_source'].astype(str)
    bi_loai = df['nhan_exclude_from_training'].astype(bool)
    sau_gap = pd.to_numeric(df['nhan_after_source_gap_steps_remaining'], errors='coerce').fillna(0).gt(0)
    m = ban_ngay & nguon.isin(['measured', 'etl_imputed']) & ~sau_gap & ~bi_loai
    return m & df['y_true'].notna()


def build_sample_weight(df, experiment=EXPERIMENT, clip_k=None):
    """Trong so mau theo dung bang experiment cua srcs.

    Dong co weight = 0 khong tham gia ham muc tieu nhung VAN GIU trong du lieu de bao cao.
    Weight co ban la 1.0 hoac 0.0; sau do nhan them mau_so chuan hoa khi
    CHE_DO_TRONG_SO = 'mau_so' (xem giai thich o buoc 2).
    """
    nguon = df['nhan_energy_source'].astype(str)
    nhom = df['nhan_outlier_group'].astype(str)
    w = pd.Series(0.0, index=df.index)
    el = eligibility_mask(df)

    measured = nguon.eq('measured')
    etl = nguon.eq('etl_imputed')
    normal = nhom.eq('normal')
    physical = nhom.eq('physical_over_capacity')
    gmm = nhom.eq('gmm_if_consensus')
    other_or_multi = nhom.isin(['other_physical_rule', 'multiple_rules'])

    w.loc[el & measured & normal] = 1.0
    w.loc[el & measured & other_or_multi] = 1.0

    if experiment in {'measured_only_headline', 'measured_plus_etl_imputed', 'tran_theo_du_lieu'}:
        w.loc[el & measured & gmm] = 1.0
    elif experiment == 'zero_weight_gmm_consensus':
        w.loc[el & measured & gmm] = 0.0
    elif experiment == 'zero_weight_all_flagged':
        w.loc[el & measured & (gmm | other_or_multi)] = 0.0

    if experiment == 'measured_plus_etl_imputed':
        w.loc[el & etl & normal] = 1.0

    # Vuot tran cong suat vat ly la bat kha thi nen phai loai. Nhung cai co
    # physical_over_capacity duoc gan tu capacity_kw METADATA, ma metadata nay sai o 11/42 tram
    # (site 19 vuot tran metadata 4,89 lan) nen no dang loai oan du lieu do that.
    # Experiment 'tran_theo_du_lieu' doi sang tran tinh TU DU LIEU (cot tran_cong_suat, sinh o
    # notebook 03-2 tu phan vi 99,9 cua tap TRAIN) - chi loai dong that su vuot tran do.
    if experiment == 'tran_theo_du_lieu' and 'tran_cong_suat' in df.columns:
        vuot_tran_that = df['y_true'] > df['tran_cong_suat'] * 1.02
        w.loc[el & measured & physical & ~vuot_tran_that] = 1.0
        w.loc[vuot_tran_that] = 0.0
    else:
        w.loc[physical] = 0.0

    if CHE_DO_TRONG_SO == 'mau_so':
        # Chuan hoa ve trung binh 1 tren cac dong CO tham gia hoc, de thang trong so khong
        # doi (min_child_weight / learning rate van so sanh duoc voi cau hinh cu).
        _m = pd.Series(mau_chuan_hoa(df), index=df.index).astype(float)
        _tb = _m[w > 0].mean()
        if _tb and np.isfinite(_tb) and _tb > 0:
            w = w * (_m / _tb).fillna(0.0)
    return w


def scope_masks(df):
    """Tam pham vi bao cao, giong scope_masks cua srcs."""
    el = eligibility_mask(df)
    nguon = df['nhan_energy_source'].astype(str)
    nhom = df['nhan_outlier_group'].astype(str)
    return {
        'eligible_rows': el,
        'headline': el & nguon.eq('measured') & ~nhom.eq('physical_over_capacity'),
        'normal_rows': el & nguon.eq('measured') & nhom.eq('normal'),
        'etl_imputed_rows': el & nguon.eq('etl_imputed'),
        'gmm_if_consensus_rows': el & nguon.eq('measured') & nhom.eq('gmm_if_consensus'),
        'physical_over_capacity_rows': el & nguon.eq('measured') & nhom.eq('physical_over_capacity'),
        'other_physical_rule_rows': el & nguon.eq('measured') & nhom.eq('other_physical_rule'),
        'multiple_rules_rows': el & nguon.eq('measured') & nhom.eq('multiple_rules'),
    }


def compute_wape(yt, yp):
    denom = np.nansum(np.abs(yt))
    return float(np.nansum(np.abs(yt - yp)) / denom * 100.0) if denom > 0 else np.nan


def compute_metrics(yt, yp):
    return {
        'wape': compute_wape(yt, yp),
        'rmse': float(root_mean_squared_error(yt, yp)),
        'mae': float(mean_absolute_error(yt, yp)),
        'r2': float(r2_score(yt, yp)),
        'n': int(len(yt)),
    }


def _cot_loc(df, ten_goc):
    """Cot dung de loc pham vi, UU TIEN ban tai T+h (tien to nhan_).

    Nhan la y(T+h) nen "do that ban ngay" phai xet DONG NHAN tai T+h, khong phai dong
    dac trung tai T. Ban cu loc theo cot tai T nen van dem ca nhung dong ma NHAN do buoc
    dien khuyet ETL sinh ra.

    Do da tren tap test niem phong (2026-08-09):
        h1: 17,6354% -> 17,7486%  (+0,11 diem, loai 9.681 dong)
        h4: 21,4351% -> 21,7786%  (+0,34 diem, loai 26.893 dong)
    Con so chat o h1 gan trung khit 17,7488% ma muc Skill Score da dung, nen sua nay lam
    hai muc trong bao cao thong nhat.

    them_muc_tieu() sinh san cot nhan_*; lui ve cot tai T neu khung khong co.
    """
    ten_nhan = f'nhan_{ten_goc}'
    if ten_nhan in df.columns:
        return df[ten_nhan]
    if ten_goc in df.columns:
        return df[ten_goc]
    return None


def metrics_3_pham_vi(df):
    """Ba pham vi: all / measured / measured_daylight. Con so chinh thuc la measured_daylight."""
    res = {'all': compute_metrics(df['y_true'].values, df['y_pred'].values)}
    _nguon = _cot_loc(df, 'energy_source')
    m = ((_nguon == 'measured').to_numpy()
         if _nguon is not None else np.ones(len(df), bool))
    if m.sum():
        res['measured'] = compute_metrics(df['y_true'].values[m], df['y_pred'].values[m])
    _ngay = _cot_loc(df, 'is_daylight')
    if _ngay is not None:
        md_ = m & _ngay.fillna(False).astype(bool).to_numpy()
        if md_.sum():
            res['measured_daylight'] = compute_metrics(df['y_true'].values[md_], df['y_pred'].values[md_])
    return res


def quet_do_tre(df, k_max=3):
    """Voi moi k, tinh RMSE giua du bao(T) va thuc te(T - k buoc). k=0 nho nhat la khong tre."""
    v = df[df['is_daylight'].fillna(False).astype(bool)].sort_values([SITE_COL, TIMESTAMP_COL])
    g = v.groupby(SITE_COL)['y_true']
    ket = {}
    for k in range(0, k_max + 1):
        yt = g.shift(k)
        m = yt.notna()
        ket[k] = float(np.sqrt(np.mean((v['y_pred'][m] - yt[m]) ** 2)))
    return ket


print("Đã định nghĩa các hàm chuẩn hoá, tính metric và quét độ trễ.")
# Out:
# Đã định nghĩa các hàm chuẩn hoá, tính metric và quét độ trễ.

# %% [markdown]
# ## 10. Chuẩn bị ma trận huấn luyện

# %%
dev_h = them_muc_tieu(dev, HORIZON_STEPS)
dev_h = dev_h[(dev_h['site_scale'] > 0) & (dev_h['sin_elevation'] > EPS_ELEV)].copy()
CLIP_K = tinh_clip_tu_train(dev_h)
dev_h['k_target'] = cat_k(dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h))
dev_h['w'] = build_sample_weight(dev_h)

# THU NGHIEM 3: bo sung cac cot tat dinh tai T+h vao tap dac trung.
# Phai lam sau them_muc_tieu vi cot _mt duoc sinh trong do.
_mt = [f'{c}_mt' for c in COT_TAT_DINH if f'{c}_mt' in dev_h.columns]
FEATURES = FEATURES + [c for c in _mt if c not in FEATURES]
print(f"Them {len(_mt)} dac trung tat dinh tai T+{HORIZON_STEPS * 15} phut:")
print(f"   {_mt}")

MEDIANS = dev_h[FEATURES].median(numeric_only=True).fillna(0.0)

# Chi train tren dong co weight > 0, giong srcs: mask = label_mask & weight_all.gt(0)
_train_mask = dev_h['w'].gt(0)
X_dev = dev_h.loc[_train_mask, FEATURES].fillna(MEDIANS).astype(DTYPE)
y_dev = dev_h.loc[_train_mask, 'k_target'].astype(DTYPE)
w_dev = dev_h.loc[_train_mask, 'w'].astype(DTYPE)

print(f"Ma tran train : {X_dev.shape[0]:,} dong x {X_dev.shape[1]} dac trung")
print(f"Muc tieu chuan hoa k: min {y_dev.min():.4f}  trung vi {np.median(y_dev):.4f}  max {y_dev.max():.4f}")

print(f"\n--- CHINH SACH OUTLIER, experiment = {EXPERIMENT} ---")
print("Dong co weight = 0 khong tham gia ham muc tieu nhung van giu de bao cao.")
_bang_w = dev_h.groupby(['nhan_energy_source', 'nhan_outlier_group'], observed=True).agg(
    so_dong=('w', 'size'),
    so_dong_weight_1=('w', lambda x: int((x > 0).sum())),
).reset_index()
_bang_w['ty_le_duoc_train_%'] = (_bang_w['so_dong_weight_1'] / _bang_w['so_dong'] * 100).round(1)
display(_bang_w.sort_values('so_dong', ascending=False))

_loai = int((~_train_mask).sum())
print(f"Tong dong bi loai khoi ham muc tieu: {_loai:,} / {len(dev_h):,} ({_loai / len(dev_h) * 100:.2f}%)")
_pc = int((dev_h['nhan_outlier_group'].astype(str) == 'physical_over_capacity').sum())
print(f"   trong do physical_over_capacity: {_pc:,} dong (luon bi loai o moi experiment)")

print(f"\nKhoang thoi gian train: {dev_h[TIMESTAMP_COL].min()} -> {dev_h[TIMESTAMP_COL].max()}")
# Out:
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 1.3587
#    chan lai 1.00% quan sat (khong xoa dong nao)
# Them 13 dac trung tat dinh tai T+15 phut:
#    ['solar_elevation_mt', 'solar_azimuth_mt', 'azimuth_sin_mt', 'azimuth_cos_mt', 'sin_elevation_mt', 'ghi_cs_mt', 'ky_vong_mt', 'ty_le_bao_hoa_mt', 'minute_of_day_mt', 'hour_mt', 'hour_cos_mt', 'doy_sin_mt', 'doy_cos_mt']
# Ma tran train : 599,545 dong x 52 dac trung
# Muc tieu chuan hoa k: min 0.0028  trung vi 0.6446  max 1.3587
#
# --- CHINH SACH OUTLIER, experiment = measured_only_headline ---
# Dong co weight = 0 khong tham gia ham muc tieu nhung van giu de bao cao.
#          nhan_energy_source   nhan_outlier_group  so_dong  so_dong_weight_1  \
# 9                  measured               normal   597868            596324
# 5               etl_imputed               normal    82375                 0
# 7                  measured     gmm_if_consensus     2675              2673
# 10                 measured  other_physical_rule      295               295
# 8                  measured       multiple_rules      253               253
# 3               etl_imputed     gmm_if_consensus      131                 0
# 0    causal_day_persistence               normal       69                 0
# 1     causal_profile_median               normal       18                 0
# 6               etl_imputed  other_physical_rule        7                 0
# 2   causal_week_persistence               normal        2                 0
# 4               etl_imputed       multiple_rules        1                 0
#
#     ty_le_duoc_train_%
# 9                 99.7
# 5                  0.0
# 7                 99.9
# 10               100.0
# 8                100.0
# 3                  0.0
# 0                  0.0
# 1                  0.0
# 6                  0.0
# 2                  0.0
# 4                  0.0
# Tong dong bi loai khoi ham muc tieu: 84,149 / 683,694 (12.31%)
#    trong do physical_over_capacity: 0 dong (luon bi loai o moi experiment)
#
# Khoang thoi gian train: 2020-01-02 06:30:00 -> 2021-06-21 17:00:00

# %%
# ── Ham doc fold (chuyen len day de tap validation dung duoc ngay) ──
FOLDS_DIR = f'{SELECTED_DIR}/time_series_folds'


CLIP_K_FOLD = {}   # fold -> nguong cat fold-local


def doc_fold(n, vai_tro, clip_k=None):
    """Doc mot fold, muc tieu va weight nhu tap development.

    SUA RO RI 2026-08-19: nguong cat k tinh RIENG tu train tung fold (truoc dung chung
    nguong train alias -> fold 1/2 nhin tuong lai). Fit cuoi/val/test khong doi.
    """
    duong_dan = f'{FOLDS_DIR}/fold_{n}_{vai_tro}_selected.parquet'
    if not os.path.exists(duong_dan):
        return None
    co_san = set(pq.ParquetFile(duong_dan).schema_arrow.names)
    cot = [c for c in dict.fromkeys(FEATURES + COT_PHU + COT_BAT_BUOC) if c in co_san]
    d = pd.read_parquet(duong_dan, columns=cot).sort_values([SITE_COL, TIMESTAMP_COL]).reset_index(drop=True)
    if EXCLUDE_SITES and SITE_COL in d.columns:
        d = d[~d[SITE_COL].isin(EXCLUDE_SITES)]
    d = them_muc_tieu(d, HORIZON_STEPS)
    d = d[(d['site_scale'] > 0) & (d['sin_elevation'] > EPS_ELEV)].copy()
    if clip_k is None:
        if vai_tro == 'train':
            clip_k = tinh_clip_tu_train(d)
            CLIP_K_FOLD[n] = clip_k
        else:
            # val dung nguong train cua fold minh; thieu thi ve nguong toan cuc
            clip_k = CLIP_K_FOLD.get(n) or lay_clip()
    d['k_target'] = cat_k(d['y_true'].to_numpy() / mau_chuan_hoa(d), clip_k=clip_k)
    d['w'] = build_sample_weight(d, clip_k=clip_k)
    d = d[d['w'].gt(0)]
    return d


def doc_val_that():
    """Doc tap VALIDATION THAT (v5_val_selected), xu ly y het doc_fold().

    TACH BIET HOAN TOAN voi tap hoc: mo hinh chi hoc v5_train_selected, nen moi dong
    trong khung nay deu la dong CHUA TUNG duoc hoc. Truoc day cho nay gop 3 fold val -
    ma fold nam trong development (= train + val) va mo hinh cuoi lai hoc ca development,
    nen con so thu duoc la cham tren bai da hoc, khong dung de chon mo hinh duoc.
    """
    d = doc_du_lieu('v5_val_selected')
    d = them_muc_tieu(d, HORIZON_STEPS)
    d = d[(d['site_scale'] > 0) & (d['sin_elevation'] > EPS_ELEV)].copy()
    d['k_target'] = cat_k(d['y_true'].to_numpy() / mau_chuan_hoa(d))
    d['w'] = build_sample_weight(d)
    return d[d['w'].gt(0)]


# ── TAP VALIDATION thay cho tap test ──
# Tap test BI NIEM PHONG: notebook nay tuyet doi khong mo no. Moi danh gia (do tre pha,
# metric 3 pham vi, metric 8 pham vi, bieu do actual-vs-predict) deu chay tren tap
# VALIDATION gop tu 3 fold. Tap test chi duoc mo DUY NHAT 1 lan o notebook 07, sau khi
# mo hinh vo dich da duoc chon xong bang chinh so lieu validation nay.
#
# Vi sao doi: ban cu mo tap test ngay trong buoc train roi in metric ra man hinh. Du
# khong dung con so do de chon gi, viec nhin thay no da lam mat y nghia "niem phong" -
# nguoi lam co the (vo tinh) chinh tham so theo huong lam dep con so test.
def _nap_val_gop():
    """Gop 3 fold validation thanh 1 khung, ap dung y het cach xu ly tap development."""
    _khung = []
    _n = 1
    while True:
        _d = doc_fold(_n, 'val')
        if _d is None:
            break
        _khung.append(_d)
        _n += 1
    if not _khung:
        raise FileNotFoundError(
            f"Khong tim thay fold validation nao trong {FOLDS_DIR}. "
            f"Hay chay lai notebook 02 den 05 truoc.")
    return pd.concat(_khung, ignore_index=True)


val_h = doc_val_that()
print(f"Tap VALIDATION that (v5_val_selected): {len(val_h):,} dong")
print("Tap nay TACH BIET voi tap hoc - mo hinh chi hoc v5_train_selected.")
print("Tap TEST: KHONG mo o notebook nay (chi mo o notebook 07).")
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 704,748 -> 671,165 dong
# Lọc v5_val_selected: 723,114 -> 671,165 dòng (49 cột)
# Tap VALIDATION that (v5_val_selected): 289,348 dong
# Tap nay TACH BIET voi tap hoc - mo hinh chi hoc v5_train_selected.
# Tap TEST: KHONG mo o notebook nay (chi mo o notebook 07).

# %% [markdown]
# ## 10.1. Chẩn đoán ngay trong lúc train - in ra các trường hợp đáng nghi
#
# In thẳng ra 3 nhóm bằng chứng để không phải đi dò lại sau khi train xong:
#
# 1. **Trần công suất**: site nào bị loại nhiều dòng vì cờ `physical_over_capacity`, và đỉnh mà model
#    thực sự được học so với đỉnh thật (nếu lệch nhiều thì model không thể dựng lại đỉnh).
# 2. **Join thời tiết**: bao nhiêu dòng đang dùng thời tiết của giờ chưa xảy ra
#    (`weather_timestamp > timestamp`). Xem `docs/open_meteo_hourly_column_semantics_vi.md` mục 5.
# 3. **Clip mục tiêu**: bao nhiêu dòng bị ngưỡng `k <= 1.5` cắt mất.

# %%
print("=" * 78)
print("CHAN DOAN 1: TRAN CONG SUAT - dinh that vs dinh model duoc hoc, theo site")
print("=" * 78)
_ch = dev_h.copy()
_ch['duoc_train'] = _ch['w'] > 0
_rows = []
for _s, _g in _ch.groupby(SITE_COL, observed=True):
    _t = _g[_g['duoc_train']]
    _rows.append({
        'site_id': _s,
        'dong_ban_ngay': len(_g),
        'dong_bi_loai': int((~_g['duoc_train']).sum()),
        'ty_le_loai_%': round((~_g['duoc_train']).mean() * 100, 1),
        'dinh_that': round(float(_g['y_true'].max()), 2),
        'dinh_duoc_hoc': round(float(_t['y_true'].max()), 2) if len(_t) else np.nan,
        'median_that': round(float(_g['y_true'].median()), 2),
        'median_duoc_hoc': round(float(_t['y_true'].median()), 2) if len(_t) else np.nan,
    })
_bang_ch = pd.DataFrame(_rows)
_bang_ch['thieu_dinh_%'] = ((_bang_ch['dinh_that'] - _bang_ch['dinh_duoc_hoc'])
                            / _bang_ch['dinh_that'] * 100).round(1)
_dang_nghi = _bang_ch[(_bang_ch['ty_le_loai_%'] > 10) | (_bang_ch['thieu_dinh_%'] > 5)]
print(f"Experiment dang dung: {EXPERIMENT} | trong so mau: {CHE_DO_TRONG_SO}")
print(f"So site DANG NGHI (loai > 10% dong hoac thieu dinh > 5%): {len(_dang_nghi)}/{len(_bang_ch)}")
if len(_dang_nghi):
    display(_dang_nghi.sort_values('ty_le_loai_%', ascending=False))
else:
    print("Khong con site nao bi loai qua nhieu du lieu - tran cong suat da dung.")

print()
print("=" * 78)
print("CHAN DOAN 2: JOIN THOI TIET - co dung thoi tiet cua gio CHUA XAY RA khong")
print("=" * 78)
_MLMART = '../../data/mlmart_base/v5_final_cleaned.parquet'
try:
    _wnames = set(pq.ParquetFile(_MLMART).schema_arrow.names)
    if {'timestamp', 'weather_timestamp'} <= _wnames:
        _wd = pd.read_parquet(_MLMART, columns=['timestamp', 'weather_timestamp'])
        _delta = ((pd.to_datetime(_wd['weather_timestamp']) - pd.to_datetime(_wd['timestamp']))
                  .dt.total_seconds() / 60)
        _leak = int((_delta > 0).sum())
        print("Phan bo (weather_timestamp - timestamp), don vi phut:")
        print(_delta.value_counts().sort_index().to_string())
        print(f"\nSo dong dung THOI TIET TUONG LAI: {_leak:,}/{len(_wd):,} ({_leak / len(_wd) * 100:.2f}%)")
        if _leak:
            print("[CANH BAO] Dong nao co delta > 0 la dang lay thoi tiet cua gio chua xay ra.")
            print("   Vi du delta = +45: dong 10:15 dung thoi tiet dan nhan 11:00.")
            print("   Cac cot buc xa/precipitation/sunshine la TRUNG BINH CA GIO nen vua ro ri")
            print("   tuong lai, vua lam PHANG dinh that - xem docs/open_meteo_hourly_column_semantics_vi.md")
        del _wd, _delta
        gc.collect()
    else:
        print("Khong co cot weather_timestamp trong mlmart base, bo qua kiem tra nay.")
except FileNotFoundError:
    print(f"Khong tim thay {_MLMART}, bo qua kiem tra nay.")

print()
print("=" * 78)
print(f"CHAN DOAN 3: CLIP MUC TIEU - bao nhieu dong bi nguong k <= {lay_clip():.4f} cat")
print("=" * 78)
_k_raw = dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h)
_bi_cat = int((_k_raw > CLIP_K).sum())
print(f"So dong bi clip boi nguong {lay_clip():.4f} : {_bi_cat:,}/{len(dev_h):,} ({_bi_cat / len(dev_h) * 100:.2f}%)")
print(f"k_raw lon nhat               : {np.nanmax(_k_raw):.3f}")
print("Neu ty le nay nho (< 1%) thi clip KHONG phai nguyen nhan mat bien do.")
del _ch, _k_raw
gc.collect()
print()
print("Hoan tat chan doan truoc khi train.")
# Out:
# ==============================================================================
# CHAN DOAN 1: TRAN CONG SUAT - dinh that vs dinh model duoc hoc, theo site
# ==============================================================================
# Experiment dang dung: measured_only_headline | trong so mau: mau_so
# So site DANG NGHI (loai > 10% dong hoac thieu dinh > 5%): 26/40
#     site_id  dong_ban_ngay  dong_bi_loai  ty_le_loai_%  dinh_that  \
# 6         7          23835          9540          40.0      16.99
# 8         9          23834          4985          20.9       2.19
# 32       35          20141          4182          20.8       6.21
# 24       27          24050          4980          20.7      99.22
# 25       28          15006          3088          20.6       3.46
# 26       29          15193          3012          19.8       3.31
# 4         5           8742          1686          19.3       2.00
# 12       13          22680          4346          19.2      13.02
# 3         4           8742          1401          16.0       2.00
# 15       16           8669          1384          16.0       3.39
# 31       34          20002          2836          14.2       4.42
# 36       39          14507          1984          13.7       6.91
# 27       30          14507          1886          13.0       8.45
# 23       26          16641          2057          12.4       7.96
# 19       21          16640          1983          11.9       8.11
# 21       23          14507          1694          11.7      12.47
# 29       32          16641          1926          11.6       7.36
# 16       17          16641          1772          10.6       9.56
# 35       38          16640          1765          10.6      11.67
# 33       36          16640          1758          10.6      10.23
# 37       40          16641          1686          10.1      16.61
# 18       20          16640          1588           9.5      16.84
# 39       42          23851          2057           8.6       6.71
# 9        10          23835          1396           5.9       9.00
# 1         2          23842          1373           5.8      20.33
# 0         1          23842          1095           4.6      23.54
#
#     dinh_duoc_hoc  median_that  median_duoc_hoc  thieu_dinh_%
# 6           16.03         5.50             5.19           5.7
# 8            2.01         0.76             0.85           8.2
# 32           6.03         1.63             1.67           2.9
# 24          99.22        29.50            28.75           0.0
# 25           3.46         0.86             0.93           0.0
# 26           3.31         0.83             0.92           0.0
# 4            2.00         0.79             0.89           0.0
# 12          13.02         4.75             4.88           0.0
# 3            2.00         0.70             0.80           0.0
# 15           3.31         0.91             1.02           2.4
# 31           4.06         1.22             1.28           8.1
# 36           6.54         1.97             2.05           5.4
# 27           8.40         2.26             2.27           0.6
# 23           7.68         2.29             2.34           3.5
# 19           8.02         2.11             2.18           1.1
# 21          12.05         3.38             3.33           3.4
# 29           7.36         1.80             1.87           0.0
# 16           9.55         2.55             2.59           0.1
# 35          11.39         3.11             3.10           2.4
# 33          10.15         2.74             2.78           0.8
# 37          16.61         4.20             4.20           0.0
# 18          15.82         4.57             4.55           6.1
# 39           6.28         2.28             2.31           6.4
# 9            7.75         3.45             3.44          13.9
# 1           18.56         6.95             6.88           8.7
# 0           21.78         8.41             8.31           7.5
# ==============================================================================
# CHAN DOAN 2: JOIN THOI TIET - co dung thoi tiet cua gio CHUA XAY RA khong
# ==============================================================================
# Phan bo (weather_timestamp - timestamp), don vi phut:
# -45.0    682910
# -30.0    683002
# -15.0    683102
#  0.0     682714
#
# So dong dung THOI TIET TUONG LAI: 0/2,731,946 (0.00%)
#
# ==============================================================================
# CHAN DOAN 3: CLIP MUC TIEU - bao nhieu dong bi nguong k <= 1.3587 cat
# ==============================================================================
# So dong bi clip boi nguong 1.3587 : 6,837/683,694 (1.00%)
# k_raw lon nhat               : 7.183
# Neu ty le nay nho (< 1%) thi clip KHONG phai nguyen nhan mat bien do.
#
# Hoan tat chan doan truoc khi train.

# %% [markdown]
# ## 10.2. CỔNG KIỂM TRA TRƯỚC TRAIN — không đạt thì dừng, không train
#
# Trước đây đã đưa ra nhiều giả thuyết về trễ pha rồi mới train, và phần lớn sai. Bước này đảo lại
# thứ tự: **đo trên dữ liệu trước, chỉ train khi dữ liệu không bắt buộc model phải trễ.**
#
# Nói rõ giới hạn: cổng này chứng minh được **dữ liệu không cài sẵn độ trễ không thể bù**, nhưng
# không bảo đảm model học ra sẽ không trễ — đó là kết quả của quá trình học, phải đo lại ở `09`.
#
# Bốn kiểm tra, `raise` ngay nếu vi phạm:
#
# | | Kiểm tra | Tiêu chí dừng |
# |---|---|---|
# | A | Nhãn đúng là `energy(T+h)` | sai lệch shift → dừng |
# | B | Thời tiết causal (`weather_ts <= timestamp`) | còn dòng dùng tương lai → dừng |
# | C | Độ trễ cài sẵn: dịch đặc trưng `k` bước thì khớp mục tiêu nhất | `k != 0` mà **không có** đặc trưng `_mt` để bù → dừng |
# | D | Vùng đỉnh có được học | site bị loại >50% dòng ban ngày → dừng |

# %%
_loi = []
print("=" * 74); print("CONG KIEM TRA TRUOC TRAIN"); print("=" * 74)

# ---- A. Nhan co dung la energy(T+h) ----
_s0 = dev_h[SITE_COL].iloc[0]
_sub = dev.loc[dev[SITE_COL].eq(_s0)].sort_values(TIMESTAMP_COL).head(HORIZON_STEPS + 5)
_ok_a = np.allclose(_sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 4].to_numpy(dtype=float),
                    _sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 4].to_numpy(dtype=float))
_chk = them_muc_tieu(_sub.copy(), HORIZON_STEPS)
if len(_chk):
    _ok_a = np.allclose(_chk['y_true'].iloc[:3].to_numpy(dtype=float),
                        _sub[TARGET_COL].iloc[HORIZON_STEPS:HORIZON_STEPS + 3].to_numpy(dtype=float),
                        equal_nan=True)
print(f"[A] y_true(T) == energy(T+{HORIZON_STEPS}): {'DAT' if _ok_a else 'SAI'}")
if not _ok_a:
    _loi.append("A: nhan khong khop energy(T+h) - shift bi lech")

# ---- B. Thoi tiet causal ----
# Notebook 01 sua join trong BO NHO roi ghi ra v5_continuous_grid.parquet, KHONG ghi lai vao
# mlmart_base. Nen phai kiem chinh file ma luong train dung, khong kiem file nguon.
# Buoc 3.1 cua notebook 01 dat weather_join_method = 'hour_causal_floor' khi sua thanh cong.
_GRID = '../../data/model/v5/01_reindex/v5_continuous_grid.parquet'
if os.path.exists(_GRID):
    _gn = set(pq.ParquetFile(_GRID).schema_arrow.names)
    if 'weather_join_method' in _gn:
        _jm = pd.read_parquet(_GRID, columns=['weather_join_method'])['weather_join_method']
        _vc = _jm.value_counts(dropna=False)
        print("[B] Thoi tiet causal - weather_join_method trong v5_continuous_grid:")
        for _k, _v in _vc.items():
            print(f"       {str(_k):<26} {_v:>10,}")
        _n_cu = int(_jm.astype(str).eq('raw_hour_causal_manual').sum())
        if _n_cu:
            _loi.append(f"B: con {_n_cu:,} dong mang nhan join CU 'raw_hour_causal_manual' "
                        f"(join hoi cuu, 71,90% dong dung thoi tiet tuong lai). "
                        f"Chay lai notebook 01 - buoc 3.1 se sua thanh 'hour_causal_floor'.")
        else:
            print("       -> Da la join causal (hour_causal_floor), khong dung du lieu tuong lai.")
        del _jm, _vc
        gc.collect()
    else:
        print("[B] Khong co cot weather_join_method trong grid, bo qua kiem tra nay.")
else:
    _loi.append(f"B: chua co {_GRID} - phai chay notebook 01 truoc.")

# ---- C. Do tre cai san ----
_b = dev_h[dev_h['w'].gt(0)]
_gb = _b.groupby(SITE_COL)
print(f"[C] Do tre cai san (dich dac trung k buoc, do bang MAE - khong dung RMSE):")
_k_xau = []
for _col in ['shortwave_radiation', 'sin_elevation']:
    if _col not in _b.columns:
        continue
    _r = {}
    for _k in range(-2, 3):
        _x = _gb[_col].shift(-_k).to_numpy(dtype=float)
        _y = _b['y_true'].to_numpy(dtype=float)
        _m = np.isfinite(_x) & np.isfinite(_y)
        if _m.sum() < 1000:
            continue
        _sc = np.nansum(_x[_m] * _y[_m]) / np.nansum(_x[_m] * _x[_m])
        _r[_k] = float(np.mean(np.abs(_sc * _x[_m] - _y[_m])))
    if not _r:
        continue
    _kb = min(_r, key=_r.get)
    print(f"    {_col:<22} " + " | ".join(f"k={k}:{v:.4f}" for k, v in _r.items())
          + f"  -> k tot nhat = {_kb}")
    if _kb != 0:
        _k_xau.append((_col, _kb))

_co_mt = [c for c in FEATURES if c.endswith('_mt')]
if _k_xau:
    print(f"    Co {len(_k_xau)} dac trung tre cai san: {_k_xau}")
    if _co_mt:
        print(f"    Nhung DA CO {len(_co_mt)} dac trung tai T+h de model tu bu -> cho di tiep.")
    else:
        _loi.append(f"C: du lieu tre cai san {_k_xau} ma KHONG co dac trung _mt de bu. "
                    f"Dat THEM_DAC_TRUNG_MUC_TIEU = True o buoc 2.")
else:
    print("    Khong co dac trung nao tre cai san.")

# ---- D. Vung dinh co duoc hoc ----
_t = dev_h.copy()
_t['duoc_train'] = _t['w'] > 0
_bo = (_t.groupby(SITE_COL, observed=True)['duoc_train']
       .apply(lambda x: 1 - x.mean()).mul(100).round(1))
_nang = _bo[_bo > 50]
print(f"[D] Site bi loai > 50% dong ban ngay: {len(_nang)}/{_bo.size}")
if len(_nang):
    print(_nang.to_string())
    _loi.append(f"D: {len(_nang)} site bi loai qua nua du lieu ban ngay -> khong hoc duoc vung dinh. "
                f"Kiem tra EXPERIMENT (dang la '{EXPERIMENT}')")
del _t, _b
gc.collect()

# ---- KET LUAN ----
print()
print("=" * 74)
if _loi:
    print("CONG KIEM TRA: KHONG DAT - DUNG, KHONG TRAIN")
    for _e in _loi:
        print(f"  - {_e}")
    print("=" * 74)
    raise RuntimeError(f"Cong kiem tra truoc train khong dat ({len(_loi)} loi). "
                       f"Sua xong roi chay lai, dung train khi chua dat.")
print("CONG KIEM TRA: DAT TOAN BO - du lieu khong cai san do tre khong the bu, cho train.")
print("=" * 74)
# Out:
# ==========================================================================
# CONG KIEM TRA TRUOC TRAIN
# ==========================================================================
# [A] y_true(T) == energy(T+1): DAT
# [B] Thoi tiet causal - weather_join_method trong v5_continuous_grid:
#        raw_hour_causal_join        2,731,728
#        nan                            52,492
#        missing_weather                   218
#        -> Da la join causal (hour_causal_floor), khong dung du lieu tuong lai.
# [C] Do tre cai san (dich dac trung k buoc, do bang MAE - khong dung RMSE):
#     shortwave_radiation    k=-2:5.1854 | k=-1:5.0445 | k=0:4.9042 | k=1:4.7854 | k=2:4.7139  -> k tot nhat = 2
#     sin_elevation          k=-2:5.2829 | k=-1:5.2192 | k=0:5.1807 | k=1:5.1801 | k=2:5.2087  -> k tot nhat = 1
#     Co 2 dac trung tre cai san: [('shortwave_radiation', 2), ('sin_elevation', 1)]
#     Nhung DA CO 13 dac trung tai T+h de model tu bu -> cho di tiep.
# [D] Site bi loai > 50% dong ban ngay: 0/40
#
# ==========================================================================
# CONG KIEM TRA: DAT TOAN BO - du lieu khong cai san do tre khong the bu, cho train.
# ==========================================================================

# %% [markdown]
# ## 10.3. Train thử nhanh và ĐO TRỄ THẬT — không sạch thì dừng, không tune
#
# Cổng ở `10.2` chỉ chứng minh **dữ liệu** không cài sẵn độ trễ. Bước này đo **model thật sự có trễ
# hay không**, bằng một mô hình nhỏ chạy trong ~1 phút, **trước khi** bỏ thời gian cho Optuna
# (15 trial × 3 fold mới là phần tốn hàng chục phút).
#
# Cách đo — theo độ dốc, **không dùng RMSE** và không dùng `argmax` đỉnh:
#
# ```
# doc(t) = (thuc_te(t+1) - thuc_te(t-1)) / 2      # do doc cua duong thuc te
# err(t) = du_bao(t) - thuc_te(t)
# tre_phut = -sum(doc * err) / sum(doc^2) * 15
# ```
#
# Nếu dự báo bị dịch phải `c` bước thì `err ≈ -c · doc`, nên hệ số hồi quy trả về đúng `c` tính bằng
# phút. Chỉ số này **tách sai số biên độ ra khỏi sai số thời điểm** — dự báo cao hay thấp đều không
# ảnh hưởng, nên không bị nhiễu bởi chuyện đỉnh tù. Đây cũng đúng công thức dashboard đang hiển thị.
#
# Không đạt ngưỡng thì `raise`, không chạy tiếp.

# %%
# ── Tham so cong do tre ──
NGUONG_TRE_PHUT = 5.0      # |tre| vuot nguong nay thi dung, khong tune
MAU_THU_NHANH = 300_000    # so dong lay mau de train thu cho nhanh
DUNG_NEU_TRE = True        # dat False de van chay tiep du tre (chi khi co ly do ro rang)


def do_tre_phut(d, cot_that, cot_du_bao):
    """Do do tre theo do doc, tra ve so PHUT. Duong = du bao di sau (dich phai).

    err ~ -c * doc neu du bao bi dich c buoc, nen he so hoi quy chinh la c.
    Tach sai so BIEN DO ra khoi sai so THOI DIEM: du bao cao hay thap deu khong anh huong.
    """
    x = d.sort_values([SITE_COL, TIMESTAMP_COL])
    g = x.groupby(SITE_COL, observed=True)[cot_that]
    doc = (g.shift(-1) - g.shift(1)) / 2
    err = x[cot_du_bao] - x[cot_that]
    m = doc.notna() & err.notna()
    if 'is_daylight' in x.columns:
        m = m & x['is_daylight'].fillna(False).astype(bool)
    a = doc[m].to_numpy(dtype=float)
    b = err[m].to_numpy(dtype=float)
    if a.size < 200 or (a ** 2).sum() == 0:
        return np.nan, 0
    return -float((a * b).sum() / (a * a).sum()) * 15, int(a.size)


print("=" * 74)
print("TRAIN THU NHANH DE DO TRE (truoc khi tune)")
print("=" * 74)

_n = min(MAU_THU_NHANH, len(X_dev))
_idx = X_dev.sample(n=_n, random_state=SEED).index
_p = {'objective': LGB_OBJECTIVE, 'random_state': SEED, 'verbosity': -1, 'n_jobs': N_JOBS,
      'max_bin': MAX_BIN, 'force_col_wise': FORCE_COL_WISE, 'deterministic': DETERMINISTIC,
      'n_estimators': 200,
      'learning_rate': 0.08, 'num_leaves': 63, 'min_child_samples': 40}
# Fit so bo CO Y dung MAE (l1) chu khong phai huber: day la giai doan 1 cua quy trinh
# hai giai doan trong thong ke ben - dung mot uoc luong BEN de do thang phan du, roi moi
# dat delta cho Huber o giai doan 2. Dung huber o day se thanh vong luan quan.
_p['objective'] = 'l1'
_p.pop('alpha', None)
if GPU_SAN_SANG:
    _p.update({'device': 'gpu', 'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID})

def _fit_thu(params, Xa, ya, wa):
    """Fit tai cho, GPU loi thi lui ve CPU. Dinh nghia rieng vi fit_an_toan
    nam o buoc 11 (phia sau cell nay)."""
    try:
        m = LGBMRegressor(**params)
        m.fit(Xa, ya, sample_weight=wa, categorical_feature=cot_categorical(Xa))
        return m
    except Exception as e:
        if params.get('device') == 'gpu':
            print(f"   [CANH BAO] GPU loi, lui ve CPU: {str(e)[:80]}")
            p2 = {k: v for k, v in params.items()
                  if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
            m = LGBMRegressor(**p2)
            m.fit(Xa, ya, sample_weight=wa, categorical_feature=cot_categorical(Xa))
            return m
        raise


_t0_thu = time.time()
_m_thu = _fit_thu(_p, X_dev.loc[_idx], y_dev.loc[_idx], w_dev.loc[_idx])
print(f"Train thu {_n:,} dong x {len(FEATURES)} dac trung trong {time.time() - _t0_thu:.1f} giay")

# ── Suy delta cua Huber tu THANG PHAN DU (khong viet cung con so nao) ─────────
# Do tren dong TRAIN NGOAI MAU vua fit -> khong lac quan nhu phan du trong mau, va khong
# dung toi validation (validation de chon mo hinh, khong de suy tham so). Dung MAD x 1,4826
# thay do lech chuan tho vi phan du co duoi nang (cu vot do may) lam std bi keo len.
_con_lai = X_dev.index.difference(_idx)
_idx_do = _con_lai[:150_000] if len(_con_lai) > 150_000 else _con_lai
if len(_idx_do) < 1_000:
    _idx_do = _idx
_r_k = _m_thu.predict(X_dev.loc[_idx_do].astype(DTYPE)) - y_dev.loc[_idx_do].to_numpy()
_sigma_mad = float(1.4826 * np.median(np.abs(_r_k - np.median(_r_k))))
HUBER_DELTA = float(1.345 * _sigma_mad)
print(f"Thang phan du (train ngoai mau, {len(_idx_do):,} dong): "
      f"|r| p50 {np.median(np.abs(_r_k)):.4f} | p90 {np.quantile(np.abs(_r_k), 0.9):.4f} "
      f"| sigma(MAD) {_sigma_mad:.4f}")
print(f"-> HUBER_DELTA = 1.345 x sigma = {HUBER_DELTA:.4f}  (quy tac Huber 1964)")
print(f"   Ty le dong vao vung TUYEN TINH cua Huber: "
      f"{(np.abs(_r_k) > HUBER_DELTA).mean() * 100:.2f}%  (voi delta = 1.0 chi ~0,02%)")

# Du bao tren tap VALIDATION, nhan nguoc mau chuan hoa va chan tran giong luc cham diem that
_te = val_h[(val_h['site_scale'] > 0) & (val_h['sin_elevation'] > EPS_ELEV)].copy()
_k = cat_k(_m_thu.predict(_te[FEATURES].fillna(MEDIANS).astype(DTYPE)))
_yp = np.minimum(_k * mau_chuan_hoa(_te), _te['tran_cong_suat'].to_numpy() * 1.02)
_te['y_pred'] = np.where(_te['sin_elevation'].to_numpy() <= EPS_ELEV, 0.0, _yp)
if 'nhan_is_daylight' in _te.columns:
    _te['is_daylight'] = _te['nhan_is_daylight']

_tre, _nd = do_tre_phut(_te, 'y_true', 'y_pred')
_wape = float(np.abs(_te['y_pred'] - _te['y_true']).sum() / np.abs(_te['y_true']).sum() * 100)
print(f"\nTREN {_nd:,} diem ban ngay cua tap VALIDATION:")
print(f"   Do tre        : {_tre:+.2f} phut   (duong = du bao di SAU thuc te)")
print(f"   Nguong cho phep: +/- {NGUONG_TRE_PHUT:.1f} phut")
print(f"   WAPE tham khao : {_wape:.2f}%  (model nho, chua tune - chi de doi chieu)")

# Do theo tung site: 1 site tre nang cung la bug, khong duoc de con so tong the che mat
_rows_tre = []
for _s, _g in _te.groupby(SITE_COL, observed=True):
    _t1, _n1 = do_tre_phut(_g, 'y_true', 'y_pred')
    if _n1 >= 200:
        _rows_tre.append({'site_id': _s, 'tre_phut': round(_t1, 2), 'so_diem': _n1})
_bang_tre = pd.DataFrame(_rows_tre).sort_values('tre_phut', key=abs, ascending=False)
_qua = _bang_tre[_bang_tre['tre_phut'].abs() > NGUONG_TRE_PHUT]
print(f"\nSite vuot nguong: {len(_qua)}/{len(_bang_tre)}")
if len(_qua):
    display(_qua.head(15))
else:
    print("   Khong site nao vuot nguong.")
print(f"Tre theo site: trung vi {_bang_tre['tre_phut'].median():+.2f} phut | "
      f"nho nhat {_bang_tre['tre_phut'].min():+.2f} | lon nhat {_bang_tre['tre_phut'].max():+.2f}")

del _m_thu, _te, _k, _yp
gc.collect()

print()
print("=" * 74)
if not np.isfinite(_tre) or abs(_tre) > NGUONG_TRE_PHUT or len(_qua) > 0:
    print("CONG DO TRE: KHONG DAT")
    if abs(_tre) > NGUONG_TRE_PHUT:
        print(f"  - Tong the tre {_tre:+.2f} phut, vuot nguong {NGUONG_TRE_PHUT} phut")
    if len(_qua):
        print(f"  - Co {len(_qua)} site tre vuot nguong (tre local van la bug)")
    print("  Khong tune/train tiep. Sua nguyen nhan roi chay lai tu buoc gay ra no.")
    print("=" * 74)
    if DUNG_NEU_TRE:
        raise RuntimeError(f"Model thu nghiem con tre {_tre:+.2f} phut "
                           f"({len(_qua)} site vuot nguong) - dung, khong tune.")
else:
    print(f"CONG DO TRE: DAT - tre {_tre:+.2f} phut, khong site nao vuot nguong.")
    print("Cho phep chay Optuna va train that.")
    print("=" * 74)
# Out:
# ==========================================================================
# TRAIN THU NHANH DE DO TRE (truoc khi tune)
# ==========================================================================
# Train thu 300,000 dong x 52 dac trung trong 9.6 giay
# Thang phan du (train ngoai mau, 150,000 dong): |r| p50 0.0855 | p90 0.3183 | sigma(MAD) 0.1267
# -> HUBER_DELTA = 1.345 x sigma = 0.1705  (quy tac Huber 1964)
#    Ty le dong vao vung TUYEN TINH cua Huber: 27.51%  (voi delta = 1.0 chi ~0,02%)
#
# TREN 289,268 diem ban ngay cua tap VALIDATION:
#    Do tre        : +2.43 phut   (duong = du bao di SAU thuc te)
#    Nguong cho phep: +/- 5.0 phut
#    WAPE tham khao : 22.12%  (model nho, chua tune - chi de doi chieu)
#
# Site vuot nguong: 0/40
#    Khong site nao vuot nguong.
# Tre theo site: trung vi +2.56 phut | nho nhat -0.42 | lon nhat +3.78
#
# ==========================================================================
# CONG DO TRE: DAT - tre +2.43 phut, khong site nao vuot nguong.
# Cho phep chay Optuna va train that.
# ==========================================================================

# %% [markdown]
# ## 11. Tune siêu tham số bằng Optuna trên 3 fold, loss Huber
#
# Dùng đúng **3 fold TimeSeriesSplit** do notebook 02 sinh ra, không dùng phép cắt 80/20 tạm bợ.
# Hàm mục tiêu là **pooled WAPE** — gộp toàn bộ residual của 3 fold rồi mới chia, thay vì lấy trung bình
# WAPE từng fold. Cách gộp này không để fold ít dòng có trọng lượng bằng fold nhiều dòng.
#
# **Sample weight áp cho cả 3 fold**, đúng chính sách `EXPERIMENT` ở trên. Nếu chỉ áp cho tập train cuối
# mà không áp cho fold thì Optuna sẽ chọn tham số trên dữ liệu có outlier rồi đem train trên dữ liệu không
# có — hai bài toán khác nhau, tham số chọn ra không còn đúng.
#
# Đặt `N_TRIALS = 0` ở cell tham số nếu muốn bỏ qua bước này.

# %%
CAC_FOLD = []
if N_TRIALS > 0:
    _n = 1
    while True:
        _tr = doc_fold(_n, 'train')
        _va = doc_fold(_n, 'val')
        if _tr is None or _va is None:
            break
        _med = _tr[FEATURES].median(numeric_only=True).fillna(0.0)
        CAC_FOLD.append({
            'fold': _n,
            'Xtr': _tr[FEATURES].fillna(_med).astype(DTYPE),
            'ytr': _tr['k_target'].astype(DTYPE),
            'wtr': _tr['w'].astype(DTYPE),
            'Xva': _va[FEATURES].fillna(_med).astype(DTYPE),
            'yva': _va['k_target'].astype(DTYPE),
            # danh gia tren thang do GOC (kWh), khong phai thang do chuan hoa
            'yva_kwh': _va['y_true'].to_numpy(),
            'mau_va': mau_chuan_hoa(_va),
            'tran_va': _va['tran_cong_suat'].to_numpy(),
            'sin_va': _va['sin_elevation'].to_numpy(),
            'clip': CLIP_K_FOLD.get(_n),
        })
        print(f"- fold {_n}: train {len(_tr):,} dong, val {len(_va):,} dong (da ap weight)")
        del _tr, _va
        gc.collect()
        _n += 1

    if not CAC_FOLD:
        raise FileNotFoundError(
            f"Khong tim thay fold nao trong {FOLDS_DIR}. Hay chay lai notebook 02 den 05."
        )
    _tong_ram = sum(f['Xtr'].memory_usage(deep=True).sum() + f['Xva'].memory_usage(deep=True).sum()
                    for f in CAC_FOLD) / 1024**3
    print(f"\nDa nap {len(CAC_FOLD)} fold, chiem khoang {_tong_ram:.2f} GB RAM")
else:
    print("Bo qua nap fold (ngan sach Optuna bang 0).")

_t0 = time.time()


def tham_so_co_ban(trial=None):
    p = {'objective': LGB_OBJECTIVE, 'random_state': SEED, 'verbosity': -1,
         'n_jobs': N_JOBS, 'max_bin': MAX_BIN, 'force_col_wise': FORCE_COL_WISE,
         'deterministic': DETERMINISTIC}
    if trial is None:
        p.update({'n_estimators': 800, 'learning_rate': 0.05, 'num_leaves': 160,
                  'min_child_samples': 30, 'subsample': 0.9, 'colsample_bytree': 0.9})
        if LGB_OBJECTIVE == 'huber':
            if HUBER_DELTA is None:
                raise RuntimeError('HUBER_DELTA chua duoc suy — chay cell fit so bo (buoc 10.3) truoc.')
            p['alpha'] = HUBER_DELTA
    else:
        p.update({
            'n_estimators': trial.suggest_int('n_estimators', 400, 1200),
            'learning_rate': trial.suggest_float('learning_rate', 0.02, 0.12, log=True),
            'num_leaves': trial.suggest_int('num_leaves', 63, 255),
            'min_child_samples': trial.suggest_int('min_child_samples', 20, 120),
            'subsample': trial.suggest_float('subsample', 0.7, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
            # alpha la delta cua Huber: cang lon thi cang gan MSE, cang nhay voi sai so lon
            # nen bat duoc dinh tot hon. Noi tran tu 5 len 20 cho THU NGHIEM 2.
            # alpha (delta cua Huber) chi co y nghia khi objective='huber'
            **({'alpha': trial.suggest_float('alpha', 0.05, 0.5, log=True)}
               if LGB_OBJECTIVE == 'huber' else {}),
        })
    if GPU_SAN_SANG:
        p.update({'device': 'gpu', 'gpu_platform_id': GPU_PLATFORM_ID, 'gpu_device_id': GPU_DEVICE_ID})
    return p


def fit_an_toan(params, Xa, ya, wa=None, X_val=None, y_val=None, lich_su=None):
    """Fit, va dung som tren validation khi duoc cung cap."""
    fit_kwargs = {'sample_weight': wa, 'categorical_feature': cot_categorical(Xa)}
    if X_val is not None and y_val is not None:
        callbacks = [early_stopping(EARLY_STOPPING_ROUNDS, first_metric_only=True, verbose=True),
                     log_evaluation(period=200)]
        if lich_su is not None:
            callbacks.insert(0, lgb.record_evaluation(lich_su))
        fit_kwargs.update({
            'eval_set': [(Xa, ya), (X_val, y_val)],
            'eval_names': ['train', 'val'],
            'eval_metric': 'l1',
            'callbacks': callbacks,
        })
    try:
        m = LGBMRegressor(**params)
        m.fit(Xa, ya, **fit_kwargs)
        return m
    except Exception as e:
        if params.get('device') == 'gpu':
            print(f"   [CANH BAO] GPU loi (lightgbm_cpu_after_gpu_retry): {str(e)[:90]}")
            p2 = {k: v for k, v in params.items()
                  if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
            p2['n_jobs'] = N_JOBS
            m = LGBMRegressor(**p2)
            m.fit(Xa, ya, **fit_kwargs)
            return m
        raise


def du_bao_kwh(model, f, so_cay=None):
    """Du bao roi nhan nguoc mau chuan hoa va chan tran, tra ve thang do kWh.

    so_cay: chi dung `so_cay` cay dau tien. De None thi dung het. Khi co early stopping
    phai truyen model.best_iteration_ vao, neu khong se cham diem bang ca nhung cay moc
    them sau diem dung - tuc bo phi ca cong dung som.
    """
    k = cat_k(model.predict(f['Xva'], num_iteration=so_cay), clip_k=f.get('clip'))
    yp = np.minimum(k * f['mau_va'], f['tran_va'] * 1.02)
    return np.where(f['sin_va'] <= EPS_ELEV, 0.0, yp)


if N_TRIALS > 0:
    def objective(trial):
        params = tham_so_co_ban(trial)
        tong_sai_so = 0.0
        tong_thuc_te = 0.0
        _cay_tung_fold = []
        for f in CAC_FOLD:
            m = fit_an_toan(params, f['Xtr'], f['ytr'], f['wtr'], f['Xva'], f['yva'])
            _cay_tung_fold.append(int(m.best_iteration_ or params['n_estimators']))
            yp = du_bao_kwh(m, f, m.best_iteration_)
            tong_sai_so += float(np.abs(yp - f['yva_kwh']).sum())
            tong_thuc_te += float(np.abs(f['yva_kwh']).sum())
            del m
        trial.set_user_attr('so_cay_tung_fold', _cay_tung_fold)
        return tong_sai_so / tong_thuc_te * 100.0 if tong_thuc_te > 0 else np.nan

    def log_trial(study, trial):
        done = trial.number + 1
        el = (time.time() - _t0) / 60
        val = f"{trial.value:.4f}%" if trial.value is not None else "pruned"
        print(f"   [Trial {done:>2}/{N_TRIALS}] pooled WAPE {val:>10} | tot nhat {study.best_value:.4f}% "
              f"| da chay {el:.1f} phut, con khoang {el / done * (N_TRIALS - done):.1f} phut")

    study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=SEED))
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=False, callbacks=[log_trial])
    BEST_PARAMS = tham_so_co_ban()
    BEST_PARAMS.update(study.best_params)
    # So cay do EARLY STOPPING quyet dinh, khong lay tu de xuat cua Optuna: trung vi
    # best_iteration qua 3 fold. Dung trung vi thay vi trung binh de mot fold di thuong
    # (vi du fold 1 rat it du lieu) khong keo lech.
    _cay_es = study.best_trial.user_attrs.get('so_cay_tung_fold')
    if _cay_es:
        BEST_PARAMS['n_estimators'] = int(np.median(_cay_es))
        print(f"So cay tung fold (early stopping): {_cay_es}")
        print(f"-> n_estimators = {BEST_PARAMS['n_estimators']} (trung vi)")
    POOLED_WAPE_CV = float(study.best_value)
    print(f"\nPooled WAPE tot nhat tren {len(CAC_FOLD)} fold = {POOLED_WAPE_CV:.4f}%")
    del CAC_FOLD
    gc.collect()
else:
    BEST_PARAMS = tham_so_co_ban()
    POOLED_WAPE_CV = None
    print("Bo qua Optuna (ngan sach bang 0), dung tham so mac dinh.")

for _k, _v in BEST_PARAMS.items():
    print(f"   {_k}: {_v}")
# Out:
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 1.8825
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 1: train 97,107 dong, val 191,547 dong (da ap weight)
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 1.3858
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 2: train 325,275 dong, val 258,363 dong (da ap weight)
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 1.3586
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 3: train 600,483 dong, val 289,348 dong (da ap weight)
#
# Da nap 3 fold, chiem khoang 0.35 GB RAM
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.067933	train's huber: 0.00512598	val's l1: 0.259662	val's huber: 0.0359077
# Early stopping, best iteration is:
# [210]	train's l1: 0.0664788	train's huber: 0.00495747	val's l1: 0.259413	val's huber: 0.0358591
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0761681	train's huber: 0.00594861	val's l1: 0.139006	val's huber: 0.0143749
# Early stopping, best iteration is:
# [223]	train's l1: 0.0733572	train's huber: 0.00560847	val's l1: 0.13888	val's huber: 0.0143606
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0855484	train's huber: 0.00707163	val's l1: 0.150763	val's huber: 0.0163602
# [400]	train's l1: 0.0678232	train's huber: 0.00494538	val's l1: 0.15083	val's huber: 0.0163826
# Early stopping, best iteration is:
# [324]	train's l1: 0.073162	train's huber: 0.00556052	val's l1: 0.150599	val's huber: 0.0163505
# Evaluated only: l1
#    [Trial  1/20] pooled WAPE   24.2301% | tot nhat 24.2301% | da chay 0.5 phut, con khoang 10.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133167	train's huber: 0.0128051	val's l1: 0.32361	val's huber: 0.0421572
# [400]	train's l1: 0.103707	train's huber: 0.00921745	val's l1: 0.279616	val's huber: 0.0351956
# [600]	train's l1: 0.0886989	train's huber: 0.00736872	val's l1: 0.270262	val's huber: 0.0336793
# [800]	train's l1: 0.0784393	train's huber: 0.00614509	val's l1: 0.268604	val's huber: 0.0334161
# Did not meet early stopping. Best iteration is:
# [965]	train's l1: 0.0722001	train's huber: 0.00543613	val's l1: 0.26802	val's huber: 0.0333216
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.132879	train's huber: 0.0123495	val's l1: 0.151019	val's huber: 0.014682
# [400]	train's l1: 0.105669	train's huber: 0.00917502	val's l1: 0.139323	val's huber: 0.0133238
# [600]	train's l1: 0.0904603	train's huber: 0.00735185	val's l1: 0.138213	val's huber: 0.0131768
# [800]	train's l1: 0.0813702	train's huber: 0.00630973	val's l1: 0.137855	val's huber: 0.0131312
# Did not meet early stopping. Best iteration is:
# [967]	train's l1: 0.0760893	train's huber: 0.00572412	val's l1: 0.137629	val's huber: 0.0131034
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.136424	train's huber: 0.0128683	val's l1: 0.163184	val's huber: 0.0164816
# [400]	train's l1: 0.112804	train's huber: 0.0100811	val's l1: 0.15037	val's huber: 0.0149461
# [600]	train's l1: 0.0992842	train's huber: 0.00839941	val's l1: 0.149347	val's huber: 0.0148115
# [800]	train's l1: 0.0903706	train's huber: 0.00732424	val's l1: 0.149099	val's huber: 0.014779
# Did not meet early stopping. Best iteration is:
# [967]	train's l1: 0.084918	train's huber: 0.00669062	val's l1: 0.149049	val's huber: 0.0147755
# Evaluated only: l1
#    [Trial  2/20] pooled WAPE   24.1177% | tot nhat 24.1177% | da chay 2.5 phut, con khoang 22.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.158686	train's huber: 0.0099289	val's l1: 0.355229	val's huber: 0.0251697
# [400]	train's l1: 0.119242	train's huber: 0.00706862	val's l1: 0.312649	val's huber: 0.0218739
# [600]	train's l1: 0.10647	train's huber: 0.00617671	val's l1: 0.297646	val's huber: 0.0207017
# Did not meet early stopping. Best iteration is:
# [744]	train's l1: 0.100493	train's huber: 0.0057629	val's l1: 0.292941	val's huber: 0.0203331
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.156029	train's huber: 0.00963303	val's l1: 0.166696	val's huber: 0.0103823
# [400]	train's l1: 0.12138	train's huber: 0.00713924	val's l1: 0.14196	val's huber: 0.00855654
# [600]	train's l1: 0.107856	train's huber: 0.00618921	val's l1: 0.139214	val's huber: 0.00835814
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.100452	train's huber: 0.00567166	val's l1: 0.138374	val's huber: 0.00829758
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.154392	train's huber: 0.00951522	val's l1: 0.177215	val's huber: 0.0111938
# [400]	train's l1: 0.125074	train's huber: 0.00741151	val's l1: 0.152851	val's huber: 0.00940269
# [600]	train's l1: 0.113161	train's huber: 0.00656966	val's l1: 0.149914	val's huber: 0.00918941
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.106902	train's huber: 0.00612582	val's l1: 0.149134	val's huber: 0.00913322
# Evaluated only: l1
#    [Trial  3/20] pooled WAPE   24.4128% | tot nhat 24.1177% | da chay 3.9 phut, con khoang 22.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.113652	train's huber: 0.0127631	val's l1: 0.27848	val's huber: 0.0525742
# [400]	train's l1: 0.0995246	train's huber: 0.0102618	val's l1: 0.273887	val's huber: 0.0513347
# [600]	train's l1: 0.0911459	train's huber: 0.00887268	val's l1: 0.27241	val's huber: 0.0509131
# [800]	train's l1: 0.0852858	train's huber: 0.00793016	val's l1: 0.271827	val's huber: 0.0507477
# Did not meet early stopping. Best iteration is:
# [805]	train's l1: 0.0851645	train's huber: 0.00791085	val's l1: 0.271766	val's huber: 0.0507315
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.117866	train's huber: 0.0128516	val's l1: 0.141025	val's huber: 0.0169805
# [400]	train's l1: 0.102323	train's huber: 0.0101943	val's l1: 0.13912	val's huber: 0.0166672
# [600]	train's l1: 0.093256	train's huber: 0.00875166	val's l1: 0.138672	val's huber: 0.0166157
# [800]	train's l1: 0.0869197	train's huber: 0.00780384	val's l1: 0.138513	val's huber: 0.0165981
# Did not meet early stopping. Best iteration is:
# [800]	train's l1: 0.0869197	train's huber: 0.00780384	val's l1: 0.138513	val's huber: 0.0165981
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.122575	train's huber: 0.013844	val's l1: 0.151808	val's huber: 0.0193286
# [400]	train's l1: 0.108441	train's huber: 0.0112918	val's l1: 0.150544	val's huber: 0.0191216
# [600]	train's l1: 0.100087	train's huber: 0.00986956	val's l1: 0.150284	val's huber: 0.0190919
# Early stopping, best iteration is:
# [687]	train's l1: 0.0972068	train's huber: 0.00939867	val's l1: 0.150147	val's huber: 0.0190806
# Evaluated only: l1
#    [Trial  4/20] pooled WAPE   24.2356% | tot nhat 24.1177% | da chay 4.7 phut, con khoang 19.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.160565	train's huber: 0.0111465	val's l1: 0.353552	val's huber: 0.0282285
# [400]	train's l1: 0.114666	train's huber: 0.00739657	val's l1: 0.306341	val's huber: 0.0240665
# [600]	train's l1: 0.0987467	train's huber: 0.00615946	val's l1: 0.275893	val's huber: 0.0213339
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.0961777	train's huber: 0.00596077	val's l1: 0.271628	val's huber: 0.0209498
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.166195	train's huber: 0.0114868	val's l1: 0.177045	val's huber: 0.0123563
# [400]	train's l1: 0.122249	train's huber: 0.00789934	val's l1: 0.144056	val's huber: 0.00960201
# [600]	train's l1: 0.107053	train's huber: 0.00671579	val's l1: 0.140436	val's huber: 0.00931419
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.104447	train's huber: 0.0065134	val's l1: 0.140074	val's huber: 0.00928401
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.165901	train's huber: 0.0114538	val's l1: 0.187709	val's huber: 0.0133045
# [400]	train's l1: 0.127811	train's huber: 0.00836061	val's l1: 0.155162	val's huber: 0.0105824
# [600]	train's l1: 0.114924	train's huber: 0.00734466	val's l1: 0.150713	val's huber: 0.0102254
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.112732	train's huber: 0.00717171	val's l1: 0.1503	val's huber: 0.0101924
# Evaluated only: l1
#    [Trial  5/20] pooled WAPE   24.0588% | tot nhat 24.0588% | da chay 6.1 phut, con khoang 18.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.109705	train's huber: 0.0122033	val's l1: 0.279507	val's huber: 0.0580022
# [400]	train's l1: 0.090903	train's huber: 0.0088652	val's l1: 0.27265	val's huber: 0.0558156
# [600]	train's l1: 0.0811405	train's huber: 0.0072697	val's l1: 0.2717	val's huber: 0.0555383
# [800]	train's l1: 0.0746617	train's huber: 0.0062936	val's l1: 0.271323	val's huber: 0.0554109
# Did not meet early stopping. Best iteration is:
# [898]	train's l1: 0.072345	train's huber: 0.00596047	val's l1: 0.271036	val's huber: 0.0553144
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112248	train's huber: 0.0119828	val's l1: 0.141453	val's huber: 0.0175932
# [400]	train's l1: 0.0933132	train's huber: 0.00879012	val's l1: 0.139882	val's huber: 0.0173321
# [600]	train's l1: 0.083914	train's huber: 0.00739508	val's l1: 0.139515	val's huber: 0.0172917
# Early stopping, best iteration is:
# [691]	train's l1: 0.0808475	train's huber: 0.00694586	val's l1: 0.139386	val's huber: 0.0172758
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118052	train's huber: 0.0131999	val's l1: 0.152401	val's huber: 0.0201914
# [400]	train's l1: 0.100195	train's huber: 0.00990666	val's l1: 0.151222	val's huber: 0.019981
# [600]	train's l1: 0.0908731	train's huber: 0.0083985	val's l1: 0.150879	val's huber: 0.0199401
# [800]	train's l1: 0.0840885	train's huber: 0.00736979	val's l1: 0.150743	val's huber: 0.0199351
# Early stopping, best iteration is:
# [763]	train's l1: 0.0853249	train's huber: 0.00755884	val's l1: 0.15068	val's huber: 0.0199243
# Evaluated only: l1
#    [Trial  6/20] pooled WAPE   24.4368% | tot nhat 24.0588% | da chay 7.6 phut, con khoang 17.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0922537	train's huber: 0.00896622	val's l1: 0.261989	val's huber: 0.0486825
# [400]	train's l1: 0.0756369	train's huber: 0.00641338	val's l1: 0.260375	val's huber: 0.0482211
# [600]	train's l1: 0.0662361	train's huber: 0.00511663	val's l1: 0.260104	val's huber: 0.0481231
# Early stopping, best iteration is:
# [625]	train's l1: 0.0652448	train's huber: 0.00499213	val's l1: 0.260018	val's huber: 0.0480915
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0993696	train's huber: 0.00965193	val's l1: 0.139332	val's huber: 0.0168013
# [400]	train's l1: 0.0823381	train's huber: 0.00706901	val's l1: 0.1391	val's huber: 0.0167649
# [600]	train's l1: 0.0728677	train's huber: 0.00579194	val's l1: 0.138945	val's huber: 0.0167833
# Early stopping, best iteration is:
# [549]	train's l1: 0.0749986	train's huber: 0.00606851	val's l1: 0.138873	val's huber: 0.0167523
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.106784	train's huber: 0.0109635	val's l1: 0.151246	val's huber: 0.019464
# [400]	train's l1: 0.0907384	train's huber: 0.00830629	val's l1: 0.151204	val's huber: 0.0195032
# Early stopping, best iteration is:
# [305]	train's l1: 0.0975369	train's huber: 0.00940141	val's l1: 0.150957	val's huber: 0.0194384
# Evaluated only: l1
#    [Trial  7/20] pooled WAPE   24.2649% | tot nhat 24.0588% | da chay 8.1 phut, con khoang 15.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.171899	train's huber: 0.0108814	val's l1: 0.369384	val's huber: 0.0262257
# [400]	train's l1: 0.132754	train's huber: 0.00801274	val's l1: 0.324754	val's huber: 0.0227601
# [600]	train's l1: 0.120686	train's huber: 0.00716458	val's l1: 0.310458	val's huber: 0.0216536
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.117677	train's huber: 0.00695143	val's l1: 0.307335	val's huber: 0.0214113
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.165087	train's huber: 0.0102899	val's l1: 0.171736	val's huber: 0.0107428
# [400]	train's l1: 0.129253	train's huber: 0.00768873	val's l1: 0.143423	val's huber: 0.008646
# [600]	train's l1: 0.117623	train's huber: 0.00687241	val's l1: 0.13958	val's huber: 0.00836942
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.113689	train's huber: 0.00659413	val's l1: 0.138695	val's huber: 0.00830532
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.160326	train's huber: 0.00993794	val's l1: 0.181797	val's huber: 0.0115235
# [400]	train's l1: 0.129715	train's huber: 0.00773249	val's l1: 0.154076	val's huber: 0.00947372
# [600]	train's l1: 0.119375	train's huber: 0.00700394	val's l1: 0.150367	val's huber: 0.00920633
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.115906	train's huber: 0.00675972	val's l1: 0.149714	val's huber: 0.00915923
# Evaluated only: l1
#    [Trial  8/20] pooled WAPE   24.6459% | tot nhat 24.0588% | da chay 9.3 phut, con khoang 13.9 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0759975	train's huber: 0.00643344	val's l1: 0.273357	val's huber: 0.0541136
# Early stopping, best iteration is:
# [242]	train's l1: 0.0710825	train's huber: 0.00572823	val's l1: 0.272727	val's huber: 0.0539108
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0814301	train's huber: 0.00698644	val's l1: 0.139411	val's huber: 0.017101
# [400]	train's l1: 0.0655804	train's huber: 0.00486791	val's l1: 0.139329	val's huber: 0.0171321
# Did not meet early stopping. Best iteration is:
# [335]	train's l1: 0.0695306	train's huber: 0.0053563	val's l1: 0.139156	val's huber: 0.0170909
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0895442	train's huber: 0.0081664	val's l1: 0.151485	val's huber: 0.0198067
# [400]	train's l1: 0.0732618	train's huber: 0.00581775	val's l1: 0.151248	val's huber: 0.0197989
# Did not meet early stopping. Best iteration is:
# [307]	train's l1: 0.0792527	train's huber: 0.00663113	val's l1: 0.151105	val's huber: 0.0197634
# Evaluated only: l1
#    [Trial  9/20] pooled WAPE   24.6100% | tot nhat 24.0588% | da chay 9.9 phut, con khoang 12.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.133283	train's huber: 0.0121429	val's l1: 0.31128	val's huber: 0.0366899
# [400]	train's l1: 0.115308	train's huber: 0.0100566	val's l1: 0.284379	val's huber: 0.0328565
# [600]	train's l1: 0.106481	train's huber: 0.00903136	val's l1: 0.277055	val's huber: 0.0318127
# [800]	train's l1: 0.0999653	train's huber: 0.00828241	val's l1: 0.274667	val's huber: 0.0314712
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.0973428	train's huber: 0.00798962	val's l1: 0.273772	val's huber: 0.0313447
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.139212	train's huber: 0.0126504	val's l1: 0.146226	val's huber: 0.0133375
# [400]	train's l1: 0.120273	train's huber: 0.0104387	val's l1: 0.140831	val's huber: 0.0127102
# [600]	train's l1: 0.109971	train's huber: 0.00922411	val's l1: 0.139236	val's huber: 0.012517
# [800]	train's l1: 0.102813	train's huber: 0.00840371	val's l1: 0.13845	val's huber: 0.0124159
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.100016	train's huber: 0.00809064	val's l1: 0.138041	val's huber: 0.0123684
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.140457	train's huber: 0.0128439	val's l1: 0.158441	val's huber: 0.0149873
# [400]	train's l1: 0.124329	train's huber: 0.0109431	val's l1: 0.151947	val's huber: 0.0142051
# [600]	train's l1: 0.115966	train's huber: 0.00994887	val's l1: 0.150256	val's huber: 0.0140012
# [800]	train's l1: 0.10967	train's huber: 0.00920099	val's l1: 0.149704	val's huber: 0.0139326
# Did not meet early stopping. Best iteration is:
# [883]	train's l1: 0.107516	train's huber: 0.00894681	val's l1: 0.149662	val's huber: 0.0139275
# Evaluated only: l1
#    [Trial 10/20] pooled WAPE   24.0315% | tot nhat 24.0315% | da chay 11.1 phut, con khoang 11.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118158	train's huber: 0.0100469	val's l1: 0.293078	val's huber: 0.0324469
# [400]	train's l1: 0.10026	train's huber: 0.00808007	val's l1: 0.27901	val's huber: 0.0305533
# [600]	train's l1: 0.0901076	train's huber: 0.00697431	val's l1: 0.276215	val's huber: 0.0301824
# [800]	train's l1: 0.0832555	train's huber: 0.00624723	val's l1: 0.274945	val's huber: 0.0300088
# Early stopping, best iteration is:
# [815]	train's l1: 0.0828142	train's huber: 0.00620113	val's l1: 0.274809	val's huber: 0.0299905
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119946	train's huber: 0.0100478	val's l1: 0.140885	val's huber: 0.0122683
# [400]	train's l1: 0.0998549	train's huber: 0.00782309	val's l1: 0.138502	val's huber: 0.0119931
# [600]	train's l1: 0.0895546	train's huber: 0.00672984	val's l1: 0.13801	val's huber: 0.0119396
# [800]	train's l1: 0.0824174	train's huber: 0.00598442	val's l1: 0.137912	val's huber: 0.0119297
# Early stopping, best iteration is:
# [725]	train's l1: 0.0849131	train's huber: 0.00624325	val's l1: 0.137838	val's huber: 0.0119212
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.123811	train's huber: 0.0105016	val's l1: 0.152667	val's huber: 0.0137609
# [400]	train's l1: 0.107144	train's huber: 0.00862864	val's l1: 0.149844	val's huber: 0.0134399
# [600]	train's l1: 0.0971775	train's huber: 0.00753026	val's l1: 0.149474	val's huber: 0.0133991
# Early stopping, best iteration is:
# [617]	train's l1: 0.0965423	train's huber: 0.00746129	val's l1: 0.149419	val's huber: 0.0133931
# Evaluated only: l1
#    [Trial 11/20] pooled WAPE   24.1579% | tot nhat 24.0315% | da chay 12.4 phut, con khoang 10.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.227856	train's huber: 0.010879	val's l1: 0.408092	val's huber: 0.0205175
# [400]	train's l1: 0.180779	train's huber: 0.00839992	val's l1: 0.372857	val's huber: 0.0186375
# Did not meet early stopping. Best iteration is:
# [506]	train's l1: 0.164512	train's huber: 0.00755731	val's l1: 0.35842	val's huber: 0.0178674
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.22895	train's huber: 0.01092	val's l1: 0.229412	val's huber: 0.0109365
# [400]	train's l1: 0.177369	train's huber: 0.00819137	val's l1: 0.180794	val's huber: 0.0083553
# Did not meet early stopping. Best iteration is:
# [506]	train's l1: 0.160459	train's huber: 0.00730979	val's l1: 0.165484	val's huber: 0.00755214
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.222899	train's huber: 0.0105921	val's l1: 0.2366	val's huber: 0.0113231
# [400]	train's l1: 0.172258	train's huber: 0.00792227	val's l1: 0.191713	val's huber: 0.00893594
# Did not meet early stopping. Best iteration is:
# [506]	train's l1: 0.157405	train's huber: 0.00715334	val's l1: 0.177913	val's huber: 0.00820863
# Evaluated only: l1
#    [Trial 12/20] pooled WAPE   28.0528% | tot nhat 24.0315% | da chay 13.3 phut, con khoang 8.8 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.132708	train's huber: 0.0100106	val's l1: 0.331566	val's huber: 0.030745
# [400]	train's l1: 0.0973088	train's huber: 0.0067762	val's l1: 0.28165	val's huber: 0.0254539
# [600]	train's l1: 0.0822169	train's huber: 0.00545032	val's l1: 0.267998	val's huber: 0.0239814
# [800]	train's l1: 0.0723815	train's huber: 0.00461168	val's l1: 0.264475	val's huber: 0.0236035
# [1000]	train's l1: 0.0649645	train's huber: 0.00399423	val's l1: 0.263486	val's huber: 0.023498
# Did not meet early stopping. Best iteration is:
# [1105]	train's l1: 0.0616668	train's huber: 0.00372324	val's l1: 0.263176	val's huber: 0.0234638
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.137527	train's huber: 0.0102728	val's l1: 0.156578	val's huber: 0.0120506
# [400]	train's l1: 0.106072	train's huber: 0.00742939	val's l1: 0.140798	val's huber: 0.0105813
# [600]	train's l1: 0.0903624	train's huber: 0.00603448	val's l1: 0.13928	val's huber: 0.010436
# [800]	train's l1: 0.0802583	train's huber: 0.00514782	val's l1: 0.138854	val's huber: 0.0103933
# Early stopping, best iteration is:
# [769]	train's l1: 0.0815562	train's huber: 0.00525924	val's l1: 0.138808	val's huber: 0.0103885
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.141059	train's huber: 0.0106336	val's l1: 0.167928	val's huber: 0.0132215
# [400]	train's l1: 0.114087	train's huber: 0.00817926	val's l1: 0.150935	val's huber: 0.0116381
# [600]	train's l1: 0.100076	train's huber: 0.00689534	val's l1: 0.149405	val's huber: 0.0114935
# [800]	train's l1: 0.090413	train's huber: 0.00602323	val's l1: 0.149054	val's huber: 0.0114583
# Early stopping, best iteration is:
# [794]	train's l1: 0.0907041	train's huber: 0.00604945	val's l1: 0.149037	val's huber: 0.011457
# Evaluated only: l1
#    [Trial 13/20] pooled WAPE   24.0864% | tot nhat 24.0315% | da chay 15.2 phut, con khoang 8.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.102504	train's huber: 0.0100933	val's l1: 0.262245	val's huber: 0.0396588
# [400]	train's l1: 0.0832655	train's huber: 0.00729135	val's l1: 0.256963	val's huber: 0.0385573
# Did not meet early stopping. Best iteration is:
# [565]	train's l1: 0.0738105	train's huber: 0.00604107	val's l1: 0.256354	val's huber: 0.0384344
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.109221	train's huber: 0.0106987	val's l1: 0.139689	val's huber: 0.01525
# [400]	train's l1: 0.0896137	train's huber: 0.00785631	val's l1: 0.138083	val's huber: 0.0150111
# Did not meet early stopping. Best iteration is:
# [571]	train's l1: 0.0802241	train's huber: 0.00661681	val's l1: 0.13758	val's huber: 0.0149319
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.115661	train's huber: 0.0117087	val's l1: 0.151262	val's huber: 0.0173612
# [400]	train's l1: 0.0982686	train's huber: 0.00907432	val's l1: 0.150249	val's huber: 0.0171945
# Did not meet early stopping. Best iteration is:
# [580]	train's l1: 0.088976	train's huber: 0.00776655	val's l1: 0.150127	val's huber: 0.0171695
# Evaluated only: l1
#    [Trial 14/20] pooled WAPE   23.9582% | tot nhat 23.9582% | da chay 16.1 phut, con khoang 6.9 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.104378	train's huber: 0.0103347	val's l1: 0.262918	val's huber: 0.0396515
# [400]	train's l1: 0.0860686	train's huber: 0.00766642	val's l1: 0.258276	val's huber: 0.0387218
# Did not meet early stopping. Best iteration is:
# [559]	train's l1: 0.0774625	train's huber: 0.00650683	val's l1: 0.257769	val's huber: 0.0386335
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112498	train's huber: 0.0111613	val's l1: 0.140311	val's huber: 0.0153136
# [400]	train's l1: 0.0935537	train's huber: 0.00837352	val's l1: 0.13878	val's huber: 0.0150866
# Did not meet early stopping. Best iteration is:
# [558]	train's l1: 0.0848889	train's huber: 0.00720283	val's l1: 0.13846	val's huber: 0.0150412
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.118452	train's huber: 0.0121201	val's l1: 0.151897	val's huber: 0.017429
# [400]	train's l1: 0.101684	train's huber: 0.00954604	val's l1: 0.150567	val's huber: 0.0172193
# Did not meet early stopping. Best iteration is:
# [530]	train's l1: 0.0950335	train's huber: 0.00857722	val's l1: 0.150283	val's huber: 0.017172
# Evaluated only: l1
#    [Trial 15/20] pooled WAPE   24.0702% | tot nhat 23.9582% | da chay 16.9 phut, con khoang 5.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.105633	train's huber: 0.0108251	val's l1: 0.277632	val's huber: 0.0452221
# [400]	train's l1: 0.0877783	train's huber: 0.00807343	val's l1: 0.270927	val's huber: 0.0437214
# [600]	train's l1: 0.0778336	train's huber: 0.00666728	val's l1: 0.269875	val's huber: 0.0434879
# [800]	train's l1: 0.0711065	train's huber: 0.00575731	val's l1: 0.269546	val's huber: 0.0434118
# [1000]	train's l1: 0.0661147	train's huber: 0.005113	val's l1: 0.26927	val's huber: 0.0433444
# Did not meet early stopping. Best iteration is:
# [1052]	train's l1: 0.0650432	train's huber: 0.00498126	val's l1: 0.269218	val's huber: 0.043332
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.110607	train's huber: 0.0111158	val's l1: 0.140595	val's huber: 0.0157946
# [400]	train's l1: 0.0913249	train's huber: 0.00820613	val's l1: 0.139203	val's huber: 0.0155732
# [600]	train's l1: 0.0815073	train's huber: 0.00687184	val's l1: 0.138728	val's huber: 0.0155121
# [800]	train's l1: 0.0748278	train's huber: 0.00600454	val's l1: 0.138564	val's huber: 0.0155106
# Early stopping, best iteration is:
# [751]	train's l1: 0.0762562	train's huber: 0.0061866	val's l1: 0.138524	val's huber: 0.0154997
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.116783	train's huber: 0.0121502	val's l1: 0.151594	val's huber: 0.0179416
# Early stopping, best iteration is:
# [299]	train's l1: 0.106809	train's huber: 0.010536	val's l1: 0.150529	val's huber: 0.0177715
# Evaluated only: l1
#    [Trial 16/20] pooled WAPE   24.2570% | tot nhat 23.9582% | da chay 17.9 phut, con khoang 4.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.134564	train's huber: 0.0117387	val's l1: 0.308971	val's huber: 0.0340294
# [400]	train's l1: 0.117766	train's huber: 0.00989608	val's l1: 0.284726	val's huber: 0.0308468
# Did not meet early stopping. Best iteration is:
# [401]	train's l1: 0.117715	train's huber: 0.00989046	val's l1: 0.284637	val's huber: 0.030835
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.139985	train's huber: 0.0121841	val's l1: 0.146831	val's huber: 0.012809
# [400]	train's l1: 0.12231	train's huber: 0.0102311	val's l1: 0.14094	val's huber: 0.0121457
# Did not meet early stopping. Best iteration is:
# [403]	train's l1: 0.122131	train's huber: 0.0102104	val's l1: 0.140896	val's huber: 0.0121409
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.140751	train's huber: 0.0122947	val's l1: 0.158568	val's huber: 0.014287
# [400]	train's l1: 0.125717	train's huber: 0.0106187	val's l1: 0.152169	val's huber: 0.0135524
# Did not meet early stopping. Best iteration is:
# [403]	train's l1: 0.125568	train's huber: 0.0106021	val's l1: 0.152129	val's huber: 0.013548
# Evaluated only: l1
#    [Trial 17/20] pooled WAPE   24.2648% | tot nhat 23.9582% | da chay 18.5 phut, con khoang 3.3 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0962549	train's huber: 0.00964924	val's l1: 0.26815	val's huber: 0.0579683
# [400]	train's l1: 0.0788391	train's huber: 0.00683247	val's l1: 0.265872	val's huber: 0.0571999
# Early stopping, best iteration is:
# [469]	train's l1: 0.0748848	train's huber: 0.00623688	val's l1: 0.265711	val's huber: 0.0571678
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.10539	train's huber: 0.010737	val's l1: 0.141573	val's huber: 0.0178642
# [400]	train's l1: 0.0880477	train's huber: 0.00789429	val's l1: 0.140037	val's huber: 0.0176217
# Did not meet early stopping. Best iteration is:
# [559]	train's l1: 0.0795836	train's huber: 0.0066513	val's l1: 0.139662	val's huber: 0.017556
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.112294	train's huber: 0.012054	val's l1: 0.152464	val's huber: 0.0205684
# [400]	train's l1: 0.0967862	train's huber: 0.00933487	val's l1: 0.151852	val's huber: 0.0204839
# Early stopping, best iteration is:
# [422]	train's l1: 0.0955714	train's huber: 0.00913695	val's l1: 0.151765	val's huber: 0.0204711
# Evaluated only: l1
#    [Trial 18/20] pooled WAPE   24.4228% | tot nhat 23.9582% | da chay 19.1 phut, con khoang 2.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0949756	train's huber: 0.00932079	val's l1: 0.276005	val's huber: 0.0474082
# [400]	train's l1: 0.0791123	train's huber: 0.00691783	val's l1: 0.274028	val's huber: 0.0469332
# [600]	train's l1: 0.070535	train's huber: 0.00573028	val's l1: 0.27323	val's huber: 0.0467401
# Early stopping, best iteration is:
# [530]	train's l1: 0.0730697	train's huber: 0.0060718	val's l1: 0.273191	val's huber: 0.0467281
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0983342	train's huber: 0.00936388	val's l1: 0.138859	val's huber: 0.0159895
# [400]	train's l1: 0.0820882	train's huber: 0.00700615	val's l1: 0.13826	val's huber: 0.0159052
# Early stopping, best iteration is:
# [413]	train's l1: 0.081378	train's huber: 0.00691406	val's l1: 0.138193	val's huber: 0.0158961
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.10551	train's huber: 0.0105036	val's l1: 0.151181	val's huber: 0.0184341
# Early stopping, best iteration is:
# [295]	train's l1: 0.0964763	train's huber: 0.00909071	val's l1: 0.150837	val's huber: 0.0183765
# Evaluated only: l1
#    [Trial 19/20] pooled WAPE   24.3155% | tot nhat 23.9582% | da chay 19.8 phut, con khoang 1.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.120446	train's huber: 0.0116985	val's l1: 0.291042	val's huber: 0.0389473
# [400]	train's l1: 0.103792	train's huber: 0.00949907	val's l1: 0.274143	val's huber: 0.0360631
# [600]	train's l1: 0.0938371	train's huber: 0.00821094	val's l1: 0.271178	val's huber: 0.035562
# [800]	train's l1: 0.0869001	train's huber: 0.00734039	val's l1: 0.269589	val's huber: 0.0352913
# [1000]	train's l1: 0.0816468	train's huber: 0.00669173	val's l1: 0.269002	val's huber: 0.0351918
# Did not meet early stopping. Best iteration is:
# [1035]	train's l1: 0.0807564	train's huber: 0.00658408	val's l1: 0.268903	val's huber: 0.035174
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.126701	train's huber: 0.0122389	val's l1: 0.14207	val's huber: 0.0141434
# [400]	train's l1: 0.10788	train's huber: 0.00974955	val's l1: 0.138791	val's huber: 0.013698
# [600]	train's l1: 0.0971188	train's huber: 0.00836339	val's l1: 0.137912	val's huber: 0.0135773
# [800]	train's l1: 0.0896725	train's huber: 0.00743899	val's l1: 0.137494	val's huber: 0.0135305
# [1000]	train's l1: 0.0842522	train's huber: 0.0067892	val's l1: 0.137277	val's huber: 0.0135046
# Did not meet early stopping. Best iteration is:
# [1026]	train's l1: 0.0836491	train's huber: 0.00671654	val's l1: 0.13723	val's huber: 0.0135
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.12994	train's huber: 0.0127179	val's l1: 0.153701	val's huber: 0.0159446
# [400]	train's l1: 0.114254	train's huber: 0.0106053	val's l1: 0.150264	val's huber: 0.0154789
# [600]	train's l1: 0.104651	train's huber: 0.00932048	val's l1: 0.14953	val's huber: 0.0153768
# [800]	train's l1: 0.0979308	train's huber: 0.00845097	val's l1: 0.149302	val's huber: 0.0153434
# [1000]	train's l1: 0.0926093	train's huber: 0.0077845	val's l1: 0.149302	val's huber: 0.0153404
# Early stopping, best iteration is:
# [903]	train's l1: 0.0950756	train's huber: 0.00809365	val's l1: 0.149254	val's huber: 0.0153339
# Evaluated only: l1
#    [Trial 20/20] pooled WAPE   24.0537% | tot nhat 23.9582% | da chay 21.1 phut, con khoang 0.0 phut
# So cay tung fold (early stopping): [565, 571, 580]
# -> n_estimators = 571 (trung vi)
#
# Pooled WAPE tot nhat tren 3 fold = 23.9582%
#    objective: huber
#    random_state: 42
#    verbosity: -1
#    n_jobs: 6
#    max_bin: 127
#    force_col_wise: True
#    deterministic: True
#    n_estimators: 571
#    learning_rate: 0.0502542974886058
#    num_leaves: 129
#    min_child_samples: 59
#    subsample: 0.7029074750047504
#    colsample_bytree: 0.8749681461898982
#    alpha: 0.22851510891855428
#    reg_alpha: 2.4155493298033965
#    reg_lambda: 9.96345659366045

# %% [markdown]
# ## 12. Train mô hình cuối trên tập train (v5_train_selected, tới 2021-06)

# %%
_X_val_es = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_y_val_es = val_h['k_target'].astype(DTYPE)
LICH_SU_EARLY_STOP = {}
_t1 = time.time()
model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev, _X_val_es, _y_val_es, LICH_SU_EARLY_STOP)
BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': int(model.best_iteration_)}
print(f"Train xong sau {(time.time() - _t1) / 60:.1f} phút | dung som tai {model.best_iteration_} cay")

# Du bao tren tap VALIDATION, nhan nguoc mau chuan hoa roi chan tran cong suat
_k_pred = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
val_h['y_pred'] = np.minimum(_k_pred * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
# Luu du bao validation de ve lai sau nay khong can kernel/model
val_h[[SITE_COL, 'plot_timestamp', 'y_true', 'y_pred']].to_parquet(
    f'{OUTPUT_DIR}/du_bao_val.parquet', index=False)

print(f"Đã dự báo {len(val_h):,} dòng")
# Xep theo GAIN (split-count thien vi cot categorical nhieu nhan); bao cao dung SHAP (08)
_cot = model.booster_.feature_name()
_gain = pd.Series(model.booster_.feature_importance('gain'), index=_cot)
_imp = pd.DataFrame({
    'gain_%': (_gain / _gain.sum() * 100).round(2),
    'so_nhat_cat': pd.Series(model.booster_.feature_importance('split'), index=_cot),
}).sort_values('gain_%', ascending=False)
print("\n--- 12 DAC TRUNG QUAN TRONG NHAT (xep theo GAIN) ---")
display(_imp.head(12))
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.115897	train's huber: 0.0117462	val's l1: 0.151165	val's huber: 0.0173512
# [400]	train's l1: 0.0982026	train's huber: 0.00906561	val's l1: 0.149948	val's huber: 0.0171615
# Early stopping, best iteration is:
# [471]	train's l1: 0.0941184	train's huber: 0.00847811	val's l1: 0.149845	val's huber: 0.0171485
# Evaluated only: l1
# Train xong sau 0.4 phút | dung som tai 471 cay
# Đã dự báo 289,348 dòng
#
# --- 12 DAC TRUNG QUAN TRONG NHAT (xep theo GAIN) ---
#                           gain_%  so_nhat_cat
# direct_normal_irradiance   30.36         2335
# diffuse_ratio               8.83         2628
# rolling_min_4               5.55         1391
# weather_description_enc     5.54         1085
# site_id_enc                 4.60         3260
# ghi_cs_mt                   3.63         1172
# rolling_mean_4              3.55         1220
# ky_vong                     3.21         1546
# minute_of_day               3.21         1436
# temperature_c               2.93         3454
# rolling_max_4               2.80         1332
# rolling_std_4               2.24         1165

# %% [markdown]
# ## 12.1. Đường cong huấn luyện — chẩn đoán quá khớp
#
# Vẽ sai số trên tập **train** và tập **validation** theo từng vòng boosting, giống đường loss
# của mạng nơ-ron. Đây là bằng chứng trực quan cho câu hỏi *"mô hình có học vẹt không"*.
#
# **Cách đọc.** Train giảm đều mà validation đi ngang rồi ngóc lên nghĩa là bắt đầu quá khớp;
# điểm thấp nhất của đường validation chính là số cây nên dừng. Hai đường bám nhau và cùng đi
# xuống nghĩa là còn học được, chưa quá khớp.
#
# Tầng trái là $L_1$ trên mục tiêu chuẩn hoá $k$ — lấy trực tiếp từ `evals_result_` nên có đủ
# mọi vòng. Tầng phải là **WAPE thật trên thang kWh**, phạm vi `measured_daylight` tại $T+h$ —
# đây mới là chỉ số báo cáo công bố, nên nó mới là đường đáng tin để kết luận.
#
# Validation ở đây là `v5_val_selected`, **chưa từng tham gia huấn luyện**.

# %%
# === DUONG CONG HUAN LUYEN ===
# Fit rieng mot ban co eval_set de lay evals_result_ (ban `model` o cell tren fit khong
# co eval_set nen khong co duong cong). Ban nay CHI dung de ve, khong thay the model.
import matplotlib.pyplot as plt

# Dung lich su cua model cuoi: cell nay KHONG fit/train them model nao.
_m_dc = model
_lich_su = LICH_SU_EARLY_STOP
SO_CAY_DUONG_CONG = int(model.best_iteration_)
BUOC_DO_DUONG_CONG = SO_CAY_DUONG_CONG

_Xva_dc = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_yva_dc = val_h['k_target'].astype(DTYPE)


def _wape_tai(khung, X, mask, so_cay):
    """WAPE that (kWh) khi chi dung `so_cay` cay dau tien."""
    _k = cat_k(_m_dc.predict(X, num_iteration=so_cay))
    _se = khung['sin_elevation'].to_numpy()
    _yp = np.minimum(_k * mau_chuan_hoa(khung),
                     khung['tran_cong_suat'].to_numpy() * 1.02)
    _yp = np.where(_se <= EPS_ELEV, 0.0, _yp)
    _yt = khung['y_true'].to_numpy()
    return float(np.nansum(np.abs(_yt[mask] - _yp[mask]))
                 / np.nansum(np.abs(_yt[mask])) * 100)


# Mask pham vi cong bo: xet NHAN tai T+h, khong phai cot tai T
def _mask_cong_bo(khung):
    _n = _cot_loc(khung, 'energy_source')
    _d = _cot_loc(khung, 'is_daylight')
    _m = (_n == 'measured').to_numpy() if _n is not None else np.ones(len(khung), bool)
    if _d is not None:
        _m = _m & _d.fillna(False).astype(bool).to_numpy()
    return _m


_dev_dc = dev_h.loc[X_dev.index]
_m_tr = _mask_cong_bo(_dev_dc)
_m_va = _mask_cong_bo(val_h)

_moc = list(range(BUOC_DO_DUONG_CONG, SO_CAY_DUONG_CONG + 1, BUOC_DO_DUONG_CONG))
_w_tr = [_wape_tai(_dev_dc, X_dev, _m_tr, i) for i in _moc]
_w_va = [_wape_tai(val_h, _Xva_dc, _m_va, i) for i in _moc]
_i_tot = int(np.argmin(_w_va))
_w_min = _w_va[_i_tot]

# VUNG BINH NGUYEN: moi moc co WAPE val nam trong nguong tuong doi so voi diem thap nhat.
# Them cay ngoai vung nay khong cai thien co y nghia, chi lam mo hinh nang va de qua khop.
DUNG_NGUONG = 0.001                      # 0,1% tuong doi
_trong_vung = [j for j, w in enumerate(_w_va) if w <= _w_min * (1 + DUNG_NGUONG)]
_j_dau, _j_cuoi = _trong_vung[0], _trong_vung[-1]
SO_CAY_KHUYEN_NGHI = _moc[_j_dau]        # nho nhat ma van dat -> re nhat, it qua khop nhat

print(f"WAPE val thap nhat  : {_w_min:.4f}% tai {_moc[_i_tot]} cay "
      f"(train cung moc {_w_tr[_i_tot]:.4f}%)")
print(f"Vung binh nguyen    : {_moc[_j_dau]} - {_moc[_j_cuoi]} cay "
      f"(WAPE val trong {DUNG_NGUONG*100:.1f}% so voi diem thap nhat)")
print(f"So cay khuyen nghi  : {SO_CAY_KHUYEN_NGHI}")
print(f"Dang dung           : {SO_CAY_DUONG_CONG} cay -> "
      f"{'DU, nen giam' if SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG * 0.9 else 'hop ly'}")
print(f"Khoang cach train-val tai diem thap nhat: "
      f"{_w_va[_i_tot] - _w_tr[_i_tot]:+.4f} diem")

_fig, _ax = plt.subplots(1, 2, figsize=(15, 5.2))
_l_tr, _l_va = _lich_su['train']['l1'], _lich_su['val']['l1']
_x = np.arange(1, len(_l_tr) + 1)
_ax[0].plot(_x, _l_tr, lw=1.4, label='train')
_ax[0].plot(_x, _l_va, lw=1.4, label='validation')
_ax[0].set_xlabel('Số vòng boosting')
_ax[0].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[0].set_title(f'Đường cong huấn luyện — {LOSS_NAME.upper()}, H{HORIZON_STEPS}')
_ax[0].axvline(_m_dc.best_iteration_, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_m_dc.best_iteration_} cay')
_ax[0].legend(); _ax[0].grid(alpha=.3)

_best, _end = int(_m_dc.best_iteration_), len(_l_va)
_start = max(1, _best - 20)
_x_zoom = np.arange(_start, _end + 1)
_ax[1].plot(_x_zoom, _l_tr[_start - 1:_end], lw=1.5, label='train')
_ax[1].plot(_x_zoom, _l_va[_start - 1:_end], lw=1.7, label='validation')
_span_label = (f'{_end - _best} vòng xác nhận không cải thiện'
               if _end >= _best + EARLY_STOPPING_ROUNDS
               else f'chạm trần {SO_CAY_DUONG_CONG} cây')
_ax[1].axvspan(_best, _end, color='crimson', alpha=.12, label=_span_label)
_ax[1].axvline(_best, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_best} cây')
_ax[1].set_xlabel('Số vòng boosting')
_ax[1].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[1].set_title('Vùng early stopping trên validation')
_ax[1].legend(); _ax[1].grid(alpha=.3)
_fig.suptitle('Chẩn đoán quá khớp — validation là v5_val_selected, chưa từng được học',
              y=1.0, fontsize=10)
plt.tight_layout(); plt.show()

# ── Train lai mo hinh cuoi o so cay khuyen nghi ──
# Dat False neu muon giu nguyen so cay cua Optuna.
DUNG_SO_CAY_KHUYEN_NGHI = False  # early stopping da chon best_iteration_ tu validation

if DUNG_SO_CAY_KHUYEN_NGHI and SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG:
    print(f"\nTrain lai mo hinh cuoi voi {SO_CAY_KHUYEN_NGHI} cay "
          f"(thay vi {SO_CAY_DUONG_CONG})...")
    BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': SO_CAY_KHUYEN_NGHI}
    model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev)

    # Du bao lai tren val de moi bang metric phia sau dung mo hinh moi
    _k2 = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
    val_h['y_pred'] = np.minimum(_k2 * mau_chuan_hoa(val_h),
                                 val_h['tran_cong_suat'].to_numpy() * 1.02)
    val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
    _m2 = metrics_3_pham_vi(val_h)['measured_daylight']
    print(f"WAPE val sau khi giam so cay: {_m2['wape']:.4f}%  (n={_m2['n']:,})")
    print("BEST_PARAMS da cap nhat -> cac cell export phia sau se ghi so cay moi.")
else:
    print(f"\nGiu nguyen {SO_CAY_DUONG_CONG} cay.")

pd.DataFrame({'so_cay': _moc, 'wape_train': _w_tr, 'wape_val': _w_va,
              'trong_vung_dung_som': [j in _trong_vung for j in range(len(_moc))]}).head(12)
# Out:
# WAPE val thap nhat  : 22.3204% tai 471 cay (train cung moc 12.9124%)
# Vung binh nguyen    : 471 - 471 cay (WAPE val trong 0.1% so voi diem thap nhat)
# So cay khuyen nghi  : 471
# Dang dung           : 471 cay -> hop ly
# Khoang cach train-val tai diem thap nhat: +9.4080 diem
# Giu nguyen 471 cay.
#    so_cay  wape_train   wape_val  trong_vung_dung_som
# 0     471   12.912403  22.320441                 True

# %% [markdown]
# ## 13. Kiểm chứng trễ pha - phần quan trọng nhất của notebook
#
# Đây là tiêu chí nghiệm thu: **dự báo phải đúng thời điểm**. Giá trị cao hay thấp hơn thực tế thì còn
# chấp nhận được, nhưng nếu dự báo đến sau thì nó không còn là dự báo.

# %%
_quet = quet_do_tre(val_h)
_k_tot = min(_quet, key=_quet.get)
print("--- QUET DO TRE TOAN BO 42 TRAM ---")
print("So du bao(T) voi thuc te(T - k buoc). k=0 nho nhat la khong tre.\n")
for k, v in _quet.items():
    danh_dau = '  <== nho nhat' if k == _k_tot else ''
    print(f"   k={k} ({k * 15:>2} phut truoc): RMSE {v:.4f}{danh_dau}")
print(f"\nKết luận: {'KHONG TRE PHA' if _k_tot == 0 else f'TRE {_k_tot} BUOC = {_k_tot * 15} PHUT'}")

# quet rieng tung tram
_rows = []
for _s, _z in val_h[val_h['is_daylight'].fillna(False).astype(bool)].groupby(SITE_COL):
    _z = _z.sort_values(TIMESTAMP_COL)
    _r = {}
    for k in range(0, 3):
        _yt = _z['y_true'].shift(k)
        _m = _yt.notna()
        _r[k] = float(np.sqrt(np.mean((_z['y_pred'][_m] - _yt[_m]) ** 2)))
    _rows.append({'site_id': _s, 'k_tot_nhat': min(_r, key=_r.get),
                  'rmse_k0': round(_r[0], 4), 'rmse_k1': round(_r[1], 4), 'rmse_k2': round(_r[2], 4)})
df_tre = pd.DataFrame(_rows)
print("\n--- PHAN BO k TOT NHAT THEO TRAM ---")
print(df_tre['k_tot_nhat'].value_counts().sort_index().to_string())
print(f"\nSố trạm không trễ (k=0): {(df_tre['k_tot_nhat'] == 0).sum()}/{len(df_tre)}")
display(df_tre.head(10))
# Out:
# --- QUET DO TRE TOAN BO 42 TRAM ---
# So du bao(T) voi thuc te(T - k buoc). k=0 nho nhat la khong tre.
#
#    k=0 ( 0 phut truoc): RMSE 3.6197
#    k=1 (15 phut truoc): RMSE 3.5315
#    k=2 (30 phut truoc): RMSE 3.5178  <== nho nhat
#    k=3 (45 phut truoc): RMSE 4.0128
#
# Kết luận: TRE 2 BUOC = 30 PHUT
#
# --- PHAN BO k TOT NHAT THEO TRAM ---
# k_tot_nhat
# 0     4
# 1     9
# 2    27
#
# Số trạm không trễ (k=0): 4/40
#    site_id  k_tot_nhat  rmse_k0  rmse_k1  rmse_k2
# 0        1           1   2.5467   2.4423   2.4524
# 1        2           1   2.1750   2.0831   2.1175
# 2        3           1   1.5934   1.5265   1.5386
# 3        4           0   0.2473   0.2475   0.2561
# 4        5           1   0.2505   0.2447   0.2484
# 5        6           1   3.2273   3.0925   3.1027
# 6        7           0   1.7730   2.1025   2.4918
# 7        8           1   3.2156   3.1212   3.1748
# 8        9           0   0.2724   0.2759   0.2875
# 9       10           1   0.9811   0.9717   1.0048

# %% [markdown]
# ## 14. Bảng metric ba phạm vi

# %%
_m = metrics_3_pham_vi(val_h)
_bang = pd.DataFrame(_m).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4)
print("--- METRIC TREN TAP VALIDATION (test chi mo o notebook 07) ---")
print("Con so chinh thuc de bao cao la dong measured_daylight.")
display(_bang)

# So voi persistence: du bao bang chinh gia tri gan nhat da biet
_v = val_h[val_h['is_daylight'].fillna(False).astype(bool)].sort_values([SITE_COL, TIMESTAMP_COL]).copy()
_v['persistence'] = _v.groupby(SITE_COL)[TARGET_COL].transform(lambda s: s)
_w_mo_hinh = compute_wape(_v['y_true'].values, _v['y_pred'].values)
_w_per = compute_wape(_v['y_true'].values, _v['persistence'].values)
print(f"\n--- SO VOI PERSISTENCE (chep gia tri gan nhat) ---")
print(f"   Persistence WAPE : {_w_per:.2f}%")
print(f"   Mo hinh WAPE     : {_w_mo_hinh:.2f}%")
print(f"   Skill score      : hon persistence {(_w_per - _w_mo_hinh) / _w_per * 100:.2f}%")
# Out:
# --- METRIC TREN TAP VALIDATION (test chi mo o notebook 07) ---
# Con so chinh thuc de bao cao la dong measured_daylight.
#                           n     wape    rmse    mae     r2
# all                289348.0  22.3204  3.6061  1.522  0.902
# measured           289348.0  22.3204  3.6061  1.522  0.902
# measured_daylight  289348.0  22.3204  3.6061  1.522  0.902
# --- SO VOI PERSISTENCE (chep gia tri gan nhat) ---
#    Persistence WAPE : 20.47%
#    Mo hinh WAPE     : 22.32%
#    Skill score      : hon persistence -9.00%

# %% [markdown]
# ## 14.1. Bảng metric theo 8 phạm vi giống srcs
#
# `srcs` không báo một con số duy nhất mà tách theo phạm vi, để thấy mô hình làm ăn thế nào trên từng loại
# dòng. Con số **headline** là con số chính thức: `eligible` và `measured` và **không phải**
# `physical_over_capacity`.
#
# Điểm cần đọc trên bảng: `physical_over_capacity_rows` phải có sai số **rất lớn**. Đó là dấu hiệu tốt —
# nghĩa là mô hình **không** học theo mấy dòng vượt trần vật lý đó, đúng như mong muốn.

# %%
_scopes = scope_masks(val_h)
_rows = []
for _ten, _mask in _scopes.items():
    _n = int(_mask.sum())
    if _n < 10:
        _rows.append({'pham_vi': _ten, 'so_dong': _n, 'wape_%': np.nan,
                      'rmse': np.nan, 'mae': np.nan, 'r2': np.nan})
        continue
    _z = val_h.loc[_mask]
    _mt = compute_metrics(_z['y_true'].values, _z['y_pred'].values)
    _rows.append({'pham_vi': _ten, 'so_dong': _n, 'wape_%': round(_mt['wape'], 4),
                  'rmse': round(_mt['rmse'], 4), 'mae': round(_mt['mae'], 4),
                  'r2': round(_mt['r2'], 4)})

df_scope = pd.DataFrame(_rows)
print("--- METRIC THEO 8 PHAM VI (giong scope_masks cua srcs) ---")
print("Con so CHINH THUC de bao cao la dong headline.")
display(df_scope)

_hl = df_scope[df_scope['pham_vi'] == 'headline']
if not _hl.empty and pd.notna(_hl['wape_%'].iloc[0]):
    print(f"\nHEADLINE WAPE = {_hl['wape_%'].iloc[0]:.4f}%  tren {int(_hl['so_dong'].iloc[0]):,} dong")

_pc = df_scope[df_scope['pham_vi'] == 'physical_over_capacity_rows']
_nr = df_scope[df_scope['pham_vi'] == 'normal_rows']
if not _pc.empty and not _nr.empty and pd.notna(_pc['wape_%'].iloc[0]) and pd.notna(_nr['wape_%'].iloc[0]):
    _ty = _pc['wape_%'].iloc[0] / _nr['wape_%'].iloc[0]
    print(f"WAPE tai physical_over_capacity gap {_ty:.1f} lan so voi normal_rows.")
    if _ty > 2:
        print("   TOT: mo hinh KHONG hoc theo may dong vuot tran vat ly.")
    else:
        print("   [CANH BAO] Ty le nay thap, co the mo hinh dang hoc ca outlier vuot tran.")
# Out:
# --- METRIC THEO 8 PHAM VI (giong scope_masks cua srcs) ---
# Con so CHINH THUC de bao cao la dong headline.
#                        pham_vi  so_dong    wape_%     rmse     mae      r2
# 0                eligible_rows   289348   22.3204   3.6061  1.5220  0.9020
# 1                     headline   289348   22.3204   3.6061  1.5220  0.9020
# 2                  normal_rows   287518   22.0182   3.5359  1.4985  0.9056
# 3             etl_imputed_rows        0       NaN      NaN     NaN     NaN
# 4        gmm_if_consensus_rows     1493   51.5895   9.0660  4.8189  0.5575
# 5  physical_over_capacity_rows        0       NaN      NaN     NaN     NaN
# 6     other_physical_rule_rows      177   67.7514   8.2792  4.8526  0.0104
# 7          multiple_rules_rows      160  131.2282  14.3915  9.4541 -0.7439
# HEADLINE WAPE = 22.3204%  tren 289,348 dong

# %% [markdown]
# ## 14.2. Trực quan hoá chính sách sample weight
#
# Ba việc cần thấy:
#
# 1. Số dòng của từng nhóm `outlier_group` và bao nhiêu trong đó được đưa vào hàm mục tiêu
# 2. WAPE theo từng phạm vi — cột `physical_over_capacity_rows` phải cao vọt lên
# 3. Dự báo so với thực tế **tại chính các dòng outlier** — đường dự báo phải **không** đuổi theo phốc

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

_g = dev_h.groupby('nhan_outlier_group', observed=True).agg(
    tong=('w', 'size'), duoc_train=('w', lambda x: int((x > 0).sum()))).reset_index()
_g['bi_loai'] = _g['tong'] - _g['duoc_train']
_g = _g.sort_values('tong', ascending=False)
_x = np.arange(len(_g))
axes[0].bar(_x, _g['duoc_train'], color='#16a34a', label='duoc train (weight = 1)')
axes[0].bar(_x, _g['bi_loai'], bottom=_g['duoc_train'], color='#dc2626', label='bi loai (weight = 0)')
axes[0].set_xticks(_x)
axes[0].set_xticklabels(_g['nhan_outlier_group'], rotation=25, ha='right', fontsize=8)
axes[0].set_title(f"Phan bo nhom outlier cua NHAN va chinh sach weight\nexperiment = {EXPERIMENT}", fontsize=11)
axes[0].set_ylabel('so dong')
axes[0].set_yscale('log')
axes[0].legend(fontsize=8)
axes[0].grid(alpha=0.3, axis='y')

_p = df_scope.dropna(subset=['wape_%']).sort_values('wape_%')
_col = ['#dc2626' if 'physical_over_capacity' in t else '#4878a8' for t in _p['pham_vi']]
axes[1].barh(_p['pham_vi'], _p['wape_%'], color=_col)
axes[1].set_xlabel('WAPE (%)')
axes[1].set_title('WAPE theo pham vi\n(do: nhom vuot tran vat ly, cang cao cang tot)', fontsize=11)
axes[1].grid(alpha=0.3, axis='x')

plt.tight_layout()
plt.show()

print("--- BANG CHI TIET NHOM OUTLIER TRONG TAP TRAIN ---")
display(_g)
# Out:
# --- BANG CHI TIET NHOM OUTLIER TRONG TAP TRAIN ---
#     nhan_outlier_group    tong  duoc_train  bi_loai
# 2               normal  680332      596324    84008
# 0     gmm_if_consensus    2806        2673      133
# 3  other_physical_rule     302         295        7
# 1       multiple_rules     254         253        1

# %% [markdown]
# ### Nhận xét về xử lý outlier
#
# Cách làm này giống `srcs`: **không xoá dòng outlier khỏi dữ liệu**, chỉ đặt `sample_weight = 0` để chúng
# không tham gia hàm mục tiêu. Nhờ vậy vẫn giữ được dòng để báo cáo theo phạm vi, và biết được mô hình
# hành xử thế nào trên chúng.
#
# Nhóm được xét là nhóm của **dòng nhãn** `y(T+h)`, không phải dòng đặc trưng. Đúng logic: nếu giá trị cần
# dự báo là outlier thì mới không nên học theo nó.
#
# Nếu WAPE tại `physical_over_capacity_rows` gần bằng `normal_rows` thì mô hình vẫn đang bám theo phốc
# outlier, phải xem lại `build_sample_weight` đã áp đúng chưa.

# %% [markdown]
# ## 15. Trực quan hoá - phóng to quanh đỉnh từng trạm
#
# Vẽ cửa sổ 5 giờ quanh đỉnh của ngày nhiều nắng nhất. Trục thời gian chia mốc 15 phút để nhìn rõ
# có lệch bước nào không. Tiêu đề mỗi ô ghi RMSE theo `k` để đối chiếu bằng số ngay trên hình.

# %%
SITE_VE = [1, 2, 3, 4, 19, 24]
fig, axes = plt.subplots(len(SITE_VE), 1, figsize=(18, 4.2 * len(SITE_VE)))
_t = val_h.copy()
_t['ngay'] = _t['plot_timestamp'].dt.date
for ax, s in zip(np.atleast_1d(axes), SITE_VE):
    x = _t[_t[SITE_COL] == s]
    if x.empty:
        ax.set_title(f'Trạm {s}: không có dữ liệu')
        continue
    ngay = x.groupby('ngay')['y_true'].sum().idxmax()
    z = x[x['ngay'] == ngay].sort_values('plot_timestamp')
    tpk = z.loc[z['y_true'].idxmax(), 'plot_timestamp']
    z = z[z['plot_timestamp'].between(tpk - pd.Timedelta(hours=2, minutes=30),
                                     tpk + pd.Timedelta(hours=2, minutes=30))]
    ax.plot(z['plot_timestamp'], z['y_true'], '-o', ms=8, lw=2.5, color='#1f77b4', label='Thực tế')
    ax.plot(z['plot_timestamp'], z['y_pred'], '-s', ms=7, lw=2.3, color='#FFA500', label='Dự báo')
    r = {k: float(np.sqrt(((z['y_pred'] - z['y_true'].shift(k)).dropna() ** 2).mean())) for k in range(0, 3)}
    ax.set_title(f"Trạm {s} | {ngay} | RMSE k0 {r[0]:.3f}  k1 {r[1]:.3f}  k2 {r[2]:.3f}"
                 f"  -> nhỏ nhất k={min(r, key=r.get)}", fontsize=11)
    ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=15))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.grid(alpha=0.45)
    ax.legend(fontsize=9)
    ax.set_ylabel('kWh')
    plt.setp(ax.get_xticklabels(), rotation=45, fontsize=8)
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/zoom_quanh_dinh.png', dpi=100)
plt.show()
print(f"Đã lưu {OUTPUT_DIR}/zoom_quanh_dinh.png")
# Out:
# Đã lưu ../../data/model/v5/06_2_train_huber/zoom_quanh_dinh.png

# %% [markdown]
# ### Nhận xét
#
# Nếu khử trễ thành công thì trên hình phải thấy: **sườn lên và sườn xuống của hai đường trùng nhịp nhau**.
# Phần còn lại là đường dự báo nằm thấp hơn ở đoạn đỉnh phẳng, đó là lệch **độ cao** do inverter cắt đỉnh,
# không phải lệch **thời gian**. Tiêu đề mỗi ô phải ghi `nhỏ nhất k=0`.
#
# Nếu còn ô nào ghi `k=1` hoặc `k=2` thì trạm đó vẫn còn dư trễ, cần soi riêng.

# %% [markdown]
# ## 16. Vẽ toàn cảnh một tuần để nhìn tổng thể

# %%
# Chon tram de ve THEO TIEU CHI DO DUOC, khong gan tay.
# Ly do: tram gan tay co the roi vao tram co dinh bi chan lap lai gan y het moi ngay
# (inverter bao hoa, vd tram 3: dinh 13,40 kWh lap 4/8 ngay) nen duong ve ra phang,
# khong the hien duoc kha nang bam bien thien cua mo hinh. Tieu chi duoi day chon tram
# co ty le DO THAT cao nhat trong cua so ve, tie-break bang muc bien thien dinh giua
# cac ngay -> hinh phan anh du lieu that, va tieu chi duoc in ra de kiem chung lai.
_w = _t[_t['plot_timestamp'] >= _t['plot_timestamp'].max() - pd.Timedelta(days=7)].copy()
_w['_do_that'] = (_w['energy_source'] == 'measured') if 'energy_source' in _w.columns else True
_dnn = _w.groupby([SITE_COL, _w['plot_timestamp'].dt.date])['y_true'].max()

_bang = pd.DataFrame({
    'ty_le_do_that':   _w.groupby(SITE_COL)['_do_that'].mean() * 100,
    'dinh':            _w.groupby(SITE_COL)['y_true'].max(),
    'bien_thien_dinh': _dnn.groupby(level=0).std() / _dnn.groupby(level=0).mean() * 100,
}).dropna()
_bang = _bang[_bang['dinh'] > 8]          # bo tram cong suat qua nho, ve ra deo sat truc
_bang = _bang.sort_values(['ty_le_do_that', 'bien_thien_dinh'], ascending=False)

SITE_TUAN = int(_bang.index[0])
print("--- CHON TRAM DE VE (5 tram dan dau) ---")
print(_bang.head(5).round(1).to_string())
print(f"\nChon tram {SITE_TUAN}: do that {_bang.iloc[0]['ty_le_do_that']:.1f}%, "
      f"dinh {_bang.iloc[0]['dinh']:.1f} kWh, bien thien dinh {_bang.iloc[0]['bien_thien_dinh']:.1f}%")

x = _t[_t[SITE_COL] == SITE_TUAN].sort_values('plot_timestamp')
t_cuoi = x['plot_timestamp'].max()
z = x[x['plot_timestamp'] >= t_cuoi - pd.Timedelta(days=7)]
fig, ax = plt.subplots(figsize=(18, 5))
ax.plot(z['plot_timestamp'], z['y_true'], lw=1.9, color='#1f77b4', label='Thực tế')
ax.plot(z['plot_timestamp'], z['y_pred'], lw=1.7, color='#FFA500', label='Dự báo')
ax.fill_between(z['plot_timestamp'], z['y_true'], z['y_pred'], color='#cccccc', alpha=0.35)
ax.set_title(f'Trạm {SITE_TUAN} — 7 ngày cuối tập kiểm định '
             f'(chọn theo tỷ lệ đo thật cao nhất: {_bang.iloc[0]["ty_le_do_that"]:.1f}%)', fontsize=12)
ax.set_ylabel('kWh')
ax.grid(alpha=0.3)
ax.legend()
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/toan_canh_1_tuan.png', dpi=100)
plt.show()
print(f"Đã lưu {OUTPUT_DIR}/toan_canh_1_tuan.png")
# Out:
# --- CHON TRAM DE VE (5 tram dan dau) ---
#          ty_le_do_that  dinh  bien_thien_dinh
# site_id
# 27                99.7  85.9             37.9
# 8                 98.1  27.0             26.6
# 6                 97.4  28.7             23.4
# 12                97.3  17.6             23.4
# 13                97.0  12.9             23.7
#
# Chon tram 27: do that 99.7%, dinh 85.9 kWh, bien thien dinh 37.9%
# Đã lưu ../../data/model/v5/06_2_train_huber/toan_canh_1_tuan.png

# %% [markdown]
# ## 17. Export kết quả

# %%
with open(f'{OUTPUT_DIR}/model_h1.pkl', 'wb') as f:
    pickle.dump({'model': model, 'features': FEATURES, 'medians': MEDIANS.to_dict(),
                 'eps_elev': EPS_ELEV, 'clip_k': lay_clip(), 'horizon_steps': HORIZON_STEPS,
                 'loss': LOSS_NAME, 'chuan_hoa': True,
                 'che_do_trong_so': CHE_DO_TRONG_SO, 'experiment': EXPERIMENT,
                 'mau_so': MAU_SO, 'clip_phan_vi': CLIP_PHAN_VI}, f)

df_tre.to_csv(f'{OUTPUT_DIR}/tre_pha_theo_tram.csv', index=False)
_bang.to_csv(f'{OUTPUT_DIR}/metrics.csv')
with open(f'{OUTPUT_DIR}/ket_qua.json', 'w', encoding='utf-8') as f:
    json.dump({'loss': LOSS_NAME, 'horizon_steps': HORIZON_STEPS,
               # Cau hinh dinh doat nhan + trong so - phai luu de tai lap va doi chung
               # giua cac lan chay (truoc day thieu, khong biet model nao chay che do nao).
               'che_do_trong_so': CHE_DO_TRONG_SO, 'experiment': EXPERIMENT,
               'mau_so': MAU_SO, 'clip_phan_vi': CLIP_PHAN_VI,
               'clip_k': lay_clip(), 'eps_elev': EPS_ELEV,
               'so_dac_trung': len(FEATURES), 'features': FEATURES,
               'bo_di': bo_di, 'best_params': BEST_PARAMS,
               # tham so THAT tu mo hinh da fit - dung cai nay de doi chung, khong dung
               # best_params (chi la thu duoc yeu cau, thieu cac khoa Optuna khong dong toi)
               'tham_so_thuc_te': {k: v for k, v in model.get_params().items()
                                   if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
               'quet_do_tre': {str(k): v for k, v in _quet.items()},
               'k_tot_nhat': int(_k_tot),
               'so_tram_khong_tre': int((df_tre['k_tot_nhat'] == 0).sum()),
               'metrics': _m}, f, indent=2, ensure_ascii=False, default=str)

print("--- HOAN TAT ---")
print(f"Thư mục kết quả: {OUTPUT_DIR}")
for _f in sorted(os.listdir(OUTPUT_DIR)):
    print(f"   {_f}")

# ── Ghi thêm bộ artifact theo đúng định dạng mà notebook 07 và 08 mong đợi ──
# 07 quét thư mục 06_train/<loss>/<h_label>/ nên phải ghi vào đúng cấu trúc đó.
TRAIN_COMPAT_DIR = f'../../data/model/v5/06_train/{LOSS_NAME}/h{HORIZON_STEPS}'
os.makedirs(TRAIN_COMPAT_DIR, exist_ok=True)

with open(f'{TRAIN_COMPAT_DIR}/model.pkl', 'wb') as f:
    pickle.dump(model, f)                      # model tho, de 07 goi model.predict duoc

with open(f'{TRAIN_COMPAT_DIR}/model_config.json', 'w', encoding='utf-8') as f:
    json.dump({
        'horizon_steps': int(HORIZON_STEPS),
        'loss_name': LOSS_NAME,
        'feature_set_name': '',
        'excluded_features': bo_di,
        'lgb_objective': LGB_OBJECTIVE,
        'features': FEATURES,
        'feature_medians': {k: float(v) for k, v in MEDIANS.items()},
        'train_rows': int(len(X_dev)),
        # ba khoa duoi day cho biet phai nhan nguoc mau chuan hoa khi du bao
        # Quy mo va tran cong suat da nam san trong du lieu duoi dang cot, sinh o notebook 03-2.
        # Khi cham diem chi can nhan nguoc site_scale * sin_elevation roi chan tran_cong_suat.
        'chuan_hoa': True,
        'cot_quy_mo': 'site_scale',
        'cot_sin_elev': 'sin_elevation',
        'cot_tran': 'tran_cong_suat',
        'eps_elev': float(EPS_ELEV),
                    'clip_k': float(lay_clip()),
                    'mau_so': MAU_SO,
        # Doc tham so THAT tu mo hinh da fit, khong lay lai BEST_PARAMS: BEST_PARAMS chi la
        # thu duoc YEU CAU, con get_params() la thu LightGBM THUC SU dung - gom ca cac khoa
        # Optuna khong dong toi (reg_alpha, reg_lambda...) voi dung gia tri mac dinh da ap.
        'model_params': {k: v for k, v in model.get_params().items()
                         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
    }, f, indent=2, ensure_ascii=False)


# FIX (chong ro ri): metrics_val.json de notebook 07 quet va chon mo hinh vo dich BAT BUOC
# phai tinh tren tap VALIDATION that, khong duoc dung _m (dang tinh tren val_h). Truoc day
# file nay bi ghi nham tu _m (tap test) khien viec chon MAE/Huber/MSE "thay truoc" tap test.
# Tap VAL that - tach biet hoan toan voi tap hoc (mo hinh chi hoc v5_train_selected).
val_h = doc_val_that()
_k_pred_val = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
val_h['y_pred'] = np.minimum(_k_pred_val * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
_m_val = metrics_3_pham_vi(val_h)
print(f"--- METRIC TREN TAP VALIDATION THAT ({len(val_h):,} dong, dung de chon mo hinh) ---")
display(pd.DataFrame(_m_val).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4))

_val_scope = _m_val.get('measured_daylight', _m_val.get('measured', _m_val['all']))
with open(f'{TRAIN_COMPAT_DIR}/metrics_val.json', 'w', encoding='utf-8') as f:
    json.dump({'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME,
               'feature_set_name': '', 'measured_daylight': _val_scope,
               'all': _m_val['all']}, f, indent=2, ensure_ascii=False, default=str)


# Ma tran test da san sang, kem cac cot can de dung lai du bao.
# 07 va 08 doc file nay thay vi tu dung lai dac trung, tranh lech logic.

print(f"\nĐã ghi bộ artifact tương thích notebook 07/08 vào: {TRAIN_COMPAT_DIR}")
for _f in sorted(os.listdir(TRAIN_COMPAT_DIR)):
    print(f"   {_f}")
# Out:
# --- HOAN TAT ---
# Thư mục kết quả: ../../data/model/v5/06_2_train_huber
#    du_bao_val.parquet
#    ket_qua.json
#    metrics.csv
#    model_h1.pkl
#    toan_canh_1_tuan.png
#    tre_pha_theo_tram.csv
#    zoom_quanh_dinh.png
#     Loai [19, 24] (capacity_kw khong dang tin): 704,748 -> 671,165 dong
# Lọc v5_val_selected: 723,114 -> 671,165 dòng (49 cột)
# --- METRIC TREN TAP VALIDATION THAT (289,348 dong, dung de chon mo hinh) ---
#                           n     wape    rmse    mae     r2
# all                289348.0  22.3204  3.6061  1.522  0.902
# measured           289348.0  22.3204  3.6061  1.522  0.902
# measured_daylight  289348.0  22.3204  3.6061  1.522  0.902
# Đã ghi bộ artifact tương thích notebook 07/08 vào: ../../data/model/v5/06_train/huber/h1
#    metrics_val.json
#    model.pkl
#    model_config.json

# %% [markdown]
# ## 18. Nguồn tham khảo
#
# ### Phương pháp downscale bức xạ bằng chỉ số trời quang
# - Temporal and spatial downscaling for solar radiation - https://arxiv.org/pdf/2405.11046
# - Intra-hour irradiance forecasting techniques for solar power integration: a review -
#   https://pmc.ncbi.nlm.nih.gov/articles/PMC8531863/
# - Short-term photovoltaic generation forecasting using multiple heterogenous sources of data -
#   https://arxiv.org/pdf/1910.05944
# - A fully convolutional neural network to interpolate solar irradiation NWP ensemble forecasts -
#   https://www.sciencedirect.com/science/article/pii/S0038092X25006280
# - Review of Onsite Temperature and Solar Forecasting Models (NREL/OSTI) -
#   https://www.osti.gov/servlets/purl/1855958
#
# Thuật toán tách chỉ số trời quang theo giờ thành thành phần xu thế và nhiễu của Graham và Hollands là
# cơ sở cho cách làm ở mục 6. Điểm khác biệt của notebook này là **không nội suy giữa các giờ** để giữ
# tính nhân quả, chỉ dùng phép nhân với bức xạ trời quang 15 phút.
#
# ### Công thức góc mặt trời
# - NOAA Solar Calculator, phương trình thời gian và độ lệch mặt trời -
#   https://gml.noaa.gov/grad/solcalc/calcdetails.html
#
# ### Mô hình bức xạ trời quang
# - Haurwitz clear-sky model, dạng `GHI = 1098 x sin(h) x exp(-0.057 / sin(h))`
#
# ### Hiện tượng mô hình hội tụ về persistence
# Việc mô hình có đặc trưng tự hồi quy trên chuỗi tự tương quan cao sẽ hội tụ về dự báo naive là hiện tượng
# đã được ghi nhận trong các tổng quan về dự báo bức xạ nội giờ ở trên. Cách xử lý chuẩn của ngành là báo cáo
# **skill score so với persistence** thay vì chỉ báo WAPE trần - đã cài ở mục 14.

# %% [markdown]
# ## 19. TRAIN H4 (chạy SAU khi H1 đã ổn định)
#
# **⚠️ CẢNH BÁO Restart & Run All: 4 cell dưới đây SẼ TỰ CHẠY và train luôn H4 (tốn thêm cả
# tiếng CPU/GPU) nếu bấm "Run All" trên toàn bộ notebook.** Nếu CHỈ muốn train H1 trước (khuyến
# nghị), sau khi cell "17. Export kết quả" (H1) chạy xong thì DỪNG LẠI, đừng bấm Run All tiếp —
# hoặc xoá/comment tạm nội dung 4 cell H4 này. Khi nào muốn train H4, quay lại chạy tay 4 cell
# này (Shift+Enter từng cell), không cần chạy lại từ đầu notebook.
#
# Dùng lại TOÀN BỘ hàm đã định nghĩa ở phần H1 phía trên (`them_muc_tieu`, `build_sample_weight`,
# `doc_fold`, `tham_so_co_ban`, `fit_an_toan`, `du_bao_kwh`, `quet_do_tre`, `metrics_3_pham_vi`) —
# không định nghĩa lại. Các hàm này đọc `HORIZON_STEPS`/`OUTPUT_DIR` từ biến toàn cục, nên chỉ cần
# gán lại 2 biến đó rồi chạy lại đúng luồng train (build target → Optuna → train final → export).
#
# **Điều kiện tiên quyết:** đã chạy xong tới hết phần H1 phía trên trong CÙNG 1 phiên kernel (để
# có sẵn `dev`, `test`, `FEATURES` gốc, các hàm/imports...) — không cần chạy lại từ đầu notebook,
# nhưng bắt buộc phải chạy H1 trước ít nhất 1 lần trong kernel đang mở.

# %%
# ── Chuyen sang HORIZON_STEPS = 4, OUTPUT_DIR rieng (khong dung H1) ──
HORIZON_STEPS = 4
OUTPUT_DIR = '../../data/model/v5/06_2_train_huber_h4'
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Chuyen sang train H4 (T+{HORIZON_STEPS * 15} phut). Ghi ket qua vao: {OUTPUT_DIR}")

# Build lai target/weight cho H4 - GIONG HET logic cell 'Chuan bi ma tran huan luyen' o
# phan H1 (buoc 10), chi khac HORIZON_STEPS. FEATURES_GOC luu lai truoc khi them cot _mt,
# de neu chay lai cell nay nhieu lan khong bi cong don _mt trung.
if 'FEATURES_GOC' not in dir():
    FEATURES_GOC = list(FEATURES)
FEATURES = list(FEATURES_GOC)

dev_h = them_muc_tieu(dev, HORIZON_STEPS)
dev_h = dev_h[(dev_h['site_scale'] > 0) & (dev_h['sin_elevation'] > EPS_ELEV)].copy()
dev_h['k_target'] = cat_k(dev_h['y_true'].to_numpy() / mau_chuan_hoa(dev_h))
dev_h['w'] = build_sample_weight(dev_h)

_mt = [f'{c}_mt' for c in COT_TAT_DINH if f'{c}_mt' in dev_h.columns]
FEATURES = FEATURES + [c for c in _mt if c not in FEATURES]
print(f"Them {len(_mt)} dac trung tat dinh tai T+{HORIZON_STEPS * 15} phut: {_mt}")

MEDIANS = dev_h[FEATURES].median(numeric_only=True).fillna(0.0)
_train_mask = dev_h['w'].gt(0)
X_dev = dev_h.loc[_train_mask, FEATURES].fillna(MEDIANS).astype(DTYPE)
y_dev = dev_h.loc[_train_mask, 'k_target'].astype(DTYPE)
w_dev = dev_h.loc[_train_mask, 'w'].astype(DTYPE)
print(f"Ma tran train H4: {X_dev.shape[0]:,} dong x {X_dev.shape[1]} dac trung")

# ── Cong kiem tra nhanh truoc train H4 (rut gon tu buoc 10.2, chi kiem C va D vi A/B
# khong doi theo horizon) ──
_loi_h4 = []
_b4 = dev_h[dev_h['w'].gt(0)]
_t4 = dev_h.copy()
_t4['duoc_train'] = _t4['w'] > 0
_bo4 = (_t4.groupby(SITE_COL, observed=True)['duoc_train'].apply(lambda x: 1 - x.mean()).mul(100).round(1))
_nang4 = _bo4[_bo4 > 50]
print(f"[D-H4] Site bi loai > 50% dong ban ngay: {len(_nang4)}/{_bo4.size}")
if len(_nang4):
    print(_nang4.to_string())
    _loi_h4.append(f"D-H4: {len(_nang4)} site bi loai qua nua du lieu ban ngay o horizon H4.")
del _t4, _b4
gc.collect()

if _loi_h4:
    raise RuntimeError(f"Cong kiem tra H4 khong dat ({len(_loi_h4)} loi): {_loi_h4}")
print("CONG KIEM TRA H4: DAT - cho train.")
# Out:
# Chuyen sang train H4 (T+60 phut). Ghi ket qua vao: ../../data/model/v5/06_2_train_huber_h4
# Them 13 dac trung tat dinh tai T+60 phut: ['solar_elevation_mt', 'solar_azimuth_mt', 'azimuth_sin_mt', 'azimuth_cos_mt', 'sin_elevation_mt', 'ghi_cs_mt', 'ky_vong_mt', 'ty_le_bao_hoa_mt', 'minute_of_day_mt', 'hour_mt', 'hour_cos_mt', 'doy_sin_mt', 'doy_cos_mt']
# Ma tran train H4: 566,069 dong x 52 dac trung
# [D-H4] Site bi loai > 50% dong ban ngay: 0/40
# CONG KIEM TRA H4: DAT - cho train.

# %%
# ── Optuna tune + train final cho H4 (dung lai doc_fold/tham_so_co_ban/fit_an_toan da
# dinh nghia o phan H1 - cac ham nay doc HORIZON_STEPS tu bien toan cuc nen tu dong dung
# cho H4 sau khi cell tren da gan lai HORIZON_STEPS = 4) ──
CAC_FOLD = []
if N_TRIALS > 0:
    _n = 1
    while True:
        _tr = doc_fold(_n, 'train')
        _va = doc_fold(_n, 'val')
        if _tr is None or _va is None:
            break
        _med = _tr[FEATURES].median(numeric_only=True).fillna(0.0)
        CAC_FOLD.append({
            'fold': _n,
            'Xtr': _tr[FEATURES].fillna(_med).astype(DTYPE),
            'ytr': _tr['k_target'].astype(DTYPE),
            'wtr': _tr['w'].astype(DTYPE),
            'Xva': _va[FEATURES].fillna(_med).astype(DTYPE),
            'yva': _va['k_target'].astype(DTYPE),
            'yva_kwh': _va['y_true'].to_numpy(),
            'mau_va': mau_chuan_hoa(_va),
            'tran_va': _va['tran_cong_suat'].to_numpy(),
            'sin_va': _va['sin_elevation'].to_numpy(),
            'clip': CLIP_K_FOLD.get(_n),
        })
        print(f"- fold {_n}: train {len(_tr):,} dong, val {len(_va):,} dong (H4, da ap weight)")
        del _tr, _va
        gc.collect()
        _n += 1
    if not CAC_FOLD:
        raise FileNotFoundError(f"Khong tim thay fold nao trong {FOLDS_DIR}.")
    print(f"\nDa nap {len(CAC_FOLD)} fold cho H4.")

    _t0_h4 = time.time()

    def objective_h4(trial):
        params = tham_so_co_ban(trial)
        tong_sai_so = 0.0
        tong_thuc_te = 0.0
        _cay_tung_fold = []
        for f in CAC_FOLD:
            m = fit_an_toan(params, f['Xtr'], f['ytr'], f['wtr'], f['Xva'], f['yva'])
            _cay_tung_fold.append(int(m.best_iteration_ or params['n_estimators']))
            yp = du_bao_kwh(m, f, m.best_iteration_)
            tong_sai_so += float(np.abs(yp - f['yva_kwh']).sum())
            tong_thuc_te += float(np.abs(f['yva_kwh']).sum())
            del m
        trial.set_user_attr('so_cay_tung_fold', _cay_tung_fold)
        return tong_sai_so / tong_thuc_te * 100.0 if tong_thuc_te > 0 else np.nan

    def log_trial_h4(study, trial):
        done = trial.number + 1
        el = (time.time() - _t0_h4) / 60
        val = f"{trial.value:.4f}%" if trial.value is not None else "pruned"
        print(f"   [H4 Trial {done:>2}/{N_TRIALS}] pooled WAPE {val:>10} | tot nhat {study.best_value:.4f}% "
              f"| da chay {el:.1f} phut, con khoang {el / done * (N_TRIALS - done):.1f} phut")

    study_h4 = optuna.create_study(direction='minimize', sampler=TPESampler(seed=SEED))
    study_h4.optimize(objective_h4, n_trials=N_TRIALS, show_progress_bar=False, callbacks=[log_trial_h4])
    BEST_PARAMS = tham_so_co_ban()
    BEST_PARAMS.update(study_h4.best_params)
    print(f"\nPooled WAPE tot nhat H4 tren {len(CAC_FOLD)} fold = {study_h4.best_value:.4f}%")
    del CAC_FOLD
    gc.collect()
else:
    BEST_PARAMS = tham_so_co_ban()
    print("Bo qua Optuna H4 (ngan sach bang 0), dung tham so mac dinh.")

val_h = doc_val_that()   # dung lai theo HORIZON_STEPS hien tai (H4)
_X_val_es = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_y_val_es = val_h['k_target'].astype(DTYPE)
LICH_SU_EARLY_STOP = {}
_t1_h4 = time.time()
model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev, _X_val_es, _y_val_es, LICH_SU_EARLY_STOP)
BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': int(model.best_iteration_)}
print(f"Train H4 xong sau {(time.time() - _t1_h4) / 60:.1f} phut | dung som tai {model.best_iteration_} cay")

_k_pred = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
val_h['y_pred'] = np.minimum(_k_pred * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
# Luu du bao validation de ve lai sau nay khong can kernel/model
val_h[[SITE_COL, 'plot_timestamp', 'y_true', 'y_pred']].to_parquet(
    f'{OUTPUT_DIR}/du_bao_val.parquet', index=False)
print(f"Da du bao {len(val_h):,} dong (H4)")
# Out:
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 2.4878
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 1: train 91,402 dong, val 180,727 dong (H4, da ap weight)
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 2.0481
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 2: train 307,021 dong, val 243,908 dong (H4, da ap weight)
# Nguong cat suy tu tap train: phan vi 0.99 cua k = 2.0036
#    chan lai 1.00% quan sat (khong xoa dong nao)
# - fold 3: train 566,976 dong, val 273,376 dong (H4, da ap weight)
#
# Da nap 3 fold cho H4.
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0737928	train's huber: 0.00596475	val's l1: 0.352955	val's huber: 0.0539334
# [400]	train's l1: 0.0517163	train's huber: 0.0034761	val's l1: 0.351631	val's huber: 0.0536584
# Early stopping, best iteration is:
# [418]	train's l1: 0.0504038	train's huber: 0.00334572	val's l1: 0.351365	val's huber: 0.0536077
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0829082	train's huber: 0.00698924	val's l1: 0.188842	val's huber: 0.0233161
# Early stopping, best iteration is:
# [210]	train's l1: 0.0814991	train's huber: 0.00681675	val's l1: 0.188656	val's huber: 0.0232861
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0934863	train's huber: 0.00832759	val's l1: 0.195977	val's huber: 0.0243802
# Early stopping, best iteration is:
# [220]	train's l1: 0.090485	train's huber: 0.00793296	val's l1: 0.195868	val's huber: 0.024365
# Evaluated only: l1
#    [H4 Trial  1/20] pooled WAPE   28.3979% | tot nhat 28.3979% | da chay 0.6 phut, con khoang 10.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.156896	train's huber: 0.0162733	val's l1: 0.433768	val's huber: 0.0603585
# [400]	train's l1: 0.115005	train's huber: 0.0108745	val's l1: 0.383832	val's huber: 0.052383
# [600]	train's l1: 0.0960765	train's huber: 0.00847201	val's l1: 0.359148	val's huber: 0.0482806
# [800]	train's l1: 0.0848314	train's huber: 0.00710436	val's l1: 0.350367	val's huber: 0.04681
# Did not meet early stopping. Best iteration is:
# [967]	train's l1: 0.0779198	train's huber: 0.00629387	val's l1: 0.3477	val's huber: 0.046364
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.152172	train's huber: 0.015241	val's l1: 0.209337	val's huber: 0.0238408
# [400]	train's l1: 0.114972	train's huber: 0.0105421	val's l1: 0.192849	val's huber: 0.0216369
# [600]	train's l1: 0.0987175	train's huber: 0.00851936	val's l1: 0.189379	val's huber: 0.0211082
# [800]	train's l1: 0.0884076	train's huber: 0.00730083	val's l1: 0.188191	val's huber: 0.0209343
# Did not meet early stopping. Best iteration is:
# [966]	train's l1: 0.0824347	train's huber: 0.0066114	val's l1: 0.187881	val's huber: 0.0208889
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.158086	train's huber: 0.0161349	val's l1: 0.223473	val's huber: 0.0259641
# [400]	train's l1: 0.125982	train's huber: 0.0120063	val's l1: 0.20063	val's huber: 0.0227449
# [600]	train's l1: 0.109636	train's huber: 0.00987696	val's l1: 0.196398	val's huber: 0.0220729
# [800]	train's l1: 0.0993831	train's huber: 0.00859355	val's l1: 0.194559	val's huber: 0.0217841
# Did not meet early stopping. Best iteration is:
# [966]	train's l1: 0.0930118	train's huber: 0.0078253	val's l1: 0.194032	val's huber: 0.0216921
# Evaluated only: l1
#    [H4 Trial  2/20] pooled WAPE   28.0719% | tot nhat 28.0719% | da chay 2.5 phut, con khoang 22.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.190474	train's huber: 0.0123692	val's l1: 0.458937	val's huber: 0.0333595
# [400]	train's l1: 0.140879	train's huber: 0.00869675	val's l1: 0.413926	val's huber: 0.0298827
# [600]	train's l1: 0.122766	train's huber: 0.00740636	val's l1: 0.398514	val's huber: 0.0286772
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.114357	train's huber: 0.00681077	val's l1: 0.389759	val's huber: 0.027988
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.18278	train's huber: 0.0117046	val's l1: 0.225855	val's huber: 0.0149997
# [400]	train's l1: 0.138087	train's huber: 0.00841537	val's l1: 0.196268	val's huber: 0.0128105
# [600]	train's l1: 0.119338	train's huber: 0.00707029	val's l1: 0.192057	val's huber: 0.0124873
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.111422	train's huber: 0.00650533	val's l1: 0.189725	val's huber: 0.0123068
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.183105	train's huber: 0.0117379	val's l1: 0.242525	val's huber: 0.0162947
# [400]	train's l1: 0.144015	train's huber: 0.00886511	val's l1: 0.207575	val's huber: 0.0136719
# [600]	train's l1: 0.12832	train's huber: 0.00772246	val's l1: 0.200427	val's huber: 0.0131186
# Did not meet early stopping. Best iteration is:
# [745]	train's l1: 0.120485	train's huber: 0.00715627	val's l1: 0.197856	val's huber: 0.0129187
# Evaluated only: l1
#    [H4 Trial  3/20] pooled WAPE   28.8330% | tot nhat 28.0719% | da chay 3.9 phut, con khoang 22.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.128372	train's huber: 0.0159017	val's l1: 0.364087	val's huber: 0.0783591
# [400]	train's l1: 0.109673	train's huber: 0.012355	val's l1: 0.359582	val's huber: 0.0769964
# [600]	train's l1: 0.0989324	train's huber: 0.0104942	val's l1: 0.358574	val's huber: 0.0766786
# Early stopping, best iteration is:
# [561]	train's l1: 0.100735	train's huber: 0.0107994	val's l1: 0.358484	val's huber: 0.0766506
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.131342	train's huber: 0.0158401	val's l1: 0.191793	val's huber: 0.0295895
# [400]	train's l1: 0.112435	train's huber: 0.0123754	val's l1: 0.189882	val's huber: 0.029181
# [600]	train's l1: 0.10147	train's huber: 0.0105311	val's l1: 0.189358	val's huber: 0.0290771
# Early stopping, best iteration is:
# [635]	train's l1: 0.100076	train's huber: 0.0103083	val's l1: 0.189189	val's huber: 0.0290431
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.139379	train's huber: 0.0175184	val's l1: 0.196601	val's huber: 0.0303136
# [400]	train's l1: 0.121249	train's huber: 0.0139412	val's l1: 0.195027	val's huber: 0.0299421
# [600]	train's l1: 0.110629	train's huber: 0.012079	val's l1: 0.194844	val's huber: 0.0299133
# Early stopping, best iteration is:
# [649]	train's l1: 0.108518	train's huber: 0.0117085	val's l1: 0.19474	val's huber: 0.029904
# Evaluated only: l1
#    [H4 Trial  4/20] pooled WAPE   28.4293% | tot nhat 28.0719% | da chay 4.6 phut, con khoang 18.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.194923	train's huber: 0.0141665	val's l1: 0.469132	val's huber: 0.0386621
# [400]	train's l1: 0.1337	train's huber: 0.00901667	val's l1: 0.415124	val's huber: 0.0338992
# [600]	train's l1: 0.111784	train's huber: 0.00726211	val's l1: 0.385659	val's huber: 0.031252
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.108461	train's huber: 0.00699869	val's l1: 0.382095	val's huber: 0.0309308
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.19583	train's huber: 0.0141386	val's l1: 0.241164	val's huber: 0.0180906
# [400]	train's l1: 0.139296	train's huber: 0.0093764	val's l1: 0.199786	val's huber: 0.0145838
# [600]	train's l1: 0.118988	train's huber: 0.00774222	val's l1: 0.193539	val's huber: 0.0140443
# Did not meet early stopping. Best iteration is:
# [642]	train's l1: 0.11582	train's huber: 0.00748829	val's l1: 0.193073	val's huber: 0.0140045
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.197934	train's huber: 0.0143154	val's l1: 0.258871	val's huber: 0.0196677
# [400]	train's l1: 0.147055	train's huber: 0.0100423	val's l1: 0.212831	val's huber: 0.0157179
# [600]	train's l1: 0.130309	train's huber: 0.00867624	val's l1: 0.202847	val's huber: 0.0148476
# Did not meet early stopping. Best iteration is:
# [643]	train's l1: 0.127676	train's huber: 0.00845967	val's l1: 0.201657	val's huber: 0.0147422
# Evaluated only: l1
#    [H4 Trial  5/20] pooled WAPE   28.7829% | tot nhat 28.0719% | da chay 5.9 phut, con khoang 17.8 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.120141	train's huber: 0.0147804	val's l1: 0.365492	val's huber: 0.0887408
# [400]	train's l1: 0.0980547	train's huber: 0.0105866	val's l1: 0.356408	val's huber: 0.0855071
# [600]	train's l1: 0.0868602	train's huber: 0.00864918	val's l1: 0.354896	val's huber: 0.084903
# Early stopping, best iteration is:
# [689]	train's l1: 0.0833505	train's huber: 0.00807581	val's l1: 0.35461	val's huber: 0.0847871
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.121356	train's huber: 0.0143098	val's l1: 0.190839	val's huber: 0.0314499
# [400]	train's l1: 0.100454	train's huber: 0.0105259	val's l1: 0.189013	val's huber: 0.0310418
# [600]	train's l1: 0.089457	train's huber: 0.00871305	val's l1: 0.188836	val's huber: 0.0310066
# [800]	train's l1: 0.0823756	train's huber: 0.00760763	val's l1: 0.188891	val's huber: 0.0310503
# Early stopping, best iteration is:
# [754]	train's l1: 0.0838054	train's huber: 0.00782581	val's l1: 0.188667	val's huber: 0.0309891
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.130595	train's huber: 0.0161377	val's l1: 0.196528	val's huber: 0.0322475
# [400]	train's l1: 0.109118	train's huber: 0.0119805	val's l1: 0.195064	val's huber: 0.0318796
# Early stopping, best iteration is:
# [481]	train's l1: 0.104102	train's huber: 0.011086	val's l1: 0.194962	val's huber: 0.0318685
# Evaluated only: l1
#    [H4 Trial  6/20] pooled WAPE   28.4370% | tot nhat 28.0719% | da chay 7.1 phut, con khoang 16.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.101361	train's huber: 0.0108369	val's l1: 0.357338	val's huber: 0.0783865
# [400]	train's l1: 0.0809375	train's huber: 0.00750762	val's l1: 0.355627	val's huber: 0.0778372
# [600]	train's l1: 0.0703159	train's huber: 0.00595795	val's l1: 0.355382	val's huber: 0.0777388
# Early stopping, best iteration is:
# [638]	train's l1: 0.0687206	train's huber: 0.00575208	val's l1: 0.355241	val's huber: 0.0776879
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.107814	train's huber: 0.0115577	val's l1: 0.190271	val's huber: 0.0298395
# [400]	train's l1: 0.0888979	train's huber: 0.00847704	val's l1: 0.189134	val's huber: 0.029614
# Early stopping, best iteration is:
# [437]	train's l1: 0.0864342	train's huber: 0.00809715	val's l1: 0.188958	val's huber: 0.0295597
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.119612	train's huber: 0.0136514	val's l1: 0.195732	val's huber: 0.0305386
# Early stopping, best iteration is:
# [234]	train's l1: 0.115238	train's huber: 0.0128641	val's l1: 0.19552	val's huber: 0.0305015
# Evaluated only: l1
#    [H4 Trial  7/20] pooled WAPE   28.7119% | tot nhat 28.0719% | da chay 7.6 phut, con khoang 14.2 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.204963	train's huber: 0.0134296	val's l1: 0.466895	val's huber: 0.033912
# [400]	train's l1: 0.158611	train's huber: 0.00997341	val's l1: 0.425354	val's huber: 0.0307098
# [600]	train's l1: 0.141811	train's huber: 0.00875877	val's l1: 0.405968	val's huber: 0.0291956
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.137126	train's huber: 0.00842046	val's l1: 0.401308	val's huber: 0.0288297
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.193123	train's huber: 0.0124657	val's l1: 0.23034	val's huber: 0.0153124
# [400]	train's l1: 0.148448	train's huber: 0.0091592	val's l1: 0.198345	val's huber: 0.012943
# [600]	train's l1: 0.131047	train's huber: 0.00790844	val's l1: 0.193355	val's huber: 0.0125621
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.126247	train's huber: 0.00756352	val's l1: 0.192147	val's huber: 0.0124694
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.190386	train's huber: 0.0122665	val's l1: 0.246174	val's huber: 0.0165433
# [400]	train's l1: 0.151083	train's huber: 0.00937392	val's l1: 0.209567	val's huber: 0.0137981
# [600]	train's l1: 0.136884	train's huber: 0.00834014	val's l1: 0.201993	val's huber: 0.0132143
# Did not meet early stopping. Best iteration is:
# [685]	train's l1: 0.132053	train's huber: 0.00798951	val's l1: 0.200307	val's huber: 0.013083
# Evaluated only: l1
#    [H4 Trial  8/20] pooled WAPE   29.0552% | tot nhat 28.0719% | da chay 8.7 phut, con khoang 13.1 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0810859	train's huber: 0.00758587	val's l1: 0.362163	val's huber: 0.083953
# Early stopping, best iteration is:
# [245]	train's l1: 0.0753229	train's huber: 0.0067	val's l1: 0.361777	val's huber: 0.0838051
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.0871831	train's huber: 0.00825473	val's l1: 0.189521	val's huber: 0.0304137
# Early stopping, best iteration is:
# [229]	train's l1: 0.0834453	train's huber: 0.00769665	val's l1: 0.189205	val's huber: 0.0303602
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.097217	train's huber: 0.00980714	val's l1: 0.195626	val's huber: 0.0314264
# Early stopping, best iteration is:
# [180]	train's l1: 0.100465	train's huber: 0.0103441	val's l1: 0.195481	val's huber: 0.0313803
# Evaluated only: l1
#    [H4 Trial  9/20] pooled WAPE   28.7164% | tot nhat 28.0719% | da chay 9.2 phut, con khoang 11.3 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.156969	train's huber: 0.0153059	val's l1: 0.409156	val's huber: 0.0510951
# [400]	train's l1: 0.132495	train's huber: 0.0123212	val's l1: 0.380299	val's huber: 0.0469269
# [600]	train's l1: 0.121208	train's huber: 0.0109371	val's l1: 0.369144	val's huber: 0.0452894
# [800]	train's l1: 0.112543	train's huber: 0.00988887	val's l1: 0.364441	val's huber: 0.0445924
# Did not meet early stopping. Best iteration is:
# [899]	train's l1: 0.1092	train's huber: 0.00949231	val's l1: 0.363555	val's huber: 0.0444599
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.160501	train's huber: 0.0155596	val's l1: 0.19994	val's huber: 0.0209388
# [400]	train's l1: 0.135605	train's huber: 0.0124791	val's l1: 0.192214	val's huber: 0.0198932
# [600]	train's l1: 0.123701	train's huber: 0.0110207	val's l1: 0.18923	val's huber: 0.0194886
# [800]	train's l1: 0.114842	train's huber: 0.00995119	val's l1: 0.188522	val's huber: 0.0193974
# Did not meet early stopping. Best iteration is:
# [891]	train's l1: 0.111569	train's huber: 0.00957222	val's l1: 0.188193	val's huber: 0.0193539
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.164205	train's huber: 0.0161167	val's l1: 0.209981	val's huber: 0.0222866
# [400]	train's l1: 0.143364	train's huber: 0.0134941	val's l1: 0.199002	val's huber: 0.0207709
# [600]	train's l1: 0.132326	train's huber: 0.0121118	val's l1: 0.195349	val's huber: 0.0202683
# [800]	train's l1: 0.124182	train's huber: 0.0111145	val's l1: 0.194459	val's huber: 0.0201423
# Did not meet early stopping. Best iteration is:
# [878]	train's l1: 0.121504	train's huber: 0.0107848	val's l1: 0.194266	val's huber: 0.0201135
# Evaluated only: l1
#    [H4 Trial 10/20] pooled WAPE   28.3302% | tot nhat 28.0719% | da chay 10.5 phut, con khoang 10.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.174584	train's huber: 0.0172367	val's l1: 0.445712	val's huber: 0.055322
# [400]	train's l1: 0.127505	train's huber: 0.0115915	val's l1: 0.397398	val's huber: 0.0486712
# [600]	train's l1: 0.107214	train's huber: 0.00923181	val's l1: 0.37103	val's huber: 0.0448893
# [800]	train's l1: 0.0947206	train's huber: 0.00780497	val's l1: 0.358758	val's huber: 0.0431055
# [1000]	train's l1: 0.0862049	train's huber: 0.00686121	val's l1: 0.353424	val's huber: 0.0423293
# Did not meet early stopping. Best iteration is:
# [1174]	train's l1: 0.0801035	train's huber: 0.00619585	val's l1: 0.351189	val's huber: 0.0420043
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.164727	train's huber: 0.0156872	val's l1: 0.217793	val's huber: 0.0227884
# [400]	train's l1: 0.122255	train's huber: 0.0107201	val's l1: 0.194043	val's huber: 0.0199431
# [600]	train's l1: 0.104565	train's huber: 0.00869035	val's l1: 0.190647	val's huber: 0.0194949
# [800]	train's l1: 0.0940228	train's huber: 0.00751354	val's l1: 0.188766	val's huber: 0.0192446
# [1000]	train's l1: 0.086344	train's huber: 0.00667836	val's l1: 0.188242	val's huber: 0.0191765
# Did not meet early stopping. Best iteration is:
# [1174]	train's l1: 0.081325	train's huber: 0.00614743	val's l1: 0.187852	val's huber: 0.0191291
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.168737	train's huber: 0.0162322	val's l1: 0.233478	val's huber: 0.0249032
# [400]	train's l1: 0.132386	train's huber: 0.0119556	val's l1: 0.203983	val's huber: 0.0212351
# [600]	train's l1: 0.1154	train's huber: 0.0099442	val's l1: 0.198726	val's huber: 0.0205087
# [800]	train's l1: 0.104723	train's huber: 0.0087016	val's l1: 0.196282	val's huber: 0.0201718
# [1000]	train's l1: 0.096722	train's huber: 0.00779761	val's l1: 0.19555	val's huber: 0.0200669
# Did not meet early stopping. Best iteration is:
# [1174]	train's l1: 0.0912531	train's huber: 0.00720183	val's l1: 0.195088	val's huber: 0.0199996
# Evaluated only: l1
#    [H4 Trial 11/20] pooled WAPE   28.2288% | tot nhat 28.0719% | da chay 13.1 phut, con khoang 10.7 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.16833	train's huber: 0.0168987	val's l1: 0.440073	val's huber: 0.0566444
# [400]	train's l1: 0.122887	train's huber: 0.0113254	val's l1: 0.388249	val's huber: 0.0491487
# [600]	train's l1: 0.103269	train's huber: 0.00896915	val's l1: 0.364088	val's huber: 0.0455143
# [800]	train's l1: 0.090839	train's huber: 0.00751089	val's l1: 0.351738	val's huber: 0.0436321
# [1000]	train's l1: 0.0821249	train's huber: 0.00652378	val's l1: 0.347799	val's huber: 0.0430239
# Did not meet early stopping. Best iteration is:
# [1198]	train's l1: 0.0755777	train's huber: 0.0058005	val's l1: 0.345689	val's huber: 0.042701
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.16055	train's huber: 0.0155545	val's l1: 0.214922	val's huber: 0.0231164
# [400]	train's l1: 0.11983	train's huber: 0.0106807	val's l1: 0.193597	val's huber: 0.0204778
# [600]	train's l1: 0.102558	train's huber: 0.00863978	val's l1: 0.190118	val's huber: 0.0199989
# [800]	train's l1: 0.0920153	train's huber: 0.00743405	val's l1: 0.18878	val's huber: 0.0198085
# [1000]	train's l1: 0.0844739	train's huber: 0.00660093	val's l1: 0.188221	val's huber: 0.019738
# Did not meet early stopping. Best iteration is:
# [1170]	train's l1: 0.0794991	train's huber: 0.00606567	val's l1: 0.187962	val's huber: 0.0197025
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.165289	train's huber: 0.0162258	val's l1: 0.230115	val's huber: 0.0252384
# [400]	train's l1: 0.130281	train's huber: 0.0119891	val's l1: 0.202841	val's huber: 0.0217162
# [600]	train's l1: 0.113456	train's huber: 0.00993064	val's l1: 0.197914	val's huber: 0.021003
# [800]	train's l1: 0.103076	train's huber: 0.00868971	val's l1: 0.195733	val's huber: 0.0206941
# [1000]	train's l1: 0.0953761	train's huber: 0.00780002	val's l1: 0.194892	val's huber: 0.0205738
# Did not meet early stopping. Best iteration is:
# [1188]	train's l1: 0.0892699	train's huber: 0.00712135	val's l1: 0.194756	val's huber: 0.0205481
# Evaluated only: l1
#    [H4 Trial 12/20] pooled WAPE   28.1219% | tot nhat 28.0719% | da chay 15.8 phut, con khoang 10.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.137456	train's huber: 0.015115	val's l1: 0.409203	val's huber: 0.0663366
# [400]	train's l1: 0.103022	train's huber: 0.0101068	val's l1: 0.362631	val's huber: 0.0570799
# [600]	train's l1: 0.0865186	train's huber: 0.00781178	val's l1: 0.352153	val's huber: 0.0549382
# [800]	train's l1: 0.0760276	train's huber: 0.00641314	val's l1: 0.349301	val's huber: 0.0543603
# [1000]	train's l1: 0.0687236	train's huber: 0.00549128	val's l1: 0.348091	val's huber: 0.0541082
# Did not meet early stopping. Best iteration is:
# [1168]	train's l1: 0.063893	train's huber: 0.00490481	val's l1: 0.34767	val's huber: 0.0540193
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.135891	train's huber: 0.0144004	val's l1: 0.198027	val's huber: 0.0252
# [400]	train's l1: 0.104517	train's huber: 0.00996044	val's l1: 0.189855	val's huber: 0.0238645
# [600]	train's l1: 0.0900977	train's huber: 0.00800987	val's l1: 0.188406	val's huber: 0.0236296
# Early stopping, best iteration is:
# [678]	train's l1: 0.086199	train's huber: 0.00750414	val's l1: 0.188027	val's huber: 0.02357
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.143065	train's huber: 0.0156195	val's l1: 0.209183	val's huber: 0.0270942
# [400]	train's l1: 0.114749	train's huber: 0.0114242	val's l1: 0.196975	val's huber: 0.0249676
# [600]	train's l1: 0.100304	train's huber: 0.00936541	val's l1: 0.19465	val's huber: 0.0245438
# [800]	train's l1: 0.091109	train's huber: 0.00810312	val's l1: 0.194018	val's huber: 0.02442
# [1000]	train's l1: 0.0842855	train's huber: 0.00721409	val's l1: 0.193771	val's huber: 0.0243834
# Early stopping, best iteration is:
# [955]	train's l1: 0.0857839	train's huber: 0.00739999	val's l1: 0.193702	val's huber: 0.0243706
# Evaluated only: l1
#    [H4 Trial 13/20] pooled WAPE   28.1367% | tot nhat 28.0719% | da chay 17.9 phut, con khoang 9.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.173075	train's huber: 0.0143927	val's l1: 0.442853	val's huber: 0.0440442
# [400]	train's l1: 0.126733	train's huber: 0.00983394	val's l1: 0.39358	val's huber: 0.0387018
# [600]	train's l1: 0.106777	train's huber: 0.00793428	val's l1: 0.369368	val's huber: 0.0359968
# [800]	train's l1: 0.0942703	train's huber: 0.00675508	val's l1: 0.35682	val's huber: 0.0345818
# [1000]	train's l1: 0.0857938	train's huber: 0.00597571	val's l1: 0.351407	val's huber: 0.0339687
# Did not meet early stopping. Best iteration is:
# [1035]	train's l1: 0.0844769	train's huber: 0.00585624	val's l1: 0.351033	val's huber: 0.0339269
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.164848	train's huber: 0.0133761	val's l1: 0.217234	val's huber: 0.0189306
# [400]	train's l1: 0.122443	train's huber: 0.00927047	val's l1: 0.193921	val's huber: 0.016626
# [600]	train's l1: 0.105108	train's huber: 0.00761552	val's l1: 0.190416	val's huber: 0.0162574
# [800]	train's l1: 0.0944563	train's huber: 0.00662166	val's l1: 0.188624	val's huber: 0.0160666
# [1000]	train's l1: 0.0867292	train's huber: 0.00591998	val's l1: 0.187979	val's huber: 0.015999
# Did not meet early stopping. Best iteration is:
# [1035]	train's l1: 0.0855746	train's huber: 0.00581605	val's l1: 0.187966	val's huber: 0.015997
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.168761	train's huber: 0.0137993	val's l1: 0.233203	val's huber: 0.0206506
# [400]	train's l1: 0.132589	train's huber: 0.0102766	val's l1: 0.204272	val's huber: 0.0177065
# [600]	train's l1: 0.11589	train's huber: 0.00865263	val's l1: 0.198931	val's huber: 0.0171205
# [800]	train's l1: 0.105119	train's huber: 0.00761785	val's l1: 0.196601	val's huber: 0.0168666
# [1000]	train's l1: 0.0978678	train's huber: 0.00692887	val's l1: 0.195219	val's huber: 0.0167211
# Did not meet early stopping. Best iteration is:
# [1035]	train's l1: 0.0970105	train's huber: 0.00684496	val's l1: 0.195132	val's huber: 0.0167122
# Evaluated only: l1
#    [H4 Trial 14/20] pooled WAPE   28.1761% | tot nhat 28.0719% | da chay 20.1 phut, con khoang 8.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.154301	train's huber: 0.018449	val's l1: 0.420521	val's huber: 0.0735501
# [400]	train's l1: 0.120945	train's huber: 0.0132386	val's l1: 0.376004	val's huber: 0.0640799
# [600]	train's l1: 0.104684	train's huber: 0.0107279	val's l1: 0.362959	val's huber: 0.0612213
# [800]	train's l1: 0.0943058	train's huber: 0.0091848	val's l1: 0.357835	val's huber: 0.0600949
# [1000]	train's l1: 0.0870361	train's huber: 0.00814606	val's l1: 0.355748	val's huber: 0.0596265
# Did not meet early stopping. Best iteration is:
# [1040]	train's l1: 0.085806	train's huber: 0.00797338	val's l1: 0.355486	val's huber: 0.0595663
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.146289	train's huber: 0.0165301	val's l1: 0.201504	val's huber: 0.0270097
# [400]	train's l1: 0.115058	train's huber: 0.011862	val's l1: 0.190907	val's huber: 0.0252497
# [600]	train's l1: 0.101078	train's huber: 0.00980343	val's l1: 0.18842	val's huber: 0.0247927
# [800]	train's l1: 0.0921271	train's huber: 0.00853186	val's l1: 0.187611	val's huber: 0.0246505
# Early stopping, best iteration is:
# [864]	train's l1: 0.0898754	train's huber: 0.00822162	val's l1: 0.187399	val's huber: 0.0246188
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.151652	train's huber: 0.0175823	val's l1: 0.21321	val's huber: 0.029154
# [400]	train's l1: 0.124159	train's huber: 0.0132869	val's l1: 0.197746	val's huber: 0.0263621
# [600]	train's l1: 0.109865	train's huber: 0.0110677	val's l1: 0.195294	val's huber: 0.0258553
# [800]	train's l1: 0.100738	train's huber: 0.00970733	val's l1: 0.194447	val's huber: 0.0256828
# [1000]	train's l1: 0.0941575	train's huber: 0.00876755	val's l1: 0.193934	val's huber: 0.0255875
# Did not meet early stopping. Best iteration is:
# [1034]	train's l1: 0.0931615	train's huber: 0.00862845	val's l1: 0.193909	val's huber: 0.0255821
# Evaluated only: l1
#    [H4 Trial 15/20] pooled WAPE   28.2627% | tot nhat 28.0719% | da chay 22.1 phut, con khoang 7.4 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.147286	train's huber: 0.0133175	val's l1: 0.424024	val's huber: 0.0494537
# [400]	train's l1: 0.109202	train's huber: 0.00909417	val's l1: 0.37447	val's huber: 0.0428833
# [600]	train's l1: 0.0913954	train's huber: 0.00715964	val's l1: 0.354029	val's huber: 0.0401045
# [800]	train's l1: 0.0805457	train's huber: 0.0060271	val's l1: 0.348686	val's huber: 0.0393741
# [1000]	train's l1: 0.0728967	train's huber: 0.00524822	val's l1: 0.346606	val's huber: 0.0390875
# Did not meet early stopping. Best iteration is:
# [1040]	train's l1: 0.0716082	train's huber: 0.00511933	val's l1: 0.346399	val's huber: 0.0390585
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.145413	train's huber: 0.0128698	val's l1: 0.203752	val's huber: 0.0201604
# [400]	train's l1: 0.110788	train's huber: 0.0090591	val's l1: 0.191819	val's huber: 0.0187417
# [600]	train's l1: 0.0951939	train's huber: 0.00737847	val's l1: 0.188824	val's huber: 0.0183635
# [800]	train's l1: 0.0854675	train's huber: 0.00637556	val's l1: 0.188149	val's huber: 0.0182825
# [1000]	train's l1: 0.0780585	train's huber: 0.00563626	val's l1: 0.18796	val's huber: 0.018265
# Did not meet early stopping. Best iteration is:
# [1041]	train's l1: 0.0768138	train's huber: 0.00551366	val's l1: 0.187878	val's huber: 0.0182562
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.15186	train's huber: 0.0136754	val's l1: 0.217726	val's huber: 0.0219082
# [400]	train's l1: 0.122015	train's huber: 0.0103203	val's l1: 0.200134	val's huber: 0.0197503
# [600]	train's l1: 0.106566	train's huber: 0.00859757	val's l1: 0.196241	val's huber: 0.0192452
# [800]	train's l1: 0.0964017	train's huber: 0.00750396	val's l1: 0.194878	val's huber: 0.0190711
# [1000]	train's l1: 0.0890827	train's huber: 0.00672834	val's l1: 0.194519	val's huber: 0.0190213
# Did not meet early stopping. Best iteration is:
# [1033]	train's l1: 0.0880264	train's huber: 0.00661934	val's l1: 0.19441	val's huber: 0.0190079
# Evaluated only: l1
#    [H4 Trial 16/20] pooled WAPE   28.1263% | tot nhat 28.0719% | da chay 24.2 phut, con khoang 6.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.200944	train's huber: 0.0091471	val's l1: 0.469591	val's huber: 0.0229146
# [400]	train's l1: 0.143665	train's huber: 0.00627991	val's l1: 0.413385	val's huber: 0.0200461
# [600]	train's l1: 0.123124	train's huber: 0.00527433	val's l1: 0.384993	val's huber: 0.0185865
# [800]	train's l1: 0.11166	train's huber: 0.00471707	val's l1: 0.361021	val's huber: 0.017353
# [1000]	train's l1: 0.103572	train's huber: 0.00432493	val's l1: 0.350245	val's huber: 0.0167974
# Did not meet early stopping. Best iteration is:
# [1096]	train's l1: 0.100367	train's huber: 0.00417017	val's l1: 0.348435	val's huber: 0.0167039
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.204963	train's huber: 0.00932485	val's l1: 0.241984	val's huber: 0.0112034
# [400]	train's l1: 0.150907	train's huber: 0.00660971	val's l1: 0.200942	val's huber: 0.00914025
# [600]	train's l1: 0.132088	train's huber: 0.00568564	val's l1: 0.194434	val's huber: 0.00880953
# [800]	train's l1: 0.12139	train's huber: 0.00516084	val's l1: 0.191394	val's huber: 0.00865556
# [1000]	train's l1: 0.113037	train's huber: 0.00475478	val's l1: 0.189434	val's huber: 0.00855611
# Did not meet early stopping. Best iteration is:
# [1095]	train's l1: 0.109366	train's huber: 0.00457792	val's l1: 0.188805	val's huber: 0.00852475
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.205285	train's huber: 0.00934127	val's l1: 0.259666	val's huber: 0.0121096
# [400]	train's l1: 0.157124	train's huber: 0.0069277	val's l1: 0.213834	val's huber: 0.00979414
# [600]	train's l1: 0.141455	train's huber: 0.00615295	val's l1: 0.203539	val's huber: 0.00926998
# [800]	train's l1: 0.131545	train's huber: 0.00566303	val's l1: 0.199214	val's huber: 0.00904924
# [1000]	train's l1: 0.124041	train's huber: 0.00529337	val's l1: 0.196997	val's huber: 0.00893633
# Did not meet early stopping. Best iteration is:
# [1096]	train's l1: 0.121301	train's huber: 0.00515855	val's l1: 0.196097	val's huber: 0.00889048
# Evaluated only: l1
#    [H4 Trial 17/20] pooled WAPE   27.9504% | tot nhat 27.9504% | da chay 25.9 phut, con khoang 4.6 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.175802	train's huber: 0.00819311	val's l1: 0.445593	val's huber: 0.0226426
# [400]	train's l1: 0.13193	train's huber: 0.00593092	val's l1: 0.393319	val's huber: 0.0198516
# [600]	train's l1: 0.115089	train's huber: 0.00507794	val's l1: 0.36762	val's huber: 0.0184675
# [800]	train's l1: 0.104217	train's huber: 0.00452796	val's l1: 0.352036	val's huber: 0.0176259
# Did not meet early stopping. Best iteration is:
# [981]	train's l1: 0.0966236	train's huber: 0.00414884	val's l1: 0.346901	val's huber: 0.0173478
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.178584	train's huber: 0.00830655	val's l1: 0.218427	val's huber: 0.0104182
# [400]	train's l1: 0.138509	train's huber: 0.00623608	val's l1: 0.195517	val's huber: 0.00922516
# [600]	train's l1: 0.122485	train's huber: 0.0054164	val's l1: 0.191287	val's huber: 0.00900099
# [800]	train's l1: 0.111943	train's huber: 0.00487999	val's l1: 0.188875	val's huber: 0.00887253
# Did not meet early stopping. Best iteration is:
# [981]	train's l1: 0.104535	train's huber: 0.00450913	val's l1: 0.187835	val's huber: 0.00881728
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.18064	train's huber: 0.00842128	val's l1: 0.234802	val's huber: 0.0112932
# [400]	train's l1: 0.147254	train's huber: 0.00669302	val's l1: 0.205733	val's huber: 0.00976796
# [600]	train's l1: 0.132843	train's huber: 0.00594919	val's l1: 0.199347	val's huber: 0.00942638
# [800]	train's l1: 0.123263	train's huber: 0.00545708	val's l1: 0.19632	val's huber: 0.00926501
# Did not meet early stopping. Best iteration is:
# [981]	train's l1: 0.116463	train's huber: 0.00510958	val's l1: 0.194861	val's huber: 0.00918626
# Evaluated only: l1
#    [H4 Trial 18/20] pooled WAPE   27.9489% | tot nhat 27.9489% | da chay 27.4 phut, con khoang 3.0 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.183928	train's huber: 0.00830906	val's l1: 0.454338	val's huber: 0.022201
# [400]	train's l1: 0.134522	train's huber: 0.00584881	val's l1: 0.400446	val's huber: 0.019442
# [600]	train's l1: 0.116734	train's huber: 0.00497806	val's l1: 0.369098	val's huber: 0.0178231
# [800]	train's l1: 0.105875	train's huber: 0.00445097	val's l1: 0.350112	val's huber: 0.0168422
# [1000]	train's l1: 0.0973184	train's huber: 0.00403844	val's l1: 0.34386	val's huber: 0.0165174
# Did not meet early stopping. Best iteration is:
# [1099]	train's l1: 0.0940595	train's huber: 0.00388207	val's l1: 0.341955	val's huber: 0.016419
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.188402	train's huber: 0.00850711	val's l1: 0.226828	val's huber: 0.010463
# [400]	train's l1: 0.142789	train's huber: 0.00622827	val's l1: 0.19725	val's huber: 0.00897849
# [600]	train's l1: 0.125379	train's huber: 0.00537203	val's l1: 0.192808	val's huber: 0.00875195
# [800]	train's l1: 0.115272	train's huber: 0.00487473	val's l1: 0.190078	val's huber: 0.00861238
# [1000]	train's l1: 0.106518	train's huber: 0.0044518	val's l1: 0.188973	val's huber: 0.00855582
# Did not meet early stopping. Best iteration is:
# [1100]	train's l1: 0.102817	train's huber: 0.00427288	val's l1: 0.188591	val's huber: 0.00853664
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.18973	train's huber: 0.00857864	val's l1: 0.244211	val's huber: 0.011353
# [400]	train's l1: 0.15089	train's huber: 0.0066396	val's l1: 0.208341	val's huber: 0.00954332
# [600]	train's l1: 0.136063	train's huber: 0.00590208	val's l1: 0.200965	val's huber: 0.00916421
# [800]	train's l1: 0.126344	train's huber: 0.00542101	val's l1: 0.197783	val's huber: 0.00900147
# [1000]	train's l1: 0.118769	train's huber: 0.00504814	val's l1: 0.195926	val's huber: 0.00890638
# Did not meet early stopping. Best iteration is:
# [1100]	train's l1: 0.115628	train's huber: 0.00489445	val's l1: 0.194974	val's huber: 0.0088577
# Evaluated only: l1
#    [H4 Trial 19/20] pooled WAPE   27.9080% | tot nhat 27.9080% | da chay 29.0 phut, con khoang 1.5 phut
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.174513	train's huber: 0.00802036	val's l1: 0.444719	val's huber: 0.0222737
# [400]	train's l1: 0.131263	train's huber: 0.00582439	val's l1: 0.393639	val's huber: 0.0195855
# Did not meet early stopping. Best iteration is:
# [579]	train's l1: 0.11635	train's huber: 0.00507942	val's l1: 0.370305	val's huber: 0.0183488
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.17705	train's huber: 0.00811985	val's l1: 0.216951	val's huber: 0.0102031
# [400]	train's l1: 0.137874	train's huber: 0.00612516	val's l1: 0.195273	val's huber: 0.00909098
# Did not meet early stopping. Best iteration is:
# [579]	train's l1: 0.122965	train's huber: 0.00537409	val's l1: 0.19153	val's huber: 0.00889513
# Evaluated only: l1
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.179085	train's huber: 0.00823214	val's l1: 0.23307	val's huber: 0.0110512
# [400]	train's l1: 0.146438	train's huber: 0.00656676	val's l1: 0.2053	val's huber: 0.00961465
# Did not meet early stopping. Best iteration is:
# [579]	train's l1: 0.133476	train's huber: 0.00590822	val's l1: 0.199332	val's huber: 0.0093002
# Evaluated only: l1
#    [H4 Trial 20/20] pooled WAPE   28.4164% | tot nhat 27.9080% | da chay 30.0 phut, con khoang 0.0 phut
#
# Pooled WAPE tot nhat H4 tren 3 fold = 27.9080%
#     Loai [19, 24] (capacity_kw khong dang tin): 704,748 -> 671,165 dong
# Lọc v5_val_selected: 723,114 -> 671,165 dòng (49 cột)
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.177236	train's huber: 0.00793188	val's l1: 0.215856	val's huber: 0.00988726
# [400]	train's l1: 0.139301	train's huber: 0.00605497	val's l1: 0.183243	val's huber: 0.00826225
# [600]	train's l1: 0.125201	train's huber: 0.00535742	val's l1: 0.179112	val's huber: 0.00805533
# [800]	train's l1: 0.115878	train's huber: 0.00489989	val's l1: 0.177481	val's huber: 0.00797224
# [1000]	train's l1: 0.10894	train's huber: 0.00456121	val's l1: 0.176706	val's huber: 0.00793361
# Did not meet early stopping. Best iteration is:
# [1096]	train's l1: 0.10592	train's huber: 0.00441447	val's l1: 0.176524	val's huber: 0.0079245
# Evaluated only: l1
# Train H4 xong sau 0.7 phut | dung som tai 1096 cay
# Da du bao 273,376 dong (H4)

# %% [markdown]
# ## 12.1. Đường cong huấn luyện — chẩn đoán quá khớp
#
# Vẽ sai số trên tập **train** và tập **validation** theo từng vòng boosting, giống đường loss
# của mạng nơ-ron. Đây là bằng chứng trực quan cho câu hỏi *"mô hình có học vẹt không"*.
#
# **Cách đọc.** Train giảm đều mà validation đi ngang rồi ngóc lên nghĩa là bắt đầu quá khớp;
# điểm thấp nhất của đường validation chính là số cây nên dừng. Hai đường bám nhau và cùng đi
# xuống nghĩa là còn học được, chưa quá khớp.
#
# Tầng trái là $L_1$ trên mục tiêu chuẩn hoá $k$ — lấy trực tiếp từ `evals_result_` nên có đủ
# mọi vòng. Tầng phải là **WAPE thật trên thang kWh**, phạm vi `measured_daylight` tại $T+h$ —
# đây mới là chỉ số báo cáo công bố, nên nó mới là đường đáng tin để kết luận.
#
# Validation ở đây là `v5_val_selected`, **chưa từng tham gia huấn luyện**.

# %%
# === DUONG CONG HUAN LUYEN ===
# Fit rieng mot ban co eval_set de lay evals_result_ (ban `model` o cell tren fit khong
# co eval_set nen khong co duong cong). Ban nay CHI dung de ve, khong thay the model.
import matplotlib.pyplot as plt

BUOC_DO_DUONG_CONG = 50          # do WAPE that moi bao nhieu cay
SO_CAY_DUONG_CONG = int(BEST_PARAMS.get('n_estimators', 685))

_p_dc = {k: v for k, v in BEST_PARAMS.items()
         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')}
_p_dc['n_estimators'] = SO_CAY_DUONG_CONG

_Xva_dc = val_h[FEATURES].fillna(MEDIANS).astype(DTYPE)
_yva_dc = val_h['k_target'].astype(DTYPE)

_lich_su = {}
_m_dc = lgb.LGBMRegressor(**_p_dc)
_m_dc.fit(X_dev, y_dev, sample_weight=w_dev,
          categorical_feature=cot_categorical(X_dev),
          eval_set=[(X_dev, y_dev), (_Xva_dc, _yva_dc)],
          eval_names=['train', 'val'], eval_metric='l1',
          callbacks=[lgb.record_evaluation(_lich_su),
                     early_stopping(EARLY_STOPPING_ROUNDS, first_metric_only=True, verbose=True),
                     lgb.log_evaluation(period=200)])
SO_CAY_DUONG_CONG = int(_m_dc.best_iteration_)
# WAPE chi tinh mot moc de tom tat; do thi dung loss theo tung vong de thay early stopping.
BUOC_DO_DUONG_CONG = SO_CAY_DUONG_CONG


def _wape_tai(khung, X, mask, so_cay):
    """WAPE that (kWh) khi chi dung `so_cay` cay dau tien."""
    _k = cat_k(_m_dc.predict(X, num_iteration=so_cay))
    _se = khung['sin_elevation'].to_numpy()
    _yp = np.minimum(_k * mau_chuan_hoa(khung),
                     khung['tran_cong_suat'].to_numpy() * 1.02)
    _yp = np.where(_se <= EPS_ELEV, 0.0, _yp)
    _yt = khung['y_true'].to_numpy()
    return float(np.nansum(np.abs(_yt[mask] - _yp[mask]))
                 / np.nansum(np.abs(_yt[mask])) * 100)


# Mask pham vi cong bo: xet NHAN tai T+h, khong phai cot tai T
def _mask_cong_bo(khung):
    _n = _cot_loc(khung, 'energy_source')
    _d = _cot_loc(khung, 'is_daylight')
    _m = (_n == 'measured').to_numpy() if _n is not None else np.ones(len(khung), bool)
    if _d is not None:
        _m = _m & _d.fillna(False).astype(bool).to_numpy()
    return _m


_dev_dc = dev_h.loc[X_dev.index]
_m_tr = _mask_cong_bo(_dev_dc)
_m_va = _mask_cong_bo(val_h)

_moc = list(range(BUOC_DO_DUONG_CONG, SO_CAY_DUONG_CONG + 1, BUOC_DO_DUONG_CONG))
_w_tr = [_wape_tai(_dev_dc, X_dev, _m_tr, i) for i in _moc]
_w_va = [_wape_tai(val_h, _Xva_dc, _m_va, i) for i in _moc]
_i_tot = int(np.argmin(_w_va))
_w_min = _w_va[_i_tot]

# VUNG BINH NGUYEN: moi moc co WAPE val nam trong nguong tuong doi so voi diem thap nhat.
# Them cay ngoai vung nay khong cai thien co y nghia, chi lam mo hinh nang va de qua khop.
DUNG_NGUONG = 0.001                      # 0,1% tuong doi
_trong_vung = [j for j, w in enumerate(_w_va) if w <= _w_min * (1 + DUNG_NGUONG)]
_j_dau, _j_cuoi = _trong_vung[0], _trong_vung[-1]
SO_CAY_KHUYEN_NGHI = _moc[_j_dau]        # nho nhat ma van dat -> re nhat, it qua khop nhat

print(f"WAPE val thap nhat  : {_w_min:.4f}% tai {_moc[_i_tot]} cay "
      f"(train cung moc {_w_tr[_i_tot]:.4f}%)")
print(f"Vung binh nguyen    : {_moc[_j_dau]} - {_moc[_j_cuoi]} cay "
      f"(WAPE val trong {DUNG_NGUONG*100:.1f}% so voi diem thap nhat)")
print(f"So cay khuyen nghi  : {SO_CAY_KHUYEN_NGHI}")
print(f"Dang dung           : {SO_CAY_DUONG_CONG} cay -> "
      f"{'DU, nen giam' if SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG * 0.9 else 'hop ly'}")
print(f"Khoang cach train-val tai diem thap nhat: "
      f"{_w_va[_i_tot] - _w_tr[_i_tot]:+.4f} diem")

_fig, _ax = plt.subplots(1, 2, figsize=(15, 5.2))
_l_tr, _l_va = _lich_su['train']['l1'], _lich_su['val']['l1']
_x = np.arange(1, len(_l_tr) + 1)
_ax[0].plot(_x, _l_tr, lw=1.4, label='train')
_ax[0].plot(_x, _l_va, lw=1.4, label='validation')
_ax[0].set_xlabel('Số vòng boosting')
_ax[0].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[0].set_title(f'Đường cong huấn luyện — {LOSS_NAME.upper()}, H{HORIZON_STEPS}')
_ax[0].axvline(_m_dc.best_iteration_, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_m_dc.best_iteration_} cay')
_ax[0].legend(); _ax[0].grid(alpha=.3)

_best, _end = int(_m_dc.best_iteration_), len(_l_va)
_start = max(1, _best - 20)
_x_zoom = np.arange(_start, _end + 1)
_ax[1].plot(_x_zoom, _l_tr[_start - 1:_end], lw=1.5, label='train')
_ax[1].plot(_x_zoom, _l_va[_start - 1:_end], lw=1.7, label='validation')
_span_label = (f'{_end - _best} vòng xác nhận không cải thiện'
               if _end >= _best + EARLY_STOPPING_ROUNDS
               else f'chạm trần {SO_CAY_DUONG_CONG} cây')
_ax[1].axvspan(_best, _end, color='crimson', alpha=.12, label=_span_label)
_ax[1].axvline(_best, ls='--', c='crimson', lw=1.3,
               label=f'best iteration: {_best} cây')
_ax[1].set_xlabel('Số vòng boosting')
_ax[1].set_ylabel('$L_1$ trên mục tiêu chuẩn hoá $k$')
_ax[1].set_title('Vùng early stopping trên validation')
_ax[1].legend(); _ax[1].grid(alpha=.3)
_fig.suptitle('Chẩn đoán quá khớp — validation là v5_val_selected, chưa từng được học',
              y=1.0, fontsize=10)
plt.tight_layout(); plt.show()

# ── Train lai mo hinh cuoi o so cay khuyen nghi ──
# Dat False neu muon giu nguyen so cay cua Optuna.
DUNG_SO_CAY_KHUYEN_NGHI = False  # early stopping da chon best_iteration_ tu validation

if DUNG_SO_CAY_KHUYEN_NGHI and SO_CAY_KHUYEN_NGHI < SO_CAY_DUONG_CONG:
    print(f"\nTrain lai mo hinh cuoi voi {SO_CAY_KHUYEN_NGHI} cay "
          f"(thay vi {SO_CAY_DUONG_CONG})...")
    BEST_PARAMS = {**BEST_PARAMS, 'n_estimators': SO_CAY_KHUYEN_NGHI}
    model = fit_an_toan(BEST_PARAMS, X_dev, y_dev, w_dev)

    # Du bao lai tren val de moi bang metric phia sau dung mo hinh moi
    _k2 = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
    val_h['y_pred'] = np.minimum(_k2 * mau_chuan_hoa(val_h),
                                 val_h['tran_cong_suat'].to_numpy() * 1.02)
    val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
    _m2 = metrics_3_pham_vi(val_h)['measured_daylight']
    print(f"WAPE val sau khi giam so cay: {_m2['wape']:.4f}%  (n={_m2['n']:,})")
    print("BEST_PARAMS da cap nhat -> cac cell export phia sau se ghi so cay moi.")
else:
    print(f"\nGiu nguyen {SO_CAY_DUONG_CONG} cay.")

pd.DataFrame({'so_cay': _moc, 'wape_train': _w_tr, 'wape_val': _w_va,
              'trong_vung_dung_som': [j in _trong_vung for j in range(len(_moc))]}).head(12)
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	train's l1: 0.177236	train's huber: 0.00793188	val's l1: 0.215856	val's huber: 0.00988726
# [400]	train's l1: 0.139301	train's huber: 0.00605497	val's l1: 0.183243	val's huber: 0.00826225
# [600]	train's l1: 0.125201	train's huber: 0.00535742	val's l1: 0.179112	val's huber: 0.00805533
# [800]	train's l1: 0.115878	train's huber: 0.00489989	val's l1: 0.177481	val's huber: 0.00797224
# [1000]	train's l1: 0.10894	train's huber: 0.00456121	val's l1: 0.176706	val's huber: 0.00793361
# Did not meet early stopping. Best iteration is:
# [1096]	train's l1: 0.10592	train's huber: 0.00441447	val's l1: 0.176524	val's huber: 0.0079245
# Evaluated only: l1
# WAPE val thap nhat  : 26.6597% tai 1096 cay (train cung moc 16.1776%)
# Vung binh nguyen    : 1096 - 1096 cay (WAPE val trong 0.1% so voi diem thap nhat)
# So cay khuyen nghi  : 1096
# Dang dung           : 1096 cay -> hop ly
# Khoang cach train-val tai diem thap nhat: +10.4821 diem
# Giu nguyen 1096 cay.
#    so_cay  wape_train  wape_val  trong_vung_dung_som
# 0    1096   16.177629  26.65973                 True

# %%
# ── Kiem chung tre pha + metric cho H4 (dung lai quet_do_tre/metrics_3_pham_vi) ──
_quet = quet_do_tre(val_h)
_k_tot = min(_quet, key=_quet.get)
print("--- QUET DO TRE H4 - TOAN BO 42 TRAM (SAU KHI LOAI SITE 19/24) ---")
for k, v in _quet.items():
    danh_dau = '  <== nho nhat' if k == _k_tot else ''
    print(f"   k={k} ({k * 15:>2} phut truoc): RMSE {v:.4f}{danh_dau}")
print(f"\nKet luan H4: {'KHONG TRE PHA' if _k_tot == 0 else f'TRE {_k_tot} BUOC = {_k_tot * 15} PHUT'}")

_rows = []
for _s, _z in val_h[val_h['is_daylight'].fillna(False).astype(bool)].groupby(SITE_COL):
    _z = _z.sort_values(TIMESTAMP_COL)
    _r = {}
    for k in range(0, 3):
        _yt = _z['y_true'].shift(k)
        _m = _yt.notna()
        _r[k] = float(np.sqrt(np.mean((_z['y_pred'][_m] - _yt[_m]) ** 2)))
    _rows.append({'site_id': _s, 'k_tot_nhat': min(_r, key=_r.get)})
df_tre = pd.DataFrame(_rows)
print(f"So tram khong tre (k=0): {(df_tre['k_tot_nhat'] == 0).sum()}/{len(df_tre)}")

_m = metrics_3_pham_vi(val_h)
_bang = pd.DataFrame(_m).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4)
print("\n--- METRIC H4 TREN TAP VALIDATION (measured_daylight la con so chinh thuc) ---")
display(_bang)
# Out:
# --- QUET DO TRE H4 - TOAN BO 42 TRAM (SAU KHI LOAI SITE 19/24) ---
#    k=0 ( 0 phut truoc): RMSE 4.2783
#    k=1 (15 phut truoc): RMSE 4.2409  <== nho nhat
#    k=2 (30 phut truoc): RMSE 4.4155
#    k=3 (45 phut truoc): RMSE 4.7582
#
# Ket luan H4: TRE 1 BUOC = 15 PHUT
# So tram khong tre (k=0): 7/40
#
# --- METRIC H4 TREN TAP VALIDATION (measured_daylight la con so chinh thuc) ---
#                           n     wape    rmse     mae     r2
# all                273376.0  26.6597  4.2558  1.9073  0.869
# measured           273376.0  26.6597  4.2558  1.9073  0.869
# measured_daylight  273376.0  26.6597  4.2558  1.9073  0.869

# %%
# ── Export H4 - dung dung cau truc file nhu H1 (ten file tu dong doi theo HORIZON_STEPS) ──

with open(f'{OUTPUT_DIR}/model_h{HORIZON_STEPS}.pkl', 'wb') as f:
    pickle.dump({'model': model, 'features': FEATURES, 'medians': MEDIANS.to_dict(),
                 'eps_elev': EPS_ELEV, 'clip_k': lay_clip(), 'horizon_steps': HORIZON_STEPS,
                 'loss': LOSS_NAME, 'chuan_hoa': True,
                 'che_do_trong_so': CHE_DO_TRONG_SO, 'experiment': EXPERIMENT,
                 'mau_so': MAU_SO, 'clip_phan_vi': CLIP_PHAN_VI}, f)

df_tre.to_csv(f'{OUTPUT_DIR}/tre_pha_theo_tram.csv', index=False)
_bang.to_csv(f'{OUTPUT_DIR}/metrics.csv')
with open(f'{OUTPUT_DIR}/ket_qua.json', 'w', encoding='utf-8') as f:
    json.dump({'loss': LOSS_NAME, 'horizon_steps': HORIZON_STEPS,
               # Cau hinh dinh doat nhan + trong so - phai luu de tai lap va doi chung
               # giua cac lan chay (truoc day thieu, khong biet model nao chay che do nao).
               'che_do_trong_so': CHE_DO_TRONG_SO, 'experiment': EXPERIMENT,
               'mau_so': MAU_SO, 'clip_phan_vi': CLIP_PHAN_VI,
               'clip_k': lay_clip(), 'eps_elev': EPS_ELEV,
               'so_dac_trung': len(FEATURES), 'features': FEATURES,
               'best_params': BEST_PARAMS,
               'tham_so_thuc_te': {k: v for k, v in model.get_params().items()
                                   if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
               'quet_do_tre': {str(k): v for k, v in _quet.items()},
               'k_tot_nhat': int(_k_tot),
               'so_tram_khong_tre': int((df_tre['k_tot_nhat'] == 0).sum()),
               'metrics': _m}, f, indent=2, ensure_ascii=False, default=str)

TRAIN_COMPAT_DIR = f'../../data/model/v5/06_train/{LOSS_NAME}/h{HORIZON_STEPS}'
os.makedirs(TRAIN_COMPAT_DIR, exist_ok=True)
with open(f'{TRAIN_COMPAT_DIR}/model.pkl', 'wb') as f:
    pickle.dump(model, f)
with open(f'{TRAIN_COMPAT_DIR}/model_config.json', 'w', encoding='utf-8') as f:
    json.dump({
        'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME, 'feature_set_name': '',
        'lgb_objective': LGB_OBJECTIVE, 'features': FEATURES,
        'feature_medians': {k: float(v) for k, v in MEDIANS.items()},
        'train_rows': int(len(X_dev)), 'chuan_hoa': True,
        'cot_quy_mo': 'site_scale', 'cot_sin_elev': 'sin_elevation', 'cot_tran': 'tran_cong_suat',
        'eps_elev': float(EPS_ELEV),
                    'clip_k': float(lay_clip()),
                    'mau_so': MAU_SO,
        # Doc tham so THAT tu mo hinh da fit, khong lay lai BEST_PARAMS: BEST_PARAMS chi la
        # thu duoc YEU CAU, con get_params() la thu LightGBM THUC SU dung - gom ca cac khoa
        # Optuna khong dong toi (reg_alpha, reg_lambda...) voi dung gia tri mac dinh da ap.
        'model_params': {k: v for k, v in model.get_params().items()
                         if k not in ('device', 'gpu_platform_id', 'gpu_device_id')},
    }, f, indent=2, ensure_ascii=False)


# FIX (chong ro ri): metrics_val.json de notebook 07 quet va chon mo hinh vo dich BAT BUOC
# phai tinh tren tap VALIDATION that, khong duoc dung _m (dang tinh tren val_h). Truoc day
# file nay bi ghi nham tu _m (tap test) khien viec chon MAE/Huber/MSE "thay truoc" tap test.
# Tap VAL that - tach biet hoan toan voi tap hoc (mo hinh chi hoc v5_train_selected).
val_h = doc_val_that()
_k_pred_val = cat_k(model.predict(val_h[FEATURES].fillna(MEDIANS).astype(np.float32)))
val_h['y_pred'] = np.minimum(_k_pred_val * mau_chuan_hoa(val_h), val_h['tran_cong_suat'].to_numpy() * 1.02)
val_h.loc[val_h['sin_elevation'] <= EPS_ELEV, 'y_pred'] = 0.0
_m_val = metrics_3_pham_vi(val_h)
print(f"--- METRIC TREN TAP VALIDATION THAT ({len(val_h):,} dong, dung de chon mo hinh) ---")
display(pd.DataFrame(_m_val).T[['n', 'wape', 'rmse', 'mae', 'r2']].round(4))

_val_scope_h4 = _m_val.get('measured_daylight', _m_val.get('measured', _m_val['all']))
with open(f'{TRAIN_COMPAT_DIR}/metrics_val.json', 'w', encoding='utf-8') as f:
    json.dump({'horizon_steps': int(HORIZON_STEPS), 'loss_name': LOSS_NAME,
               'feature_set_name': '', 'measured_daylight': _val_scope_h4,
               'all': _m_val['all']}, f, indent=2, ensure_ascii=False, default=str)


# X_test_h4.parquet - dong bo voi 06_1, tranh loi so cot khong khop khi 07 doc
_cot_xuat_h4 = list(dict.fromkeys(
    FEATURES + [SITE_COL, TIMESTAMP_COL, 'plot_timestamp', TARGET_COL, 'y_true',
                'energy_source', 'is_daylight', 'site_scale', 'sin_elevation', 'tran']
))
_cot_xuat_h4 = [c for c in _cot_xuat_h4 if c in val_h.columns]

print("--- HOAN TAT H4 ---")
print(f"Thu muc ket qua: {OUTPUT_DIR}")
for _f in sorted(os.listdir(OUTPUT_DIR)):
    print(f"   {_f}")
# Out:
#     Loai [19, 24] (capacity_kw khong dang tin): 704,748 -> 671,165 dong
# Lọc v5_val_selected: 723,114 -> 671,165 dòng (49 cột)
# --- METRIC TREN TAP VALIDATION THAT (273,376 dong, dung de chon mo hinh) ---
#                           n     wape    rmse     mae     r2
# all                273376.0  26.6597  4.2558  1.9073  0.869
# measured           273376.0  26.6597  4.2558  1.9073  0.869
# measured_daylight  273376.0  26.6597  4.2558  1.9073  0.869
# --- HOAN TAT H4 ---
# Thu muc ket qua: ../../data/model/v5/06_2_train_huber_h4
#    du_bao_val.parquet
#    ket_qua.json
#    metrics.csv
#    model_h4.pkl
#    tre_pha_theo_tram.csv
