# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet(r'D:\Learning\FPT_polytechnic\Sem6\datn_outlier_hs_nlmt\data\mlmart_base\v2_preprocessing.parquet')
df.head(10)
# Out:
#    gen_id  site_id  geo_id   date_id  time_id           timestamp  \
# 0       1        1       1  20200101       15 2020-01-01 00:15:00
# 1      11        1       1  20200101       30 2020-01-01 00:30:00
# 2      21        1       1  20200101       45 2020-01-01 00:45:00
# 3      31        1       1  20200101      100 2020-01-01 01:00:00
# 4      41        1       1  20200101      115 2020-01-01 01:15:00
# 5      51        1       1  20200101      130 2020-01-01 01:30:00
# 6      61        1       1  20200101      145 2020-01-01 01:45:00
# 7      71        1       1  20200101      200 2020-01-01 02:00:00
# 8      81        1       1  20200101      215 2020-01-01 02:15:00
# 9      91        1       1  20200101      230 2020-01-01 02:30:00
#
#    is_dst_repeat  full_date  year  month  ...  cloud_cover_low  \
# 0              0 2020-01-01  2020      1  ...              NaN
# 1              0 2020-01-01  2020      1  ...              NaN
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2731946 entries, 0 to 2731945
# Data columns (total 47 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   gen_id                    Int64
#  1   site_id                   Int64
#  2   geo_id                    Int64
#  3   date_id                   Int64
#  4   time_id                   Int64
#  5   timestamp                 datetime64[us]
#  6   is_dst_repeat             Int64
#  7   full_date                 datetime64[ms]
#  8   year                      Int64
#  9   month                     Int64
#  10  day                       Int64
#  11  day_of_week               Int64
#  12  hour                      Int64
#  13  minute                    Int64
#  14  energy_generated_kwh      float64
#  15  gmm_if_outlier_flag       boolean
#  16  gmm_if_outlier_reason     str
#  17  campus_name               string
#  18  capacity_kw               float64
#  19  number_of_panels          float64
# ...

# %%
drop_null_capa = df['capacity_kw'].dropna()
drop_null_capa.describe()
# Out:
# count    1.599868e+06
# mean     9.532623e+01
# std      1.233715e+02
# min      2.139000e+01
# 25%      3.927000e+01
# 50%      5.115000e+01
# 75%      7.722000e+01
# max      5.398000e+02
# Name: capacity_kw, dtype: float64
